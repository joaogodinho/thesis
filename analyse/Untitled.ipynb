# %%
import pandas as pd
import numpy as np
import math
import re
import matplotlib.pyplot as plt

data_folder = '../data/csv_data/'
extension = '.csv.gz'
build_path = lambda x: data_folder + x + extension

# %%
dataset = pd.read_csv(build_path('real_dataset')).set_index('link')

# %%
len(dataset)
# Out:
# 155057

# %%
dataset.dropna(how='all').describe()
# Out:
#               other       ransom      spyware        trojan        virus  \
# count  14750.000000  1160.000000  5955.000000  24176.000000  6899.000000
# mean       0.212415     0.130441     0.136925      0.658086     0.258316
# std        0.191041     0.099569     0.154121      0.273148     0.326101
# min        0.017241     0.019608     0.020000      0.034483     0.017544
# 25%        0.055556     0.050000     0.041667      0.440000     0.040000
# 50%        0.136364     0.090909     0.062500      0.727273     0.060606
# 75%        0.321429     0.193548     0.137931      0.900000     0.526316
# max        0.863636     0.515152     0.634146      1.000000     1.000000
#
#               worm
# count  9381.000000
# mean      0.305530
# std       0.274610
# min       0.017544
# 25%       0.062500
# 50%       0.192308
# 75%       0.538462
# max       0.960000

# %%
dataset.dropna(how='all')
# Out:
#                                                 other    ransom   spyware  \
# link
# ZTZhNjE4OTIzNzU2NGVkZWI4MzE3ZTVmYTkyNWEzYWY  0.055556       NaN  0.055556
# ZTQwYTQ4M2U3MDM0NGI1YmFhNjgzMTcwYTcwM2Y2NDU  0.208333       NaN       NaN
# ZjYwNDRhOWJhZjM3NGU4ODllODVjZmNhZDdlZTU4ZTE       NaN       NaN  0.041667
# NzQ1MTRiYzNmM2MyNGZjZmI5ZWZiZjhjZjlkZjM1OTE       NaN       NaN       NaN
# NzdkMTAwZjJmNGE4NDExNTlkMTFkYjA0MTBmZTIwOTU       NaN       NaN  0.040000
# YzA1NzIxMzQ2OTlhNGYwNjlmMDc1Yjg0MWEyOTc2NGI       NaN       NaN       NaN
# ZTA1ZTlkYjY1NzU1NGIxZjg0ODJhOWRmMmFlNTczMDU       NaN  0.043478       NaN
# M2E3ZWVjZmE4ZGI1NGRjYjlkMmYxODNiMGQzZGIwZTU       NaN       NaN       NaN
# MzdjM2M2Yzc0ZGU5NDNjNWEwMmNkMDUzMTQyZjFmZGE       NaN       NaN       NaN
# NmI0MWFhZmQyNGM5NDRlNmJjYTViYTZhNjEzMTE4MmM  0.031250  0.125000       NaN
# NDI0ZTM2ODQ0MzZmNGYxYTg0NzgxMWFmYWRlMWJhNWI  0.107143       NaN  0.107143
# ZDUwYjIxOTMwZGYxNDk3MGFhYjZlYzA1ODM0NjcxZGQ  0.166667       NaN       NaN
# ...
