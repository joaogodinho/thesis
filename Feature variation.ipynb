# %% [markdown]
# # Feature Variation
#
# The purpose of this notebook is to see how the features (imports in this case) vary through time.
#
# The first thing is to check in small dataset how the features vary and then do the same for all the imports. If in both cases the features vary in the same way, the LR made for the small dataset can behave similarly when used on the bigger dataset.

# %%
import lib.data_loading as jcfg_data_loading
import pandas as pd
from IPython.display import display
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
import matplotlib.pyplot as plt
import numpy as np

dataset_name = "dataset"
numb_datasets = 6

datasets = []

# Load all samples with an array, where each ith position are samples
# up to the ith+1 submission of the target sample
for i in range(numb_datasets):
    datasets.append(pd.read_csv(dataset_name + str(i) + '.csv'))
    datasets[i] = datasets[i].set_index('md5')
    datasets[i].dropna(inplace=True, subset=['imports'])
    print('Final {0}th dataset size: {1}'.format(i, len(datasets[i])))
# Out:
# Final 0th dataset size: 2798
# Final 1th dataset size: 31
# Final 2th dataset size: 22
# Final 3th dataset size: 121
# Final 4th dataset size: 286
# Final 5th dataset size: 465

# %%
# Parameters for the bag of words
# Split by the semicolon
count_vec_pattern = u'[^;]+'
# A call must be present at least in x samples
min_df = 2
max_df = 1.0

train_test = [datasets[0], pd.concat(datasets[1:])]

# Create the bag of words baseline
cv = CountVectorizer(token_pattern=count_vec_pattern, max_df=max_df, min_df=min_df)
cv.fit(train_test[0].imports)
cv2 = CountVectorizer(token_pattern=count_vec_pattern, max_df=max_df, min_df=min_df)
cv2.fit(train_test[1].imports)

train_features = list(cv.vocabulary_.keys())
test_features = list(cv2.vocabulary_.keys())
common_features = [i for i in train_features if i in test_features]

print('Number of train imports: {0}'.format(len(train_features)))
print('Number of test imports: {0}'.format(len(test_features)))
print('Common imports: {0} ({1:.3} of train)'.format(len(common_features), len(common_features)/len(train_features)))
# Out:
# Number of train imports: 10519
# Number of test imports: 3976
# Common imports: 3191 (0.303 of train)

# %%
all_imports = pd.read_csv('data/imports.csv')
all_imports['date'] = pd.to_datetime(all_imports['date'], format='%Y/%m/%d')
# Set date as index
all_imports = all_imports.set_index('date')
# Drop useless columns
all_imports.drop(labels=['md5', 'link', 'malware'], axis=1, inplace=True)
all_imports.dropna(inplace=True)

# %%
all_imports.imports.resample('M').apply(lambda x: print(x))
# Out:
# 2013-04-16           getprocaddress;loadlibrary;getmodulehandle
# 2013-04-16    setenvironmentvariable;_unlink;copyfile;strnca...
# 2013-04-16                                          _corexemain
# 2013-04-16    setenvironmentvariable;isdbcsleadbyte;movefile...
# 2013-04-16                                                sleep
# 2013-04-16    getprocessheap;getprocaddress;createthread;hea...
# 2013-04-16    isprocessorfeaturepresent;setenvironmentvariab...
# 2013-04-16    exitprocess;dragacceptfiles;createfile;seteven...
# 2013-04-16    vfprintf;wcslen;calloc;exitprocess;tlsgetvalue...
# 2013-04-16                                          _corexemain
# 2013-04-17    sendmessagetimeout;getwindowsdirectory;getcapt...
# 2013-04-17    getwindowsdirectory;virtualfree;createdirector...
# 2013-04-17    isprocessorfeaturepresent;sendmessagetimeout;r...
# 2013-04-17    _initterm;_acmdln;__p__commode;??2@yapaxi@z;cr...
# 2013-04-17    _initterm;isdbcsleadbyte;modf;_memicmp;getproc...
# 2013-04-17    isprocessorfeaturepresent;movefile;getwindowsd...
# 2013-04-17    lstrcpyn;loadlibrary;lstrcat;sysfreestring;get...
# 2013-04-17    sendmessagetimeout;movefile;getwindowsdirector...
# 2013-04-17    movefile;getwindowsdirectory;isbadreadptr;gett...
# 2013-04-17    senddlgitemmessage;exitprocess;getclassinfoex;...
# 2013-04-17                                          exitprocess
# 2013-04-17    swprintf;expandenvironmentstrings;_initterm;ge...
# 2013-04-17    __initenv;_initterm;gettickcount;__p__commode;...
# 2013-04-17    setenvironmentvariable;isbadreadptr;virtualfre...
# 2013-04-18    movefile;getwindowsdirectory;setenvironmentvar...
# 2013-04-18    wcstok;_initterm;sprintf;_strnicmp;__p__commod...
# 2013-04-18    swprintf;expandenvironmentstrings;_initterm;ge...
# 2013-04-18    loadlibrary;virtualprotect;dragfinish;escape;c...
# 2013-04-18    getconsolemode;gettickcount;virtualfree;resume...
# 2013-04-18    movefile;gettickcount;getprocessheap;getprocad...
#                                     ...
# 2013-04-28    loadlibrary;shgetspecialfolderpath;sysfreestri...
# 2013-04-28    loadlibrary;virtualprotect;virtualfree;exitpro...
# 2013-04-28    loadlibrary;virtualprotect;virtualfree;exitpro...
# 2013-04-28    gettextalign;movefile;impersonatenamedpipeclie...
# 2013-04-28    setenvironmentvariable;createremotethread;gett...
# 2013-04-28                                          _corexemain
# 2013-04-28    setenvironmentvariable;movefile;releasedc;coin...
# 2013-04-29                          exitprocess;getmodulehandle
# 2013-04-29                                          _corexemain
# 2013-04-29    sendmessagetimeout;movefile;getwindowsdirector...
# 2013-04-29    getcapture;setviewportorgex;createdialogindire...
# 2013-04-29    gettickcount;getconsolemode;virtualfree;regope...
# 2013-04-29    loadlibrary;virtualprotect;virtualfree;exitpro...
# 2013-04-29    _cexit;getprocaddress;setbkmode;showwindow;cre...
# 2013-04-29    loadlibrary;virtualprotect;virtualfree;exitpro...
# 2013-04-29    getwindowsdirectory;getcapture;setviewportorge...
# 2013-04-29    sendmessagetimeout;movefile;getwindowsdirector...
# 2013-04-29    setenvironmentvariable;isdbcsleadbyte;movefile...
# 2013-04-29                                          _corexemain
# 2013-04-30    openprocesstoken;movefile;isdbcsleadbyte;virtu...
# 2013-04-30    sendmessagetimeout;movefile;getwindowsdirector...
# 2013-04-30    releasedc;getwindowsdirectory;settextalign;set...
# 2013-04-30    coinitialize;gettickcount;getconsolemode;virtu...
# 2013-04-30    loadlibrary;time;exitprocess;shchangenotify;me...
# 2013-04-30    _initterm;hwnd_usermarshal;getprocaddress;hbit...
# 2013-04-30    sendmessagetimeout;movefile;getwindowsdirector...
# 2013-04-30    virtualfree;exitprocess;getversion;getprocaddr...
# 2013-04-30    loadlibrary;virtualprotect;virtualfree;exitpro...
# 2013-04-30    getwindowsdirectory;releasedc;getthreaddesktop...
# 2013-04-30    enddoc;virtualfree;showwindow;oleduplicatedata...
# Name: imports, dtype: object
# 2013-05-01                                          _corexemain
# 2013-05-01    coinitialize;memcpy;exitprocess;closehandle;ge...
# 2013-05-01    gettickcount;exitprocess;virtualfree;isvalidco...
# 2013-05-01    deleteurlcacheentry;exitprocess;virtualfree;fi...
# 2013-05-01    sendmessagetimeout;movefile;getwindowsdirector...
# 2013-05-01    openprocesstoken;isdbcsleadbyte;getwindowsdire...
# 2013-05-01    gettickcount;createdirectory;_cexit;getprocadd...
# 2013-05-01    sendmessagetimeout;movefile;getwindowsdirector...
# 2013-05-01    coinitialize;createsemaphore;registerclass;get...
# 2013-05-01    gettickcount;exitprocess;virtualfree;getversio...
# 2013-05-01    sleep;registerdevicenotification;internetopen;...
# 2013-05-01    isbadreadptr;gettickcount;createdirectory;getp...
# 2013-05-01    openprocesstoken;isdbcsleadbyte;getwindowsdire...
# 2013-05-01    expandenvironmentstrings;pathissystemfolder;ge...
# 2013-05-01    isprocessorfeaturepresent;setenvironmentvariab...
# 2013-05-01    getwindowsdirectory;imagelist_seticonsize;getc...
# 2013-05-02                                          _corexemain
# 2013-05-02    loadlibrary;virtualprotect;urldownloadtofile;v...
# 2013-05-02    loadlibrary;dodragdrop;virtualprotect;getdc;im...
# 2013-05-02    changeserviceconfig;exitprocess;virtualfree;ge...
# 2013-05-02    _initterm;wctomb;memcpy;gettickcount;calloc;__...
# 2013-05-02    getwindowsdirectory;imagelist_seticonsize;getc...
# 2013-05-02    isbadcodeptr;isbadreadptr;gettickcount;exitpro...
# 2013-05-02    loadlibrary;virtualprotect;virtualfree;exitpro...
# 2013-05-02    movefile;isdbcsleadbyte;coinitialize;pathremov...
# 2013-05-02    getwindowsdirectory;gettickcount;exitprocess;v...
# 2013-05-02    loadlibrary;_cicos;virtualfree;exitprocess;get...
# 2013-05-02    loadlibrary;strstri;exitprocess;shellexecute;g...
# 2013-05-02    openprocesstoken;getwindowsdirectory;openfile;...
# 2013-05-02    _initterm;gettickcount;__p__commode;_cexit;int...
#                                     ...
# 2013-05-30    coinitialize;loadlibrary;verqueryvalue;virtual...
# 2013-05-30                                          _corexemain
# 2013-05-30    setenvironmentvariable;movefile;getwindowsdire...
# 2013-05-30    enddoc;settextalign;isdbcsleadbyte;getwindowsd...
# 2013-05-30    setenvironmentvariable;getwindowsdirectory;mov...
# 2013-05-30    loadlibrary;virtualprotect;cofiletimenow;virtu...
# 2013-05-30    loadlibrary;getdc;regenumkey;exitprocess;shell...
# 2013-05-30    enddoc;settextalign;isdbcsleadbyte;getwindowsd...
# 2013-05-30    getwindowsdirectory;imagelist_seticonsize;getc...
# 2013-05-30    getwindowsdirectory;gettickcount;virtualfree;c...
# 2013-05-30    getwindowsdirectory;getprivateprofileint;getti...
# 2013-05-30    _cicos;_adj_fdiv_m16i;__vbavarcat;__vbanew2;_a...
# 2013-05-30    cryptdecrypt;translateaccelerator;closehandle;...
# 2013-05-30    _zn5qfilec1erk7qstring;_zn9qlineedit14mousemov...
# 2013-05-30    coinitialize;virtualfree;createfile;getprocess...
# 2013-05-30    loadlibrary;getprocessheap;getprocaddress;heap...
# 2013-05-30    enddoc;settextalign;isdbcsleadbyte;getwindowsd...
# 2013-05-31    imagelist_seticonsize;setviewportorgex;getcapt...
# 2013-05-31    gettickcount;getconsolemode;exitprocess;virtua...
# 2013-05-31    getwindowsdirectory;settextalign;senddlgitemme...
# 2013-05-31    coinitialize;gettickcount;createdirectory;getp...
# 2013-05-31    imagelist_seticonsize;setviewportorgex;getcapt...
# 2013-05-31    loadlibrary;getdc;exitprocess;imagelist_add;ge...
# 2013-05-31    acmstreamsize;urldownloadtofile;virtualfree;ex...
# 2013-05-31    movefile;setenvironmentvariable;getcapture;vir...
# 2013-05-31                initcommoncontrols;lstrcpy;createfile
# 2013-05-31    acmstreamsize;urldownloadtofile;virtualfree;ex...
# 2013-05-31    acmstreamsize;urldownloadtofile;virtualfree;ex...
# 2013-05-31    getwindowsdirectory;releasedc;senddlgitemmessa...
# 2013-05-31    __initenv;movefile;getwindowsdirectory;setenvi...
# Name: imports, dtype: object
# 2013-06-01                                          _corexemain
# 2013-06-01    setenvironmentvariable;setendoffile;isbadreadp...
# 2013-06-01    releasedc;gettickcount;virtualfree;getprocessh...
# 2013-06-01                                          _corexemain
# 2013-06-01    createmdiwindow;ftpgetfile;createcaret;created...
# 2013-06-01    getwindowsdirectory;imagelist_seticonsize;setv...
# 2013-06-01    sendmessagetimeout;movefile;getwindowsdirector...
# 2013-06-01    exitprocess;virtualfree;getversion;tlssetvalue...
# 2013-06-01    releasedc;getcapture;setviewportorgex;gettickc...
# 2013-06-01    setenvironmentvariable;enddoc;getconsolemode;g...
# 2013-06-01                                          _corexemain
# 2013-06-01    isprocessorfeaturepresent;gettickcount;getcons...
# 2013-06-02    sendmessagetimeout;movefile;getwindowsdirector...
# 2013-06-02                                          _corexemain
# 2013-06-02    coinitialize;loadlibrary;virtualprotect;acmstr...
# 2013-06-02    internetclosehandle;getwindowsdirectory;isbadr...
# 2013-06-02    isprocessorfeaturepresent;setenvironmentvariab...
# 2013-06-02    lockfileex;gettickcount;putchar;_cexit;getproc...
# 2013-06-02    coinitialize;loadlibrary;virtualprotect;getdc;...
# 2013-06-02    sendmessagetimeout;movefile;isdbcsleadbyte;get...
# 2013-06-02    sendmessagetimeout;movefile;getwindowsdirector...
# 2013-06-02    movefile;getwindowsdirectory;setenvironmentvar...
# 2013-06-02    getprocaddress;loadlibrary;virtualalloc;virtua...
# 2013-06-02    isprocessorfeaturepresent;setenvironmentvariab...
# 2013-06-02    exitprocess;getcommandline;freelibrary;seterro...
# 2013-06-02    isprocessorfeaturepresent;isbadcodeptr;isbadre...
# 2013-06-02    expandenvironmentstrings;getwindowsdirectory;s...
# 2013-06-02    gettickcount;virtualfree;createdirectory;showw...
# 2013-06-02    exitprocess;virtualfree;getversion;tlssetvalue...
# 2013-06-02    sendmessagetimeout;movefile;getwindowsdirector...
#                                     ...
# 2013-06-28    _initterm;_memccpy;modf;cofiletimenow;gettickc...
# 2013-06-28    movefile;getwindowsdirectory;releasedc;invertr...
# 2013-06-29    loadlibrary;virtualprotect;setparent;virtualfr...
# 2013-06-29                                          _corexemain
# 2013-06-29    movefile;getwindowsdirectory;setenvironmentvar...
# 2013-06-29    setsecuritydescriptordacl;exitprocess;virtualf...
# 2013-06-29                                          _corexemain
# 2013-06-29    releasedc;getwindowsdirectory;settextalign;set...
# 2013-06-29    loadlibrary;exitprocess;rand;getprocaddress;ws...
# 2013-06-29    setenvironmentvariable;releasedc;enddoc;coinit...
# 2013-06-29    sendmessagetimeout;movefile;getwindowsdirector...
# 2013-06-29    sendmessagetimeout;getwindowsdirectory;getcapt...
# 2013-06-30    coinitialize;getprocessimagefilename;getthread...
# 2013-06-30    openfile;getconsolemode;imagelist_getdragimage...
# 2013-06-30    getmenustate;waitmessage;objectdeleteauditalar...
# 2013-06-30    deleteipnetentry;loadlibrary;stretchdibits;she...
# 2013-06-30    openprocesstoken;isdbcsleadbyte;getwindowsdire...
# 2013-06-30            getprocaddress;loadlibrary;sleep;settimer
# 2013-06-30    winhttpopen;loadlibrary;virtualprotect;getadap...
# 2013-06-30    loadlibrary;virtualprotect;virtualfree;exitpro...
# 2013-06-30    expandenvironmentstrings;getwindowsdirectory;e...
# 2013-06-30                                          _corexemain
# 2013-06-30    gettitlebarinfo;releasedc;fillrect;getlogicald...
# 2013-06-30    adjusttokengroups;chord;createthread;blockinpu...
# 2013-06-30    gettickcount;exitprocess;findclose;getlargestc...
# 2013-06-30                             exitprocess;seterrormode
# 2013-06-30    coinitialize;releasedc;_initterm;sprintf;_acmd...
# 2013-06-30    sendmessagetimeout;movefile;getwindowsdirector...
# 2013-06-30    globalrealloc;exitprocess;tlssetvalue;getversi...
# 2013-06-30                               exitprocess;messagebox
# Name: imports, dtype: object
# 2013-07-01    exitprocess;calcmenubar;getwindowtextlength;ge...
# 2013-07-01    setenvironmentvariable;getprivateprofileint;is...
# 2013-07-01               getprocaddress;loadlibrary;exitprocess
# 2013-07-01    internetclosehandle;sprintf;wcslen;??0exceptio...
# 2013-07-01    setenvironmentvariable;movefile;gettickcount;v...
# 2013-07-01                                              addatom
# 2013-07-01    getoemcp;enumsystemcodepages;virtualprotect;is...
# 2013-07-01    __vbastrvarmove;__vbafreevar;_cicos;__vbaprint...
# 2013-07-01    _initterm;getstretchbltmode;_ultoa;ismenu;getw...
# 2013-07-01    loadlibrary;alphablend;virtualprotect;oledraw;...
# 2013-07-01    movefile;releasedc;_fstat;getcapture;isbadread...
# 2013-07-01    httpopenrequest;internetconnect;internetcloseh...
# 2013-07-01    exitprocess;getprocessheap;getprocaddress;heap...
# 2013-07-01    _initterm;_memccpy;isbadreadptr;_ultoa;getvers...
# 2013-07-01    movefile;getthreaddesktop;gettickcount;resumet...
# 2013-07-01    gettitlebarinfo;_initterm;isdbcsleadbyte;isbad...
# 2013-07-01    _initterm;hmenu_usersize;memcpy;gettickcount;h...
# 2013-07-01    gettickcount;virtualfree;resumethread;copyfile...
# 2013-07-01    sendmessagetimeout;pathremovefilespec;exitproc...
# 2013-07-01                                          _corexemain
# 2013-07-01    sendmessagetimeout;getwindowsdirectory;imageli...
# 2013-07-01    sendmessagetimeout;getwindowsdirectory;imageli...
# 2013-07-01    setsecuritydescriptordacl;loadlibrary;virtualp...
# 2013-07-01    rtlcapturestackbacktrace;isdbcsleadbyte;rtlupc...
# 2013-07-01    imagelist_seticonsize;setviewportorgex;getcapt...
# 2013-07-01    releasedc;getwindowsdirectory;settextalign;set...
# 2013-07-01    coinitialize;virtualfree;getenvironmentvariabl...
# 2013-07-01    getwindowsdirectory;debugbreak;gettickcount;ge...
# 2013-07-01    sendmessagetimeout;coinitialize;getwindowsdire...
# 2013-07-02    getcommandline;exitprocess;getstartupinfo;mess...
#                                     ...
# 2013-07-30    loadlibrary;getdc;regenumkey;exitprocess;shell...
# 2013-07-30    loadlibrary;dragfinish;getdc;rtldecompressbuff...
# 2013-07-30    lstrlen;getcommandline;createprocess;exitproce...
# 2013-07-30    pathremovefilespec;releasedc;senddlgitemmessag...
# 2013-07-30    getcapture;changeserviceconfig;setviewportorge...
# 2013-07-30    __vbafreevar;_cicos;_adj_fdiv_m16i;_adj_fdivr_...
# 2013-07-30    loadlibrary;getdc;regenumkey;exitprocess;shell...
# 2013-07-30           getprocaddress;loadlibrary;getmodulehandle
# 2013-07-30    enddoc;releasedc;virtualfree;getenvironmentvar...
# 2013-07-30    cmcheckrgbs;exitprocess;cmcreatedevicelinkprof...
# 2013-07-30    sendmessagetimeout;movefile;getwindowsdirector...
# 2013-07-30    event_sink_queryinterface;event_sink_addref;me...
# 2013-07-30    sendmessagetimeout;getwindowsdirectory;getcapt...
# 2013-07-30    movefile;releasedc;getthreaddesktop;gettickcou...
# 2013-07-30    __vbastrvarmove;_allmul;__vbafreevar;_cicos;_a...
# 2013-07-30    setenvironmentvariable;movefile;isbadreadptr;v...
# 2013-07-31    isprocessorfeaturepresent;gettickcount;getcons...
# 2013-07-31    getwindowsdirectory;changeserviceconfig;assign...
# 2013-07-31    setenvironmentvariable;movefile;setendoffile;g...
# 2013-07-31    sendmessagetimeout;movefile;getwindowsdirector...
# 2013-07-31    sendmessagetimeout;getcapture;certgetnamestrin...
# 2013-07-31    sysallocstringlen;virtualfree;exitprocess;getv...
# 2013-07-31    _initterm;_acmdln;__p__commode;globalalloc;int...
# 2013-07-31    getwindowsdirectory;enumsystemcodepages;isbadr...
# 2013-07-31    senddlgitemmessage;_tempnam;exitprocess;getver...
# 2013-07-31    sendmessagetimeout;movefile;getwindowsdirector...
# 2013-07-31    createsemaphore;tlssetvalue;closehandle;tlsget...
# 2013-07-31    createtoolhelp32snapshot;gettickcount;isvalidc...
# 2013-07-31    sendmessagetimeout;movefile;getwindowsdirector...
# 2013-07-31    sendmessagetimeout;getwindowsdirectory;setview...
# Name: imports, dtype: object
# 2013-08-01    getwindowsdirectory;getcapture;createdialogind...
# 2013-08-01    ?osfilehaschanged@@yghpauosfilechangedata@@@z;...
# 2013-08-01    _vsnprintf_s;setvbuf;getenvironmentvariable;ge...
# 2013-08-01                                          _corexemain
# 2013-08-01    wahopencurrentthread;getwindowsdirectory;wahcl...
# 2013-08-01    strlen;heaprealloc;memset;initializecriticalse...
# 2013-08-01    releasedc;imagelist_seticonsize;setviewportorg...
# 2013-08-01                                          _corexemain
# 2013-08-01    isprocessorfeaturepresent;setenvironmentvariab...
# 2013-08-01    __vbafreevar;_cicos;__vbavarcat;__vbar4var;__v...
# 2013-08-01    getcapture;setviewportorgex;createdialogindire...
# 2013-08-01    pathremovefilespec;messageboxex;getconsolemode...
# 2013-08-01    wahopencurrentthread;getwindowsdirectory;wahcl...
# 2013-08-01    setenvironmentvariable;getwindowsdirectory;_fs...
# 2013-08-01    movefile;getwindowsdirectory;isbadreadptr;gett...
# 2013-08-01                                          _corexemain
# 2013-08-01    setenvironmentvariable;createremotethread;debu...
# 2013-08-01    isprocessorfeaturepresent;setenvironmentvariab...
# 2013-08-01    sendmessagetimeout;movefile;getwindowsdirector...
# 2013-08-01    isprocessorfeaturepresent;coinitialize;release...
# 2013-08-01    nsigetparameter;gettickcount;resumethread;gete...
# 2013-08-01    _memccpy;isdbcsleadbyte;_initterm;modf;isbadco...
# 2013-08-01    _initterm;_acmdln;__p__commode;globalalloc;int...
# 2013-08-01    ndismregisterminiport;write_port_ushort;ndisre...
# 2013-08-01                                          _corexemain
# 2013-08-01    isprocessorfeaturepresent;setenvironmentvariab...
# 2013-08-01    _initterm;__p__commode;strncmp;globalalloc;glo...
# 2013-08-01    ??0wgconnectionobjectbrowser@@qae@pavtreposito...
# 2013-08-01    isprocessorfeaturepresent;setenvironmentvariab...
# 2013-08-01    imagelist_seticonsize;virtualfree;exitprocess;...
#                                     ...
# 2013-08-30    __vbafreevar;__vbacastobj;_cicos;__vbalenbstr;...
# 2013-08-30    isprocessorfeaturepresent;getconsolemode;getti...
# 2013-08-30    _initterm;_acmdln;exitprocess;virtualfree;__p_...
# 2013-08-30    openprocesstoken;isdbcsleadbyte;getwindowsdire...
# 2013-08-30    isprocessorfeaturepresent;getconsolemode;getti...
# 2013-08-30    cygwin_create_path;_getpwuid32;cygwin_detach_d...
# 2013-08-30    lual_loadbuffer;lua_newuserdata;?getpersonanam...
# 2013-08-30    setenvironmentvariable;movefile;isbadreadptr;g...
# 2013-08-30    movefile;isdbcsleadbyte;setenvironmentvariable...
# 2013-08-30                                          _corexemain
# 2013-08-30    getwindowsdirectory;setviewportorgex;restoredc...
# 2013-08-30    setenvironmentvariable;releasedc;coinitialize;...
# 2013-08-30    getwindowsdirectory;gettickcount;virtualfree;c...
# 2013-08-30    event_sink_invoke;event_sink_queryinterface;ev...
# 2013-08-30    openprocesstoken;isdbcsleadbyte;getwindowsdire...
# 2013-08-30    rtlcapturestackbacktrace;setenvironmentvariabl...
# 2013-08-30    coinitialize;openfile;releasedc;getprocaddress...
# 2013-08-30    imagelist_seticonsize;getcapture;setviewportor...
# 2013-08-31    isprocessorfeaturepresent;getwindowsdirectory;...
# 2013-08-31                                          _corexemain
# 2013-08-31    loadlibrary;shgetspecialfolderpath;sysfreestri...
# 2013-08-31                                          _corexemain
# 2013-08-31    isbadcodeptr;isbadreadptr;exitprocess;virtualf...
# 2013-08-31                                          _corexemain
# 2013-08-31                                          _corexemain
# 2013-08-31    loadlibrary;geterrorinfo;sysfreestring;imageli...
# 2013-08-31    gettickcount;cstdstubbuffer_connect;cstdstubbu...
# 2013-08-31                                          _corexemain
# 2013-08-31    setenvironmentvariable;releasedc;regenumkey;se...
# 2013-08-31                                          _corexemain
# Name: imports, dtype: object
# 2013-09-01    faultiniefeature;loadlibrary;getmenu;virtualpr...
# 2013-09-01    virtualfree;exitprocess;getprocaddress;imageli...
# 2013-09-01                                          _corexemain
# 2013-09-01    copyacceleratortable;coinitialize;isdbcsleadby...
# 2013-09-01    releasedc;registerclass;exitprocess;virtualfre...
# 2013-09-01    setenvironmentvariable;gettickcount;virtualfre...
# 2013-09-01    getwindowsdirectory;setviewportorgex;getcaptur...
# 2013-09-01    virtualfree;readclassstm;getprocaddress;adjust...
# 2013-09-01    copyacceleratortable;setenvironmentvariable;ge...
# 2013-09-01    __vbafreevar;_cicos;__vbaprintfile;__vbavarcat...
# 2013-09-01    openprocesstoken;createremotethread;netuserget...
# 2013-09-02    isprocessorfeaturepresent;gettickcount;getcons...
# 2013-09-02    loadlibrary;virtualprotect;getdc;virtualfree;e...
# 2013-09-02    gettickcount;createtoolhelp32snapshot;exitproc...
# 2013-09-02                                          _corexemain
# 2013-09-02                                          _corexemain
# 2013-09-02                                          _corexemain
# 2013-09-02                                          _corexemain
# 2013-09-02    isprocessorfeaturepresent;setenvironmentvariab...
# 2013-09-02    _initterm;_acmdln;gettickcount;__p__commode;wn...
# 2013-09-02    isbadreadptr;gettickcount;virtualfree;_cexit;g...
# 2013-09-02    imagelist_seticonsize;setviewportorgex;getcapt...
# 2013-09-02                                          _corexemain
# 2013-09-02                                          _corexemain
# 2013-09-02    openprocesstoken;isdbcsleadbyte;getwindowsdire...
# 2013-09-02                                          _corexemain
# 2013-09-02    getprivateprofileint;gettickcount;copyfile;cre...
# 2013-09-03    movefile;isdbcsleadbyte;releasedc;senddlgitemm...
# 2013-09-03                                          _corexemain
# 2013-09-03    expandenvironmentstrings;gettickcount;exitproc...
#                                     ...
# 2013-09-28    pssetcreatethreadnotifyroutine;seexports;exall...
# 2013-09-28    pathremovefilespec;registerclass;gettickcount;...
# 2013-09-28    openprocesstoken;isdbcsleadbyte;getwindowsdire...
# 2013-09-28    openprocesstoken;isdbcsleadbyte;getwindowsdire...
# 2013-09-28    _initterm;gettickcount;getprocaddress;interloc...
# 2013-09-28    releasedc;senddlgitemmessage;getcapture;isbadr...
# 2013-09-29                                          _corexemain
# 2013-09-29    gettickcount;exitprocess;virtualfree;getversio...
# 2013-09-29                                          _corexemain
# 2013-09-29                                          _corexemain
# 2013-09-29    getwindowsdirectory;imagelist_seticonsize;getc...
# 2013-09-29    releasedc;setwindowtext;getprocessid;exitproce...
# 2013-09-29    __initenv;gettickcount;_cexit;getprocessheap;g...
# 2013-09-30    isdbcsleadbyte;getwindowsdirectory;senddlgitem...
# 2013-09-30    movefile;setenvironmentvariable;isdbcsleadbyte...
# 2013-09-30    setenvironmentvariable;isbadreadptr;gettickcou...
# 2013-09-30    sendmessagetimeout;getwindowsdirectory;created...
# 2013-09-30    isprocessorfeaturepresent;setenvironmentvariab...
# 2013-09-30    isprocessorfeaturepresent;setenvironmentvariab...
# 2013-09-30    sendmessagetimeout;movefile;getwindowsdirector...
# 2013-09-30    setenvironmentvariable;isbadreadptr;gettickcou...
# 2013-09-30    movefile;getwindowsdirectory;setenvironmentvar...
# 2013-09-30    setenvironmentvariable;getwindowsdirectory;mov...
# 2013-09-30    event_sink_queryinterface;event_sink_addref;me...
# 2013-09-30    removefontmemresourceex;heap32next;heap32listf...
# 2013-09-30    loadlibrary;virtualprotect;virtualfree;exitpro...
# 2013-09-30    getwindowsdirectory;getcapture;setviewportorge...
# 2013-09-30    isprocessorfeaturepresent;pathremovefilespec;s...
# 2013-09-30    cmcallforward;pvtgetnodeidbypath;createdialogi...
# 2013-09-30    getwindowsdirectory;assignprocesstojobobject;n...
# Name: imports, dtype: object
# 2013-10-01    getwindowsdirectory;releasedc;getcapture;isbad...
# 2013-10-01    loadlibrary;virtualprotect;cofiletimenow;getdc...
# 2013-10-01    loadlibrary;alphablend;virtualprotect;getdc;ve...
# 2013-10-01    __vbafreevar;_cicos;__vbaprintfile;__vbavarcat...
# 2013-10-01    __vbastrvarmove;__vbafreevar;_cicos;__vbavarmo...
# 2013-10-01    gettickcount;exitprocess;virtualfree;isvalidco...
# 2013-10-01                                          _corexemain
# 2013-10-01               getprocaddress;loadlibrary;exitprocess
# 2013-10-01    loadlibrary;memset;virtualprotect;credfree;exi...
# 2013-10-01    setenvironmentvariable;getwindowsdirectory;coi...
# 2013-10-01    setenvironmentvariable;_unlink;copyfile;strnca...
# 2013-10-01    gettitlebarinfo;_initterm;isdbcsleadbyte;cofil...
# 2013-10-01    sendmessagetimeout;movefile;getwindowsdirector...
# 2013-10-01                                          _corexemain
# 2013-10-01    getwindowsdirectory;gettickcount;virtualfree;c...
# 2013-10-01    movefile;isdbcsleadbyte;releasedc;_vsnprintf_s...
# 2013-10-01                                          _corexemain
# 2013-10-01    coinitialize;changeserviceconfig;gettickcount;...
# 2013-10-01    isprocessorfeaturepresent;setenvironmentvariab...
# 2013-10-01    kelowerirql;extrytoacquirefastmutex;kequeryper...
# 2013-10-01    setenvironmentvariable;movefile;releasedc;send...
# 2013-10-01    getprocaddress;loadlibrary;virtualalloc;virtua...
# 2013-10-01               getprocaddress;loadlibrary;exitprocess
# 2013-10-01    exitprocess;findclose;closehandle;createfile;g...
# 2013-10-01    loadlibrary;virtualprotect;exitprocess;getproc...
# 2013-10-01    setdibits;getwindowsdirectory;releasedc;stretc...
# 2013-10-01    coinitialize;getwindowsdirectory;changeservice...
# 2013-10-02    sendmessagetimeout;getwindowsdirectory;setview...
# 2013-10-02    getwindowsdirectory;setwindowtext;senddlgitemm...
# 2013-10-02    openprocesstoken;isdbcsleadbyte;getwindowsdire...
#                                     ...
# 2013-10-30    loadlibrary;virtualprotect;virtualfree;exitpro...
# 2013-10-30    sendmessagetimeout;getwindowsdirectory;glgetin...
# 2013-10-30                                          _corexemain
# 2013-10-30    setenvironmentvariable;movefile;senddlgitemmes...
# 2013-10-30    getprocaddress;loadlibrary;virtualalloc;virtua...
# 2013-10-30    isprocessorfeaturepresent;setenvironmentvariab...
# 2013-10-30    setenvironmentvariable;getwindowsdirectory;coi...
# 2013-10-30    _initterm;registerclass;memcpy;__p__commode;ge...
# 2013-10-30    sendmessagetimeout;movefile;getwindowsdirector...
# 2013-10-30    ?_type_info_dtor_internal_method@type_info@@qa...
# 2013-10-30    exitprocess;findclose;getenvironmentvariable;g...
# 2013-10-30    isbadreadptr;gettickcount;virtualfree;_cexit;g...
# 2013-10-30    imagelist_seticonsize;setviewportorgex;getcapt...
# 2013-10-30    openprocesstoken;createremotethread;netuserget...
# 2013-10-30    _initterm;releasedc;registerclass;gettickcount...
# 2013-10-30    isdbcsleadbyte;releasedc;invertrect;settextali...
# 2013-10-30    __vbafreevar;_cicos;__vbavarcat;__vbavartstgt;...
# 2013-10-30    isbadcodeptr;isbadreadptr;gettickcount;isvalid...
# 2013-10-30    copysid;loadlibrary;imagelist_draw;virtualprot...
# 2013-10-30    openprocesstoken;isdbcsleadbyte;getwindowsdire...
# 2013-10-30    sendmessagetimeout;movefile;getwindowsdirector...
# 2013-10-30                                          _corexemain
# 2013-10-31    getwindowsdirectory;getconsolemode;exitprocess...
# 2013-10-31    createsemaphore;gettickcount;virtualfree;exitp...
# 2013-10-31    getcapture;setviewportorgex;createdialogindire...
# 2013-10-31                                          exitprocess
# 2013-10-31    openprocesstoken;isdbcsleadbyte;getwindowsdire...
# 2013-10-31    loadlibrary;exit;virtualprotect;virtualfree;ex...
# 2013-10-31    wcscat_s;getwindowsdirectory;gettickcount;?do_...
# 2013-10-31    setenvironmentvariable;isdbcsleadbyte;movefile...
# Name: imports, dtype: object
# 2013-11-01    __vbafreevar;_cicos;__vbavarmod;__vbaput3;__vb...
# 2013-11-01                                          _corexemain
# 2013-11-01    sendmessagetimeout;movefile;getwindowsdirector...
# 2013-11-01    isprocessorfeaturepresent;setenvironmentvariab...
# 2013-11-01    releasedc;senddlgitemmessage;getcapture;setvie...
# 2013-11-01    sendmessagetimeout;movefile;getwindowsdirector...
# 2013-11-01    getwindowsdirectory;gettickcount;virtualfree;c...
# 2013-11-01    loadlibrary;time;exitprocess;shchangenotify;me...
# 2013-11-01    __initenv;_initterm;_acmdln;__p__commode;strnc...
# 2013-11-01    setenvironmentvariable;movefile;releasedc;send...
# 2013-11-01    _initterm;registerclass;_acmdln;__p__commode;g...
# 2013-11-01                                          _corexemain
# 2013-11-01    setenvironmentvariable;strncat;getenvironmentv...
# 2013-11-01    isprocessorfeaturepresent;setenvironmentvariab...
# 2013-11-01    zwfreevirtualmemory;zwclose;swprintf;memcpy;mm...
# 2013-11-01    __vbafreevar;_cicos;_adj_fdiv_m16i;__vbanew2;_...
# 2013-11-01    getconsolemode;gettickcount;exitprocess;virtua...
# 2013-11-01                                          _cordllmain
# 2013-11-01                                          _corexemain
# 2013-11-01    loadlibrary;getdc;cocreateguid;bitblt;exitproc...
# 2013-11-02    loadlibrary;dialogboxparam;destroycursor;getpr...
# 2013-11-02    setenvironmentvariable;getwindowsdirectory;isd...
# 2013-11-02    sendmessagetimeout;movefile;getwindowsdirector...
# 2013-11-02                                          _corexemain
# 2013-11-02    rpcstringbindingparse;gettickcount;evtintrepor...
# 2013-11-02    loadlibrary;strstr;virtualprotect;virtualfree;...
# 2013-11-02    loadlibrary;dodragdrop;virtualprotect;getdc;im...
# 2013-11-02                                          _corexemain
# 2013-11-02    ?mousepressevent@qgraphicsview@@maexpavqmousee...
# 2013-11-02    isprocessorfeaturepresent;setenvironmentvariab...
#                                     ...
# 2013-11-29                               exitprocess;messagebox
# 2013-11-29    createpen;findclose;createfile;showwindow;dele...
# 2013-11-29    sendmessagetimeout;setviewportorgex;copyfile;g...
# 2013-11-29    setenvironmentvariable;movefile;senddlgitemmes...
# 2013-11-29    isbadreadptr;gettickcount;virtualfree;resumeth...
# 2013-11-29    movefile;getwindowsdirectory;coinitialize;isba...
# 2013-11-29    setvbuf;copyfile;getenvironmentvariable;getpro...
# 2013-11-29    sendmessagetimeout;movefile;getwindowsdirector...
# 2013-11-29    event_sink_queryinterface;event_sink_addref;me...
# 2013-11-30    gettickcount;getconsolemode;virtualfree;exitpr...
# 2013-11-30                                          _corexemain
# 2013-11-30                                          _corexemain
# 2013-11-30    sendmessagetimeout;pathremovefilespec;gettickc...
# 2013-11-30    isbadreadptr;gettickcount;virtualfree;_cexit;g...
# 2013-11-30    pathremovefilespec;lsaclose;getprivateprofilei...
# 2013-11-30    getwindowsdirectory;gettickcount;virtualfree;c...
# 2013-11-30    _zn5qfilec1erk7qstring;_zn9qlineedit14mousemov...
# 2013-11-30                                          _corexemain
# 2013-11-30    steamapi_init;movefile;isdbcsleadbyte;setenvir...
# 2013-11-30    getwindowsdirectory;getcapture;setviewportorge...
# 2013-11-30    isprocessorfeaturepresent;coinitialize;getwind...
# 2013-11-30    lstrcat;pathisprefix;strstri;loadbitmap;ismenu...
# 2013-11-30                                          _corexemain
# 2013-11-30                                          exitprocess
# 2013-11-30    __vbastrvarmove;__vbafreevar;_cicos;__vbavaran...
# 2013-11-30    isprocessorfeaturepresent;??1?$basic_ios@du?$c...
# 2013-11-30    lstrcat;pathisprefix;strstri;loadbitmap;ismenu...
# 2013-11-30    isprocessorfeaturepresent;?in@?$codecvt@ddh@st...
# 2013-11-30    isbadreadptr;gettickcount;virtualfree;_cexit;g...
# 2013-11-30                                          _corexemain
# Name: imports, dtype: object
# 2013-12-01    event_sink_queryinterface;event_sink_addref;me...
# 2013-12-01    sendmessagetimeout;movefile;getwindowsdirector...
# 2013-12-01    loadlibrary;exit;virtualprotect;exitprocess;ge...
# 2013-12-01    event_sink_queryinterface;event_sink_addref;me...
# 2013-12-01                                          _corexemain
# 2013-12-01    setenvironmentvariable;isdbcsleadbyte;movefile...
# 2013-12-01    broadcastsystemmessage;enumsystemcodepages;get...
# 2013-12-01    __vbafreevar;_cicos;__vbaput3;__vbavarcat;__vb...
# 2013-12-01    waitforsingleobject;createremotethread;loadlib...
# 2013-12-01    sendmessagetimeout;movefile;getwindowsdirector...
# 2013-12-01                                          _corexemain
# 2013-12-01                                          _corexemain
# 2013-12-01    setenvironmentvariable;isdbcsleadbyte;movefile...
# 2013-12-01    setenvironmentvariable;isdbcsleadbyte;movefile...
# 2013-12-02    getprocaddress;loadlibrary;_cicos;getmodulehandle
# 2013-12-02    sendmessagetimeout;releasedc;getwindowsdirecto...
# 2013-12-02    event_sink_queryinterface;event_sink_addref;me...
# 2013-12-02    isbadreadptr;gettickcount;lsagetsystemaccessac...
# 2013-12-02    isprocessorfeaturepresent;gettickcount;exitpro...
# 2013-12-02    movefile;getwindowsdirectory;gettickcount;copy...
# 2013-12-02    _initterm;_acmdln;__p__commode;findclose;delet...
# 2013-12-02    isdbcsleadbyte;?erase@?$basic_string@gu?$char_...
# 2013-12-02    nsigetparameter;gettickcount;resumethread;gete...
# 2013-12-02    isprocessorfeaturepresent;setenvironmentvariab...
# 2013-12-02    sendmessagetimeout;gettickcount;createdirector...
# 2013-12-02    isprocessorfeaturepresent;setenvironmentvariab...
# 2013-12-02    imagelist_seticonsize;setviewportorgex;getcapt...
# 2013-12-02    loadlibrary;pathmatchspec;endpaint;virtualprot...
# 2013-12-02    openprocesstoken;isdbcsleadbyte;getwindowsdire...
# 2013-12-02                                          _cordllmain
#                                     ...
# 2013-12-30    setenvironmentvariable;isdbcsleadbyte;movefile...
# 2013-12-30    _initterm;_acmdln;isbadreadptr;virtualfree;__p...
# 2013-12-30                                          _corexemain
# 2013-12-30    loadlibrary;geterrorinfo;sysfreestring;imageli...
# 2013-12-30                                          _corexemain
# 2013-12-30    movetoex;releasedc;setwindowtext;senddlgitemme...
# 2013-12-30    openprocesstoken;isdbcsleadbyte;getwindowsdire...
# 2013-12-30    setenvironmentvariable;isdbcsleadbyte;movefile...
# 2013-12-30    _initterm;gettickcount;??2@yapaxi@z;regopenkey...
# 2013-12-30    setenvironmentvariable;createsemaphore;showmod...
# 2013-12-30    movefile;gettickcount;resumethread;copyfile;cr...
# 2013-12-30    setenvironmentvariable;strncat;getenvironmentv...
# 2013-12-30    __initenv;_initterm;memcpy;gettickcount;isbadr...
# 2013-12-30    openprocesstoken;setsecuritydescriptordacl;exp...
# 2013-12-30    virtualfree;exitprocess;copyfile;getversion;ge...
# 2013-12-30                                          _corexemain
# 2013-12-30    isprocessorfeaturepresent;setenvironmentvariab...
# 2013-12-31    getcapture;setviewportorgex;createdialogindire...
# 2013-12-31                                          _corexemain
# 2013-12-31    isprocessorfeaturepresent;setenvironmentvariab...
# 2013-12-31                                          _corexemain
# 2013-12-31                                          _corexemain
# 2013-12-31                                          _corexemain
# 2013-12-31    coinitialize;getwindowsdirectory;releasedc;sen...
# 2013-12-31    getcapture;setviewportorgex;createdialogindire...
# 2013-12-31    imagelist_seticonsize;getcapture;setviewportor...
# 2013-12-31    setenvironmentvariable;isdbcsleadbyte;movefile...
# 2013-12-31    _cicos;_adj_fdiv_m16i;_adj_fdivr_m32;_adj_fdiv...
# 2013-12-31    _vsnprintf_s;changeserviceconfig;?id@?$ctype@d...
# 2013-12-31    coinitialize;d3dxvec3normalize;debugbreak;getc...
# Name: imports, dtype: object
# 2014-01-01    loadlibrary;variantchangetypeex;getmodulehandl...
# 2014-01-01    sendmessagetimeout;movefile;getwindowsdirector...
# 2014-01-01    getwindowsdirectory;gettickcount;virtualfree;c...
# 2014-01-01    movefile;_initterm;sprintf;_acmdln;createtoolh...
# 2014-01-01                                          _corexemain
# 2014-01-01    lstrcat;lstrlen;exitprocess;writefile;enumreso...
# 2014-01-01    settextalign;getdibits;exitprocess;fillrect;cr...
# 2014-01-01    vfprintf;wcslen;calloc;exitprocess;closehandle...
# 2014-01-01    setenvironmentvariable;gettickcount;_cexit;get...
# 2014-01-01    getwindowsdirectory;getcapture;setviewportorge...
# 2014-01-01    isprocessorfeaturepresent;setenvironmentvariab...
# 2014-01-01    kicoprocessorerror;keinitializedpc;iogetdevice...
# 2014-01-01    isprocessorfeaturepresent;?_xout_of_range@std@...
# 2014-01-01                                          _corexemain
# 2014-01-02    event_sink_queryinterface;event_sink_addref;me...
# 2014-01-02    isprocessorfeaturepresent;getconsolemode;getti...
# 2014-01-02               getprocaddress;loadlibrary;exitprocess
# 2014-01-02    sendmessagetimeout;movefile;getwindowsdirector...
# 2014-01-02    coinitialize;getwindowsdirectory;releasedc;sen...
# 2014-01-02    movefile;getwindowsdirectory;gettickcount;virt...
# 2014-01-02    getwindowsdirectory;gettickcount;virtualfree;c...
# 2014-01-02                                          _corexemain
# 2014-01-02    coinitialize;gettickcount;getconsolemode;virtu...
# 2014-01-02    setenvironmentvariable;isbadreadptr;gettickcou...
# 2014-01-02               getprocaddress;loadlibrary;exitprocess
# 2014-01-02    openfile;getwindowsdirectory;getcapture;setvie...
# 2014-01-02    getwindowsdirectory;imagelist_seticonsize;getc...
# 2014-01-02    __vbafreevar;_cicos;__vbaprintfile;__vbaput3;_...
# 2014-01-02    imagelist_seticonsize;setviewportorgex;getcapt...
# 2014-01-02    acmstreamsize;urldownloadtofile;virtualfree;ex...
#                                     ...
# 2014-01-30    movetoex;loadlibrary;regenumvalue;getsavefilen...
# 2014-01-30    __initenv;_initterm;?tie@?$basic_ios@du?$char_...
# 2014-01-30    movefile;getwindowsdirectory;setenvironmentvar...
# 2014-01-30    directdrawcreate;setenvironmentvariable;releas...
# 2014-01-30    setenvironmentvariable;getconsolemode;fillcons...
# 2014-01-30    _initterm;_acmdln;_close;__p__commode;??2@yapa...
# 2014-01-31                                          _corexemain
# 2014-01-31                                          _corexemain
# 2014-01-31    openprocesstoken;isdbcsleadbyte;getwindowsdire...
# 2014-01-31    _initterm;getwindowsdirectory;sprintf;register...
# 2014-01-31    getwindowsdirectory;releasedc;senddlgitemmessa...
# 2014-01-31                                          _corexemain
# 2014-01-31    gettickcount;getconsolemode;exitprocess;virtua...
# 2014-01-31    sendmessagetimeout;movefile;getwindowsdirector...
# 2014-01-31    sendmessagetimeout;getwindowsdirectory;getcapt...
# 2014-01-31    loadlibrary;exitprocess;shgetmalloc;oleinitial...
# 2014-01-31                                          _corexemain
# 2014-01-31                                          _corexemain
# 2014-01-31    gettickcount;getconsolemode;virtualfree;regope...
# 2014-01-31    getwindowsdirectory;gettickcount;virtualfree;c...
# 2014-01-31    openprocesstoken;isdbcsleadbyte;getwindowsdire...
# 2014-01-31    event_sink_queryinterface;event_sink_addref;me...
# 2014-01-31    getwindowsdirectory;rand;memcpy;exitprocess;fi...
# 2014-01-31    coinitialize;gettickcount;certgetnamestring;_c...
# 2014-01-31    asn1open_cmp;virtualfree;virtualalloc;_wgetcwd...
# 2014-01-31    _initterm;_acmdln;isbadreadptr;virtualfree;__p...
# 2014-01-31    movefile;coinitialize;gettickcount;getconsolem...
# 2014-01-31    getwindowsdirectory;imagelist_seticonsize;getc...
# 2014-01-31    releasedc;getwindowsdirectory;settextalign;set...
# 2014-01-31    loadlibrary;dragfinish;getdc;rtldecompressbuff...
# Name: imports, dtype: object
# 2014-02-01    openprocesstoken;isdbcsleadbyte;getwindowsdire...
# 2014-02-01                                          _corexemain
# 2014-02-01    setenvironmentvariable;isdbcsleadbyte;movefile...
# 2014-02-01                                          _corexemain
# 2014-02-01    isprocessorfeaturepresent;gettickcount;getcons...
# 2014-02-01                                          _corexemain
# 2014-02-01    sendmessagetimeout;movefile;getwindowsdirector...
# 2014-02-01    gettickcount;_cexit;getprocaddress;getprocessh...
# 2014-02-01    setenvironmentvariable;isdbcsleadbyte;movefile...
# 2014-02-02    openprocesstoken;isdbcsleadbyte;getwindowsdire...
# 2014-02-02                                          _corexemain
# 2014-02-02    sendmessagetimeout;movefile;getwindowsdirector...
# 2014-02-02    loadlibrary;virtualprotect;_dup;virtualfree;ex...
# 2014-02-02                                          _corexemain
# 2014-02-02    _initterm;vfprintf;wcslen;memcpy;gettickcount;...
# 2014-02-02    getwindowlong;loadlibrary;readfile;d3dxvec3tra...
# 2014-02-02    loadlibrary;virtualprotect;virtualfree;exitpro...
# 2014-02-02    loadlibrary;virtualprotect;exitprocess;message...
# 2014-02-02    cryptencodeobject;debugbreak;gettickcount;virt...
# 2014-02-02    pathremovefilespec;messageboxex;getconsolemode...
# 2014-02-02    pathremovefilespec;_initterm;senddlgitemmessag...
# 2014-02-02    __initenv;_cicos;gettickcount;_cexit;decodepoi...
# 2014-02-02                                          _corexemain
# 2014-02-02                                          _corexemain
# 2014-02-02    getwindowsdirectory;imagelist_seticonsize;getc...
# 2014-02-02    sendmessagetimeout;movefile;getwindowsdirector...
# 2014-02-03    sendmessagetimeout;movefile;getwindowsdirector...
# 2014-02-03    regopenkey;coinitialize;loadlibrary;time;shget...
# 2014-02-03    movefile;getconsolemode;gettickcount;virtualfr...
# 2014-02-03    sendmessagetimeout;__initenv;releasedc;coiniti...
#                                     ...
# 2014-02-27    _initterm;perl_newxs;perl_mg_set;perl_tcurpad_...
# 2014-02-27    _vsnprintf_s;gettickcount;_cexit;getprocaddres...
# 2014-02-27    isprocessorfeaturepresent;setenvironmentvariab...
# 2014-02-27    __initenv;gettickcount;getprocaddress;createth...
# 2014-02-27    sendmessagetimeout;movefile;getwindowsdirector...
# 2014-02-27                                          _corexemain
# 2014-02-27    closehandle;getversionex;toascii;getcurrentthr...
# 2014-02-28    loadlibrary;virtualprotect;dragfinish;escape;g...
# 2014-02-28    sendmessagetimeout;getwindowsdirectory;getcapt...
# 2014-02-28    openprocesstoken;isdbcsleadbyte;getwindowsdire...
# 2014-02-28    virtualfree;exitprocess;cryptmsgclose;freesid;...
# 2014-02-28    gettickcount;getprocessheap;getprocaddress;rpc...
# 2014-02-28    setviewportorgex;getcapture;createdialogindire...
# 2014-02-28    loadlibrary;virtualprotect;virtualfree;exitpro...
# 2014-02-28    sendmessagetimeout;getwindowsdirectory;setview...
# 2014-02-28    coinitializeex;_initterm;createsemaphore;wcsle...
# 2014-02-28    setviewportorgex;getcapture;createdialogindire...
# 2014-02-28    loadlibrary;verqueryvalue;virtualprotect;dragf...
# 2014-02-28    sendmessagetimeout;movefile;getwindowsdirector...
# 2014-02-28    isprocessorfeaturepresent;senddlgitemmessage;g...
# 2014-02-28    getwindowsdirectory;gettickcount;virtualfree;c...
# 2014-02-28    sendmessagetimeout;getwindowsdirectory;setview...
# 2014-02-28    setenvironmentvariable;getwindowsdirectory;cre...
# 2014-02-28    imagelist_seticonsize;getcapture;setviewportor...
# 2014-02-28    rtlisgenerictableempty;changeserviceconfig;imp...
# 2014-02-28    senddlgitemmessage;gettickcount;_cexit;getproc...
# 2014-02-28    createwaitabletimer;exitprocess;createdirector...
# 2014-02-28    initcommoncontrolsex;loadlibrary;documentprope...
# 2014-02-28    getwindowsdirectory;getcapture;setviewportorge...
# 2014-02-28    loadlibrary;virtualprotect;virtualfree;exitpro...
# Name: imports, dtype: object
# 2014-03-01    isbadcodeptr;isbadreadptr;exitprocess;virtualf...
# 2014-03-01    setenvironmentvariable;getwindowsdirectory;rel...
# 2014-03-01                                          _corexemain
# 2014-03-01    loadlibrary;shell_notifyicon;memset;virtualpro...
# 2014-03-01    copyacceleratortable;setenvironmentvariable;re...
# 2014-03-01    gettickcount;exitprocess;virtualfree;isvalidco...
# 2014-03-01    getwindowsdirectory;gettickcount;virtualfree;c...
# 2014-03-01    gettickcount;getconsolemode;virtualfree;resume...
# 2014-03-01    createtoolhelp32snapshot;gettickcount;isvalidc...
# 2014-03-01    setwindowtext;exitprocess;virtualfree;findclos...
# 2014-03-01    initcommoncontrolsex;loadlibrary;virtualprotec...
# 2014-03-01                                          _corexemain
# 2014-03-01    coinitialize;releasedc;getcapture;setviewporto...
# 2014-03-01    sendmessagetimeout;movefile;getwindowsdirector...
# 2014-03-01    setwindowtext;exitprocess;virtualfree;findclos...
# 2014-03-01    gettickcount;?setgeometry@qwidget@@qaexabvqrec...
# 2014-03-01    releasedc;getcapture;releasecapture;createdial...
# 2014-03-01    isprocessorfeaturepresent;movefile;getwindowsd...
# 2014-03-01                                          _corexemain
# 2014-03-01                                          _corexemain
# 2014-03-01    setwindowtext;exitprocess;virtualfree;findclos...
# 2014-03-01    loadlibrary;virtualprotect;getdc;virtualfree;e...
# 2014-03-01                                          _corexemain
# 2014-03-01    _initterm;pathremovefilespec;gettickcount;__p_...
# 2014-03-02    isprocessorfeaturepresent;_cicos;gettickcount;...
# 2014-03-02    loadlibrary;virtualprotect;virtualfree;exitpro...
# 2014-03-02                                          _corexemain
# 2014-03-02    event_sink_queryinterface;event_sink_addref;me...
# 2014-03-02    movefile;setenvironmentvariable;gettickcount;v...
# 2014-03-02           getprocaddress;loadlibrary;getmodulehandle
#                                     ...
# 2014-03-31    movefile;pathremovefilespec;??1fastwriter@json...
# 2014-03-31    setenvironmentvariable;isdbcsleadbyte;movefile...
# 2014-03-31    movefile;createdirectory;getenvironmentvariabl...
# 2014-03-31    gettickcount;exitprocess;translateaccelerator;...
# 2014-03-31    __initenv;_initterm;memcpy;gettickcount;isbadr...
# 2014-03-31    isprocessorfeaturepresent;releasedc;senddlgite...
# 2014-03-31    imagelist_seticonsize;getcapture;setviewportor...
# 2014-03-31    isprocessorfeaturepresent;gettickcount;isvalid...
# 2014-03-31    __initenv;_initterm;gettickcount;__p__commode;...
# 2014-03-31    getwindowsdirectory;imagelist_seticonsize;setv...
# 2014-03-31    movefile;createremotethread;gettickcount;virtu...
# 2014-03-31    getwindowsdirectory;?erase@?$basic_string@_wu?...
# 2014-03-31    __vbafreevar;_cicos;__vbaprintfile;__vbavarcat...
# 2014-03-31    strrstri;getwindowsdirectory;shqueryrecyclebin...
# 2014-03-31    isprocessorfeaturepresent;setenvironmentvariab...
# 2014-03-31    setenvironmentvariable;isdbcsleadbyte;movefile...
# 2014-03-31                                          _corexemain
# 2014-03-31    releasedc;imagelist_seticonsize;setviewportorg...
# 2014-03-31    __initenv;_initterm;isbadreadptr;gettickcount;...
# 2014-03-31                                          _corexemain
# 2014-03-31    setenvironmentvariable;movefile;pathremovefile...
# 2014-03-31    sendmessagetimeout;movefile;getwindowsdirector...
# 2014-03-31    sendmessagetimeout;getwindowsdirectory;setview...
# 2014-03-31    sendmessagetimeout;movefile;getwindowsdirector...
# 2014-03-31    _initterm;_acmdln;memcpy;exitprocess;systemtim...
# 2014-03-31    __vbafreevar;_cicos;__vbaprintfile;__vbacyvar;...
# 2014-03-31    exitprocess;virtualfree;findclose;getversion;g...
# 2014-03-31    closehandle;getprocaddress;globalalloc;enumwin...
# 2014-03-31                                          _corexemain
# 2014-03-31    iofcompleterequest;iocreatesymboliclink;iodele...
# Name: imports, dtype: object
# 2014-04-01    getwindowsdirectory;??1?$basic_ios@du?$char_tr...
# 2014-04-01    isprocessorfeaturepresent;gettickcount;getcons...
# 2014-04-01    setenvironmentvariable;isdbcsleadbyte;movefile...
# 2014-04-01    loadlibrary;getmodulehandle;getprocaddress;str...
# 2014-04-01    createsemaphore;exitprocess;closehandle;_cexit...
# 2014-04-01                                          _corexemain
# 2014-04-01    setenvironmentvariable;releasedc;virtualfree;c...
# 2014-04-01    getwindowsdirectory;getprivateprofileint;getti...
# 2014-04-01    movefile;pathremovefilespec;_vsnprintf_s;getpr...
# 2014-04-01    sendmessagetimeout;movefile;getwindowsdirector...
# 2014-04-01    setrect;virtualfree;exitprocess;getversion;get...
# 2014-04-01    getwindowsdirectory;gettickcount;virtualfree;c...
# ...
# 2016-07-01                                          _cordllmain
# 2016-07-01    initcommoncontrolsex;loadlibrary;virtualprotec...
# 2016-07-01    sendmessagetimeout;movefile;getwindowsdirector...
# 2016-07-01    movefile;getwindowsdirectory;changeserviceconf...
# 2016-07-01    sendmessagetimeout;movefile;getwindowsdirector...
# 2016-07-01                                          _corexemain
# 2016-07-01    getwindowsdirectory;imagelist_seticonsize;setv...
# 2016-07-01           getprocaddress;loadlibrary;getmodulehandle
# 2016-07-01    gettickcount;virtualfree;exitprocess;isvalidco...
# 2016-07-01    setenvironmentvariable;releasedc;settextalign;...
# 2016-07-01    sendmessagetimeout;getwindowsdirectory;getcapt...
# 2016-07-01    isprocessorfeaturepresent;gettickcount;exitpro...
# 2016-07-01    sendmessagetimeout;movefile;getwindowsdirector...
# 2016-07-01                                          _corexemain
# 2016-07-01                                          _corexemain
# 2016-07-01                                          _corexemain
# 2016-07-02    isbadreadptr;gettickcount;isvalidcodepage;exit...
# 2016-07-02    sendmessagetimeout;movefile;getwindowsdirector...
# 2016-07-02    openprocesstoken;isdbcsleadbyte;getwindowsdire...
# 2016-07-02    openfile;_cicos;setviewportorgex;setvbuf;resto...
#                                     ...
# 2016-07-30    isprocessorfeaturepresent;_initterm;queryservi...
# 2016-07-30    fopen;getwindowlong;_onexit;fclose;updatewindo...
# 2016-07-30                                          _corexemain
# 2016-07-30    getwindowsdirectory;gettickcount;virtualfree;c...
# 2016-07-30    loadlibrary;exitprocess;virtualfree;getcommand...
# 2016-07-30    isprocessorfeaturepresent;_initterm;__initenv;...
# 2016-07-30                                          _corexemain
# 2016-07-30    movefile;getwindowsdirectory;isbadreadptr;getc...
# 2016-07-30                                          _corexemain
# 2016-07-31    releasedc;createdialogindirectparam;fillrect;_...
# 2016-07-31    isprocessorfeaturepresent;setenvironmentvariab...
# 2016-07-31                                          _corexemain
# 2016-07-31                                          _corexemain
# 2016-07-31                                          _corexemain
# 2016-07-31    sendmessagetimeout;setenvironmentvariable;getw...
# 2016-07-31                                          _corexemain
# 2016-07-31                                   exitprocess;rundll
# 2016-07-31    getcapture;setviewportorgex;createdialogindire...
# 2016-07-31    copyacceleratortable;setenvironmentvariable;op...
# 2016-07-31    __vbaexcepthandler;proccallengine;dllfunctioncall
# 2016-07-31    getwindowsdirectory;settextalign;senddlgitemme...
# 2016-07-31                                          _corexemain
# 2016-07-31                                          _corexemain
# 2016-07-31                                          _corexemain
# 2016-07-31                                          _corexemain
# 2016-07-31    __initenv;_initterm;vfprintf;_acmdln;memcpy;ge...
# 2016-07-31                           initcommoncontrols;lstrcpy
# 2016-07-31                                          _corexemain
# 2016-07-31    getwindowsdirectory;gettickcount;virtualfree;c...
# 2016-07-31    imagelist_seticonsize;getcapture;setviewportor...
# Name: imports, dtype: object
# 2016-08-01    sendmessagetimeout;movefile;getwindowsdirector...
# 2016-08-01    loadlibrary;alphablend;virtualprotect;sysfrees...
# 2016-08-01                                          _corexemain
# 2016-08-01    @classes@tcomponent@updateaction$qqrp20classes...
# 2016-08-01    imagelist_seticonsize;getcapture;setviewportor...
# 2016-08-01    getwindowsdirectory;gettickcount;virtualfree;c...
# 2016-08-01                                          _corexemain
# 2016-08-01    ?getthismessagemap@clocalizedpropertypage@@kgp...
# 2016-08-01    isdbcsleadbyte;getwindowsdirectory;senddlgitem...
# 2016-08-01    coinitialize;gettickcount;virtualfree;exitproc...
# 2016-08-01                                          _corexemain
# 2016-08-01    coinitialize;_wfopen;getprocaddress;getdrivety...
# 2016-08-01    getwindowsdirectory;getcapture;setviewportorge...
# 2016-08-01    loadlibrary;?_badoff@std@@3_jb;virtualprotect;...
# 2016-08-01                                          _corexemain
# 2016-08-01    getwindowsdirectory;gettickcount;virtualfree;c...
# 2016-08-01    getwindowsdirectory;setviewportorgex;createdia...
# 2016-08-01    acmstreamsize;urldownloadtofile;virtualfree;ex...
# 2016-08-01    loadlibrary;dodragdrop;virtualprotect;getdc;im...
# 2016-08-01                                          _corexemain
# 2016-08-01    coinitialize;openfile;releasedc;invertrect;isb...
# 2016-08-01                                          _corexemain
# 2016-08-01    sendmessagetimeout;enddoc;releasedc;settextali...
# 2016-08-01    sendmessagetimeout;getwindowsdirectory;getcapt...
# 2016-08-01    gettickcount;exitprocess;resumethread;findclos...
# 2016-08-01    regopenkey;loadlibrary;readfile;waitforsingleo...
# 2016-08-01    getwindowsdirectory;imagelist_seticonsize;getc...
# 2016-08-01    coinitialize;lockfileex;gettickcount;createdir...
# 2016-08-01    loadlibrary;dodragdrop;virtualprotect;dragfini...
# 2016-08-01    gettickcount;virtualfree;queryservicestatusex;...
#                                     ...
# 2016-08-31    isprocessorfeaturepresent;createwaitabletimer;...
# 2016-08-31    coinitialize;openfile;getwindowsdirectory;rele...
# 2016-08-31    openprocesstoken;expandenvironmentstrings;exit...
# 2016-08-31    coinitialize;settextalign;setviewportorgex;res...
# 2016-08-31    isprocessorfeaturepresent;setenvironmentvariab...
# 2016-08-31    isprocessorfeaturepresent;setenvironmentvariab...
# 2016-08-31    openprocesstoken;isdbcsleadbyte;getwindowsdire...
# 2016-08-31    rtlupcaseunicodestring;ntquerysymboliclinkobje...
# 2016-08-31    sendmessagetimeout;getwindowsdirectory;glgetin...
# 2016-08-31    setenvironmentvariable;releasedc;coinitialize;...
# 2016-08-31    __vbacastobj;_cicos;_adj_fdiv_m16i;__vbalateid...
# 2016-08-31    openprocesstoken;isdbcsleadbyte;getwindowsdire...
# 2016-08-31    getwindowsdirectory;gettickcount;virtualfree;c...
# 2016-08-31    getwindowsdirectory;releasedc;senddlgitemmessa...
# 2016-08-31    gettickcount;_cexit;process32next;wcsstr;exit;...
# 2016-08-31    getthemebackgroundcontentrect;coinitialize;get...
# 2016-08-31    sendmessagetimeout;movefile;getwindowsdirector...
# 2016-08-31    __initenv;gettickcount;getenvironmentvariable;...
# 2016-08-31    sendmessagetimeout;getwindowsdirectory;glgetin...
# 2016-08-31                                          _corexemain
# 2016-08-31    loadlibrary;recvfrom;virtualprotect;virtualfre...
# 2016-08-31    sendmessagetimeout;getwindowsdirectory;glgetin...
# 2016-08-31    _zn11qmainwindow11qt_metacastepkc;_zn7qobject1...
# 2016-08-31    gettickcount;exitprocess;virtualfree;isvalidco...
# 2016-08-31    isprocessorfeaturepresent;setenvironmentvariab...
# 2016-08-31    loadlibrary;getdc;regenumkey;exitprocess;shell...
# 2016-08-31    __vbastrvarmove;__vbafreevar;_cicos;__vbaprint...
# 2016-08-31    isprocessorfeaturepresent;getprivateprofileint...
# 2016-08-31    isprocessorfeaturepresent;__initenv;_initterm;...
# 2016-08-31    isprocessorfeaturepresent;pathremovefilespec;s...
# Name: imports, dtype: object
# 2016-09-01    event_sink_queryinterface;event_sink_addref;me...
# 2016-09-01                                          _corexemain
# 2016-09-01    isprocessorfeaturepresent;getconsolemode;getti...
# 2016-09-01                                          _corexemain
# 2016-09-01    __initenv;gettickcount;impersonatenamedpipecli...
# 2016-09-01                                          _corexemain
# 2016-09-01    loadlibrary;shbrowseforfolder;uuidcreate;sysst...
# 2016-09-01    _initterm;rtlipv4stringtoaddress;memcpy;gettic...
# 2016-09-01                                          _corexemain
# 2016-09-01    gettickcount;virtualfree;exitprocess;regopenke...
# 2016-09-01    loadlibrary;virtualprotect;virtualfree;exitpro...
# 2016-09-01    isprocessorfeaturepresent;setenvironmentvariab...
# 2016-09-01    isprocessorfeaturepresent;releasedc;gettickcou...
# 2016-09-01    sendmessagetimeout;movefile;getwindowsdirector...
# 2016-09-01    sendmessagetimeout;movefile;getwindowsdirector...
# 2016-09-01                           getprocaddress;loadlibrary
# 2016-09-01    isprocessorfeaturepresent;setenvironmentvariab...
# 2016-09-01    sendmessagetimeout;movefile;getwindowsdirector...
# 2016-09-01    exitprocess;virtualfree;getversion;closehandle...
# 2016-09-01    getwindowsdirectory;gettickcount;virtualfree;c...
# 2016-09-01    ?create@csfpicturectrl@@uaehpbdkabutagrect@@pa...
# 2016-09-01                                          _corexemain
# 2016-09-01                                          _corexemain
# 2016-09-01    sendmessagetimeout;movefile;getwindowsdirector...
# 2016-09-01    propvariantclear;getprocessheap;getprocaddress...
# 2016-09-01    gettickcount;getprocaddress;enumwindows;regflu...
# 2016-09-01    isprocessorfeaturepresent;setenvironmentvariab...
# 2016-09-01                                          _corexemain
# 2016-09-01    sendmessagetimeout;getwindowsdirectory;copyfil...
# 2016-09-01                                          _corexemain
#                                     ...
# 2016-09-29    assignprocesstojobobject;createdialogindirectp...
# 2016-09-29                                          _corexemain
# 2016-09-29    getprocessmitigationpolicy;pathremovefilespec;...
# 2016-09-29    releasedc;getcapture;setviewportorgex;gettickc...
# 2016-09-29    sendmessagetimeout;movefile;getwindowsdirector...
# 2016-09-30    loadlibrary;virtualprotect;virtualfree;exitpro...
# 2016-09-30    isbadreadptr;gettickcount;getprocessheap;getpr...
# 2016-09-30    sendmessagetimeout;movefile;setenvironmentvari...
# 2016-09-30    coinitialize;movefile;gettickcount;virtualfree...
# 2016-09-30    isprocessorfeaturepresent;getcapture;gettickco...
# 2016-09-30    gettickcount;getprocessheap;getprocaddress;reg...
# 2016-09-30    isprocessorfeaturepresent;gettickcount;created...
# 2016-09-30                                          _corexemain
# 2016-09-30    __vbastrvarmove;__vbafreevar;_cicos;__vbalenbs...
# 2016-09-30    restoredc;getprocessheap;getprocaddress;create...
# 2016-09-30                                          _corexemain
# 2016-09-30                                          _cordllmain
# 2016-09-30    connect;gettickcount;urldownloadtofile;virtual...
# 2016-09-30    imagelist_seticonsize;getcapture;setviewportor...
# 2016-09-30    setenvironmentvariable;_close;_findfirst;exitp...
# 2016-09-30    getwindowsdirectory;imagelist_seticonsize;getc...
# 2016-09-30    openprocesstoken;openfile;releasedc;registercl...
# 2016-09-30    event_sink_queryinterface;event_sink_addref;me...
# 2016-09-30    coinitialize;releasedc;setenvironmentvariable;...
# 2016-09-30    getwindowsdirectory;imagelist_seticonsize;getc...
# 2016-09-30                                          _corexemain
# 2016-09-30    getwindowsdirectory;gettickcount;virtualfree;c...
# 2016-09-30    loadlibrary;exit;virtualprotect;urldownloadtof...
# 2016-09-30    getwindowsdirectory;isdbcsleadbyte;releasedc;g...
# 2016-09-30    isprocessorfeaturepresent;_pythreadstate_curre...
# Name: imports, dtype: object
# 2016-10-01                                          _corexemain
# 2016-10-01    __vbafreevar;_cicos;__vbaui1errvar;__vbavarcat...
# 2016-10-01    setenvironmentvariable;releasedc;senddlgitemme...
# 2016-10-01    coinitialize;releasedc;getconsolemode;gettickc...
# 2016-10-01                                          _corexemain
# 2016-10-01    getwindowsdirectory;imagelist_seticonsize;getc...
# 2016-10-01    __vbastrvarmove;__vbafreevar;_cicos;__vbaprint...
# 2016-10-01    getcapture;setviewportorgex;createdialogindire...
# 2016-10-01                                          _corexemain
# 2016-10-01    getwindowsdirectory;imagelist_seticonsize;getc...
# 2016-10-01    createremotethread;sysallocstringlen;gettickco...
# 2016-10-01                                          _corexemain
# 2016-10-01    openprocesstoken;isdbcsleadbyte;getwindowsdire...
# 2016-10-01                                          _corexemain
# 2016-10-01    setenvironmentvariable;getwindowsdirectory;cha...
# 2016-10-01    exitprocess;virtualfree;getversion;closehandle...
# 2016-10-01    getcapture;setviewportorgex;createdialogindire...
# 2016-10-01    openprocesstoken;isdbcsleadbyte;getwindowsdire...
# 2016-10-01                                          _corexemain
# 2016-10-01                                          _corexemain
# 2016-10-01    releasedc;senddlgitemmessage;gettickcount;crea...
# 2016-10-01                                          _corexemain
# 2016-10-01    setupfindfirstline;setenvironmentvariable;chan...
# 2016-10-01    _initterm;_acmdln;gettickcount;__p__commode;ex...
# 2016-10-01    setenvironmentvariable;isbadcodeptr;isbadreadp...
# 2016-10-01    isprocessorfeaturepresent;coinitialize;getwind...
# 2016-10-02    _initterm;wcslen;_acmdln;connect;createtoolhel...
# 2016-10-02    wdfversionunbind;_allshl;ndisallocatenetbuffer...
# 2016-10-02                                          _corexemain
# 2016-10-02    _iob;coinitialize;loadlibrary;alphablend;virtu...
#                                     ...
# 2016-10-09    initcommoncontrolsex;coinitialize;loadlibrary;...
# 2016-10-09    virtualfree;exitprocess;findclose;getversion;g...
# 2016-10-09                                          _corexemain
# 2016-10-09    releasedc;senddlgitemmessage;gettickcount;virt...
# 2016-10-09    exitprocess;virtualfree;getversion;getfiletype...
# 2016-10-09    virtualfree;exitprocess;cryptmsgclose;freesid;...
# 2016-10-09                                          _corexemain
# 2016-10-09    __vbafreevar;_cicos;__vbaput3;__vbafreestr;__v...
# 2016-10-09    getwindowsdirectory;gettickcount;virtualfree;c...
# 2016-10-09    loadlibrary;shgetspecialfolderpath;sysfreestri...
# 2016-10-09    __vbafreevar;_cicos;__vbaput3;__vbafreestr;__v...
# 2016-10-09                                          _corexemain
# 2016-10-09    assignprocesstojobobject;createdialogindirectp...
# 2016-10-09    sendmessagetimeout;getwindowsdirectory;?id@?$c...
# 2016-10-09    getwindowsdirectory;_vsnprintf_s;getcapture;_c...
# 2016-10-09    releasedc;getcapture;setviewportorgex;getconso...
# 2016-10-09    cocreateinstance;exitprocess;couninitialize;co...
# 2016-10-09    expandenvironmentstrings;getwindowsdirectory;i...
# 2016-10-09    coinitialize;openfile;releasedc;getprocaddress...
# 2016-10-09                                          _corexemain
# 2016-10-10                                          _corexemain
# 2016-10-10                                          _corexemain
# 2016-10-10    assignprocesstojobobject;createdialogindirectp...
# 2016-10-10    zwclose;ioreleasecancelspinlock;wcslen;iodelet...
# 2016-10-10    loadlibrary;shbrowseforfolder;urldownloadtofil...
# 2016-10-10    sendmessagetimeout;movefile;getwindowsdirector...
# 2016-10-10    coinitialize;getwindowsdirectory;gettickcount;...
# 2016-10-10    enddoc;releasedc;senddlgitemmessage;virtualfre...
# 2016-10-10    loadlibrary;virtualprotect;virtualfree;exitpro...
# 2016-10-10    getwindowsdirectory;exitprocess;closehandle;cr...
# Name: imports, dtype: object
# date
# 2013-04-30    None
# 2013-05-31    None
# 2013-06-30    None
# 2013-07-31    None
# 2013-08-31    None
# 2013-09-30    None
# 2013-10-31    None
# 2013-11-30    None
# 2013-12-31    None
# 2014-01-31    None
# 2014-02-28    None
# 2014-03-31    None
# 2014-04-30    None
# 2014-05-31    None
# 2014-06-30    None
# 2014-07-31    None
# 2014-08-31    None
# 2014-09-30    None
# 2014-10-31    None
# 2014-11-30    None
# 2014-12-31    None
# 2015-01-31    None
# 2015-02-28    None
# 2015-03-31    None
# 2015-04-30    None
# 2015-05-31    None
# 2015-06-30    None
# 2015-07-31    None
# 2015-08-31    None
# 2015-09-30    None
# 2015-10-31    None
# 2015-11-30    None
# 2015-12-31    None
# 2016-01-31    None
# 2016-02-29    None
# 2016-03-31    None
# 2016-04-30    None
# 2016-05-31    None
# 2016-06-30    None
# 2016-07-31    None
# 2016-08-31    None
# 2016-09-30    None
# 2016-10-31    None
# Freq: M, Name: imports, dtype: object
