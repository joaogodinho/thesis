# %% [markdown]
# # Normalize AV Classifcation
#
# Trying to figure out the naming convention each vendor uses, this allows a finer filter on choosing malware.

# %%
import pandas as pd
import numpy as np
import datetime
import re
from IPython.display import display
from sklearn.feature_extraction.text import CountVectorizer

pe32_av = pd.read_csv('data/pe32_static_av.csv', dtype=str)
pe32_av['date'] = pd.to_datetime(pe32_av['date'], format='%Y/%m/%d')
pe32_av = pe32_av.set_index('date').sort_index()

# Filter vendors with high presence
vendors_presence = pd.Series.from_csv('data/vendors_presence.csv')
vendors = vendors_presence[vendors_presence > 0.7].keys()

# Remove unused columns
pe32_av.drop([v for v in pe32_av.columns if v not in vendors], axis=1, inplace=True)
pe32_av.fillna('clean', inplace=True)

print('Total samples: {}'.format(len(pe32_av)))
# Out:
# Total samples: 388513

# %%
# Vendors to filter
display(vendors_presence.sort_values())
display(', '.join(vendors))
# Out:
#  win32_virut_xp (v)     0.000003
# pandab3                 0.000010
# drwebse                 0.000013
# antivir7                0.000015
# t3                      0.000026
# f-prot4                 0.000033
# etrust-inoculateit      0.000039
# una                     0.000059
# escan                   0.000142
# fortinetbeta            0.000152
# mcafeebeta              0.000160
# fileadvisor             0.000198
# savmail                 0.000237
# command                 0.000335
# secureweb-gateway       0.000345
# webwasher-gateway       0.000618
# nod32v2                 0.000677
# ahnlab                  0.000695
# ewido                   0.000777
# pandabeta               0.000852
# nod32beta               0.001372
# prevx1                  0.001506
# mcafee+artemis          0.004978
# avast5                  0.005058
# a-squared               0.005897
# sunbelt                 0.007596
# authentium              0.007660
# prevx                   0.010435
# crowdstrike             0.013565
# etrust-vet              0.013925
#                           ...
# panda                   0.715062
# trendmicro-housecall    0.715366
# ahnlab-v3               0.717268
# vipre                   0.718179
# jiangmin                0.718215
# drweb                   0.718259
# antiy-avl               0.719556
# sophos                  0.720244
# trendmicro              0.721227
# superantispyware        0.724748
# symantec                0.725144
# mcafee-gw-edition       0.725641
# kaspersky               0.726727
# vba32                   0.727469
# avg                     0.727772
# avast                   0.728300
# comodo                  0.728617
# nprotect                0.728949
# microsoft               0.729144
# mcafee                  0.730261
# clamav                  0.730660
# k7antivirus             0.730665
# f-prot                  0.730681
# gdata                   0.731559
# ikarus                  0.731813
# virobot                 0.731994
# fortinet                0.732436
# cat-quickheal           0.732650
# bitdefender             0.732663
# thehacker               0.732732
# dtype: float64
# 'ahnlab-v3, antiy-avl, avast, avg, bitdefender, cat-quickheal, clamav, comodo, drweb, emsisoft, eset-nod32, f-prot, f-secure, fortinet, gdata, ikarus, jiangmin, k7antivirus, k7gw, kaspersky, malwarebytes, mcafee, mcafee-gw-edition, microsoft, microworld-escan, nano-antivirus, nprotect, panda, sophos, superantispyware, symantec, thehacker, trendmicro, trendmicro-housecall, vba32, vipre, virobot'

# %%
# Testing the CV on naming
sample = pe32_av[:1]
token_pattern = r'\b[a-z0-9@_~-]{2,}\b'
stop_words = ['clean', 'heuristic', 'variant', 'lookslike', 'suspicious', 'file', 'heur', 'malware',
              'behaveslike', 'win32', 'win', 'w32', 'possible', 'threat', 'mal']

relevant_types = ['trojan', 'backdoor', 'worm']

sample = list(map(lambda x: ' '.join(x), sample.values))
# sample = [' '.join(sample.values)]
# display(sample)

cv = CountVectorizer(token_pattern=token_pattern, stop_words=stop_words)
vector = cv.fit_transform(sample)
occurrences = sorted(zip(cv.get_feature_names(),
                         np.asarray(vector.sum(axis=0)).ravel()), key=lambda x: x[1], reverse=True)
display(occurrences)
# Out:
# [('runouce', 12),
#  ('chir', 11),
#  ('b@mm', 10),
#  ('worm', 5),
#  ('virus', 4),
#  ('emailworm', 3),
#  ('runonce', 3),
#  ('10748', 2),
#  ('b-o', 2),
#  ('email-worm', 2),
#  ('pe_chir', 2),
#  ('6652', 1),
#  ('agent', 1),
#  ('brontok', 1),
#  ('bxafx', 1),
#  ('chihack', 1),
#  ('chir-a', 1),
#  ('cnpeace', 1),
#  ('dannado', 1),
#  ('gen', 1),
#  ('gen-runonce', 1),
#  ('suspiciouspe', 1),
#  ('thecid', 1),
#  ('trj', 1),
#  ('trojan', 1),
#  ('v001', 1)]

# %% [markdown]
# ## Known Naming
#
# Start with vendors that provide their naming convention

# %% [markdown]
# ### Microsoft
#
# `TYPE DELIM PLATFORM DELIM FAMILY DELIM VARIANT DELIM INFO`
#
# e.g.: `Backdoor:Win32/Caphaw.D!lnk`

# %%
microsoft_samples = pe32_av['microsoft']
microsoft_samples = microsoft_samples[microsoft_samples != 'clean'].dropna()

display(microsoft_samples[:10])

def microsoft_get_types(x):
    return x.split(':')[0]

def microsoft_get_platf(x):
    return x.split('/')[0].split(':')[-1]

def microsoft_get_families(x):
    return x.split('/')[-1].split('.')[0]

types = set(map(microsoft_get_types, microsoft_samples.values))
platf = set(map(microsoft_get_platf, microsoft_samples.values))
famls = set(map(microsoft_get_families, microsoft_samples.values))
# Out:
# date
# 2013-04-16              virus:win32/chir.b@mm
# 2013-04-16             trojan:win32/sefnit.aj
# 2013-04-16           backdoor:win32/poison.bf
# 2013-04-16           backdoor:win32/ursap!rts
# 2013-04-16                worm:win32/boychi.a
# 2013-04-16    trojandownloader:win32/kuluoz.b
# 2013-04-16              trojan:win32/meredrop
# 2013-04-16    trojandownloader:win32/dofoil.r
# 2013-04-16              virus:win32/chir.b@mm
# 2013-04-16              hacktool:win32/wpepro
# Name: microsoft, dtype: object

# %% [markdown]
# ## Ahnlab-v3

# %%
ahnlab_samples = pe32_av[vendors[0]]
# ahnlab_samples = pe32_av['bitdefender']
# Remove clean and NaN samples
ahnlab_samples = ahnlab_samples[ahnlab_samples != 'clean'].dropna()

display(ahnlab_samples[:10])

# Filter the delimiters
# '/' seems like the first one
replaceables = ['win-', 'i-']
delims = ['-', '.', '/']

def filter_func(x):
    # x = x.split('.')[0]
    
    for d in delims:
        x = x.replace(d, ' DELIM ')

    for t in types:
        x = x.replace(t + ' ', 'TYPE ')
    
    for p in platf:
        x = x.replace(p + ' ', 'PLAT ')
        
    for f in list(famls)[:1000]:
        x = x.replace(f + ' ', 'FAM ')
        
    return x

display(set(map(filter_func, ahnlab_samples.values)))
# Out:
# date
# 2013-04-16                      win32.runouce.b@mm
# 2013-04-16                  gen:variant.kazy.44812
# 2013-04-16               trojan.generic.kdv.380263
# 2013-04-16                   gen:variant.symmi.689
# 2013-04-16                  gen:variant.kazy.61786
# 2013-04-16               trojan.generic.kdv.787211
# 2013-04-16                  gen:variant.symmi.3565
# 2013-04-16                 gen:variant.kazy.161265
# 2013-04-16                      win32.runouce.b@mm
# 2013-04-16    dropped:application.sniffer.wpepro.e
# Name: bitdefender, dtype: object
# {'TYPE DELIM generic DELIM 12847796',
#  'TYPE DELIM generickd DELIM 1167723',
#  'TYPE DELIM TYPE DELIM agent DELIM scw',
#  'gen:variant DELIM symmi DELIM 41940',
#  'gen:variant DELIM kazy DELIM 8023',
#  'gen:variant DELIM razy DELIM 13238',
#  'TYPE DELIM dropper DELIM vrm',
#  'gen:variant DELIM kazy DELIM 324841',
#  'gen:variant DELIM kazy DELIM 546085',
#  'TYPE DELIM generickd DELIM 2058223',
#  'generic DELIM malware DELIM sp!pk!g DELIM e605539d',
#  'TYPE DELIM downloader DELIM zlob DELIM acmz',
#  'gen:variant DELIM barys DELIM 9064',
#  'TYPE DELIM generic DELIM kdz DELIM 10704',
#  'PLAT DELIM hllo DELIM nwu',
#  'gen:variant DELIM graftor DELIM 208988',
#  'TYPE DELIM agent DELIM nxr',
#  'TYPE DELIM generic DELIM kd DELIM 21607',
#  'TYPE DELIM generic DELIM 13407588',
#  'gen:variant DELIM symmi DELIM 50307',
#  'gen:variant DELIM graftor DELIM 194161',
#  'generic DELIM poisonivy DELIM df6c8887',
#  'memscan:TYPE DELIM sdbot DELIM dflt',
#  'TYPE DELIM generickd DELIM 2901541',
#  'TYPE DELIM htmclip DELIM a',
#  'gen:variant DELIM zusy DELIM 196481',
#  'TYPE DELIM generickd DELIM 2818947',
#  'gen:variant DELIM kazy DELIM 180265',
#  'gen:variant DELIM strictor DELIM 4095',
#  'gen:variant DELIM graftor DELIM 112619',
#  'gen:heur DELIM cryptowall DELIM 3',
#  'dropped:TYPE DELIM generic DELIM 8511173',
#  'TYPE DELIM generic DELIM 544797',
#  'TYPE DELIM TYPE DELIM FAM DELIM zwu',
#  'TYPE DELIM generickd DELIM 1661564',
#  'TYPE DELIM generickd DELIM 1492036',
#  'TYPE DELIM TYPE DELIM FAM DELIM aup',
#  'gen:TYPE DELIM heur DELIM gmw@!@n2x3k',
#  'gen:variant DELIM zusy DELIM 117113',
#  'gen:variant DELIM symmi DELIM 41435',
#  'gen:variant DELIM kazy DELIM 123099',
#  'genpack:generic DELIM perfloger DELIM 51f9c1ab',
#  'TYPE DELIM generickd DELIM 2028535',
#  'gen:variant DELIM graftor DELIM 154448',
#  'TYPE DELIM generic DELIM 4124778',
#  'gen:variant DELIM zusy DELIM 89881',
#  'gen:TYPE DELIM heur DELIM dp DELIM tk1@agqxprbi',
#  'gen:variant DELIM graftor DELIM 103540',
#  'gen:TYPE DELIM heur DELIM hm0@srigmvdi',
#  'gen:TYPE DELIM heur2 DELIM fu DELIM aix@aczso1ii',
#  'genpack:TYPE DELIM TYPE DELIM vub',
#  'TYPE DELIM generickd DELIM 2552873',
#  'gen:variant DELIM strictor DELIM 80595',
#  'TYPE DELIM generickd DELIM 2864864',
#  'gen:variant DELIM zusy DELIM 39068',
#  'TYPE DELIM generic DELIM 29385',
#  'gen:variant DELIM symmi DELIM 49304',
#  'TYPE DELIM generickd DELIM 3182839',
#  'gen:TYPE DELIM heur DELIM sfm DELIM tngnage9qbbq',
#  'generic DELIM PLAT DELIM bladabindi DELIM 1f3dac66',
#  'gen:variant DELIM zusy DELIM 73277',
#  'application DELIM hackTYPE DELIM flooder DELIM n',
#  'application DELIM agent DELIM ec',
#  'gen:variant DELIM symmi DELIM 28328',
#  'TYPE DELIM generic DELIM 9425887',
#  'application DELIM generic DELIM 659599',
#  'TYPE DELIM generickdv DELIM 1136676',
#  'TYPE DELIM injector DELIM asx',
#  'gen:variant DELIM graftor DELIM 135475',
#  'gen:variant DELIM kazy DELIM 239275',
#  'TYPE DELIM generic DELIM 7932003',
#  'generic DELIM banker DELIM delf DELIM 26bc0723',
#  'gen:PLAT DELIM smtp DELIM mailer DELIM nigeasfx!njg',
#  'gen:variant DELIM kazy DELIM 218684',
#  'TYPE DELIM generic DELIM 3599834',
#  'generic DELIM rebhip DELIM ad3c33b1',
#  'TYPE DELIM generic DELIM 7924453',
#  'gen:variant DELIM kazy DELIM 566333',
#  'TYPE DELIM ibryte DELIM ac',
#  'application DELIM downloader DELIM xu',
#  'gen:variant DELIM kazy DELIM 94353',
#  'gen:variant DELIM kazy DELIM 494648',
#  'TYPE DELIM generickd DELIM 2009744',
#  'TYPE DELIM generickd DELIM 1484006',
#  'TYPE DELIM generickd DELIM 2667138',
#  'TYPE DELIM generickd DELIM 2041070',
#  'TYPE DELIM generickd DELIM 2154154',
#  'application DELIM bundler DELIM softpulse DELIM d',
#  'TYPE DELIM generickd DELIM 1364646',
#  'gen:variant DELIM ursnif DELIM 8',
#  'TYPE DELIM darkkomet DELIM f',
#  'deepscan:generic DELIM netTYPE DELIM fbb354ad',
#  'gen:variant DELIM strictor DELIM 57116',
#  'TYPE DELIM agent DELIM bjzr',
#  'TYPE DELIM packed DELIM 34849',
#  'gen:TYPE DELIM heur DELIM jp DELIM fu0@acmrqmok',
#  'deepscan:generic DELIM sdbot DELIM 1abbe8d9',
#  'generic DELIM poisonivy DELIM de4e5a9e',
#  'TYPE DELIM generic DELIM 221851',
#  'gen:variant DELIM kazy DELIM 158537',
#  'gen:TYPE DELIM heur DELIM 3kw@rtjlw2ogf',
#  'TYPE DELIM generic DELIM 13050471',
#  'TYPE DELIM generic DELIM 545289',
#  'TYPE DELIM generic DELIM 3306773',
#  'gen:variant DELIM banker DELIM 4',
#  'TYPE DELIM generickd DELIM 2423033',
#  'TYPE DELIM generic DELIM 2990223',
#  'gen:variant DELIM strictor DELIM 9331',
#  'gen:variant DELIM kazy DELIM 399194',
#  'gen:TYPE DELIM heur2 DELIM gz DELIM ngz@b8cauyji',
#  'gen:variant DELIM razy DELIM 49291',
#  'gen:TYPE DELIM heur DELIM vb DELIM cm0@cul788oi',
#  'gen:variant DELIM symmi DELIM 54525',
#  'TYPE DELIM generic DELIM 17946456',
#  'TYPE DELIM TYPE DELIM bho DELIM a',
#  'application DELIM downloader DELIM ys',
#  'generic DELIM malware DELIM sfdld! DELIM fe79da72',
#  'application DELIM generic DELIM 602217',
#  'gen:variant DELIM zusy DELIM 53782',
#  'application DELIM elex DELIM n',
#  'TYPE DELIM generic DELIM 1704339',
#  'gen:TYPE DELIM heur DELIM rp DELIM amw@ayzdvyf',
#  'TYPE DELIM generickd DELIM 1627799',
#  'TYPE DELIM generickd DELIM 963301',
#  'TYPE DELIM PLAT DELIM bom',
#  'application DELIM bundler DELIM morstar DELIM g',
#  'TYPE DELIM agentwdcr DELIM gxp',
#  'TYPE DELIM generickd DELIM 1491957',
#  'TYPE DELIM generickd DELIM 2200370',
#  'TYPE DELIM generic DELIM 4103909',
#  'gen:variant DELIM razy DELIM 74889',
#  'gen:variant DELIM kazy DELIM 224923',
#  'TYPE DELIM generic DELIM kd DELIM 6355',
#  'TYPE DELIM generic DELIM 7556',
#  'TYPE DELIM generic DELIM 11870553',
#  'TYPE DELIM generickd DELIM 2395194',
#  'TYPE DELIM TYPE DELIM fanet DELIM a',
#  'gen:variant DELIM graftor DELIM 108672',
#  'TYPE DELIM generic DELIM 8258550',
#  'TYPE DELIM generic DELIM 13123366',
#  'gen:variant DELIM kazy DELIM 187599',
#  'gen:variant DELIM symmi DELIM 8490',
#  'TYPE DELIM pFAM DELIM vb DELIM s',
#  'TYPE DELIM generic DELIM 11563011',
#  'gen:TYPE DELIM heur DELIM dmkfrxhk91eaz',
#  'TYPE DELIM generic DELIM 3588161',
#  'gen:variant DELIM symmi DELIM 16042',
#  'gen:variant DELIM kazy DELIM 348687',
#  'TYPE DELIM generic DELIM 8970648',
#  'gen:variant DELIM zusy DELIM 63239',
#  'TYPE DELIM generic DELIM 12787748',
#  'gen:variant DELIM zusy DELIM 85225',
#  'memscan:TYPE DELIM FAM DELIM bw',
#  'gen:PLAT DELIM fileinfector DELIM aqx@agfigee',
#  'gen:variant DELIM sirefef DELIM 480',
#  'TYPE DELIM generic DELIM kd DELIM 261298',
#  'gen:variant DELIM msilperseus DELIM 7042',
#  'gen:variant DELIM sirefef DELIM 956',
#  'gen:variant DELIM kazy DELIM 322328',
#  'TYPE DELIM generic DELIM 2098502',
#  'TYPE DELIM generic DELIM 359272',
#  'gen:variant DELIM kazy DELIM 128180',
#  'gen:variant DELIM strictor DELIM 28723',
#  'gen:TYPE DELIM heur DELIM rp DELIM pzw@aki8zydi',
#  'generic DELIM malware DELIM dld!! DELIM 94d737ad',
#  'TYPE DELIM generic DELIM 15250403',
#  'TYPE DELIM generickd DELIM 2566877',
#  'gen:variant DELIM kazy DELIM 473976',
#  'dropped:generic DELIM malware DELIM fdld DELIM 81f02844',
#  'TYPE DELIM generickd DELIM 1975067',
#  'gen:application DELIM heur DELIM 2v1@mwocqvfo',
#  'TYPE DELIM pakes DELIM uv',
#  'TYPE DELIM generickd DELIM 1215423',
#  'application DELIM bitcoinminer DELIM be',
#  'gen:variant DELIM zusy DELIM 134813',
#  'TYPE DELIM generic DELIM 11937778',
#  'TYPE DELIM generickd DELIM 1669777',
#  'TYPE DELIM generickd DELIM 3390691',
#  'gen:variant DELIM graftor DELIM 29747',
#  'gen:TYPE DELIM heur DELIM rp DELIM aqw@ay566if',
#  'gen:variant DELIM symmi DELIM 31500',
#  'application DELIM agent DELIM hn',
#  'gen:variant DELIM kazy DELIM 234226',
#  'gen:variant DELIM symmi DELIM 37769',
#  'TYPE DELIM vb DELIM amf',
#  'deepscan:generic DELIM spy DELIM bank DELIM zwq DELIM 1f409eac',
#  'gen:variant DELIM razy DELIM 61485',
#  'gen:TYPE DELIM heur DELIM mr DELIM 8rz@agqdr4pc',
#  'TYPE DELIM generickd DELIM 1466020',
#  'TYPE DELIM TYPE DELIM qqpass DELIM bo',
#  'TYPE DELIM generic DELIM 357584',
#  'TYPE DELIM generic DELIM kdv DELIM 150325',
#  'gen:variant DELIM graftor DELIM 179242',
#  'TYPE DELIM generic DELIM kdv DELIM 127769',
#  'gen:TYPE DELIM heur DELIM bg8@rwn1z4ji',
#  'gen:TYPE DELIM heur DELIM lp DELIM qz5aa8nro5gi',
#  'TYPE DELIM downloader DELIM banload DELIM avh',
#  'TYPE DELIM generic DELIM 210672',
#  'TYPE DELIM crypt DELIM ds',
#  'TYPE DELIM injector DELIM bng',
#  'TYPE DELIM generickd DELIM 2003816',
#  'TYPE DELIM generic DELIM 11277090',
#  'TYPE DELIM generic DELIM 6712014',
#  'TYPE DELIM TYPE DELIM pornoblocker DELIM l',
#  'TYPE DELIM generic DELIM 1486442',
#  'TYPE DELIM agent DELIM 4163',
#  'TYPE DELIM generickd DELIM 3416016',
#  'TYPE DELIM generic DELIM 418763',
#  'generic DELIM pwstealer DELIM 703361b4',
#  'gen:variant DELIM TYPE DELIM graftor DELIM 131371',
#  'TYPE DELIM generic DELIM 14798968',
#  'TYPE DELIM generic DELIM 8500555',
#  'TYPE DELIM downloader DELIM banload DELIM ats',
#  'TYPE DELIM bo2k DELIM plugin DELIM bored',
#  'gen:TYPE DELIM heur DELIM rp DELIM dwwbag7v!5',
#  'gen:variant DELIM zusy DELIM 171393',
#  'gen:variant DELIM zusy DELIM 84433',
#  'TYPE DELIM generickd DELIM 2869375',
#  'TYPE DELIM generic DELIM 187573',
#  'gen:variant DELIM razy DELIM 5348',
#  'TYPE DELIM generic DELIM kdv DELIM 204276',
#  'TYPE DELIM generic DELIM 9635306',
#  'gen:variant DELIM graftor DELIM 73196',
#  'TYPE DELIM dipass DELIM a',
#  'gen:variant DELIM kazy DELIM 140193',
#  'TYPE DELIM FAM DELIM new',
#  'gen:variant DELIM symmi DELIM 3345',
#  'gen:variant DELIM zusy DELIM 90696',
#  'generic DELIM malware DELIM sp!cpkg DELIM 0d06984b',
#  'TYPE DELIM generic DELIM 1443308',
#  'gen:variant DELIM symmi DELIM 39462',
#  'gen:variant DELIM kazy DELIM 507665',
#  'gen:variant DELIM kazy DELIM 498476',
#  'generic DELIM malware DELIM sl! DELIM 4e771bcd',
#  'gen:application DELIM heur DELIM dmkfbsdeayao',
#  'TYPE DELIM generic DELIM 2533344',
#  'TYPE DELIM generic DELIM 16404024',
#  'TYPE DELIM bot DELIM 87201',
#  'gen:variant DELIM graftor DELIM 64417',
#  'generic DELIM pwstealer DELIM f67debc3',
#  'gen:variant DELIM kazy DELIM 171012',
#  'TYPE DELIM generickd DELIM 2499047',
#  'gen:variant DELIM zusy DELIM 170651',
#  'dropped:generic DELIM malware DELIM dld! DELIM 85a5620d',
#  'TYPE DELIM downloader DELIM banload DELIM oev',
#  'TYPE DELIM generic DELIM 3878188',
#  'gen:variant DELIM kazy DELIM 224568',
#  'TYPE DELIM downloader DELIM FAM DELIM doy',
#  'gen:TYPE DELIM heur DELIM zp DELIM 52a94408',
#  'gen:variant DELIM kazy DELIM 551665',
#  'TYPE DELIM generic DELIM kdv DELIM 881902',
#  'TYPE DELIM generic DELIM kd DELIM 896651',
#  'gen:variant DELIM kazy DELIM 553827',
#  'TYPE DELIM generickd DELIM 2046490',
#  'dropped:TYPE DELIM generic DELIM 5153364',
#  'TYPE DELIM generickd DELIM 2630105',
#  'gen:variant DELIM graftor DELIM 70844',
#  'TYPE DELIM generickd DELIM 1939222',
#  'gen:variant DELIM kazy DELIM 319158',
#  'TYPE DELIM generickd DELIM 2641576',
#  'TYPE DELIM generickd DELIM 1437500',
#  'TYPE DELIM generic DELIM 4430145',
#  'gen:variant DELIM strictor DELIM 101650',
#  'TYPE DELIM spy DELIM banker DELIM vb DELIM i',
#  'TYPE DELIM generic DELIM kdv DELIM 269180',
#  'TYPE DELIM generic DELIM 15974044',
#  'TYPE DELIM generic DELIM 1625931',
#  'TYPE DELIM generic DELIM 14553191',
#  'application DELIM generic DELIM 909577',
#  'gen:variant DELIM graftor DELIM 170280',
#  'TYPE DELIM generic DELIM kdv DELIM 403032',
#  'gen:TYPE DELIM heur DELIM cix@rj0g!ud',
#  'gen:variant DELIM strictor DELIM 63036',
#  'gen:variant DELIM barys DELIM 51267',
#  'TYPE DELIM generic DELIM 44424',
#  'TYPE DELIM generic DELIM 215739',
#  'gen:variant DELIM graftor DELIM 101159',
#  'TYPE DELIM packed DELIM 25109',
#  'TYPE DELIM agent DELIM bche',
#  'TYPE DELIM generickd DELIM 3363181',
#  'TYPE DELIM bitcoinminer DELIM ae',
#  'gen:variant DELIM zusy DELIM 79973',
#  'TYPE DELIM generickd DELIM 2247716',
#  'TYPE DELIM generickdz DELIM 21212',
#  'TYPE DELIM generickd DELIM 2275908',
#  'TYPE DELIM generickd DELIM 2245959',
#  'dropped:TYPE DELIM generickd DELIM 2443387',
#  'gen:variant DELIM application DELIM bundler DELIM domaiq DELIM 12',
#  'gen:variant DELIM symmi DELIM 41461',
#  'gen:variant DELIM kazy DELIM 490288',
#  'TYPE DELIM agent DELIM bhyl',
#  'TYPE DELIM script DELIM 8495',
#  'TYPE DELIM 10847',
#  'TYPE DELIM generickdv DELIM 1058186',
#  'TYPE DELIM generickd DELIM 2598614',
#  'generic DELIM pwstealer DELIM 82bc01ec',
#  'TYPE DELIM generickd DELIM 3494791',
#  'generic DELIM malware DELIM sl!! DELIM 6864c164',
#  'gen:TYPE DELIM heur DELIM jp DELIM fqw@as481bbb',
#  'TYPE DELIM generickd DELIM 1953779',
#  'TYPE DELIM FAM DELIM ecx',
#  'gen:variant DELIM symmi DELIM 39320',
#  'TYPE DELIM redosdru DELIM l',
#  'gen:variant DELIM graftor DELIM 132013',
#  'gen:variant DELIM TYPE DELIM kazy DELIM 622347',
#  'TYPE DELIM generic DELIM 14636693',
#  'gen:TYPE DELIM heur DELIM bgw@tfycjrnaf',
#  'TYPE DELIM generickd DELIM 2321025',
#  'TYPE DELIM generic DELIM 5382315',
#  'gen:TYPE DELIM heur DELIM kt DELIM 4 DELIM ku5@ack1dhdi',
#  'gen:variant DELIM barys DELIM 21566',
#  'TYPE DELIM crypt DELIM delf DELIM k',
#  'gen:variant DELIM jaik DELIM 11262',
#  'TYPE DELIM generickd DELIM 1661371',
#  'gen:variant DELIM symmi DELIM 29296',
#  'TYPE DELIM gamarue DELIM cj',
#  'generic DELIM banker DELIM delf DELIM 2dace8c3',
#  'TYPE DELIM generickd DELIM 2227646',
#  'gen:variant DELIM mikey DELIM 22144',
#  'TYPE DELIM generic DELIM kd DELIM 115038',
#  'PLAT DELIM klez DELIM a@mm',
#  'TYPE DELIM generic DELIM 1467461',
#  'gen:TYPE DELIM heur DELIM d DELIM dmhfbsnqybd',
#  'gen:TYPE DELIM heur DELIM rp DELIM quz@aiiuc5kk',
#  'gen:variant DELIM kazy DELIM 619457',
#  'gen:variant DELIM razy DELIM 7321',
#  'TYPE DELIM generickd DELIM 3163041',
#  'TYPE DELIM dropper DELIM FAM DELIM nbz',
#  'gen:TYPE DELIM heur2 DELIM gz DELIM 6ywabwwj19f',
#  'TYPE DELIM generickd DELIM 1867065',
#  'TYPE DELIM generic DELIM 6830148',
#  'gen:variant DELIM kazy DELIM 613116',
#  'TYPE DELIM generic DELIM 2520344',
#  'TYPE DELIM generic DELIM 2678203',
#  'TYPE DELIM generickd DELIM 3105806',
#  'TYPE DELIM generickd DELIM 2266221',
#  'gen:variant DELIM barys DELIM 884',
#  'TYPE DELIM generic DELIM 5587871',
#  'TYPE DELIM generickd DELIM 1855600',
#  'gen:variant DELIM kazy DELIM 259817',
#  'gen:variant DELIM graftor DELIM elzob DELIM 84',
#  'TYPE DELIM generickd DELIM 1668327',
#  'gen:TYPE DELIM heur DELIM vp DELIM em0@aatpvejb',
#  'TYPE DELIM generickd DELIM 1764204',
#  'TYPE DELIM generic DELIM 14736041',
#  'gen:variant DELIM jaik DELIM 1383',
#  'gen:variant DELIM kazy DELIM 135620',
#  'gen:TYPE DELIM heur DELIM fu DELIM sqw@ambiwtib',
#  'TYPE DELIM agent DELIM bczo',
#  'gen:variant DELIM symmi DELIM 67189',
#  'generic DELIM rebhip DELIM 33744faa',
#  'PLAT DELIM TYPE DELIM generic DELIM 7832',
#  'TYPE DELIM generic DELIM 1408725',
#  'TYPE DELIM generickdz DELIM 21837',
#  'gen:variant DELIM kazy DELIM 409318',
#  'gen:variant DELIM graftor DELIM 126236',
#  'TYPE DELIM agent DELIM bizv',
#  'TYPE DELIM generic DELIM 1743179',
#  'TYPE DELIM hupigon DELIM 18276',
#  'TYPE DELIM generickd DELIM 2399977',
#  'generic DELIM malware DELIM smdldg DELIM 6c2ad345',
#  'gen:variant DELIM kazy DELIM 385349',
#  'TYPE DELIM generic DELIM 11272993',
#  'TYPE DELIM vb DELIM aig',
#  'gen:TYPE DELIM heur DELIM em0@xamyctmb',
#  'TYPE DELIM generic DELIM kdv DELIM 575619',
#  'TYPE DELIM generickd DELIM 3104300',
#  'TYPE DELIM generic DELIM 1781679',
#  'TYPE DELIM generickd DELIM 2529984',
#  'TYPE DELIM generickd DELIM 3548296',
#  'TYPE DELIM agent DELIM bcgz',
#  'TYPE DELIM generic DELIM 2837373',
#  'gen:variant DELIM symmi DELIM 27433',
#  'TYPE DELIM generickd DELIM 1710969',
#  'rootkit DELIM 4731',
#  'TYPE DELIM generickd DELIM 1043001',
#  'TYPE DELIM generic DELIM 13188518',
#  'TYPE DELIM TYPE DELIM eg',
#  'TYPE DELIM generic DELIM kd DELIM 209510',
#  'TYPE DELIM downloader DELIM delf DELIM om',
#  'gen:variant DELIM vundo DELIM 7',
#  'TYPE DELIM generic DELIM 11311827',
#  'gen:variant DELIM kazy DELIM 507946',
#  'gen:variant DELIM zusy DELIM 107927',
#  'TYPE DELIM generic DELIM 12863675',
#  'gen:variant DELIM graftor DELIM 135834',
#  'TYPE DELIM generic DELIM 961918',
#  'generic DELIM TYPE DELIM 2 DELIM 25d1aff5',
#  'gen:TYPE DELIM heur DELIM FAM DELIM hm3@cce7gnm',
#  'generic DELIM malware DELIM syn!!bdq!wg DELIM 9918a6ff',
#  'TYPE DELIM dropper DELIM delf DELIM crypt DELIM b',
#  'TYPE DELIM generic DELIM 10493063',
#  'TYPE DELIM generickd DELIM 1660481',
#  'gen:TYPE DELIM heur DELIM ii0@rzila6lod',
#  'TYPE DELIM generic DELIM 4897257',
#  'gen:TYPE DELIM heur DELIM vp2 DELIM amkfaspzjhei',
#  'TYPE DELIM generickd DELIM 2017168',
#  'TYPE DELIM generickd DELIM 2324750',
#  'TYPE DELIM generic DELIM 4425786',
#  'gen:variant DELIM symmi DELIM 26172',
#  'genpack:TYPE DELIM bot DELIM 128260',
#  'TYPE DELIM generickd DELIM 2897162',
#  'gen:variant DELIM barys DELIM 54782',
#  'TYPE DELIM generic DELIM 12661772',
#  'gen:variant DELIM kazy DELIM 312104',
#  'TYPE DELIM TYPE DELIM deathmin DELIM a',
#  'gen:variant DELIM symmi DELIM 25443',
#  'gen:variant DELIM kazy DELIM 575477',
#  'gen:variant DELIM TYPE DELIM strictor DELIM 43537',
#  'deepscan:generic DELIM malware DELIM sl!! DELIM bd299a2e',
#  'TYPE DELIM generic DELIM 422063',
#  'TYPE DELIM generic DELIM 2076692',
#  'gen:variant DELIM strictor DELIM 103167',
#  'TYPE DELIM generickdv DELIM 1378632',
#  'application DELIM hackTYPE DELIM gm',
#  'TYPE DELIM generic DELIM 15475764',
#  'gen:variant DELIM zusy DELIM 139738',
#  'gen:heur DELIM conjar DELIM 5',
#  'gen:TYPE DELIM heur DELIM vp DELIM mm0@amagyshc',
#  'TYPE DELIM agent DELIM befc',
#  'TYPE DELIM generickd DELIM 2772594',
#  'gen:TYPE DELIM heur2 DELIM lvp DELIM ad0@ag@pytn',
#  'TYPE DELIM generickd DELIM 3455014',
#  'gen:variant DELIM graftor DELIM 299520',
#  'TYPE DELIM krypt DELIM al',
#  'gen:TYPE DELIM heur DELIM ayw@!lwmiooi',
#  'TYPE DELIM generickd DELIM 2903592',
#  'TYPE DELIM generickd DELIM 1325138',
#  'TYPE DELIM pushdo DELIM d',
#  'TYPE DELIM generickd DELIM 1672076',
#  'TYPE DELIM vb DELIM hw',
#  'TYPE DELIM generic DELIM 12350664',
#  'TYPE DELIM generic DELIM kd DELIM 696991',
#  'TYPE DELIM generic DELIM kdv DELIM 667697',
#  'gen:variant DELIM mikey DELIM 12692',
#  'TYPE DELIM generic DELIM kdz DELIM 10016',
#  'TYPE DELIM generickdz DELIM 15002',
#  'TYPE DELIM generickdz DELIM 20496',
#  'gen:variant DELIM zusy DELIM 60373',
#  'TYPE DELIM fakealert DELIM po',
#  'gen:TYPE DELIM heur DELIM rp DELIM md0@awbtsnii',
#  'TYPE DELIM generickd DELIM 1785453',
#  'gen:variant DELIM application DELIM bundler DELIM softpulse DELIM 3',
#  'TYPE DELIM generic DELIM 180367',
#  'gen:variant DELIM graftor DELIM 293939',
#  'gen:TYPE DELIM downloader DELIM ngw@au8346k',
#  'dropped:generic DELIM rebhip DELIM e9a4aafe',
#  'TYPE DELIM generic DELIM 9051058',
#  'TYPE DELIM generic DELIM 1307815',
#  'gen:variant DELIM strictor DELIM 27662',
#  'TYPE DELIM generickdz DELIM 21762',
#  'TYPE DELIM agent DELIM ajfw',
#  'gen:variant DELIM graftor DELIM 259360',
#  'gen:variant DELIM graftor DELIM 36704',
#  'TYPE DELIM generic DELIM 15631605',
#  'TYPE DELIM generic DELIM 11307853',
#  'TYPE DELIM generickd DELIM 2014922',
#  'gen:variant DELIM symmi DELIM 2186',
#  'gen:variant DELIM zusy DELIM 194934',
#  'gen:variant DELIM delf DELIM 241',
#  'gen:variant DELIM kazy DELIM 275837',
#  'TYPE DELIM generic DELIM 955252',
#  'gen:variant DELIM kazy DELIM 199244',
#  'TYPE DELIM agent DELIM bleq',
#  'gen:variant DELIM graftor DELIM 16821',
#  'TYPE DELIM dropper DELIM delf DELIM abz',
#  'gen:variant DELIM graftor DELIM 73665',
#  'TYPE DELIM generic DELIM 676058',
#  'gen:PLAT DELIM explorerhijack DELIM wmofaci0knjo',
#  'gen:TYPE DELIM heur DELIM pk0@reg2ifps',
#  'TYPE DELIM agent DELIM bijj',
#  'gen:variant DELIM graftor DELIM 130681',
#  'TYPE DELIM generickd DELIM 2215267',
#  'gen:variant DELIM graftor DELIM 120460',
#  'gen:variant DELIM kazy DELIM 362734',
#  'gen:variant DELIM graftor DELIM 80913',
#  'gen:variant DELIM zusy DELIM 42775',
#  'generic DELIM malware DELIM sdld!! DELIM fb0fba5a',
#  'gen:variant DELIM symmi DELIM 31972',
#  'TYPE DELIM generickd DELIM 2304109',
#  'TYPE DELIM spy DELIM finanz DELIM q',
#  'TYPE DELIM agent DELIM boax',
#  'gen:variant DELIM kazy DELIM 498617',
#  'TYPE DELIM generic DELIM 12460962',
#  'TYPE DELIM generickd DELIM 3178914',
#  'TYPE DELIM generic DELIM 2168169',
#  'generic DELIM malware DELIM smg DELIM 66968c64',
#  'gen:TYPE DELIM packed DELIM heur DELIM digeibejukm',
#  'memscan:TYPE DELIM FAM DELIM aacv',
#  'generic DELIM malware DELIM p!dldpk! DELIM 3b4c8a4d',
#  'dropped:TYPE DELIM agent DELIM brml',
#  'gen:variant DELIM zusy DELIM 92247',
#  'gen:variant DELIM graftor DELIM 271187',
#  'gen:TYPE DELIM heur2 DELIM @xy@isjcu7g',
#  'gen:variant DELIM zusy DELIM 80438',
#  'TYPE DELIM vb DELIM alk',
#  'TYPE DELIM generic DELIM 1310064',
#  'TYPE DELIM generic DELIM 14486809',
#  'gen:variant DELIM razy DELIM 11021',
#  'gen:variant DELIM graftor DELIM 269175',
#  'gen:TYPE DELIM heur DELIM pxnfrpvtvfoib',
#  'gen:variant DELIM graftor DELIM 139998',
#  'TYPE DELIM generickd DELIM 2418428',
#  'gen:variant DELIM kazy DELIM 309965',
#  'TYPE DELIM generickd DELIM 2717130',
#  'generic DELIM malware DELIM sf DELIM f3ba6a8a',
#  'TYPE DELIM generickd DELIM 1660729',
#  'PLAT DELIM TYPE DELIM FAM DELIM gen',
#  'gen:TYPE DELIM heur DELIM em0@xg0pieeo',
#  'TYPE DELIM generic DELIM kdv DELIM 908587',
#  'gen:variant DELIM strictor DELIM 62079',
#  'TYPE DELIM generickd DELIM 2293397',
#  'gen:variant DELIM kazy DELIM 53579',
#  'gen:variant DELIM symmi DELIM 49160',
#  'generic DELIM sdbot DELIM e58192a9',
#  'generic DELIM sdbot DELIM 80dc9e0e',
#  'TYPE DELIM generic DELIM 1248877',
#  'TYPE DELIM teslacrypt DELIM ck',
#  'gen:variant DELIM zusy DELIM 74228',
#  'TYPE DELIM generic DELIM 8790456',
#  'deepscan:generic DELIM malware DELIM dld!! DELIM 14d0cffd',
#  'gen:TYPE DELIM downloader DELIM cmw@a4g8swd',
#  'gen:variant DELIM mikey DELIM 26804',
#  'TYPE DELIM generickd DELIM 3031748',
#  'gen:variant DELIM application DELIM bundler DELIM 88',
#  'TYPE DELIM hupigon DELIM cbf',
#  'TYPE DELIM generic DELIM 11268467',
#  'generic DELIM malware DELIM fwx! DELIM 24fc1842',
#  'gen:variant DELIM graftor DELIM 115365',
#  'gen:variant DELIM upatre DELIM 2',
#  'generic DELIM PLAT DELIM bladabindi DELIM 1aa9fc64',
#  'TYPE DELIM generic DELIM 444207',
#  'gen:variant DELIM barys DELIM 7898',
#  'gen:variant DELIM graftor DELIM elzob DELIM 12605',
#  'TYPE DELIM generickd DELIM 2573050',
#  'TYPE DELIM agent DELIM blcg',
#  'TYPE DELIM generickdz DELIM 17562',
#  'TYPE DELIM injector DELIM bsb',
#  'TYPE DELIM generic DELIM 8726412',
#  'gen:variant DELIM downloader DELIM 167',
#  'gen:variant DELIM kazy DELIM 577146',
#  'TYPE DELIM generic DELIM 675326',
#  'gen:variant DELIM kazy DELIM 7277',
#  'gen:TYPE DELIM heur DELIM FAM DELIM mm3@c8mrxzci',
#  'generic DELIM PLAT DELIM bladabindi DELIM d600ec2d',
#  'TYPE DELIM generic DELIM 2568093',
#  'TYPE DELIM generic DELIM 11249898',
#  'gen:variant DELIM graftor DELIM elzob DELIM 20474',
#  'TYPE DELIM generic DELIM 2164369',
#  'TYPE DELIM generic DELIM 12345448',
#  'dropped:generic DELIM malware DELIM dld!! DELIM 7648d87f',
#  'gen:variant DELIM symmi DELIM 51597',
#  'TYPE DELIM generic DELIM 4488420',
#  'TYPE DELIM generickd DELIM 2904475',
#  'gen:variant DELIM symmi DELIM 19732',
#  'TYPE DELIM generic DELIM kdv DELIM 215687',
#  'generic DELIM pwstealer DELIM 2055e2ce',
#  'TYPE DELIM downloader DELIM jkpo',
#  'TYPE DELIM generickd DELIM 3037932',
#  'TYPE DELIM TYPE DELIM borger DELIM a',
#  'TYPE DELIM generickd DELIM 2537396',
#  'dropped:TYPE DELIM generic DELIM 579019',
#  'TYPE DELIM generic DELIM 405433',
#  'gen:TYPE DELIM heur DELIM rp DELIM sywbags785gb',
#  'gen:variant DELIM kazy DELIM 595471',
#  'TYPE DELIM downloader DELIM loadadv DELIM xxa',
#  'deepscan:generic DELIM banker DELIM delf DELIM d7470df2',
#  'gen:variant DELIM graftor DELIM 140918',
#  'gen:TYPE DELIM heur DELIM xuw@!t4pt4m',
#  'TYPE DELIM spy DELIM banker DELIM aczc',
#  'TYPE DELIM generickd DELIM 3067516',
#  'gen:variant DELIM symmi DELIM 39702',
#  'generic DELIM rebhip DELIM 662631f2',
#  'gen:variant DELIM barys DELIM 996',
#  'TYPE DELIM generickd DELIM 1604714',
#  'TYPE DELIM generic DELIM kdv DELIM 381266',
#  'gen:variant DELIM graftor DELIM 791',
#  'TYPE DELIM generic DELIM 11788033',
#  'gen:variant DELIM symmi DELIM 28852',
#  'gen:variant DELIM zusy DELIM 144693',
#  'gen:variant DELIM graftor DELIM 180321',
#  'gen:variant DELIM kazy DELIM 346079',
#  'TYPE DELIM agentwdcr DELIM cgs',
#  'TYPE DELIM generickd DELIM 1863284',
#  'TYPE DELIM generickd DELIM 2192644',
#  'gen:TYPE DELIM heur DELIM pyw@r1rxb7gay',
#  'gen:variant DELIM zusy DELIM 168224',
#  'TYPE DELIM generic DELIM 15342879',
#  'gen:variant DELIM jaik DELIM 9173',
#  'TYPE DELIM generickd DELIM 3081274',
#  'TYPE DELIM generickd DELIM 1130928',
#  'TYPE DELIM generic DELIM 11267933',
#  'TYPE DELIM TYPE DELIM zce',
#  'TYPE DELIM laserv DELIM b',
#  'gen:variant DELIM razy DELIM 14381',
#  'TYPE DELIM generickd DELIM 1457703',
#  'TYPE DELIM downloader DELIM ibill DELIM ai',
#  'TYPE DELIM generickdv DELIM 1038697',
#  'TYPE DELIM generickd DELIM 3230860',
#  'TYPE DELIM generickd DELIM 2446661',
#  'TYPE DELIM generic DELIM 12764031',
#  'dropped:TYPE DELIM keylogger DELIM agent DELIM o',
#  'TYPE DELIM generic DELIM 1291436',
#  'TYPE DELIM generickd DELIM 1585853',
#  'application DELIM generic DELIM 44713',
#  'gen:variant DELIM kazy DELIM 766896',
#  'gen:variant DELIM TYPE DELIM symmi DELIM 55978',
#  'TYPE DELIM agent DELIM bqtk',
#  'TYPE DELIM generic DELIM 11452949',
#  'gen:variant DELIM symmi DELIM 37620',
#  'TYPE DELIM generic DELIM 892267',
#  'dropped:TYPE DELIM agent DELIM bjye',
#  'gen:variant DELIM graftor DELIM 13439',
#  'TYPE DELIM downloader DELIM jqax',
#  'TYPE DELIM generickd DELIM 2018496',
#  'TYPE DELIM generickd DELIM 2563963',
#  'gen:variant DELIM kazy DELIM 666772',
#  'TYPE DELIM generickd DELIM 1595463',
#  'gen:variant DELIM zusy DELIM 151813',
#  'genpack:generic DELIM malware DELIM sbdldg DELIM 543a053c',
#  'TYPE DELIM TYPE DELIM aiu',
#  'gen:TYPE DELIM packed DELIM heur DELIM dioeixt@8e',
#  'gen:variant DELIM symmi DELIM 44917',
#  'TYPE DELIM generic DELIM 12311832',
#  'TYPE DELIM generickd DELIM 2906160',
#  'gen:TYPE DELIM heur DELIM dkw@rxmmrligd',
#  'application DELIM crack DELIM pei',
#  'deepscan:generic DELIM FAM DELIM 12 DELIM d6903d4b',
#  'gen:variant DELIM zusy DELIM 62323',
#  'TYPE DELIM graybr DELIM mh',
#  'gen:variant DELIM kazy DELIM 625953',
#  'gen:TYPE DELIM heur DELIM au0@stigyxtay',
#  'gen:variant DELIM zusy DELIM 121991',
#  'TYPE DELIM generic DELIM 6711451',
#  'gen:TYPE DELIM heur DELIM jp DELIM oyw@acsyz0p',
#  'TYPE DELIM generickd DELIM 2731053',
#  'gen:TYPE DELIM heur DELIM fu DELIM guw@aqvaivp',
#  'gen:variant DELIM kazy DELIM 737219',
#  'gen:variant DELIM graftor DELIM 182989',
#  'gen:variant DELIM graftor DELIM 101673',
#  'gen:variant DELIM razy DELIM 16934',
#  'TYPE DELIM generic DELIM 282115',
#  'gen:variant DELIM fakeinit DELIM 1',
#  'TYPE DELIM generic DELIM 415691',
#  'gen:variant DELIM barys DELIM 52427',
#  'generic DELIM keylogger DELIM 3 DELIM f7dc5768',
#  'TYPE DELIM generickd DELIM 1661250',
#  'PLAT DELIM FAM DELIM 477',
#  'TYPE DELIM generickd DELIM 3368218',
#  'TYPE DELIM TYPE DELIM msn DELIM faker DELIM a',
#  'TYPE DELIM generickd DELIM 3458337',
#  'gen:variant DELIM strictor DELIM 98542',
#  'TYPE DELIM bot DELIM 75178',
#  'TYPE DELIM generickd DELIM 1677052',
#  'gen:variant DELIM symmi DELIM 34773',
#  'TYPE DELIM generic DELIM 15012774',
#  'TYPE DELIM generickd DELIM 3027682',
#  'gen:variant DELIM kazy DELIM 180084',
#  'gen:variant DELIM TYPE DELIM symmi DELIM 39559',
#  'gen:variant DELIM rimecud DELIM 10',
#  'TYPE DELIM generickd DELIM 2473470',
#  'gen:variant DELIM jaik DELIM 8062',
#  'TYPE DELIM generickd DELIM 2918241',
#  'gen:variant DELIM zusy DELIM 168065',
#  'application DELIM hackTYPE DELIM vncpass DELIM a',
#  'TYPE DELIM generic DELIM 1248945',
#  'TYPE DELIM generickd DELIM 1148866',
#  'gen:variant DELIM kazy DELIM 227328',
#  'generic DELIM lmir DELIM e16a9915',
#  'TYPE DELIM generic DELIM 4876800',
#  'gen:variant DELIM msilperseus DELIM 46185',
#  'TYPE DELIM generic DELIM 1183193',
#  'TYPE DELIM generic DELIM 8803396',
#  'TYPE DELIM agent DELIM aij',
#  'TYPE DELIM downloader DELIM delf DELIM ade',
#  'gen:variant DELIM kazy DELIM 556866',
#  'TYPE DELIM generickd DELIM 1969468',
#  'gen:variant DELIM zusy DELIM 20332',
#  'TYPE DELIM PLAT DELIM agent DELIM ags',
#  'gen:variant DELIM symmi DELIM 54088',
#  'gen:variant DELIM graftor DELIM 187262',
#  'TYPE DELIM generickd DELIM 3241983',
#  'TYPE DELIM generickd DELIM 2037070',
#  'TYPE DELIM dropper DELIM agent DELIM tnb',
#  'gen:variant DELIM razy DELIM 96246',
#  'gen:variant DELIM zusy DELIM 77453',
#  'gen:variant DELIM zusy DELIM 43750',
#  'gen:variant DELIM graftor DELIM 145138',
#  'gen:variant DELIM strictor DELIM 8749',
#  'gen:variant DELIM kazy DELIM 676592',
#  'memscan:TYPE DELIM generic DELIM kdv DELIM 147777',
#  'TYPE DELIM vb DELIM ii',
#  'TYPE DELIM fakealert DELIM blf',
#  'gen:variant DELIM graftor DELIM 137651',
#  'TYPE DELIM generickd DELIM 1711472',
#  'TYPE DELIM generic DELIM 111170',
#  'TYPE DELIM generickd DELIM 2990357',
#  'TYPE DELIM generic DELIM 7061348',
#  'gen:variant DELIM msilperseus DELIM 30942',
#  'gen:packer DELIM rcryptor DELIM ycgbaseonypj',
#  'gen:variant DELIM TYPE DELIM mplug DELIM 36',
#  'gen:variant DELIM razy DELIM 37984',
#  'TYPE DELIM generickd DELIM 2111897',
#  'TYPE DELIM generickd DELIM 1654368',
#  'TYPE DELIM downloader DELIM jkdb',
#  'gen:variant DELIM FAM DELIM 79',
#  'gen:variant DELIM graftor DELIM 261909',
#  'gen:variant DELIM kazy DELIM 599065',
#  'TYPE DELIM generickd DELIM 2758634',
#  'TYPE DELIM agent DELIM bkej',
#  'TYPE DELIM generic DELIM 2614658',
#  'TYPE DELIM generickd DELIM 1912076',
#  'gen:variant DELIM kazy DELIM 210418',
#  'gen:variant DELIM kazy DELIM 293843',
#  'TYPE DELIM generic DELIM kdz DELIM 225',
#  'TYPE DELIM generickd DELIM 2280641',
#  'TYPE DELIM generic DELIM 7328509',
#  'TYPE DELIM generic DELIM 714721',
#  'gen:variant DELIM strictor DELIM 81461',
#  'TYPE DELIM generickd DELIM 2168721',
#  'generic DELIM banker DELIM delf DELIM dddd32e3',
#  'TYPE DELIM generickd DELIM 3182578',
#  'TYPE DELIM generickd DELIM 3423279',
#  'TYPE DELIM generic DELIM 15805461',
#  'TYPE DELIM generic DELIM kdv DELIM 607304',
#  'TYPE DELIM generic DELIM 7419626',
#  'TYPE DELIM generic DELIM 7038374',
#  'memscan:application DELIM bundler DELIM outbrowse DELIM e',
#  'gen:variant DELIM kazy DELIM 267561',
#  'gen:variant DELIM kazy DELIM 467850',
#  'TYPE DELIM generic DELIM 5586503',
#  'TYPE DELIM generic DELIM 12354769',
#  'TYPE DELIM generic DELIM 887588',
#  'gen:TYPE DELIM heur DELIM rp DELIM cmw@ayzvx1',
#  'gen:variant DELIM strictor DELIM 102497',
#  'TYPE DELIM generic DELIM 49164',
#  'gen:TYPE DELIM heur DELIM vp DELIM em0@ayzjp1hi',
#  'gen:variant DELIM delf DELIM 200',
#  'ait:TYPE DELIM generictka DELIM 280',
#  'PLAT DELIM TYPE DELIM FAM DELIM gr',
#  'gen:TYPE DELIM trustedzone DELIM pkw@aukzr9jo',
#  'gen:variant DELIM zusy DELIM 189623',
#  'TYPE DELIM generickd DELIM 1699575',
#  'TYPE DELIM downloader DELIM jktz',
#  'TYPE DELIM generickd DELIM 3114061',
#  'gen:TYPE DELIM heur DELIM im0@svi5e5mih',
#  'gen:variant DELIM graftor DELIM elzob DELIM 7924',
#  'gen:variant DELIM kazy DELIM 754388',
#  'rootkit DELIM 28915',
#  'TYPE DELIM generickd DELIM 1603826',
#  'TYPE DELIM generic DELIM 310065',
#  'TYPE DELIM TYPE DELIM swz',
#  'TYPE DELIM generickd DELIM 3456522',
#  'TYPE DELIM generic DELIM 119302',
#  'TYPE DELIM generic DELIM 1976053',
#  'TYPE DELIM generickd DELIM 3254528',
#  'gen:TYPE DELIM heur2 DELIM gz DELIM ngz@bm8lvqhi',
#  'gen:PLAT DELIM PLAT DELIM TYPE DELIM buw@aefkojn',
#  'TYPE DELIM generickd DELIM 2597688',
#  'dropped:TYPE DELIM generic DELIM 1432657',
#  'gen:variant DELIM TYPE DELIM strictor DELIM 39137',
#  'TYPE DELIM generic DELIM 12071848',
#  'genpack:TYPE DELIM generic DELIM 230697',
#  'PLAT DELIM birich DELIM 44103',
#  'gen:TYPE DELIM heur DELIM lc3@xmypjnai',
#  'dropped:TYPE DELIM rootkit DELIM podnuha DELIM d',
#  'gen:TYPE DELIM heur DELIM s DELIM cew@ampq@ho',
#  'TYPE DELIM generic DELIM 11240480',
#  'TYPE DELIM generic DELIM 188508',
#  'TYPE DELIM agent DELIM bnye',
#  'gen:variant DELIM symmi DELIM 4138',
#  'generic DELIM malware DELIM sfdld DELIM d8f1d8ff',
#  'TYPE DELIM agentwdcr DELIM pq',
#  'TYPE DELIM generickd DELIM 1621893',
#  'gen:variant DELIM graftor DELIM 30851',
#  'gen:variant DELIM razy DELIM 78825',
#  'gen:variant DELIM graftor DELIM 120271',
#  'TYPE DELIM generic DELIM 4597612',
#  'gen:variant DELIM TYPE DELIM graftor DELIM 145143',
#  'TYPE DELIM generickdz DELIM 26359',
#  'TYPE DELIM generic DELIM 7379306',
#  'gen:TYPE DELIM heur DELIM dp DELIM oyw@aok@rkfc',
#  'TYPE DELIM generickd DELIM 2422104',
#  'deepscan:generic DELIM malware DELIM mpcpk DELIM 8427d007',
#  'TYPE DELIM dropper DELIM xbj',
#  'TYPE DELIM generickd DELIM 1932151',
#  'TYPE DELIM generickd DELIM 1568445',
#  'gen:variant DELIM graftor DELIM 23996',
#  'TYPE DELIM generic DELIM 11213152',
#  'TYPE DELIM generic DELIM 11143771',
#  'gen:variant DELIM zusy DELIM 196434',
#  'TYPE DELIM generic DELIM 15439723',
#  'gen:variant DELIM strictor DELIM 65989',
#  'TYPE DELIM generic DELIM 793520',
#  'gen:variant DELIM kazy DELIM 549873',
#  'gen:variant DELIM graftor DELIM 56044',
#  'TYPE DELIM TYPE DELIM avisa DELIM b',
#  'TYPE DELIM generic DELIM 8338369',
#  'TYPE DELIM generickd DELIM 3421157',
#  'TYPE DELIM generickd DELIM 1437632',
#  'gen:variant DELIM zusy DELIM 38624',
#  'TYPE DELIM generic DELIM 4038287',
#  'TYPE DELIM generic DELIM 6759809',
#  'TYPE DELIM generic DELIM 11453317',
#  'TYPE DELIM TYPE DELIM FAM DELIM ao',
#  'gen:variant DELIM kazy DELIM 653414',
#  'TYPE DELIM generickd DELIM 2587169',
#  'TYPE DELIM generickd DELIM 2824454',
#  'gen:variant DELIM kazy DELIM 339124',
#  'TYPE DELIM generic DELIM 12605698',
#  'TYPE DELIM generickd DELIM 2196224',
#  'gen:variant DELIM kazy DELIM 760625',
#  'TYPE DELIM generickd DELIM 3179376',
#  'application DELIM generic DELIM 1597892',
#  'generic DELIM banker DELIM vb DELIM 6db6c299',
#  'gen:variant DELIM symmi DELIM 25025',
#  'TYPE DELIM generickd DELIM 1994491',
#  'gen:variant DELIM graftor DELIM 298184',
#  'TYPE DELIM generickd DELIM 2693347',
#  'gen:variant DELIM graftor DELIM 164918',
#  'TYPE DELIM generickd DELIM 999134',
#  'gen:variant DELIM graftor DELIM 176923',
#  'TYPE DELIM bot DELIM 22372',
#  'dropped:generic DELIM malware DELIM fdldprn DELIM abb04fc1',
#  'gen:variant DELIM kazy DELIM 71931',
#  'gen:variant DELIM barys DELIM 7978',
#  'TYPE DELIM generic DELIM 272098',
#  'PLAT DELIM klez DELIM g@mm',
#  'gen:TYPE DELIM heur DELIM fhw@!l3w@2ji',
#  'dropped:TYPE DELIM generic DELIM 15406605',
#  'gen:variant DELIM kazy DELIM 309719',
#  'gen:variant DELIM symmi DELIM 30851',
#  'TYPE DELIM generic DELIM 15005250',
#  'TYPE DELIM generickd DELIM 2156291',
#  'gen:variant DELIM symmi DELIM 36675',
#  'gen:TYPE DELIM heur DELIM rp DELIM dqw@ayo7qk',
#  'TYPE DELIM generic DELIM 391984',
#  'TYPE DELIM generic DELIM 14754147',
#  'TYPE DELIM generickd DELIM 2505892',
#  'TYPE DELIM generic DELIM 357537',
#  'TYPE DELIM generickd DELIM 3131759',
#  'TYPE DELIM generickd DELIM 2160340',
#  'TYPE DELIM generickd DELIM 1683405',
#  'TYPE DELIM generickd DELIM 1713649',
#  'generic DELIM PLAT DELIM bladabindi DELIM 503e9ed8',
#  'TYPE DELIM generic DELIM 9504671',
#  'gen:variant DELIM kazy DELIM 356715',
#  'TYPE DELIM generic DELIM 705342',
#  'TYPE DELIM generickd DELIM 1491177',
#  'TYPE DELIM generic DELIM 3913297',
#  'gen:variant DELIM zbot DELIM 191',
#  'gen:variant DELIM kazy DELIM 530488',
#  'TYPE DELIM hupigon DELIM gs',
#  'gen:TYPE DELIM heur DELIM jp DELIM lyx@aw5ms7oi',
#  'gen:variant DELIM kazy DELIM 746315',
#  'TYPE DELIM spy DELIM zbot DELIM afb',
#  'gen:variant DELIM symmi DELIM 30493',
#  'gen:variant DELIM graftor DELIM 250106',
#  'gen:variant DELIM kazy DELIM 242675',
#  'gen:variant DELIM kazy DELIM 757736',
#  'gen:variant DELIM barys DELIM 5282',
#  'dropped:application DELIM generic DELIM 532921',
#  'gen:TYPE DELIM heur DELIM bez@rpoi5rfg2',
#  'dropped:application DELIM generic DELIM 1643718',
#  'gen:TYPE DELIM heur DELIM s DELIM umw@a82lshh',
#  'PLAT DELIM TYPE DELIM generic DELIM 2519',
#  'TYPE DELIM generic DELIM 15804754',
#  'PLAT DELIM TYPE DELIM incef DELIM a',
#  'gen:variant DELIM zusy DELIM 166015',
#  'TYPE DELIM banker DELIM mpz',
#  'gen:variant DELIM mikey DELIM 30588',
#  'gen:variant DELIM symmi DELIM 6917',
#  'memscan:TYPE DELIM generic DELIM 5781024',
#  'TYPE DELIM generickd DELIM 3408689',
#  'TYPE DELIM generic DELIM 864087',
#  'TYPE DELIM generic DELIM 13096630',
#  'TYPE DELIM generic DELIM 8887367',
#  'TYPE DELIM generic DELIM 1755944',
#  'gen:variant DELIM symmi DELIM 40991',
#  'TYPE DELIM generickd DELIM 2479072',
#  'gen:variant DELIM symmi DELIM 67036',
#  'application DELIM acespy DELIM a',
#  'gen:TYPE DELIM heur DELIM tdss DELIM iuw@buz9kkd',
#  'TYPE DELIM generickd DELIM 1688098',
#  'TYPE DELIM generic DELIM 11477071',
#  'gen:variant DELIM kazy DELIM 5652',
#  'gen:variant DELIM kazy DELIM 176566',
#  'gen:variant DELIM crypt DELIM 5',
#  'TYPE DELIM generickdz DELIM 17280',
#  'gen:variant DELIM symmi DELIM 2103',
#  'TYPE DELIM downloader DELIM agent DELIM ytn',
#  'TYPE DELIM generickd DELIM 2696053',
#  'gen:TYPE DELIM heur DELIM tdss DELIM iuw@boviauo',
#  'gen:variant DELIM strictor DELIM 650',
#  'TYPE DELIM generic DELIM 11838017',
#  'gen:variant DELIM symmi DELIM 61096',
#  'TYPE DELIM downloader DELIM delf DELIM aga',
#  'TYPE DELIM agent DELIM bden',
#  'gen:variant DELIM razy DELIM 43847',
#  'TYPE DELIM generic DELIM 894778',
#  'TYPE DELIM generickd DELIM 2912292',
#  'TYPE DELIM generic DELIM 949147',
#  'gen:variant DELIM kazy DELIM 186959',
#  'TYPE DELIM generic DELIM 273890',
#  'TYPE DELIM nsis DELIM agent DELIM bd',
#  'gen:variant DELIM application DELIM loadmoney DELIM 61',
#  'gen:TYPE DELIM heur DELIM ii0ardmr@ceiu',
#  'TYPE DELIM generickd DELIM 2780397',
#  'TYPE DELIM generic DELIM 740789',
#  'gen:variant DELIM kazy DELIM 289166',
#  'TYPE DELIM generickd DELIM 1653492',
#  'TYPE DELIM generickd DELIM 3525910',
#  'gen:variant DELIM symmi DELIM 49307',
#  'gen:variant DELIM kazy DELIM 562995',
#  'TYPE DELIM generickd DELIM 3152861',
#  'TYPE DELIM generic DELIM 748433',
#  'gen:variant DELIM symmi DELIM 32767',
#  'TYPE DELIM generic DELIM 12089974',
#  'TYPE DELIM generickd DELIM 1809150',
#  'TYPE DELIM generic DELIM 15267179',
#  'gen:variant DELIM kazy DELIM 169596',
#  'gen:variant DELIM strictor DELIM 6853',
#  'gen:variant DELIM cryptolocker DELIM 18',
#  'gen:variant DELIM kazy DELIM 187114',
#  'TYPE DELIM generickd DELIM 2327548',
#  'generic DELIM malware DELIM mpvpk DELIM 0ddc936f',
#  'TYPE DELIM generickd DELIM 2618956',
#  'dropped:TYPE DELIM generickd DELIM 2449212',
#  'gen:variant DELIM symmi DELIM 25768',
#  'TYPE DELIM generic DELIM 7529950',
#  'TYPE DELIM keylogger DELIM mxf',
#  'TYPE DELIM generic DELIM 11233186',
#  'gen:variant DELIM barys DELIM 2095',
#  'gen:variant DELIM symmi DELIM 14830',
#  'gen:variant DELIM zusy DELIM 158723',
#  'TYPE DELIM agent DELIM bmeo',
#  'gen:variant DELIM barys DELIM 277',
#  'TYPE DELIM generickd DELIM 1643265',
#  'TYPE DELIM spy DELIM agent DELIM nyq',
#  'dropped:generic DELIM malware DELIM btk DELIM 92342e09',
#  'gen:TYPE DELIM heur DELIM bm0@bzrldifi',
#  'TYPE DELIM generickd DELIM 1479711',
#  'TYPE DELIM generic DELIM 778534',
#  'TYPE DELIM generickd DELIM 2988262',
#  'TYPE DELIM generic DELIM 11209811',
#  'gen:variant DELIM kazy DELIM 393542',
#  'TYPE DELIM generickd DELIM 3183104',
#  'TYPE DELIM generic DELIM 9168529',
#  'gen:variant DELIM symmi DELIM 35871',
#  'dropped:TYPE DELIM pigeon DELIM axq',
#  'generic DELIM hupigon DELIM yqa DELIM 8c00601c',
#  'gen:variant DELIM symmi DELIM 3431',
#  'gen:malware DELIM heur DELIM hm0@bqpderfg',
#  'gen:TYPE DELIM heur DELIM gm DELIM 00004204a0',
#  'TYPE DELIM generickd DELIM 3467395',
#  'TYPE DELIM generickdz DELIM 20864',
#  'TYPE DELIM haxdoor DELIM lk',
#  'gen:TYPE DELIM heur DELIM jp DELIM qqw@ao7dkg',
#  'generic DELIM malware DELIM dld!! DELIM 64f75d1c',
#  'TYPE DELIM generic DELIM 357891',
#  'gen:variant DELIM graftor DELIM 129975',
#  'TYPE DELIM generickd DELIM 1511790',
#  'gen:TYPE DELIM heur DELIM dnp DELIM yo0@ayvfwxh',
#  'generic DELIM poisonivy DELIM 697695ef',
#  'TYPE DELIM generic DELIM kdz DELIM 7231',
#  'gen:variant DELIM TYPE DELIM graftor DELIM 174404',
#  'TYPE DELIM generickd DELIM 3384246',
#  'gen:variant DELIM barys DELIM 21306',
#  'PLAT DELIM doboc DELIM gen DELIM 2',
#  'TYPE DELIM injector DELIM avn',
#  'TYPE DELIM generickd DELIM 3490222',
#  'TYPE DELIM generic DELIM 11470028',
#  'gen:TYPE DELIM heur DELIM vb DELIM fu3@eeu84xdi',
#  'gen:variant DELIM graftor DELIM 113850',
#  'gen:variant DELIM zusy DELIM 76804',
#  'gen:variant DELIM kazy DELIM 739325',
#  'gen:variant DELIM kazy DELIM 44201',
#  'TYPE DELIM generic DELIM 8444697',
#  'TYPE DELIM generickd DELIM 3082353',
#  'TYPE DELIM agent DELIM bojr',
#  'TYPE DELIM generic DELIM kdv DELIM 922430',
#  'TYPE DELIM generickd DELIM 2323797',
#  'TYPE DELIM generickd DELIM 2657736',
#  'gen:TYPE DELIM heur DELIM rp DELIM sywbaactnggb',
#  'PLAT DELIM beefree DELIM 2110',
#  'gen:TYPE DELIM heur2 DELIM rp DELIM fqw@awlk25ei',
#  'gen:variant DELIM graftor DELIM 126822',
#  'gen:variant DELIM symmi DELIM 40119',
#  'gen:variant DELIM graftor DELIM 130888',
#  'gen:variant DELIM symmi DELIM 4971',
#  'TYPE DELIM generickd DELIM 2194003',
#  'TYPE DELIM generic DELIM 16093651',
#  'TYPE DELIM generic DELIM 3822185',
#  'TYPE DELIM generic DELIM 8576357',
#  'generic DELIM banker DELIM delf DELIM 58902641',
#  'PLAT DELIM elkern DELIM b',
#  'TYPE DELIM generic DELIM 9506943',
#  'gen:TYPE DELIM heur DELIM gz DELIM nnw@bknnlul',
#  'TYPE DELIM generickdz DELIM 18749',
#  'gen:variant DELIM barys DELIM 53081',
#  ...}

# %%
test = pe32_av[:10000]
test.fillna(' ', inplace=True)
trojan = ['trojan', 'troj']
generic = ['generic', 'genetic']
weird = ['not-a-virus']

names = []
for _, sample in test.iterrows():
    classification = ' '.join(sample[vendors].values)
    for trj in trojan:
        classification = classification.replace(trj, 'trj')
    classification
    for gen in generic:
        classification = classification.replace(gen, 'gen')
    for w in weird:
        classification = classification.replace(w, '')
    names.append(classification)

# vendors_naming = dict()
# for vendor in vendors:
#     vendors_naming[vendor] = np.unique(pe32_av[vendor])
# unique_names = np.unique(np.concatenate(list(vendors_naming.values())))

# %%
cv_token_pattern = r'\b[a-zA-Z]{3,}\b'
# cv_token_pattern = r'\b\w{3,}\b'
stop_words = ['clean', 'heuristic', 'variant', 'lookslike', 'suspicious', 'file', 'heur', 'malware',
              'behaveslike', 'win32', 'win', 'w32', 'gen', 'possible', 'threat', 'mal']
cv = CountVectorizer(token_pattern=cv_token_pattern, min_df=min_df, stop_words=stop_words, ngram_range=(2, 2))
cv.fit(names)

display(cv.get_feature_names())

# %%
first_vendor = pe32_av['kaspersky'].dropna()
first_vendor = first_vendor[first_vendor != 'clean']
display(first_vendor)

# %%
irrelevant = ['generic', 'gen']
mtype = ['email-worm', 'trojan-downloader', 'trojan', 'adware', 'worm', 'backdoor', 'ransom', 'dangerousobject',
        'trojan-dropper', 'virus']
# Sort by length so that longer matches are replaced first
mtype.sort(key=len, reverse=True)
platf = ['win32']
info = ['heur', 'uds', 'not-a-virus']
# func = ['downloader']
delim = re.compile(r'[^a-zA-Z0-9-]')
spaces= re.compile(r'\s+')

def tokenize(x):
    x = x.lower()
    
    tmp = x.split(':')
    if len(tmp) == 2:
        tmp[0] = 'INFO'
        tmp = [tmp[0]] + tmp[1].split('.')
    else:
        tmp = x.split('.')

    for i, t in enumerate(tmp):
        if t in irrelevant:
            tmp[i] = ''
            continue
        if t in mtype:
            tmp[i] = 'TYPE'
            continue
        if t in platf:
            tmp[i] = 'PLAT'
    
    # tmp = x.split('.')
    # for i in irrelevant:
#         x = x.replace(i, '')
        
    # x = re.sub(delim, ' DELIM ', x)
    
    # for t in mtype:
#         x = x.replace(t, ' TYPE ')
#     for p in platf:
#         x = x.replace(p, ' PLAT ')
#     for i in info:
#         x = x.replace(m, ' INFO ')
        
#     x = re.sub(spaces, ' ', x).strip()
    
  #   tmp = x.split(' ')
    # if len(tmp) >= 5 and tmp[0] == 'TYPE' and tmp[2] == 'PLAT':
#         tmp[4] = 'FAMILY'
#         if len(tmp) == 7:
#             tmp[6] = 'VARIANT'
    return ' '.join(tmp)

tmp = first_vendor.apply(tokenize).values
display(set(tmp))

# stop_words = ['delim', 'type', 'plat', 'meth', 'func']
# vocabulary = ['delim', 'type', 'plat', 'meth', 'func']
# cv = CountVectorizer(vocabulary=vocabulary, ngram_range=(2, 2))
# cv.fit(tmp)
display(first_vendor)
# display(cv.get_feature_names())
