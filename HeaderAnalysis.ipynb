# %%
import numpy as np
import pandas as pd
from lib.data_loading import loadHeadersCSV
from lib.plotting import *
from lib.helpers import *

# Build all other dataframes from this one
headers = loadHeadersCSV('data/header_analyses.csv')

# %% [markdown]
# # Overview

# %% [markdown]
# ## Sample size

# %%
# Monthly count for all samples
monthly_count = headers.md5.resample('M').count()
monthly_count = monthly_count.rename('All samples')
plotByMonth(monthly_count,
            'monthly_count',
            'Monthly Count ($\mu$={:.0f}, $\Sigma$={})'.format(monthly_count.mean(), monthly_count.sum()))

# %% [markdown]
# ## Duplicates

# %%
unique_count = headers.drop_duplicates(subset='md5').md5.resample('M').count().rename('Unique samples')
duplicated_count = headers[headers.duplicated(subset='md5')].md5.resample('M').count().rename('Duplicated samples')
print('Total number of unique analysis: {}'.format(unique_count.sum()))
print('Total number of duplicated analysis: {}'.format(duplicated_count.sum()))
dups_percent = pd.concat([unique_count, duplicated_count], axis=1)
dups_percent = dups_percent.divide(dups_percent.sum(axis=1), axis=0)
plotByMonthPercentage(dups_percent, 'dups_percent', 'Unique vs duplicated samples by percentage (MD5 unique)')
# Out:
# Total number of unique analysis: 550049
# Total number of duplicated analysis: 92649

# %%
# Sanity check
assert unique_count.sum() + duplicated_count.sum() == len(headers)

# %% [markdown]
# # Distribution of file types

# %%
# Different file types scanned
file_types = headers.file_type.unique()
print('Total unique file types: {}\n'.format(len(file_types)))
# for t in sorted(file_types):
#     print(t)
# Out:
# Total unique file types: 4407

# %% [markdown]
# The high number of file types can be easily explained by looking at the types list. Many of the types result to the same general type, but differ due to factors like versioning, size (for images) and encoding.
#
# ## Executables

# %%
# Some ELF/Mach-O files are not caught by "executable" filter, added manually
exec_crit = headers.file_type.map(lambda x: 'executable' in x.lower() or x.startswith('ELF') or x.startswith('Mach-O'))
exec_types = sorted(headers.file_type[exec_crit].unique())
print('Total unique file types with "executable": {}\n'.format(len(exec_types)))
for t in exec_types:
    print(t)
# Out:
# Total unique file types with "executable": 413
#
# 80386 COFF executable - version 2264
# 80386 COFF executable - version 3077
# 80386 COFF executable not stripped - version 25970
# 80386 COFF executable not stripped - version 30821
# ASCII text, with no line terminatorsPE32 executable (GUI) Intel 80386  ...
# ASCII text, with no line terminatorsPE32 executable (GUI) Intel 80386, ...
# ASCII text, with very long linesPE32 executable (GUI) Intel 80386, for ...
# BALANCE NS32000 executable (0 @ 0) version 1912629504
# Bourne-Again shell script, ASCII text executable
# Bourne-Again shell script, ASCII text executable, with CRLF line termi ...
# Bourne-Again shell script, ASCII text executable, with very long lines
# Bourne-Again shell script, UTF-8 Unicode text executable
# Bourne-Again shell script, UTF-8 Unicode text executable, with very lo ...
# COM executable for DOS
# COM executable for MS-DOS
# DOS executable (COM)
# DOS executable (block device driver :\)
# DOS executable (block device driver)
# DOS executable (block device driver,32-bit sector-support)
# ELF 32-bit LSB
# ELF 32-bit LSB  (Solaris)
# ELF 32-bit LSB  executable, ARM, EABI4 version 1 (GNU/Linux), statical ...
# ELF 32-bit LSB  executable, ARM, EABI4 version 1 (SYSV), dynamically l ...
# ELF 32-bit LSB  executable, ARM, EABI4 version 1 (SYSV), statically li ...
# ELF 32-bit LSB  executable, ARM, EABI4 version 1, statically linked, s ...
# ELF 32-bit LSB  executable, ARM, EABI5 version 1 (GNU/Linux), statical ...
# ELF 32-bit LSB  executable, ARM, EABI5 version 1 (SYSV), dynamically l ...
# ELF 32-bit LSB  executable, ARM, EABI5 version 1 (SYSV), statically li ...
# ELF 32-bit LSB  executable, ARM, EABI5 version 1, statically linked, s ...
# ELF 32-bit LSB  executable, ARM, version 1 (SYSV), statically linked,  ...
# ELF 32-bit LSB  executable, ARM, version 1, dynamically linked (uses s ...
# ELF 32-bit LSB  executable, ARM, version 1, statically linked, for GNU ...
# ELF 32-bit LSB  executable, ARM, version 1, statically linked, not str ...
# ELF 32-bit LSB  executable, ARM, version 1, statically linked, strippe ...
# ELF 32-bit LSB  executable, Altera Nios II, version 1 (SYSV), dynamica ...
# ELF 32-bit LSB  executable, Atmel AVR 8-bit, version 1 (SYSV), statica ...
# ELF 32-bit LSB  executable, Intel 80386, invalid version (SYSV), for G ...
# ELF 32-bit LSB  executable, Intel 80386, version 1 (FreeBSD), dynamica ...
# ELF 32-bit LSB  executable, Intel 80386, version 1 (FreeBSD), statical ...
# ELF 32-bit LSB  executable, Intel 80386, version 1 (GNU/Linux), static ...
# ELF 32-bit LSB  executable, Intel 80386, version 1 (GNU/Linux), too ma ...
# ELF 32-bit LSB  executable, Intel 80386, version 1 (SYSV), dynamically ...
# ELF 32-bit LSB  executable, Intel 80386, version 1 (SYSV), for GNU/Lin ...
# ELF 32-bit LSB  executable, Intel 80386, version 1 (SYSV), statically  ...
# ELF 32-bit LSB  executable, Intel 80386, version 1, dynamically linked ...
# ELF 32-bit LSB  executable, Intel 80386, version 1, statically linked, ...
# ELF 32-bit LSB  executable, MIPS, MIPS-I version 1 (SYSV), dynamically ...
# ELF 32-bit LSB  executable, MIPS, MIPS-I version 1 (SYSV), statically  ...
# ELF 32-bit LSB  executable, MIPS, MIPS-I version 1 (SYSV), too many se ...
# ELF 32-bit LSB  executable, MIPS, MIPS32 rel2 version 1 (SYSV), dynami ...
# ELF 32-bit LSB  executable, MIPS, MIPS32 rel2 version 1 (SYSV), static ...
# ELF 32-bit LSB  executable, MIPS, MIPS32 rel2 version 1, statically li ...
# ELF 32-bit LSB  executable, Renesas SH, version 1 (SYSV), dynamically  ...
# ELF 32-bit LSB  executable, Renesas SH, version 1 (SYSV), statically l ...
# ELF 32-bit LSB  relocatable, Intel 80386, version 1 (SYSV), not stripp ...
# ELF 32-bit LSB  relocatable, Intel 80386, version 1 (SYSV), stripped
# ELF 32-bit LSB  relocatable, MIPS, MIPS32 rel2 version 1 (SYSV), Build ...
# ELF 32-bit LSB  shared object, ARM, EABI4 version 1 (SYSV), dynamicall ...
# ELF 32-bit LSB  shared object, ARM, EABI5 version 1 (GNU/Linux), dynam ...
# ELF 32-bit LSB  shared object, ARM, EABI5 version 1 (SYSV), dynamicall ...
# ELF 32-bit LSB  shared object, Intel 80386, version 1 (GNU/Linux), dyn ...
# ELF 32-bit LSB  shared object, Intel 80386, version 1 (SYSV), dynamica ...
# ELF 32-bit LSB executable, ARM, version 1 (GNU/Linux), statically link ...
# ELF 32-bit LSB executable, ARM, version 1 (SYSV), dynamically linked ( ...
# ELF 32-bit LSB executable, ARM, version 1 (SYSV), statically linked, f ...
# ELF 32-bit LSB executable, ARM, version 1 (SYSV), statically linked, n ...
# ELF 32-bit LSB executable, ARM, version 1, statically linked, not stri ...
# ELF 32-bit LSB executable, ARM, version 1, statically linked, stripped
# ELF 32-bit LSB executable, Intel 80386, version 1 (FreeBSD), dynamical ...
# ELF 32-bit LSB executable, Intel 80386, version 1 (FreeBSD), staticall ...
# ELF 32-bit LSB executable, Intel 80386, version 1 (GNU/Linux), statica ...
# ELF 32-bit LSB executable, Intel 80386, version 1 (Monterey), statical ...
# ELF 32-bit LSB executable, Intel 80386, version 1 (SYSV), dynamically  ...
# ELF 32-bit LSB executable, Intel 80386, version 1 (SYSV), for GNU/Linu ...
# ELF 32-bit LSB executable, Intel 80386, version 1 (SYSV), statically l ...
# ELF 32-bit LSB executable, Intel 80386, version 1, statically linked,  ...
# ELF 32-bit LSB executable, MIPS, MIPS-I version 1 (SYSV), dynamically  ...
# ELF 32-bit LSB executable, MIPS, MIPS-I version 1 (SYSV), statically l ...
# ELF 32-bit LSB executable, MIPS, MIPS-II version 1 (SYSV), statically  ...
# ELF 32-bit LSB executable, MIPS, MIPS-IV version 1 (SYSV), corrupted p ...
# ELF 32-bit LSB no file type, version 1 (SYSV)
# ELF 32-bit LSB relocatable, Intel 80386, version 1 (SYSV), not strippe ...
# ELF 32-bit LSB shared object, ARM, version 1 (SYSV), dynamically linke ...
# ELF 32-bit LSB shared object, Intel 80386, version 1 (SYSV), dynamical ...
# ELF 32-bit MSB  executable, ARM, EABI4 version 1 (SYSV), statically li ...
# ELF 32-bit MSB  executable, ARM, EABI5 version 1 (SYSV), dynamically l ...
# ELF 32-bit MSB  executable, IA-64, version 1, dynamically linked (uses ...
# ELF 32-bit MSB  executable, MC68HC11, version 1 (SYSV), statically lin ...
# ELF 32-bit MSB  executable, MIPS, MIPS-I version 1 (SYSV), dynamically ...
# ELF 32-bit MSB  executable, MIPS, MIPS-I version 1 (SYSV), statically  ...
# ELF 32-bit MSB  executable, MIPS, MIPS-II version 1, statically linked ...
# ELF 32-bit MSB  executable, MIPS, MIPS32 rel2 version 1 (SYSV), dynami ...
# ELF 32-bit MSB  executable, MIPS, MIPS32 rel2 version 1 (SYSV), static ...
# ELF 32-bit MSB  executable, MIPS, MIPS32 rel2 version 1, statically li ...
# ELF 32-bit MSB  executable, MIPS, MIPS32 version 1 (SYSV), dynamically ...
# ELF 32-bit MSB  executable, MIPS, MIPS32 version 1 (SYSV), statically  ...
# ELF 32-bit MSB  executable, Motorola 68020 - invalid byte order, versi ...
# ELF 32-bit MSB  executable, PowerPC or cisco 4500, version 1 (GNU/Linu ...
# ELF 32-bit MSB  executable, PowerPC or cisco 4500, version 1 (SYSV), d ...
# ELF 32-bit MSB  executable, PowerPC or cisco 4500, version 1 (SYSV), s ...
# ELF 32-bit MSB  executable, SPARC version 1 (SYSV), dynamically linked ...
# ELF 32-bit MSB  executable, SPARC version 1 (SYSV), statically linked, ...
# ELF 32-bit MSB executable, MIPS, MIPS-I version 1 (SYSV), statically l ...
# ELF 32-bit MSB executable, MIPS, MIPS32 version 1 (SYSV), dynamically  ...
# ELF 64-bit LSB
# ELF 64-bit LSB  core file x86-64, version 1 (SYSV), SVR4-style, from ' ...
# ELF 64-bit LSB  core file x86-64, version 1 (SYSV), too many program h ...
# ELF 64-bit LSB  executable, IA-64, version 1 (SYSV), dynamically linke ...
# ELF 64-bit LSB  executable, MIPS, MIPS-III version 1 (SYSV), staticall ...
# ELF 64-bit LSB  executable, x86-64, invalid version (SYSV), for GNU/Li ...
# ELF 64-bit LSB  executable, x86-64, version 1 (FreeBSD), dynamically l ...
# ELF 64-bit LSB  executable, x86-64, version 1 (FreeBSD), statically li ...
# ELF 64-bit LSB  executable, x86-64, version 1 (GNU/Linux), dynamically ...
# ELF 64-bit LSB  executable, x86-64, version 1 (GNU/Linux), statically  ...
# ELF 64-bit LSB  executable, x86-64, version 1 (SYSV), BuildID[sha1]=9c ...
# ELF 64-bit LSB  executable, x86-64, version 1 (SYSV), dynamically link ...
# ELF 64-bit LSB  executable, x86-64, version 1 (SYSV), for GNU/Linux 2. ...
# ELF 64-bit LSB  executable, x86-64, version 1 (SYSV), statically linke ...
# ELF 64-bit LSB  executable, x86-64, version 1 (SYSV), too many program ...
# ELF 64-bit LSB  relocatable, x86-64, version 1 (SYSV), not stripped
# ELF 64-bit LSB  shared object, x86-64, version 1 (FreeBSD), dynamicall ...
# ELF 64-bit LSB  shared object, x86-64, version 1 (GNU/Linux), dynamica ...
# ELF 64-bit LSB  shared object, x86-64, version 1 (SYSV), dynamically l ...
# ELF 64-bit LSB  x86-64, version 1 (FreeBSD)
# ELF 64-bit LSB core file x86-64, version 1 (SYSV), SVR4-style, from '[ ...
# ELF 64-bit LSB core file x86-64, version 1 (SYSV), SVR4-style, from 't ...
# ELF 64-bit LSB executable, version 1 (SYSV), statically linked, stripp ...
# ELF 64-bit LSB executable, x86-64, version 1 (FreeBSD), dynamically li ...
# ELF 64-bit LSB executable, x86-64, version 1 (GNU/Linux), dynamically  ...
# ELF 64-bit LSB executable, x86-64, version 1 (GNU/Linux), statically l ...
# ELF 64-bit LSB executable, x86-64, version 1 (SYSV), dynamically linke ...
# ELF 64-bit LSB executable, x86-64, version 1 (SYSV), statically linked ...
# ELF 64-bit LSB relocatable, x86-64, version 1 (SYSV), BuildID[sha1]=0x ...
# ELF 64-bit LSB relocatable, x86-64, version 1 (SYSV), not stripped
# ELF 64-bit LSB shared object, x86-64, version 1 (SYSV), dynamically li ...
# ELF LSB  executable, x86-64, version 1 (SYSV), unknown class 3
# ELF, unknown class 48
# HTML document, ASCII textPE32 executable (GUI) Intel 80386 Mono/.Net a ...
# Hitachi SH big-endian COFF executable, not stripped
# Hitachi SH big-endian COFF executable, stripped
# Linux kernel ARM boot executable zImage (little-endian)
# Linux kernel x86 boot executable bzImage, version 2.6.38.5 (root@athen ...
# Linux-8086 executable, impure, A_NSYM, not stripped
# Lua script, ASCII text executable
# MIPSEB-LE MIPS-III ECOFF executable not stripped - version 119.237
# MIPSEL MIPS-II ECOFF executable not stripped - version 163.214
# MS Windows icon resource - 1 iconPE32 executable (GUI) Intel 80386, fo ...
# MS Windows shortcutPE32 executable (GUI) Intel 80386, for MS Windows
# MS-DOS executable
# MS-DOS executable ,\b LE for MS-DOS, DOS4GW DOS extender (embedded)
# MS-DOS executable, COFF
# MS-DOS executable, COFF for MS-DOS, DJGPP go32 DOS extender
# MS-DOS executable, COFF for MS-DOS, DJGPP go32 DOS extender, UPX compr ...
# MS-DOS executable, LE executable for MS Windows (VxD)
# MS-DOS executable, LE executable for MS-DOS, DOS4GW DOS extender
# MS-DOS executable, LE executable for MS-DOS, PMODE/W DOS extender, UPX ...
# MS-DOS executable, MZ for MS-DOS
# MS-DOS executable, MZ for MS-DOS Self-extracting PKZIP archive
# MS-DOS executable, MZ for MS-DOS Self-extracting PKZIP archive, ZIP se ...
# MS-DOS executable, MZ for MS-DOS, ARJ self-extracting archive
# MS-DOS executable, MZ for MS-DOS, LHa self-extracting archive
# MS-DOS executable, MZ for MS-DOS, LZEXE v0.90 compressed
# MS-DOS executable, MZ for MS-DOS, LZEXE v0.91 compressed
# MS-DOS executable, MZ for MS-DOS, RAR self-extracting archive
# MS-DOS executable, MZ for MS-DOS, WDos/X DOS extender
# MS-DOS executable, MZ for MS-DOS, ZIP self-extracting archive
# MS-DOS executable, MZ for MS-DOS, aPack compressed
# MS-DOS executable, MZ for MS-DOSPE32 executable (GUI) Intel 80386, for ...
# MS-DOS executable, NE for Borland Operating System Services
# MS-DOS executable, NE for MS Windows 3.x
# MS-DOS executable, NE for MS Windows 3.x (driver)
# MS-DOS executable, NE for MS Windows 3.x, ZIP self-extracting archive  ...
# MS-DOS executable, NE for OS/2 1.x
# MS-DOS executableHTML document, UTF-8 Unicode (with BOM) text, with CR ...
# MS-DOS executablePE32 executable (GUI) Intel 80386, for MS Windows
# Mach-O 64-bit architecture=53768 filetype=833218568
# Mach-O 64-bit executable
# Mach-O 64-bit filetype=11
# Mach-O 64-bit x86_64 bundle
# Mach-O 64-bit x86_64 dynamically linked shared library
# Mach-O 64-bit x86_64 executable
# Mach-O 64-bit x86_64 kext bundle
# Mach-O arm executable
# Mach-O arm_v6 executable
# Mach-O arm_v7 executable
# Mach-O executable acorn
# Mach-O executable i386
# Mach-O fat file with 2 architectures
# Mach-O fat file with 3 architectures
# Mach-O i386 dynamically linked shared library
# Mach-O i386 executable
# Mach-O universal binary with 1 architecture: [arm_v7: Mach-O arm_v7 ex ...
# Mach-O universal binary with 2 architectures: [arm subarchitecture=11: ...
# Mach-O universal binary with 2 architectures: [arm_v6: Mach-O arm_v6 d ...
# Mach-O universal binary with 2 architectures: [arm_v7: Mach-O arm_v7 e ...
# Mach-O universal binary with 2 architectures: [i386: Mach-O i386 dynam ...
# Mach-O universal binary with 2 architectures: [i386: Mach-O i386 execu ...
# Mach-O universal binary with 2 architectures: [ppc: Mach-O ppc executa ...
# Mach-O universal binary with 2 architectures: [ppc_7400: Mach-O ppc_74 ...
# Mach-O universal binary with 2 architectures: [x86_64: Mach-O 64-bit x ...
# Mach-O universal binary with 3 architectures: [arm_v7: Mach-O arm_v7 e ...
# Mach-O universal binary with 3 architectures: [ppc: Mach-O ppc executa ...
# Mach-O universal binary with 3 architectures: [ppc_7400: Mach-O ppc_74 ...
# Mach-O vax subarchitecture=32 filetype=300
# PARIX executable
# PC bitmap, Windows 3.x format, 7 x 11 x 24PE32 executable (GUI) Intel  ...
# PDF document, version M.MPE32 executable (DLL) (console) Intel 80386,  ...
# PDP-11 overlaid pure executable not stripped
# PDP-11 pure executable not stripped
# PE32 executable (DLL) (EFI application) EFI byte code, for MS Windows
# PE32 executable (DLL) (GUI) Intel 80386 (stripped to external PDB) sys ...
# PE32 executable (DLL) (GUI) Intel 80386 (stripped to external PDB), fo ...
# PE32 executable (DLL) (GUI) Intel 80386 Mono/.Net assembly, for MS Win ...
# PE32 executable (DLL) (GUI) Intel 80386, for MS Windows
# PE32 executable (DLL) (GUI) Intel 80386, for MS Windows, PECompact2 co ...
# PE32 executable (DLL) (GUI) Intel 80386, for MS Windows, Petite compre ...
# PE32 executable (DLL) (GUI) Intel 80386, for MS Windows, UPX compresse ...
# PE32 executable (DLL) (GUI) Intel 80386, for MS WindowsHTML document,  ...
# PE32 executable (DLL) (GUI) Intel 80386, for MS Windowsdata
# PE32 executable (DLL) (console) ARMv7 Thumb, for MS Windows
# PE32 executable (DLL) (console) Intel 80386 (stripped to external PDB) ...
# PE32 executable (DLL) (console) Intel 80386 Mono/.Net assembly, for MS ...
# PE32 executable (DLL) (console) Intel 80386, for MS Windows
# PE32 executable (DLL) (console) Intel 80386, for MS Windows, PECompact ...
# PE32 executable (DLL) (console) Intel 80386, for MS Windows, Petite co ...
# PE32 executable (DLL) (console) Intel 80386, for MS Windows, UPX compr ...
# PE32 executable (DLL) (native) Intel 80386 (stripped to external PDB), ...
# PE32 executable (DLL) (native) Intel 80386, for MS Windows
# PE32 executable (DLL) Intel 80386, for MS Windows
# PE32 executable (EFI application) Intel 80386 (stripped to external PD ...
# PE32 executable (GUI) ARM Thumb, for MS Windows
# PE32 executable (GUI) ARMv7 Thumb, for MS Windows
# PE32 executable (GUI) Alpha, for MS Windows
# PE32 executable (GUI) Intel 80386 (stripped to external PDB) Mono/.Net ...
# PE32 executable (GUI) Intel 80386 (stripped to external PDB) system fi ...
# PE32 executable (GUI) Intel 80386 (stripped to external PDB), for MS W ...
# PE32 executable (GUI) Intel 80386 Mono/.Net assembly, for MS Windows
# PE32 executable (GUI) Intel 80386 Mono/.Net assembly, for MS Windows,  ...
# PE32 executable (GUI) Intel 80386 Mono/.Net assembly, for MS WindowsHT ...
# PE32 executable (GUI) Intel 80386 system file, for MS Windows
# PE32 executable (GUI) Intel 80386 system file, for MS WindowsPE32 exec ...
# PE32 executable (GUI) Intel 80386, for MS Windows
# PE32 executable (GUI) Intel 80386, for MS Windows,
# PE32 executable (GUI) Intel 80386, for MS Windows, AIN 1.x self-extrac ...
# PE32 executable (GUI) Intel 80386, for MS Windows, AIN 2.x self-extrac ...
# PE32 executable (GUI) Intel 80386, for MS Windows, Dzip self-extractin ...
# PE32 executable (GUI) Intel 80386, for MS Windows, InnoSetup self-extr ...
# PE32 executable (GUI) Intel 80386, for MS Windows, InstallShield self- ...
# PE32 executable (GUI) Intel 80386, for MS Windows, LHa self-extracting ...
# PE32 executable (GUI) Intel 80386, for MS Windows, MS CAB-Installer se ...
# PE32 executable (GUI) Intel 80386, for MS Windows, MZ for MS-DOS
# PE32 executable (GUI) Intel 80386, for MS Windows, Nullsoft Installer  ...
# PE32 executable (GUI) Intel 80386, for MS Windows, PECompact2 compress ...
# PE32 executable (GUI) Intel 80386, for MS Windows, Petite compressed
# PE32 executable (GUI) Intel 80386, for MS Windows, Petite compressed,  ...
# PE32 executable (GUI) Intel 80386, for MS Windows, RAR self-extracting ...
# PE32 executable (GUI) Intel 80386, for MS Windows, UPX compressed
# PE32 executable (GUI) Intel 80386, for MS Windows, UPX compressed, Inn ...
# PE32 executable (GUI) Intel 80386, for MS Windows, UPX compressed, Ins ...
# PE32 executable (GUI) Intel 80386, for MS Windows, UPX compressed, Nul ...
# PE32 executable (GUI) Intel 80386, for MS Windows, UPX compressed, PEC ...
# PE32 executable (GUI) Intel 80386, for MS Windows, UPX compressed, RAR ...
# PE32 executable (GUI) Intel 80386, for MS Windows, WISE installer self ...
# PE32 executable (GUI) Intel 80386, for MS Windows, ZIP self-extracting ...
# PE32 executable (GUI) Intel 80386, for MS WindowsHTML document, UTF-8  ...
# PE32 executable (GUI) Unknown processor type 0x100, for MS Windows
# PE32 executable (GUI) Unknown processor type 0x100, for MS Windows, UP ...
# PE32 executable (GUI) Unknown processor type 0x4c, for MS Windows
# PE32 executable (GUI) Unknown processor type 0x5a31, for MS Windows
# PE32 executable (GUI) x86-64 (stripped to external PDB) Mono/.Net asse ...
# PE32 executable (Unknown subsystem 0x0) Intel 80386, for MS Windows
# PE32 executable (Unknown subsystem 0x10) Intel 80386, for MS Windows
# PE32 executable (Unknown subsystem 0x1010) Intel 80386 Mono/.Net assem ...
# PE32 executable (Unknown subsystem 0x1111) Intel 80386 Mono/.Net assem ...
# PE32 executable (Unknown subsystem 0x200) Intel 80386, for MS Windows
# PE32 executable (Unknown subsystem 0xfeff) Intel 80386, for MS Windows
# PE32 executable (Unknown subsystem Intel 80386, for MS Windows
# PE32 executable (Windows CE) ARM Thumb, for MS Windows
# PE32 executable (Windows CE) ARM, for MS Windows
# PE32 executable (Windows CE) MIPS R4000, for MS Windows
# PE32 executable (XBOX) Unknown processor type 0x1f2, for MS Windows
# PE32 executable (console) ARMv7 Thumb, for MS Windows
# PE32 executable (console) Intel 80386 (stripped to external PDB) Mono/ ...
# PE32 executable (console) Intel 80386 (stripped to external PDB) syste ...
# PE32 executable (console) Intel 80386 (stripped to external PDB), for  ...
# PE32 executable (console) Intel 80386 Mono/.Net assembly, for MS Windo ...
# PE32 executable (console) Intel 80386, for MS Windows
# PE32 executable (console) Intel 80386, for MS Windows, AIN 2.x self-ex ...
# PE32 executable (console) Intel 80386, for MS Windows, COFF
# PE32 executable (console) Intel 80386, for MS Windows, InstallShield s ...
# PE32 executable (console) Intel 80386, for MS Windows, Nullsoft Instal ...
# PE32 executable (console) Intel 80386, for MS Windows, PECompact2 comp ...
# PE32 executable (console) Intel 80386, for MS Windows, Petite compress ...
# PE32 executable (console) Intel 80386, for MS Windows, RAR self-extrac ...
# PE32 executable (console) Intel 80386, for MS Windows, UPX compressed
# PE32 executable (console) Intel 80386, for MS Windows, UPX compressed, ...
# PE32 executable (console) Intel 80386, for MS Windows, ZIP self-extrac ...
# PE32 executable (native) Intel 80386 (stripped to external PDB), for M ...
# PE32 executable (native) Intel 80386 Mono/.Net assembly, for MS Window ...
# PE32 executable (native) Intel 80386, for MS Windows
# PE32+ executable (DLL) (EFI application) x86-64, for MS Windows
# PE32+ executable (DLL) (EFI boot service driver) x86-64, for MS Window ...
# PE32+ executable (DLL) (GUI) x86-64 (stripped to external PDB), for MS ...
# PE32+ executable (DLL) (GUI) x86-64 Mono/.Net assembly, for MS Windows
# PE32+ executable (DLL) (GUI) x86-64, for MS Windows
# PE32+ executable (DLL) (console) Intel 80386 Mono/.Net assembly, for M ...
# PE32+ executable (DLL) (console) Intel Itanium, for MS Windows
# PE32+ executable (DLL) (console) x86-64 (stripped to external PDB), fo ...
# PE32+ executable (DLL) (console) x86-64 Mono/.Net assembly, for MS Win ...
# PE32+ executable (DLL) (console) x86-64, for MS Windows
# PE32+ executable (DLL) (native) x86-64, for MS Windows
# PE32+ executable (DLL) x86-64, for MS Windows
# PE32+ executable (EFI application) x86-64 (stripped to external PDB),  ...
# PE32+ executable (GUI) Intel 80386 Mono/.Net assembly, for MS Windows
# PE32+ executable (GUI) Intel Itanium Mono/.Net assembly, for MS Window ...
# PE32+ executable (GUI) x86-64 (stripped to external PDB) system file,  ...
# PE32+ executable (GUI) x86-64 (stripped to external PDB), for MS Windo ...
# PE32+ executable (GUI) x86-64 Mono/.Net assembly, for MS Windows
# PE32+ executable (GUI) x86-64, for MS Windows
# PE32+ executable (GUI) x86-64, for MS Windows, InstallShield self-extr ...
# PE32+ executable (Unknown subsystem 0x10) x86-64, for MS Windows
# PE32+ executable (console) Intel 80386 Mono/.Net assembly, for MS Wind ...
# PE32+ executable (console) Intel Itanium Mono/.Net assembly, for MS Wi ...
# PE32+ executable (console) Intel Itanium, for MS Windows
# PE32+ executable (console) x86-64 (stripped to external PDB), for MS W ...
# PE32+ executable (console) x86-64 Mono/.Net assembly, for MS Windows
# PE32+ executable (console) x86-64, for MS Windows
# PE32+ executable (native) x86-64, for MS Windows
# PHP script, ASCII text executable
# POSIX shell script, ASCII text executable
# POSIX shell script, ASCII text executable, with CRLF line terminators
# POSIX shell script, ASCII text executable, with very long lines
# POSIX shell script, Non-ISO extended-ASCII text executable, with CRLF  ...
# Perl script, ASCII text executable
# Perl script, ASCII text executable, with CRLF line terminators
# Perl script, ASCII text executable, with very long lines
# Perl script, ASCII text executable, with very long lines, with CRLF li ...
# Perl script, ISO-8859 text executable
# Perl script, Little-endian UTF-16 Unicode text executable, with CRLF,  ...
# Perl script, UTF-8 Unicode text executable
# Python script, ASCII text executable
# Python script, ASCII text executable, with CRLF line terminators
# Python script, ASCII text executable, with CRLF, LF line terminators
# Python script, ASCII text executable, with very long lines
# Python script, ASCII text executable, with very long lines, with CRLF  ...
# Python script, ISO-8859 text executable, with CRLF line terminators
# Python script, ISO-8859 text executable, with very long lines
# Python script, ISO-8859 text executable, with very long lines, with CR ...
# Python script, UTF-8 Unicode (with BOM) text executable, with CRLF lin ...
# Python script, UTF-8 Unicode text executable
# Python script, UTF-8 Unicode text executable, with CRLF line terminato ...
# SVR2 executable (USS/370) not stripped
# SVR2 executable (USS/370) not stripped - version 1417143001
# SVR2 executable (USS/370) not stripped - version 260251338
# SVR2 executable (USS/370) not stripped - version 28543
# SYMMETRY i386 executable (0 @ 0) not stripped version 268447780
# Sony Playstation executable ()
# VAX COFF executable
# VAX COFF executable - version 11080
# VAX COFF executable - version 11270
# VAX COFF executable - version 16540
# VAX COFF executable - version 19544
# VAX COFF executable - version 24962
# VAX COFF executable - version 3078
# VAX COFF executable - version 376
# VAX COFF executable - version 9973
# VAX COFF executable not stripped
# VAX COFF executable not stripped - version 13377
# VAX COFF executable not stripped - version 16959
# VAX COFF executable not stripped - version 18354
# VAX COFF executable not stripped - version 18455
# VAX COFF executable not stripped - version 20192
# VAX COFF executable not stripped - version 20993
# VAX COFF executable not stripped - version 25413
# VAX COFF executable not stripped - version 30760
# VAX COFF executable not stripped - version 32168
# VAX COFF executable not stripped - version 376
# VAX COFF executable not stripped - version 418
# VAX COFF executable not stripped - version 836
# VAX COFF executable not stripped - version 8385
# VAX COFF executable not stripped - version 9177
# VAX COFF executable not stripped - version 9286
# VAX-order 68K Blit (standalone) executable
# VAX-order 68k Blit mpx/mux executable
# VAX-order2 68k Blit mpx/mux executable
# VMS Alpha executable
# Zip archive data, at least v2.0 to extractPE32 executable (GUI) Intel  ...
# a /usr/bin/env bash script, UTF-8 Unicode text executable, with very l ...
# a /usr/bin/env xdg-open script, ASCII text executable
# a /usr/bin/perl -T -w script, ASCII text executable
# a /usr/bin/perl -w script, ASCII text executable
# a /usr/bin/perl -w script, ASCII text executable, with very long lines
# a /usr/bin/perl script, ASCII text executable
# a /usr/bin/perl script, UTF-8 Unicode text executable
# a /usr/bin/perl\015 script, ASCII text executable, with CRLF line term ...
# a /usr/bin/python  script, ASCII text executable
# a /usr/bin/python script, ASCII text executable
# a /usr/bin/python\015 script, ASCII text executable, with CRLF line te ...
# a /usr/bin/python\015 script, ASCII text executable, with very long li ...
# a lua script, ASCII text executable
# a lua script, ASCII text executable, with very long lines
# a python   script, ASCII text executable
# a python script, ASCII text executable
# a python script, ASCII text executable, with very long lines
# a python3 script, ASCII text executable
# a python\015 script, ASCII text executable, with CRLF line terminators
# a python\015 script, ASCII text executable, with very long lines, with ...
# a ruby script, ASCII text executable
# a xdg-open script, UTF-8 Unicode text executable
# apollo a88k COFF executable not stripped - version 10801
# dataPE32 executable (GUI) Intel 80386, for MS Windows, Nullsoft Instal ...
# mc68k COFF executable not stripped
# x86 executable not stripped

# %% [markdown]
# ### Windows Portable Executables (32bit)
# These analysis *generally* contain both static and dynamic analysis

# %%
pe32_types = list(filter(lambda x: x.startswith('PE32 '), exec_types))
print('Total unique PE32 (32bit) types: {}\n'.format(len(pe32_types)))
for t in pe32_types:
    print(t)
# Out:
# Total unique PE32 (32bit) types: 91
#
# PE32 executable (DLL) (EFI application) EFI byte code, for MS Windows
# PE32 executable (DLL) (GUI) Intel 80386 (stripped to external PDB) sys ...
# PE32 executable (DLL) (GUI) Intel 80386 (stripped to external PDB), fo ...
# PE32 executable (DLL) (GUI) Intel 80386 Mono/.Net assembly, for MS Win ...
# PE32 executable (DLL) (GUI) Intel 80386, for MS Windows
# PE32 executable (DLL) (GUI) Intel 80386, for MS Windows, PECompact2 co ...
# PE32 executable (DLL) (GUI) Intel 80386, for MS Windows, Petite compre ...
# PE32 executable (DLL) (GUI) Intel 80386, for MS Windows, UPX compresse ...
# PE32 executable (DLL) (GUI) Intel 80386, for MS WindowsHTML document,  ...
# PE32 executable (DLL) (GUI) Intel 80386, for MS Windowsdata
# PE32 executable (DLL) (console) ARMv7 Thumb, for MS Windows
# PE32 executable (DLL) (console) Intel 80386 (stripped to external PDB) ...
# PE32 executable (DLL) (console) Intel 80386 Mono/.Net assembly, for MS ...
# PE32 executable (DLL) (console) Intel 80386, for MS Windows
# PE32 executable (DLL) (console) Intel 80386, for MS Windows, PECompact ...
# PE32 executable (DLL) (console) Intel 80386, for MS Windows, Petite co ...
# PE32 executable (DLL) (console) Intel 80386, for MS Windows, UPX compr ...
# PE32 executable (DLL) (native) Intel 80386 (stripped to external PDB), ...
# PE32 executable (DLL) (native) Intel 80386, for MS Windows
# PE32 executable (DLL) Intel 80386, for MS Windows
# PE32 executable (EFI application) Intel 80386 (stripped to external PD ...
# PE32 executable (GUI) ARM Thumb, for MS Windows
# PE32 executable (GUI) ARMv7 Thumb, for MS Windows
# PE32 executable (GUI) Alpha, for MS Windows
# PE32 executable (GUI) Intel 80386 (stripped to external PDB) Mono/.Net ...
# PE32 executable (GUI) Intel 80386 (stripped to external PDB) system fi ...
# PE32 executable (GUI) Intel 80386 (stripped to external PDB), for MS W ...
# PE32 executable (GUI) Intel 80386 Mono/.Net assembly, for MS Windows
# PE32 executable (GUI) Intel 80386 Mono/.Net assembly, for MS Windows,  ...
# PE32 executable (GUI) Intel 80386 Mono/.Net assembly, for MS WindowsHT ...
# PE32 executable (GUI) Intel 80386 system file, for MS Windows
# PE32 executable (GUI) Intel 80386 system file, for MS WindowsPE32 exec ...
# PE32 executable (GUI) Intel 80386, for MS Windows
# PE32 executable (GUI) Intel 80386, for MS Windows,
# PE32 executable (GUI) Intel 80386, for MS Windows, AIN 1.x self-extrac ...
# PE32 executable (GUI) Intel 80386, for MS Windows, AIN 2.x self-extrac ...
# PE32 executable (GUI) Intel 80386, for MS Windows, Dzip self-extractin ...
# PE32 executable (GUI) Intel 80386, for MS Windows, InnoSetup self-extr ...
# PE32 executable (GUI) Intel 80386, for MS Windows, InstallShield self- ...
# PE32 executable (GUI) Intel 80386, for MS Windows, LHa self-extracting ...
# PE32 executable (GUI) Intel 80386, for MS Windows, MS CAB-Installer se ...
# PE32 executable (GUI) Intel 80386, for MS Windows, MZ for MS-DOS
# PE32 executable (GUI) Intel 80386, for MS Windows, Nullsoft Installer  ...
# PE32 executable (GUI) Intel 80386, for MS Windows, PECompact2 compress ...
# PE32 executable (GUI) Intel 80386, for MS Windows, Petite compressed
# PE32 executable (GUI) Intel 80386, for MS Windows, Petite compressed,  ...
# PE32 executable (GUI) Intel 80386, for MS Windows, RAR self-extracting ...
# PE32 executable (GUI) Intel 80386, for MS Windows, UPX compressed
# PE32 executable (GUI) Intel 80386, for MS Windows, UPX compressed, Inn ...
# PE32 executable (GUI) Intel 80386, for MS Windows, UPX compressed, Ins ...
# PE32 executable (GUI) Intel 80386, for MS Windows, UPX compressed, Nul ...
# PE32 executable (GUI) Intel 80386, for MS Windows, UPX compressed, PEC ...
# PE32 executable (GUI) Intel 80386, for MS Windows, UPX compressed, RAR ...
# PE32 executable (GUI) Intel 80386, for MS Windows, WISE installer self ...
# PE32 executable (GUI) Intel 80386, for MS Windows, ZIP self-extracting ...
# PE32 executable (GUI) Intel 80386, for MS WindowsHTML document, UTF-8  ...
# PE32 executable (GUI) Unknown processor type 0x100, for MS Windows
# PE32 executable (GUI) Unknown processor type 0x100, for MS Windows, UP ...
# PE32 executable (GUI) Unknown processor type 0x4c, for MS Windows
# PE32 executable (GUI) Unknown processor type 0x5a31, for MS Windows
# PE32 executable (GUI) x86-64 (stripped to external PDB) Mono/.Net asse ...
# PE32 executable (Unknown subsystem 0x0) Intel 80386, for MS Windows
# PE32 executable (Unknown subsystem 0x10) Intel 80386, for MS Windows
# PE32 executable (Unknown subsystem 0x1010) Intel 80386 Mono/.Net assem ...
# PE32 executable (Unknown subsystem 0x1111) Intel 80386 Mono/.Net assem ...
# PE32 executable (Unknown subsystem 0x200) Intel 80386, for MS Windows
# PE32 executable (Unknown subsystem 0xfeff) Intel 80386, for MS Windows
# PE32 executable (Unknown subsystem Intel 80386, for MS Windows
# PE32 executable (Windows CE) ARM Thumb, for MS Windows
# PE32 executable (Windows CE) ARM, for MS Windows
# PE32 executable (Windows CE) MIPS R4000, for MS Windows
# PE32 executable (XBOX) Unknown processor type 0x1f2, for MS Windows
# PE32 executable (console) ARMv7 Thumb, for MS Windows
# PE32 executable (console) Intel 80386 (stripped to external PDB) Mono/ ...
# PE32 executable (console) Intel 80386 (stripped to external PDB) syste ...
# PE32 executable (console) Intel 80386 (stripped to external PDB), for  ...
# PE32 executable (console) Intel 80386 Mono/.Net assembly, for MS Windo ...
# PE32 executable (console) Intel 80386, for MS Windows
# PE32 executable (console) Intel 80386, for MS Windows, AIN 2.x self-ex ...
# PE32 executable (console) Intel 80386, for MS Windows, COFF
# PE32 executable (console) Intel 80386, for MS Windows, InstallShield s ...
# PE32 executable (console) Intel 80386, for MS Windows, Nullsoft Instal ...
# PE32 executable (console) Intel 80386, for MS Windows, PECompact2 comp ...
# PE32 executable (console) Intel 80386, for MS Windows, Petite compress ...
# PE32 executable (console) Intel 80386, for MS Windows, RAR self-extrac ...
# PE32 executable (console) Intel 80386, for MS Windows, UPX compressed
# PE32 executable (console) Intel 80386, for MS Windows, UPX compressed, ...
# PE32 executable (console) Intel 80386, for MS Windows, ZIP self-extrac ...
# PE32 executable (native) Intel 80386 (stripped to external PDB), for M ...
# PE32 executable (native) Intel 80386 Mono/.Net assembly, for MS Window ...
# PE32 executable (native) Intel 80386, for MS Windows

# %% [markdown]
# ### Other architectures/platforms

# %%
not_pe32_types = list(filter(lambda x: not x.startswith('PE32 '), exec_types))
print('Total unique not PE32 (32bit) types: {}\n'.format(len(not_pe32_types)))
for t in not_pe32_types:
    print(t)
# Out:
# Total unique not PE32 (32bit) types: 322
#
# 80386 COFF executable - version 2264
# 80386 COFF executable - version 3077
# 80386 COFF executable not stripped - version 25970
# 80386 COFF executable not stripped - version 30821
# ASCII text, with no line terminatorsPE32 executable (GUI) Intel 80386  ...
# ASCII text, with no line terminatorsPE32 executable (GUI) Intel 80386, ...
# ASCII text, with very long linesPE32 executable (GUI) Intel 80386, for ...
# BALANCE NS32000 executable (0 @ 0) version 1912629504
# Bourne-Again shell script, ASCII text executable
# Bourne-Again shell script, ASCII text executable, with CRLF line termi ...
# Bourne-Again shell script, ASCII text executable, with very long lines
# Bourne-Again shell script, UTF-8 Unicode text executable
# Bourne-Again shell script, UTF-8 Unicode text executable, with very lo ...
# COM executable for DOS
# COM executable for MS-DOS
# DOS executable (COM)
# DOS executable (block device driver :\)
# DOS executable (block device driver)
# DOS executable (block device driver,32-bit sector-support)
# ELF 32-bit LSB
# ELF 32-bit LSB  (Solaris)
# ELF 32-bit LSB  executable, ARM, EABI4 version 1 (GNU/Linux), statical ...
# ELF 32-bit LSB  executable, ARM, EABI4 version 1 (SYSV), dynamically l ...
# ELF 32-bit LSB  executable, ARM, EABI4 version 1 (SYSV), statically li ...
# ELF 32-bit LSB  executable, ARM, EABI4 version 1, statically linked, s ...
# ELF 32-bit LSB  executable, ARM, EABI5 version 1 (GNU/Linux), statical ...
# ELF 32-bit LSB  executable, ARM, EABI5 version 1 (SYSV), dynamically l ...
# ELF 32-bit LSB  executable, ARM, EABI5 version 1 (SYSV), statically li ...
# ELF 32-bit LSB  executable, ARM, EABI5 version 1, statically linked, s ...
# ELF 32-bit LSB  executable, ARM, version 1 (SYSV), statically linked,  ...
# ELF 32-bit LSB  executable, ARM, version 1, dynamically linked (uses s ...
# ELF 32-bit LSB  executable, ARM, version 1, statically linked, for GNU ...
# ELF 32-bit LSB  executable, ARM, version 1, statically linked, not str ...
# ELF 32-bit LSB  executable, ARM, version 1, statically linked, strippe ...
# ELF 32-bit LSB  executable, Altera Nios II, version 1 (SYSV), dynamica ...
# ELF 32-bit LSB  executable, Atmel AVR 8-bit, version 1 (SYSV), statica ...
# ELF 32-bit LSB  executable, Intel 80386, invalid version (SYSV), for G ...
# ELF 32-bit LSB  executable, Intel 80386, version 1 (FreeBSD), dynamica ...
# ELF 32-bit LSB  executable, Intel 80386, version 1 (FreeBSD), statical ...
# ELF 32-bit LSB  executable, Intel 80386, version 1 (GNU/Linux), static ...
# ELF 32-bit LSB  executable, Intel 80386, version 1 (GNU/Linux), too ma ...
# ELF 32-bit LSB  executable, Intel 80386, version 1 (SYSV), dynamically ...
# ELF 32-bit LSB  executable, Intel 80386, version 1 (SYSV), for GNU/Lin ...
# ELF 32-bit LSB  executable, Intel 80386, version 1 (SYSV), statically  ...
# ELF 32-bit LSB  executable, Intel 80386, version 1, dynamically linked ...
# ELF 32-bit LSB  executable, Intel 80386, version 1, statically linked, ...
# ELF 32-bit LSB  executable, MIPS, MIPS-I version 1 (SYSV), dynamically ...
# ELF 32-bit LSB  executable, MIPS, MIPS-I version 1 (SYSV), statically  ...
# ELF 32-bit LSB  executable, MIPS, MIPS-I version 1 (SYSV), too many se ...
# ELF 32-bit LSB  executable, MIPS, MIPS32 rel2 version 1 (SYSV), dynami ...
# ELF 32-bit LSB  executable, MIPS, MIPS32 rel2 version 1 (SYSV), static ...
# ELF 32-bit LSB  executable, MIPS, MIPS32 rel2 version 1, statically li ...
# ELF 32-bit LSB  executable, Renesas SH, version 1 (SYSV), dynamically  ...
# ELF 32-bit LSB  executable, Renesas SH, version 1 (SYSV), statically l ...
# ELF 32-bit LSB  relocatable, Intel 80386, version 1 (SYSV), not stripp ...
# ELF 32-bit LSB  relocatable, Intel 80386, version 1 (SYSV), stripped
# ELF 32-bit LSB  relocatable, MIPS, MIPS32 rel2 version 1 (SYSV), Build ...
# ELF 32-bit LSB  shared object, ARM, EABI4 version 1 (SYSV), dynamicall ...
# ELF 32-bit LSB  shared object, ARM, EABI5 version 1 (GNU/Linux), dynam ...
# ELF 32-bit LSB  shared object, ARM, EABI5 version 1 (SYSV), dynamicall ...
# ELF 32-bit LSB  shared object, Intel 80386, version 1 (GNU/Linux), dyn ...
# ELF 32-bit LSB  shared object, Intel 80386, version 1 (SYSV), dynamica ...
# ELF 32-bit LSB executable, ARM, version 1 (GNU/Linux), statically link ...
# ELF 32-bit LSB executable, ARM, version 1 (SYSV), dynamically linked ( ...
# ELF 32-bit LSB executable, ARM, version 1 (SYSV), statically linked, f ...
# ELF 32-bit LSB executable, ARM, version 1 (SYSV), statically linked, n ...
# ELF 32-bit LSB executable, ARM, version 1, statically linked, not stri ...
# ELF 32-bit LSB executable, ARM, version 1, statically linked, stripped
# ELF 32-bit LSB executable, Intel 80386, version 1 (FreeBSD), dynamical ...
# ELF 32-bit LSB executable, Intel 80386, version 1 (FreeBSD), staticall ...
# ELF 32-bit LSB executable, Intel 80386, version 1 (GNU/Linux), statica ...
# ELF 32-bit LSB executable, Intel 80386, version 1 (Monterey), statical ...
# ELF 32-bit LSB executable, Intel 80386, version 1 (SYSV), dynamically  ...
# ELF 32-bit LSB executable, Intel 80386, version 1 (SYSV), for GNU/Linu ...
# ELF 32-bit LSB executable, Intel 80386, version 1 (SYSV), statically l ...
# ELF 32-bit LSB executable, Intel 80386, version 1, statically linked,  ...
# ELF 32-bit LSB executable, MIPS, MIPS-I version 1 (SYSV), dynamically  ...
# ELF 32-bit LSB executable, MIPS, MIPS-I version 1 (SYSV), statically l ...
# ELF 32-bit LSB executable, MIPS, MIPS-II version 1 (SYSV), statically  ...
# ELF 32-bit LSB executable, MIPS, MIPS-IV version 1 (SYSV), corrupted p ...
# ELF 32-bit LSB no file type, version 1 (SYSV)
# ELF 32-bit LSB relocatable, Intel 80386, version 1 (SYSV), not strippe ...
# ELF 32-bit LSB shared object, ARM, version 1 (SYSV), dynamically linke ...
# ELF 32-bit LSB shared object, Intel 80386, version 1 (SYSV), dynamical ...
# ELF 32-bit MSB  executable, ARM, EABI4 version 1 (SYSV), statically li ...
# ELF 32-bit MSB  executable, ARM, EABI5 version 1 (SYSV), dynamically l ...
# ELF 32-bit MSB  executable, IA-64, version 1, dynamically linked (uses ...
# ELF 32-bit MSB  executable, MC68HC11, version 1 (SYSV), statically lin ...
# ELF 32-bit MSB  executable, MIPS, MIPS-I version 1 (SYSV), dynamically ...
# ELF 32-bit MSB  executable, MIPS, MIPS-I version 1 (SYSV), statically  ...
# ELF 32-bit MSB  executable, MIPS, MIPS-II version 1, statically linked ...
# ELF 32-bit MSB  executable, MIPS, MIPS32 rel2 version 1 (SYSV), dynami ...
# ELF 32-bit MSB  executable, MIPS, MIPS32 rel2 version 1 (SYSV), static ...
# ELF 32-bit MSB  executable, MIPS, MIPS32 rel2 version 1, statically li ...
# ELF 32-bit MSB  executable, MIPS, MIPS32 version 1 (SYSV), dynamically ...
# ELF 32-bit MSB  executable, MIPS, MIPS32 version 1 (SYSV), statically  ...
# ELF 32-bit MSB  executable, Motorola 68020 - invalid byte order, versi ...
# ELF 32-bit MSB  executable, PowerPC or cisco 4500, version 1 (GNU/Linu ...
# ELF 32-bit MSB  executable, PowerPC or cisco 4500, version 1 (SYSV), d ...
# ELF 32-bit MSB  executable, PowerPC or cisco 4500, version 1 (SYSV), s ...
# ELF 32-bit MSB  executable, SPARC version 1 (SYSV), dynamically linked ...
# ELF 32-bit MSB  executable, SPARC version 1 (SYSV), statically linked, ...
# ELF 32-bit MSB executable, MIPS, MIPS-I version 1 (SYSV), statically l ...
# ELF 32-bit MSB executable, MIPS, MIPS32 version 1 (SYSV), dynamically  ...
# ELF 64-bit LSB
# ELF 64-bit LSB  core file x86-64, version 1 (SYSV), SVR4-style, from ' ...
# ELF 64-bit LSB  core file x86-64, version 1 (SYSV), too many program h ...
# ELF 64-bit LSB  executable, IA-64, version 1 (SYSV), dynamically linke ...
# ELF 64-bit LSB  executable, MIPS, MIPS-III version 1 (SYSV), staticall ...
# ELF 64-bit LSB  executable, x86-64, invalid version (SYSV), for GNU/Li ...
# ELF 64-bit LSB  executable, x86-64, version 1 (FreeBSD), dynamically l ...
# ELF 64-bit LSB  executable, x86-64, version 1 (FreeBSD), statically li ...
# ELF 64-bit LSB  executable, x86-64, version 1 (GNU/Linux), dynamically ...
# ELF 64-bit LSB  executable, x86-64, version 1 (GNU/Linux), statically  ...
# ELF 64-bit LSB  executable, x86-64, version 1 (SYSV), BuildID[sha1]=9c ...
# ELF 64-bit LSB  executable, x86-64, version 1 (SYSV), dynamically link ...
# ELF 64-bit LSB  executable, x86-64, version 1 (SYSV), for GNU/Linux 2. ...
# ELF 64-bit LSB  executable, x86-64, version 1 (SYSV), statically linke ...
# ELF 64-bit LSB  executable, x86-64, version 1 (SYSV), too many program ...
# ELF 64-bit LSB  relocatable, x86-64, version 1 (SYSV), not stripped
# ELF 64-bit LSB  shared object, x86-64, version 1 (FreeBSD), dynamicall ...
# ELF 64-bit LSB  shared object, x86-64, version 1 (GNU/Linux), dynamica ...
# ELF 64-bit LSB  shared object, x86-64, version 1 (SYSV), dynamically l ...
# ELF 64-bit LSB  x86-64, version 1 (FreeBSD)
# ELF 64-bit LSB core file x86-64, version 1 (SYSV), SVR4-style, from '[ ...
# ELF 64-bit LSB core file x86-64, version 1 (SYSV), SVR4-style, from 't ...
# ELF 64-bit LSB executable, version 1 (SYSV), statically linked, stripp ...
# ELF 64-bit LSB executable, x86-64, version 1 (FreeBSD), dynamically li ...
# ELF 64-bit LSB executable, x86-64, version 1 (GNU/Linux), dynamically  ...
# ELF 64-bit LSB executable, x86-64, version 1 (GNU/Linux), statically l ...
# ELF 64-bit LSB executable, x86-64, version 1 (SYSV), dynamically linke ...
# ELF 64-bit LSB executable, x86-64, version 1 (SYSV), statically linked ...
# ELF 64-bit LSB relocatable, x86-64, version 1 (SYSV), BuildID[sha1]=0x ...
# ELF 64-bit LSB relocatable, x86-64, version 1 (SYSV), not stripped
# ELF 64-bit LSB shared object, x86-64, version 1 (SYSV), dynamically li ...
# ELF LSB  executable, x86-64, version 1 (SYSV), unknown class 3
# ELF, unknown class 48
# HTML document, ASCII textPE32 executable (GUI) Intel 80386 Mono/.Net a ...
# Hitachi SH big-endian COFF executable, not stripped
# Hitachi SH big-endian COFF executable, stripped
# Linux kernel ARM boot executable zImage (little-endian)
# Linux kernel x86 boot executable bzImage, version 2.6.38.5 (root@athen ...
# Linux-8086 executable, impure, A_NSYM, not stripped
# Lua script, ASCII text executable
# MIPSEB-LE MIPS-III ECOFF executable not stripped - version 119.237
# MIPSEL MIPS-II ECOFF executable not stripped - version 163.214
# MS Windows icon resource - 1 iconPE32 executable (GUI) Intel 80386, fo ...
# MS Windows shortcutPE32 executable (GUI) Intel 80386, for MS Windows
# MS-DOS executable
# MS-DOS executable ,\b LE for MS-DOS, DOS4GW DOS extender (embedded)
# MS-DOS executable, COFF
# MS-DOS executable, COFF for MS-DOS, DJGPP go32 DOS extender
# MS-DOS executable, COFF for MS-DOS, DJGPP go32 DOS extender, UPX compr ...
# MS-DOS executable, LE executable for MS Windows (VxD)
# MS-DOS executable, LE executable for MS-DOS, DOS4GW DOS extender
# MS-DOS executable, LE executable for MS-DOS, PMODE/W DOS extender, UPX ...
# MS-DOS executable, MZ for MS-DOS
# MS-DOS executable, MZ for MS-DOS Self-extracting PKZIP archive
# MS-DOS executable, MZ for MS-DOS Self-extracting PKZIP archive, ZIP se ...
# MS-DOS executable, MZ for MS-DOS, ARJ self-extracting archive
# MS-DOS executable, MZ for MS-DOS, LHa self-extracting archive
# MS-DOS executable, MZ for MS-DOS, LZEXE v0.90 compressed
# MS-DOS executable, MZ for MS-DOS, LZEXE v0.91 compressed
# MS-DOS executable, MZ for MS-DOS, RAR self-extracting archive
# MS-DOS executable, MZ for MS-DOS, WDos/X DOS extender
# MS-DOS executable, MZ for MS-DOS, ZIP self-extracting archive
# MS-DOS executable, MZ for MS-DOS, aPack compressed
# MS-DOS executable, MZ for MS-DOSPE32 executable (GUI) Intel 80386, for ...
# MS-DOS executable, NE for Borland Operating System Services
# MS-DOS executable, NE for MS Windows 3.x
# MS-DOS executable, NE for MS Windows 3.x (driver)
# MS-DOS executable, NE for MS Windows 3.x, ZIP self-extracting archive  ...
# MS-DOS executable, NE for OS/2 1.x
# MS-DOS executableHTML document, UTF-8 Unicode (with BOM) text, with CR ...
# MS-DOS executablePE32 executable (GUI) Intel 80386, for MS Windows
# Mach-O 64-bit architecture=53768 filetype=833218568
# Mach-O 64-bit executable
# Mach-O 64-bit filetype=11
# Mach-O 64-bit x86_64 bundle
# Mach-O 64-bit x86_64 dynamically linked shared library
# Mach-O 64-bit x86_64 executable
# Mach-O 64-bit x86_64 kext bundle
# Mach-O arm executable
# Mach-O arm_v6 executable
# Mach-O arm_v7 executable
# Mach-O executable acorn
# Mach-O executable i386
# Mach-O fat file with 2 architectures
# Mach-O fat file with 3 architectures
# Mach-O i386 dynamically linked shared library
# Mach-O i386 executable
# Mach-O universal binary with 1 architecture: [arm_v7: Mach-O arm_v7 ex ...
# Mach-O universal binary with 2 architectures: [arm subarchitecture=11: ...
# Mach-O universal binary with 2 architectures: [arm_v6: Mach-O arm_v6 d ...
# Mach-O universal binary with 2 architectures: [arm_v7: Mach-O arm_v7 e ...
# Mach-O universal binary with 2 architectures: [i386: Mach-O i386 dynam ...
# Mach-O universal binary with 2 architectures: [i386: Mach-O i386 execu ...
# Mach-O universal binary with 2 architectures: [ppc: Mach-O ppc executa ...
# Mach-O universal binary with 2 architectures: [ppc_7400: Mach-O ppc_74 ...
# Mach-O universal binary with 2 architectures: [x86_64: Mach-O 64-bit x ...
# Mach-O universal binary with 3 architectures: [arm_v7: Mach-O arm_v7 e ...
# Mach-O universal binary with 3 architectures: [ppc: Mach-O ppc executa ...
# Mach-O universal binary with 3 architectures: [ppc_7400: Mach-O ppc_74 ...
# Mach-O vax subarchitecture=32 filetype=300
# PARIX executable
# PC bitmap, Windows 3.x format, 7 x 11 x 24PE32 executable (GUI) Intel  ...
# PDF document, version M.MPE32 executable (DLL) (console) Intel 80386,  ...
# PDP-11 overlaid pure executable not stripped
# PDP-11 pure executable not stripped
# PE32+ executable (DLL) (EFI application) x86-64, for MS Windows
# PE32+ executable (DLL) (EFI boot service driver) x86-64, for MS Window ...
# PE32+ executable (DLL) (GUI) x86-64 (stripped to external PDB), for MS ...
# PE32+ executable (DLL) (GUI) x86-64 Mono/.Net assembly, for MS Windows
# PE32+ executable (DLL) (GUI) x86-64, for MS Windows
# PE32+ executable (DLL) (console) Intel 80386 Mono/.Net assembly, for M ...
# PE32+ executable (DLL) (console) Intel Itanium, for MS Windows
# PE32+ executable (DLL) (console) x86-64 (stripped to external PDB), fo ...
# PE32+ executable (DLL) (console) x86-64 Mono/.Net assembly, for MS Win ...
# PE32+ executable (DLL) (console) x86-64, for MS Windows
# PE32+ executable (DLL) (native) x86-64, for MS Windows
# PE32+ executable (DLL) x86-64, for MS Windows
# PE32+ executable (EFI application) x86-64 (stripped to external PDB),  ...
# PE32+ executable (GUI) Intel 80386 Mono/.Net assembly, for MS Windows
# PE32+ executable (GUI) Intel Itanium Mono/.Net assembly, for MS Window ...
# PE32+ executable (GUI) x86-64 (stripped to external PDB) system file,  ...
# PE32+ executable (GUI) x86-64 (stripped to external PDB), for MS Windo ...
# PE32+ executable (GUI) x86-64 Mono/.Net assembly, for MS Windows
# PE32+ executable (GUI) x86-64, for MS Windows
# PE32+ executable (GUI) x86-64, for MS Windows, InstallShield self-extr ...
# PE32+ executable (Unknown subsystem 0x10) x86-64, for MS Windows
# PE32+ executable (console) Intel 80386 Mono/.Net assembly, for MS Wind ...
# PE32+ executable (console) Intel Itanium Mono/.Net assembly, for MS Wi ...
# PE32+ executable (console) Intel Itanium, for MS Windows
# PE32+ executable (console) x86-64 (stripped to external PDB), for MS W ...
# PE32+ executable (console) x86-64 Mono/.Net assembly, for MS Windows
# PE32+ executable (console) x86-64, for MS Windows
# PE32+ executable (native) x86-64, for MS Windows
# PHP script, ASCII text executable
# POSIX shell script, ASCII text executable
# POSIX shell script, ASCII text executable, with CRLF line terminators
# POSIX shell script, ASCII text executable, with very long lines
# POSIX shell script, Non-ISO extended-ASCII text executable, with CRLF  ...
# Perl script, ASCII text executable
# Perl script, ASCII text executable, with CRLF line terminators
# Perl script, ASCII text executable, with very long lines
# Perl script, ASCII text executable, with very long lines, with CRLF li ...
# Perl script, ISO-8859 text executable
# Perl script, Little-endian UTF-16 Unicode text executable, with CRLF,  ...
# Perl script, UTF-8 Unicode text executable
# Python script, ASCII text executable
# Python script, ASCII text executable, with CRLF line terminators
# Python script, ASCII text executable, with CRLF, LF line terminators
# Python script, ASCII text executable, with very long lines
# Python script, ASCII text executable, with very long lines, with CRLF  ...
# Python script, ISO-8859 text executable, with CRLF line terminators
# Python script, ISO-8859 text executable, with very long lines
# Python script, ISO-8859 text executable, with very long lines, with CR ...
# Python script, UTF-8 Unicode (with BOM) text executable, with CRLF lin ...
# Python script, UTF-8 Unicode text executable
# Python script, UTF-8 Unicode text executable, with CRLF line terminato ...
# SVR2 executable (USS/370) not stripped
# SVR2 executable (USS/370) not stripped - version 1417143001
# SVR2 executable (USS/370) not stripped - version 260251338
# SVR2 executable (USS/370) not stripped - version 28543
# SYMMETRY i386 executable (0 @ 0) not stripped version 268447780
# Sony Playstation executable ()
# VAX COFF executable
# VAX COFF executable - version 11080
# VAX COFF executable - version 11270
# VAX COFF executable - version 16540
# VAX COFF executable - version 19544
# VAX COFF executable - version 24962
# VAX COFF executable - version 3078
# VAX COFF executable - version 376
# VAX COFF executable - version 9973
# VAX COFF executable not stripped
# VAX COFF executable not stripped - version 13377
# VAX COFF executable not stripped - version 16959
# VAX COFF executable not stripped - version 18354
# VAX COFF executable not stripped - version 18455
# VAX COFF executable not stripped - version 20192
# VAX COFF executable not stripped - version 20993
# VAX COFF executable not stripped - version 25413
# VAX COFF executable not stripped - version 30760
# VAX COFF executable not stripped - version 32168
# VAX COFF executable not stripped - version 376
# VAX COFF executable not stripped - version 418
# VAX COFF executable not stripped - version 836
# VAX COFF executable not stripped - version 8385
# VAX COFF executable not stripped - version 9177
# VAX COFF executable not stripped - version 9286
# VAX-order 68K Blit (standalone) executable
# VAX-order 68k Blit mpx/mux executable
# VAX-order2 68k Blit mpx/mux executable
# VMS Alpha executable
# Zip archive data, at least v2.0 to extractPE32 executable (GUI) Intel  ...
# a /usr/bin/env bash script, UTF-8 Unicode text executable, with very l ...
# a /usr/bin/env xdg-open script, ASCII text executable
# a /usr/bin/perl -T -w script, ASCII text executable
# a /usr/bin/perl -w script, ASCII text executable
# a /usr/bin/perl -w script, ASCII text executable, with very long lines
# a /usr/bin/perl script, ASCII text executable
# a /usr/bin/perl script, UTF-8 Unicode text executable
# a /usr/bin/perl\015 script, ASCII text executable, with CRLF line term ...
# a /usr/bin/python  script, ASCII text executable
# a /usr/bin/python script, ASCII text executable
# a /usr/bin/python\015 script, ASCII text executable, with CRLF line te ...
# a /usr/bin/python\015 script, ASCII text executable, with very long li ...
# a lua script, ASCII text executable
# a lua script, ASCII text executable, with very long lines
# a python   script, ASCII text executable
# a python script, ASCII text executable
# a python script, ASCII text executable, with very long lines
# a python3 script, ASCII text executable
# a python\015 script, ASCII text executable, with CRLF line terminators
# a python\015 script, ASCII text executable, with very long lines, with ...
# a ruby script, ASCII text executable
# a xdg-open script, UTF-8 Unicode text executable
# apollo a88k COFF executable not stripped - version 10801
# dataPE32 executable (GUI) Intel 80386, for MS Windows, Nullsoft Instal ...
# mc68k COFF executable not stripped
# x86 executable not stripped

# %% [markdown]
# ## Text files
#
# This includes source files, scripts, html, etc.

# %%
text_keywords = ['text', 'foxpro']
text_crit = headers.file_type.map(mapKeywords(text_keywords))
# Exclude what was considered executable type
text_types = sorted(headers.file_type[~exec_crit & text_crit].unique())
print('Total unique file types with "text": {}\n'.format(len(text_types)))
for t in text_types:
    print(t)
# Out:
# Total unique file types with "text": 493
#
# ASCII C program text
# ASCII C program text, with CRLF line terminators
# ASCII C program text, with CRLF, CR line terminators
# ASCII C program text, with CRLF, LF line terminators
# ASCII C program text, with very long lines
# ASCII C program text, with very long lines, with CRLF line terminators
# ASCII C program text, with very long lines, with CRLF, LF line termina ...
# ASCII C program text, with very long lines, with no line terminators
# ASCII C++ program text
# ASCII C++ program text, with CRLF line terminators
# ASCII C++ program text, with CRLF, CR line terminators
# ASCII C++ program text, with CRLF, LF line terminators
# ASCII C++ program text, with very long lines
# ASCII C++ program text, with very long lines, with CRLF line terminato ...
# ASCII C++ program text, with very long lines, with CRLF, LF line termi ...
# ASCII English text
# ASCII English text, with CRLF line terminators
# ASCII English text, with CRLF, CR line terminators
# ASCII English text, with CRLF, LF line terminators
# ASCII English text, with no line terminators
# ASCII English text, with very long lines
# ASCII English text, with very long lines, with CR, LF line terminators
# ASCII English text, with very long lines, with CRLF line terminators
# ASCII English text, with very long lines, with CRLF, CR line terminato ...
# ASCII English text, with very long lines, with CRLF, LF line terminato ...
# ASCII English text, with very long lines, with no line terminators
# ASCII English textHTML document, UTF-8 Unicode text, with very long li ...
# ASCII HTML document text, with CRLF line terminators
# ASCII Java program text
# ASCII Java program text, with CRLF line terminators
# ASCII Pascal program text, with CRLF line terminators
# ASCII mail text
# ASCII mail text, with CRLF line terminators
# ASCII mail text, with very long lines
# ASCII mail text, with very long lines, with CRLF line terminators
# ASCII make commands text
# ASCII text
# ASCII text, with CR line terminators
# ASCII text, with CR, LF line terminators
# ASCII text, with CRLF line terminators
# ASCII text, with CRLF, CR line terminators
# ASCII text, with CRLF, CR line terminators, with escape sequences
# ASCII text, with CRLF, CR, LF line terminators
# ASCII text, with CRLF, LF line terminators
# ASCII text, with CRLF, NEL line terminators
# ASCII text, with escape sequences
# ASCII text, with no line terminators
# ASCII text, with no line terminatorsdata
# ASCII text, with very long lines
# ASCII text, with very long lines, with CR line terminators
# ASCII text, with very long lines, with CR, LF line terminators
# ASCII text, with very long lines, with CRLF line terminators
# ASCII text, with very long lines, with CRLF, CR line terminators
# ASCII text, with very long lines, with CRLF, CR, LF line terminators
# ASCII text, with very long lines, with CRLF, LF line terminators
# ASCII text, with very long lines, with no line terminators
# ASCII text, with very long lines, with no line terminators, with escap ...
# ASCII text, with very long lines, with no line terminatorsdata
# BibTeX text file, data
# Big-endian UTF-16 Unicode English text, with CRLF line terminators
# Big-endian UTF-16 Unicode text, with CRLF line terminators
# Big-endian UTF-16 Unicode text, with CRLF, LF line terminators
# Big-endian UTF-16 Unicode text, with no line terminators
# Big-endian UTF-16 Unicode text, with very long lines, with CRLF line t ...
# Big-endian UTF-16 Unicode text, with very long lines, with no line ter ...
# C source, ASCII text
# C source, ASCII text, with CRLF line terminators
# C source, ASCII text, with CRLF, CR line terminators
# C source, ASCII text, with CRLF, LF line terminators
# C source, ASCII text, with very long lines
# C source, ASCII text, with very long lines, with CRLF line terminators
# C source, ASCII text, with very long lines, with no line terminators
# C source, ISO-8859 text, with CRLF line terminators
# C source, ISO-8859 text, with very long lines, with CRLF line terminat ...
# C source, Little-endian UTF-16 Unicode text, with CRLF line terminator ...
# C source, Little-endian UTF-16 Unicode text, with very long lines, wit ...
# C source, Non-ISO extended-ASCII text
# C source, UTF-8 Unicode (with BOM) text, with CRLF line terminators
# C source, UTF-8 Unicode (with BOM) text, with very long lines
# C source, UTF-8 Unicode (with BOM) text, with very long lines, with CR ...
# C source, UTF-8 Unicode text, with very long lines
# C source, UTF-8 Unicode text, with very long lines, with CRLF line ter ...
# C source, UTF-8 Unicode text, with very long lines, with CRLF, LF line ...
# C++ source, ASCII text
# C++ source, ASCII text, with CRLF line terminators
# C++ source, ASCII text, with very long lines
# C++ source, ASCII text, with very long lines, with CRLF line terminato ...
# C++ source, Little-endian UTF-16 Unicode text, with CRLF line terminat ...
# C++ source, Little-endian UTF-16 Unicode text, with CRLF, CR line term ...
# C++ source, UTF-8 Unicode text, with very long lines, with CRLF line t ...
# DOS batch file, ASCII text
# DOS batch file, ASCII text, with CRLF line terminators
# DOS batch file, ASCII text, with CRLF, LF line terminators
# DOS batch file, ASCII text, with no line terminators
# DOS batch file, ASCII text, with very long lines
# DOS batch file, ASCII text, with very long lines, with CRLF line termi ...
# DOS batch file, ISO-8859 text, with CRLF line terminators
# DOS batch file, ISO-8859 text, with very long lines, with CRLF, NEL li ...
# DOS batch file, Little-endian UTF-16 Unicode text, with very long line ...
# DOS batch file, Non-ISO extended-ASCII text, with CRLF line terminator ...
# DOS batch file, UTF-8 Unicode (with BOM) text, with CRLF line terminat ...
# DOS batch file, UTF-8 Unicode (with BOM) text, with very long lines, w ...
# DOS batch file, UTF-8 Unicode text, with CRLF line terminators
# EBCDIC text, with very long lines, with no line terminators, with over ...
# FoxPro FPT, blocks size 0, next free block index 1224605696
# FoxPro FPT, blocks size 0, next free block index 16253183
# FoxPro FPT, blocks size 0, next free block index 16777216
# FoxPro FPT, blocks size 0, next free block index 218103808, 1st used i ...
# FoxPro FPT, blocks size 0, next free block index 3147520
# FoxPro FPT, blocks size 0, next free block index 33161216
# FoxPro FPT, blocks size 0, next free block index 33554432
# FoxPro FPT, blocks size 0, next free block index 3826515984, 1st used  ...
# FoxPro FPT, blocks size 0, next free block index 401590474
# FoxPro FPT, blocks size 0, next free block index 417475840
# FoxPro FPT, blocks size 0, next free block index 5400016
# FoxPro FPT, blocks size 0, next free block index 825569334
# FoxPro FPT, blocks size 12337, next free block index 609436745
# FoxPro FPT, blocks size 256, next free block index 1430537728
# FoxPro FPT, blocks size 256, next free block index 1712
# FoxPro FPT, blocks size 25961, next free block index 6548
# FoxPro FPT, blocks size 26219, next free block index 1048576
# FoxPro FPT, blocks size 2816, next free block index 16909060
# FoxPro FPT, blocks size 29410, next free block index 4273659134
# FoxPro FPT, blocks size 512, next free block index 4278124544
# FoxPro FPT, blocks size 59392, next free block index 4273659134
# FoxPro FPT, blocks size 62464, next free block index 4273659134
# FoxPro FPT, blocks size 65280, next free block index 1301283584
# GIF image data, version 89a, 16 x 16HTML document, UTF-8 Unicode text, ...
# GNU gettext message catalogue, ASCII text, with very long lines, with  ...
# HTML document textHTML document, ASCII text, with very long lines,
# HTML document, ASCII text
# HTML document, ASCII text, with CR line terminators
# HTML document, ASCII text, with CR, LF line terminators
# HTML document, ASCII text, with CRLF line terminators
# HTML document, ASCII text, with CRLF, CR line terminators
# HTML document, ASCII text, with CRLF, CR, LF line terminators
# HTML document, ASCII text, with CRLF, LF line terminators
# HTML document, ASCII text, with no line terminators
# HTML document, ASCII text, with very long lines
# HTML document, ASCII text, with very long lines, with CR line terminat ...
# HTML document, ASCII text, with very long lines, with CR, LF line term ...
# HTML document, ASCII text, with very long lines, with CRLF line termin ...
# HTML document, ASCII text, with very long lines, with CRLF, CR line te ...
# HTML document, ASCII text, with very long lines, with CRLF, CR, LF lin ...
# HTML document, ASCII text, with very long lines, with CRLF, LF line te ...
# HTML document, ASCII text, with very long lines, with no line terminat ...
# HTML document, Big-endian UTF-16 Unicode text, with CRLF line terminat ...
# HTML document, ISO-8859 text
# HTML document, ISO-8859 text, with CRLF line terminators
# HTML document, ISO-8859 text, with CRLF, CR line terminators
# HTML document, ISO-8859 text, with CRLF, LF line terminators
# HTML document, ISO-8859 text, with CRLF, LF, NEL line terminators
# HTML document, ISO-8859 text, with CRLF, NEL line terminators
# HTML document, ISO-8859 text, with very long lines
# HTML document, ISO-8859 text, with very long lines, with CR, LF line t ...
# HTML document, ISO-8859 text, with very long lines, with CRLF line ter ...
# HTML document, ISO-8859 text, with very long lines, with CRLF, CR line ...
# HTML document, ISO-8859 text, with very long lines, with CRLF, CR, LF  ...
# HTML document, ISO-8859 text, with very long lines, with CRLF, LF line ...
# HTML document, ISO-8859 text, with very long lines, with CRLF, LF, NEL ...
# HTML document, ISO-8859 text, with very long lines, with CRLF, NEL lin ...
# HTML document, ISO-8859 text, with very long lines, with LF, NEL line  ...
# HTML document, ISO-8859 text, with very long lines, with no line termi ...
# HTML document, Little-endian UTF-16 Unicode text, with CRLF line termi ...
# HTML document, Little-endian UTF-16 Unicode text, with CRLF, CR line t ...
# HTML document, Little-endian UTF-16 Unicode text, with CRLF, LF line t ...
# HTML document, Little-endian UTF-16 Unicode text, with very long lines
# HTML document, Little-endian UTF-16 Unicode text, with very long lines ...
# HTML document, Non-ISO extended-ASCII text
# HTML document, Non-ISO extended-ASCII text, with CR, LF line terminato ...
# HTML document, Non-ISO extended-ASCII text, with CRLF line terminators
# HTML document, Non-ISO extended-ASCII text, with CRLF, CR line termina ...
# HTML document, Non-ISO extended-ASCII text, with CRLF, CR, LF, NEL lin ...
# HTML document, Non-ISO extended-ASCII text, with CRLF, LF line termina ...
# HTML document, Non-ISO extended-ASCII text, with CRLF, LF, NEL line te ...
# HTML document, Non-ISO extended-ASCII text, with CRLF, NEL line termin ...
# HTML document, Non-ISO extended-ASCII text, with LF, NEL line terminat ...
# HTML document, Non-ISO extended-ASCII text, with very long lines
# HTML document, Non-ISO extended-ASCII text, with very long lines, with ...
# HTML document, UTF-8 Unicode (with BOM) text
# HTML document, UTF-8 Unicode (with BOM) text, with CRLF line terminato ...
# HTML document, UTF-8 Unicode (with BOM) text, with CRLF, CR line termi ...
# HTML document, UTF-8 Unicode (with BOM) text, with CRLF, CR, LF line t ...
# HTML document, UTF-8 Unicode (with BOM) text, with CRLF, LF line termi ...
# HTML document, UTF-8 Unicode (with BOM) text, with no line terminators
# HTML document, UTF-8 Unicode (with BOM) text, with very long lines
# HTML document, UTF-8 Unicode (with BOM) text, with very long lines, wi ...
# HTML document, UTF-8 Unicode text
# HTML document, UTF-8 Unicode text, with CR line terminators
# HTML document, UTF-8 Unicode text, with CRLF line terminators
# HTML document, UTF-8 Unicode text, with CRLF, CR line terminators
# HTML document, UTF-8 Unicode text, with CRLF, CR, LF line terminators
# HTML document, UTF-8 Unicode text, with CRLF, LF line terminators
# HTML document, UTF-8 Unicode text, with CRLF, LF line terminatorsPE32  ...
# HTML document, UTF-8 Unicode text, with no line terminators
# HTML document, UTF-8 Unicode text, with very long lines
# HTML document, UTF-8 Unicode text, with very long lines, with CR, LF l ...
# HTML document, UTF-8 Unicode text, with very long lines, with CRLF lin ...
# HTML document, UTF-8 Unicode text, with very long lines, with CRLF, CR ...
# HTML document, UTF-8 Unicode text, with very long lines, with CRLF, LF ...
# HTML document, UTF-8 Unicode text, with very long lines, with LF, NEL  ...
# HTML document, UTF-8 Unicode text, with very long lines, with no line  ...
# ISO-8859 C program text, with very long lines
# ISO-8859 C program text, with very long lines, with CRLF line terminat ...
# ISO-8859 C++ program text
# ISO-8859 C++ program text, with CRLF line terminators
# ISO-8859 C++ program text, with CRLF, LF line terminators
# ISO-8859 C++ program text, with very long lines, with CRLF line termin ...
# ISO-8859 C++ program text, with very long lines, with CRLF, LF line te ...
# ISO-8859 English text, with CRLF line terminators
# ISO-8859 English text, with CRLF, CR line terminators
# ISO-8859 English text, with very long lines
# ISO-8859 English text, with very long lines, with CRLF line terminator ...
# ISO-8859 English text, with very long lines, with CRLF, CR, LF line te ...
# ISO-8859 HTML document text, with very long lines, with CRLF line term ...
# ISO-8859 text
# ISO-8859 text, with CR line terminators
# ISO-8859 text, with CR, NEL line terminators, with escape sequences
# ISO-8859 text, with CRLF line terminators
# ISO-8859 text, with CRLF, CR line terminators
# ISO-8859 text, with CRLF, CR, LF line terminators
# ISO-8859 text, with CRLF, LF line terminators
# ISO-8859 text, with no line terminators
# ISO-8859 text, with very long lines
# ISO-8859 text, with very long lines, with CR line terminators
# ISO-8859 text, with very long lines, with CRLF line terminators
# ISO-8859 text, with very long lines, with CRLF, CR, LF line terminator ...
# ISO-8859 text, with very long lines, with CRLF, LF line terminators
# ISO-8859 text, with very long lines, with no line terminators
# ISO-8859 text, with very long lines, with overstriking
# International EBCDIC text, with very long lines, with no line terminat ...
# LaTeX 2e document, ISO-8859 text, with CRLF line terminators
# LaTeX 2e document, UTF-8 Unicode text
# Lisp/Scheme program, ASCII text
# Lisp/Scheme program, ASCII text, with CRLF line terminators
# Lisp/Scheme program, ISO-8859 text, with CRLF line terminators
# Lisp/Scheme program, ISO-8859 text, with very long lines, with CRLF li ...
# Little-endian UTF-16 Unicode C program text, with very long lines, wit ...
# Little-endian UTF-16 Unicode English text
# Little-endian UTF-16 Unicode English text, with CRLF line terminators
# Little-endian UTF-16 Unicode English text, with CRLF, CR line terminat ...
# Little-endian UTF-16 Unicode English text, with very long lines, with  ...
# Little-endian UTF-16 Unicode text
# Little-endian UTF-16 Unicode text, with CR line terminators
# Little-endian UTF-16 Unicode text, with CR, LF line terminators
# Little-endian UTF-16 Unicode text, with CRLF line terminators
# Little-endian UTF-16 Unicode text, with CRLF, CR line terminators
# Little-endian UTF-16 Unicode text, with no line terminators
# Little-endian UTF-16 Unicode text, with very long lines
# Little-endian UTF-16 Unicode text, with very long lines, with CR line  ...
# Little-endian UTF-16 Unicode text, with very long lines, with CRLF lin ...
# Little-endian UTF-16 Unicode text, with very long lines, with CRLF, CR ...
# Little-endian UTF-16 Unicode text, with very long lines, with CRLF, NE ...
# Little-endian UTF-16 Unicode text, with very long lines, with NEL line ...
# Little-endian UTF-16 Unicode text, with very long lines, with no line  ...
# M3U playlist, ASCII text
# M3U playlist, ASCII text, with very long lines, with CRLF line termina ...
# M3U playlist, UTF-8 Unicode text
# M3U playlist, UTF-8 Unicode text, with CRLF line terminators
# MIME entity, ASCII text, with CRLF line terminators
# MIME entity, ASCII text, with CRLF, LF line terminators
# MIME entity, ASCII text, with very long lines
# MIME entity, ASCII text, with very long lines, with CRLF line terminat ...
# MIME entity, ASCII text, with very long lines, with CRLF, CR line term ...
# MIME entity, ISO-8859 text
# MIME entity, ISO-8859 text, with CRLF line terminators
# MIME entity, ISO-8859 text, with CRLF, CR line terminators
# MIME entity, ISO-8859 text, with very long lines
# MIME entity, ISO-8859 text, with very long lines, with CRLF line termi ...
# MIME entity, ISO-8859 text, with very long lines, with CRLF, CR line t ...
# MIME entity, Non-ISO extended-ASCII text, with CRLF line terminators
# MIME entity, Non-ISO extended-ASCII text, with very long lines, with C ...
# MIME entity, UTF-8 Unicode text, with CRLF, CR line terminators
# MIME entity, UTF-8 Unicode text, with very long lines, with CRLF line  ...
# MS Windows 95 Internet shortcut text (URL=< >),
# MS Windows icon resource - 1 iconHTML document, ASCII text, with very  ...
# MS Windows icon resource - 1 iconHTML document, ISO-8859 text, with ve ...
# Motorola S-Record; binary data in text format
# Non-ISO extended-ASCII English text, with CRLF line terminators
# Non-ISO extended-ASCII English text, with very long lines
# Non-ISO extended-ASCII English text, with very long lines, with CRLF l ...
# Non-ISO extended-ASCII mail text, with CRLF line terminators
# Non-ISO extended-ASCII text
# Non-ISO extended-ASCII text, with CRLF line terminators
# Non-ISO extended-ASCII text, with CRLF, LF line terminators
# Non-ISO extended-ASCII text, with CRLF, NEL line terminators
# Non-ISO extended-ASCII text, with no line terminators
# Non-ISO extended-ASCII text, with very long lines
# Non-ISO extended-ASCII text, with very long lines, with CRLF line term ...
# Non-ISO extended-ASCII text, with very long lines, with CRLF, LF line  ...
# Non-ISO extended-ASCII text, with very long lines, with CRLF, LF, NEL  ...
# Non-ISO extended-ASCII text, with very long lines, with CRLF, NEL line ...
# Non-ISO extended-ASCII text, with very long lines, with NEL line termi ...
# Non-ISO extended-ASCII text, with very long lines, with no line termin ...
# OpenDocument Text
# OpenDocument Text Template
# PHP script, ASCII text
# PHP script, ASCII text, with CRLF line terminators
# PHP script, ASCII text, with CRLF, CR line terminators
# PHP script, ASCII text, with CRLF, CR, LF line terminators
# PHP script, ASCII text, with CRLF, LF line terminators
# PHP script, ASCII text, with no line terminators
# PHP script, ASCII text, with very long lines
# PHP script, ASCII text, with very long lines, with CR line terminators
# PHP script, ASCII text, with very long lines, with CRLF line terminato ...
# PHP script, ASCII text, with very long lines, with CRLF, CR line termi ...
# PHP script, ASCII text, with very long lines, with CRLF, CR, LF line t ...
# PHP script, ASCII text, with very long lines, with CRLF, LF line termi ...
# PHP script, ASCII text, with very long lines, with no line terminators
# PHP script, ISO-8859 text, with CRLF line terminators
# PHP script, ISO-8859 text, with very long lines
# PHP script, ISO-8859 text, with very long lines, with CRLF line termin ...
# PHP script, ISO-8859 text, with very long lines, with CRLF, LF line te ...
# PHP script, Non-ISO extended-ASCII text, with CRLF line terminators
# PHP script, Non-ISO extended-ASCII text, with very long lines, with CR ...
# PHP script, Non-ISO extended-ASCII text, with very long lines, with NE ...
# PHP script, UTF-8 Unicode (with BOM) text, with CRLF line terminators
# PHP script, UTF-8 Unicode (with BOM) text, with very long lines
# PHP script, UTF-8 Unicode (with BOM) text, with very long lines, with  ...
# PHP script, UTF-8 Unicode text
# PHP script, UTF-8 Unicode text, with CRLF line terminators
# PHP script, UTF-8 Unicode text, with CRLF, LF line terminators
# PHP script, UTF-8 Unicode text, with very long lines
# PHP script, UTF-8 Unicode text, with very long lines, with CRLF line t ...
# PLS playlist, ASCII text
# Pascal source, ASCII text
# Pascal source, ASCII text, with CRLF line terminators
# Pascal source, ASCII text, with CRLF, CR line terminators
# Pascal source, ASCII text, with CRLF, LF line terminators
# Pascal source, ASCII text, with very long lines
# Pascal source, ASCII text, with very long lines, with CRLF line termin ...
# Pascal source, Little-endian UTF-16 Unicode text, with CRLF line termi ...
# Pascal source, UTF-8 Unicode text, with CRLF line terminators
# Pascal source, UTF-8 Unicode text, with very long lines
# Pascal source, UTF-8 Unicode text, with very long lines, with CRLF lin ...
# Perl5 module source, ASCII text
# Perl5 module source, ASCII text, with CRLF line terminators
# PostScript document text
# PostScript document text conforming DSC level 2.0
# PostScript document text conforming DSC level 3.0
# PostScript document text conforming DSC level 3.0, Level 2
# PostScript document text conforming DSC level 3.0, Level 3\015
# PostScript document text conforming DSC level 3.1, type EPS, Level 2 \ ...
# RFC 822 mail, ASCII text
# RFC 822 mail, ASCII text, with CRLF line terminators
# RFC 822 mail, ASCII text, with CRLF, CR line terminators
# RFC 822 mail, ASCII text, with CRLF, LF line terminators
# RFC 822 mail, ASCII text, with very long lines
# RFC 822 mail, ASCII text, with very long lines, with CRLF line termina ...
# RFC 822 mail, ASCII text, with very long lines, with CRLF, CR line ter ...
# RFC 822 mail, ASCII text, with very long lines, with CRLF, LF line ter ...
# RFC 822 mail, ISO-8859 text
# RFC 822 mail, ISO-8859 text, with CRLF line terminators
# RFC 822 mail, ISO-8859 text, with very long lines, with CRLF line term ...
# RFC 822 mail, Non-ISO extended-ASCII text
# RFC 822 mail, Non-ISO extended-ASCII text, with CRLF line terminators
# RFC 822 mail, Non-ISO extended-ASCII text, with very long lines, with  ...
# RFC 822 mail, UTF-8 Unicode text
# RFC 822 mail, UTF-8 Unicode text, with CRLF line terminators
# RFC 822 mail, UTF-8 Unicode text, with very long lines, with CRLF line ...
# Rich Text Format data, unknown version
# Rich Text Format data, version 1, ANSI
# Rich Text Format data, version 1, Apple Macintosh
# Rich Text Format data, version 1, unknown character set
# Ruby module source, UTF-8 Unicode text
# Ruby script, ASCII text
# Ruby script, ASCII text, with CRLF line terminators
# Ruby script, ASCII text, with very long lines
# Ruby script, UTF-8 Unicode text
# SMTP mail, ASCII text
# SMTP mail, ASCII text, with CRLF line terminators
# SMTP mail, ASCII text, with very long lines
# SMTP mail, ASCII text, with very long lines, with CRLF line terminator ...
# SMTP mail, ISO-8859 text, with CRLF line terminators
# SMTP mail, ISO-8859 text, with very long lines, with CRLF line termina ...
# SMTP mail, Non-ISO extended-ASCII text, with CRLF line terminators
# SMTP mail, Non-ISO extended-ASCII text, with very long lines, with CRL ...
# SMTP mail, UTF-8 Unicode text
# SMTP mail, UTF-8 Unicode text, with CRLF line terminators
# SMTP mail, UTF-8 Unicode text, with very long lines, with CRLF line te ...
# Text/HTML,
# UTF-8 Unicode (with BOM) C++ program text, with CRLF line terminators
# UTF-8 Unicode (with BOM) C++ program text, with very long lines, with  ...
# UTF-8 Unicode (with BOM) English text, with CRLF line terminators
# UTF-8 Unicode (with BOM) English text, with very long lines
# UTF-8 Unicode (with BOM) English text, with very long lines, with CRLF ...
# UTF-8 Unicode (with BOM) English text, with very long linesPE32 execut ...
# UTF-8 Unicode (with BOM) text
# UTF-8 Unicode (with BOM) text, with CRLF line terminators
# UTF-8 Unicode (with BOM) text, with CRLF, CR line terminators
# UTF-8 Unicode (with BOM) text, with CRLF, LF line terminators
# UTF-8 Unicode (with BOM) text, with no line terminators
# UTF-8 Unicode (with BOM) text, with very long lines
# UTF-8 Unicode (with BOM) text, with very long lines, with CR line term ...
# UTF-8 Unicode (with BOM) text, with very long lines, with CRLF line te ...
# UTF-8 Unicode (with BOM) text, with very long lines, with CRLF, CR lin ...
# UTF-8 Unicode (with BOM) text, with very long lines, with CRLF, CR, LF ...
# UTF-8 Unicode (with BOM) text, with very long lines, with no line term ...
# UTF-8 Unicode C program text
# UTF-8 Unicode C++ program text, with CRLF line terminators
# UTF-8 Unicode C++ program text, with very long lines
# UTF-8 Unicode C++ program text, with very long lines, with CRLF line t ...
# UTF-8 Unicode C++ program text, with very long lines, with CRLF, LF li ...
# UTF-8 Unicode English text
# UTF-8 Unicode English text, with CRLF line terminators
# UTF-8 Unicode English text, with very long lines
# UTF-8 Unicode English text, with very long lines, with CRLF line termi ...
# UTF-8 Unicode English text, with very long lines, with CRLF, CR, LF li ...
# UTF-8 Unicode HTML document text, with very long lines, with CRLF line ...
# UTF-8 Unicode mail text, with CRLF line terminators
# UTF-8 Unicode text
# UTF-8 Unicode text, with CR, LF line terminators
# UTF-8 Unicode text, with CRLF line terminators
# UTF-8 Unicode text, with CRLF, CR line terminators
# UTF-8 Unicode text, with CRLF, LF line terminators
# UTF-8 Unicode text, with no line terminators
# UTF-8 Unicode text, with very long lines
# UTF-8 Unicode text, with very long lines, with CR line terminators
# UTF-8 Unicode text, with very long lines, with CRLF line terminators
# UTF-8 Unicode text, with very long lines, with CRLF, CR line terminato ...
# UTF-8 Unicode text, with very long lines, with CRLF, CR, LF line termi ...
# UTF-8 Unicode text, with very long lines, with CRLF, LF line terminato ...
# UTF-8 Unicode text, with very long lines, with LF, NEL line terminator ...
# UTF-8 Unicode text, with very long lines, with no line terminators
# UTF-8 Unicode text, with very long lines, with no line terminators, wi ...
# Windows Registry text (Win2K or above)
# Windows Registry text (Win95 or above)
# XML  document text
# XML  document, Little-endian UTF-16 Unicode text
# XML  document, Little-endian UTF-16 Unicode text, with CRLF, CR line t ...
# XML  document, UTF-8 Unicode (with BOM) text, with CRLF line terminato ...
# XML  document, UTF-8 Unicode (with BOM) text, with very long lines, wi ...
# XML 1.0 document text
# XML 1.0 document, Little-endian UTF-16 Unicode text, with CRLF line te ...
# XML 1.0 document, Little-endian UTF-16 Unicode text, with CRLF, CR lin ...
# XML 1.0 document, Little-endian UTF-16 Unicode text, with CRLF, CR, LF ...
# XML 1.0 document, Little-endian UTF-16 Unicode text, with very long li ...
# XML 1.0 document, UTF-8 Unicode (with BOM) text
# XML 1.0 document, UTF-8 Unicode (with BOM) text, with CRLF line termin ...
# XML 1.0 document, UTF-8 Unicode (with BOM) text, with no line terminat ...
# XML 1.0 document, UTF-8 Unicode (with BOM) text, with very long lines
# XML 1.0 document, UTF-8 Unicode (with BOM) text, with very long lines, ...
# XML document text
# XML document, ASCII text
# XML document, ASCII text, with CRLF line terminators
# XML document, ASCII text, with very long lines, with CRLF line termina ...
# XML document, ISO-8859 text, with very long lines, with CRLF line term ...
# XML document, UTF-8 Unicode (with BOM) text, with very long lines, wit ...
# a /usr/bin/coreutils --coreutils-prog-shebang=head script, ASCII text  ...
# a /usr/bin/coreutils --coreutils-prog-shebang=sleep script, ASCII text ...
# a /usr/bin/coreutils --coreutils-prog-shebang=uname script, ASCII text ...
# a /usr/bin/coreutils --coreutils-prog-shebang=vdir script, ASCII text  ...
# a /usr/bin/coreutils --coreutils-prog-shebang=wc script, ASCII text ex ...
# a /usr/bin/coreutils --coreutils-prog-shebang=yes script, ASCII text e ...
# assembler source text
# dataHTML document, ASCII text, with very long lines
# diff output, ASCII text, with CRLF line terminators
# exported SGML document, ASCII text
# exported SGML document, ASCII text, with CRLF line terminators
# exported SGML document, ASCII text, with no line terminators
# exported SGML document, ASCII text, with very long lines
# exported SGML document, ASCII text, with very long lines, with CRLF li ...
# exported SGML document, ASCII text, with very long lines, with no line ...
# exported SGML document, ISO-8859 text, with very long lines, with CRLF ...
# exported SGML document, Non-ISO extended-ASCII text, with CRLF line te ...
# exported SGML document, UTF-8 Unicode (with BOM) text, with CRLF line  ...
# exported SGML document, UTF-8 Unicode (with BOM) text, with very long  ...
# exported SGML document, UTF-8 Unicode text, with very long lines
# exported SGML document, UTF-8 Unicode text, with very long lines, with ...
# makefile script, ASCII text
# news or mail, ASCII text, with CRLF line terminators
# news or mail, ASCII text, with very long lines, with CRLF line termina ...
# news or mail, ISO-8859 text
# news or mail, Non-ISO extended-ASCII text, with CRLF line terminators
# news, ASCII text, with CRLF line terminators
# smtp mail, ASCII text
# smtp mail, ASCII text, with CRLF line terminators
# smtp mail, ASCII text, with very long lines, with CRLF, CR line termin ...
# text/html\015,
# troff or preprocessor input, ASCII text
# troff or preprocessor input, ASCII text, with CRLF line terminators
# troff or preprocessor input, ASCII text, with very long lines
# troff or preprocessor input, ASCII text, with very long lines, with CR ...
# troff or preprocessor input, ISO-8859 text
# troff or preprocessor input, ISO-8859 text, with CRLF line terminators
# troff or preprocessor input, ISO-8859 text, with very long lines
# troff or preprocessor input, ISO-8859 text, with very long lines, with ...
# troff or preprocessor input, Little-endian UTF-16 Unicode text, with C ...
# troff or preprocessor input, UTF-8 Unicode text, with CRLF line termin ...
# troff or preprocessor input, UTF-8 Unicode text, with very long lines, ...
# unified diff output, ASCII text
# uuencoded or xxencoded, ASCII text
# uuencoded or xxencoded, ASCII text, with CRLF line terminators

# %% [markdown]
# ## Media (images, audio, video)

# %%
media_keywords = ['image', 'audio', 'video', 'mpeg', 'bitmap', 'icon resource']
media_crit = headers.file_type.map(mapKeywords(media_keywords))
media_types = sorted(headers.file_type[~exec_crit & ~text_crit & media_crit].unique())
print('Total unique file types with {}: {}\n'.format(media_keywords, len(media_types)))
for t in media_types:
    print(t)
# Out:
# Total unique file types with ['image', 'audio', 'video', 'mpeg', 'bitmap', 'icon resource']: 1652
#
# Adobe Photoshop Image, 1 x 1, RGBA, 4x 8-bit channels
# Adobe Photoshop Image, 1000 x 349, RGB, 3x 8-bit channels
# Adobe Photoshop Image, 1000 x 624, RGB, 3x 8-bit channels
# Adobe Photoshop Image, 1012 x 638, RGB, 3x 8-bit channels
# Adobe Photoshop Image, 1200 x 847, RGBA, 4x 8-bit channels
# Adobe Photoshop Image, 1590 x 2114, RGB, 3x 8-bit channels
# Adobe Photoshop Image, 1850 x 2700, RGB, 3x 8-bit channels
# Adobe Photoshop Image, 225 x 98, RGB, 3x 8-bit channels
# Adobe Photoshop Image, 3500 x 4000, RGB, 3x 8-bit channels
# Adobe Photoshop Image, 400 x 250, RGB, 3x 8-bit channels
# Adobe Photoshop Image, 500 x 653, RGBA, 4x 8-bit channels
# Adobe Photoshop Image, 6800 x 9359, grayscale, 8-bit channel
# Adobe Photoshop Image, 992 x 1388, RGB, 3x 8-bit channels
# AmigaOS bitmap font
# Atari ATR image
# Audio file with ID3 version 2.2.0, contains: MPEG ADTS, layer III, v1, ...
# Audio file with ID3 version 2.3.0
# Audio file with ID3 version 2.3.0, contains:
# Audio file with ID3 version 2.3.0, contains: Audio file with ID3 versi ...
# Audio file with ID3 version 2.3.0, contains: MPEG ADTS, layer III,  v2 ...
# Audio file with ID3 version 2.3.0, contains: MPEG ADTS, layer III, v1, ...
# Audio file with ID3 version 2.3.0, contains: MPEG ADTS, layer III, v2, ...
# Audio file with ID3 version 2.4.0
# Audio file with ID3 version 2.4.0, contains: MPEG ADTS, AAC, v2 LC, 22 ...
# Audio file with ID3 version 2.4.0, contains: MPEG ADTS, layer III, v1, ...
# Bink Video rev.i, 640x480, 565 frames at rate 1/25, 1 audio track 3200 ...
# CoreAudio Format audio file
# Curses screen image
# FLAC audio bitstream data, 16 bit, stereo, 44.1 kHz, 8640072 samples
# GEM Image data 124 x 124, 4 planes, 85 x 85 pixelsize
# GIF image data 15457 x 29282
# GIF image data 23112 x 2573
# GIF image data 3425 x 15370
# GIF image data 3425 x 3338
# GIF image data, version 87a, 1 x 1
# GIF image data, version 87a, 113 x 46
# GIF image data, version 87a, 1280 x 768
# GIF image data, version 87a, 140 x 34
# GIF image data, version 87a, 144 x 22
# GIF image data, version 87a, 1474 x 1974
# GIF image data, version 87a, 16 x 16
# GIF image data, version 87a, 19 x 20
# GIF image data, version 87a, 2 x 1
# GIF image data, version 87a, 20 x 5
# GIF image data, version 87a, 201 x 201
# GIF image data, version 87a, 205 x 101
# GIF image data, version 87a, 205 x 37
# GIF image data, version 87a, 207 x 105
# GIF image data, version 87a, 22 x 23
# GIF image data, version 87a, 237 x 281
# GIF image data, version 87a, 250 x 250
# GIF image data, version 87a, 259 x 241
# GIF image data, version 87a, 289 x 240
# GIF image data, version 87a, 299 x 347
# GIF image data, version 87a, 306 x 203
# GIF image data, version 87a, 319 x 434
# GIF image data, version 87a, 3550
# GIF image data, version 87a, 359 x 449
# GIF image data, version 87a, 383 x 308
# GIF image data, version 87a, 385 x 385
# GIF image data, version 87a, 400 x 225
# GIF image data, version 87a, 434 x 614
# GIF image data, version 87a, 446 x 248
# GIF image data, version 87a, 5 x 1
# GIF image data, version 87a, 512 x 384
# GIF image data, version 87a, 582 x 166
# GIF image data, version 87a, 645 x 50
# GIF image data, version 87a, 652 x 50
# GIF image data, version 87a, 670 x 843
# GIF image data, version 87a, 695 x 51
# GIF image data, version 87a, 706 x 386
# GIF image data, version 87a, 720 x 1
# GIF image data, version 87a, 736 x 527
# GIF image data, version 89a, 1 x 1
# GIF image data, version 89a, 1 x 300
# GIF image data, version 89a, 10 x 10
# GIF image data, version 89a, 10 x 9000
# GIF image data, version 89a, 100 x 100
# GIF image data, version 89a, 100 x 27
# GIF image data, version 89a, 100 x 30
# GIF image data, version 89a, 100 x 50
# GIF image data, version 89a, 1000 x 60
# GIF image data, version 89a, 1004 x 617
# GIF image data, version 89a, 10045 x 6193
# GIF image data, version 89a, 102 x 47
# GIF image data, version 89a, 10370 x 16191
# GIF image data, version 89a, 104 x 105
# GIF image data, version 89a, 104 x 183
# GIF image data, version 89a, 108 x 38
# GIF image data, version 89a, 11 x 11
# GIF image data, version 89a, 110 x 109
# GIF image data, version 89a, 111 x 100
# GIF image data, version 89a, 114 x 118
# GIF image data, version 89a, 115 x 70
# GIF image data, version 89a, 12 x 11
# GIF image data, version 89a, 12 x 12
# GIF image data, version 89a, 12 x 14
# GIF image data, version 89a, 120 x 60
# GIF image data, version 89a, 120 x 600
# GIF image data, version 89a, 120 x 67
# GIF image data, version 89a, 120 x 70
# GIF image data, version 89a, 120 x 90
# GIF image data, version 89a, 120 x 95
# GIF image data, version 89a, 121 x 75
# GIF image data, version 89a, 123 x 46
# GIF image data, version 89a, 124 x 28
# GIF image data, version 89a, 128 x 40
# GIF image data, version 89a, 1280 x 916
# GIF image data, version 89a, 1280 x 986
# GIF image data, version 89a, 13 x 10
# GIF image data, version 89a, 13 x 15
# GIF image data, version 89a, 133 x 98
# GIF image data, version 89a, 135 x 240
# GIF image data, version 89a, 136 x 137
# GIF image data, version 89a, 140 x 70
# GIF image data, version 89a, 140 x 79
# GIF image data, version 89a, 140 x 93
# GIF image data, version 89a, 1440 x 900
# GIF image data, version 89a, 15 x 15
# GIF image data, version 89a, 150 x 1
# GIF image data, version 89a, 150 x 120
# GIF image data, version 89a, 150 x 150
# GIF image data, version 89a, 1502 x 385
# GIF image data, version 89a, 1504 x 867
# GIF image data, version 89a, 153 x 31
# GIF image data, version 89a, 15392 x 25893
# GIF image data, version 89a, 154 x 35
# GIF image data, version 89a, 15423 x 25459
# GIF image data, version 89a, 15423 x 28735
# GIF image data, version 89a, 15440 x 28735
# GIF image data, version 89a, 157 x 28
# GIF image data, version 89a, 16 x 1
# GIF image data, version 89a, 16 x 11
# GIF image data, version 89a, 16 x 16
# GIF image data, version 89a, 16 x 20
# GIF image data, version 89a, 16 x 96
# GIF image data, version 89a, 160 x 100
# GIF image data, version 89a, 160 x 39
# GIF image data, version 89a, 16129 x 16129
# GIF image data, version 89a, 16129 x 16191
# GIF image data, version 89a, 16129 x 19536
# GIF image data, version 89a, 16188 x 26736
# GIF image data, version 89a, 16191 x 16191
# GIF image data, version 89a, 162 x 38
# GIF image data, version 89a, 168 x 100
# GIF image data, version 89a, 170 x 170
# GIF image data, version 89a, 172 x 31
# GIF image data, version 89a, 173 x 69
# GIF image data, version 89a, 1774 x 18
# GIF image data, version 89a, 180 x 180
# GIF image data, version 89a, 180 x 29
# GIF image data, version 89a, 1800 x 1200
# GIF image data, version 89a, 182 x 47
# GIF image data, version 89a, 183 x 62
# GIF image data, version 89a, 1830 x 1092
# GIF image data, version 89a, 1844 x 1976
# GIF image data, version 89a, 185 x 280
# GIF image data, version 89a, 18945 x
# GIF image data, version 89a, 19 x 16
# GIF image data, version 89a, 19 x 19
# GIF image data, version 89a, 19 x 7
# GIF image data, version 89a, 190 x 250
# GIF image data, version 89a, 190 x 31
# GIF image data, version 89a, 190 x 65
# GIF image data, version 89a, 190 x 90
# GIF image data, version 89a, 1920 x 1200
# GIF image data, version 89a, 193 x 48
# GIF image data, version 89a, 19527 x 15439
# GIF image data, version 89a, 198 x 80
# GIF image data, version 89a, 2 x 2
# GIF image data, version 89a, 20 x 17
# GIF image data, version 89a, 20 x 20
# GIF image data, version 89a, 20 x 22
# GIF image data, version 89a, 200 x 200
# GIF image data, version 89a, 200 x 60
# GIF image data, version 89a, 2000 x 1500
# GIF image data, version 89a, 209 x 33
# GIF image data, version 89a, 21 x 21
# GIF image data, version 89a, 210 x 70
# GIF image data, version 89a, 215 x 100
# GIF image data, version 89a, 22 x 10
# GIF image data, version 89a, 22 x 17
# GIF image data, version 89a, 22 x 22
# GIF image data, version 89a, 220 x 250
# GIF image data, version 89a, 221 x 39
# GIF image data, version 89a, 224 x 224
# GIF image data, version 89a, 225 x 275
# GIF image data, version 89a, 225 x 50
# GIF image data, version 89a, 23 x 22
# GIF image data, version 89a, 239 x 150
# GIF image data, version 89a, 24 x 15
# GIF image data, version 89a, 24 x 24
# GIF image data, version 89a, 24 x 35
# GIF image data, version 89a, 240 x 255
# GIF image data, version 89a, 245 x 200
# GIF image data, version 89a, 248 x 193
# GIF image data, version 89a, 25 x 25
# GIF image data, version 89a, 25 x 31
# GIF image data, version 89a, 250 x 166
# GIF image data, version 89a, 250 x 63
# GIF image data, version 89a, 256 x 256
# GIF image data, version 89a, 2572 x 3288
# GIF image data, version 89a, 2573 x 16188
# GIF image data, version 89a, 2573 x 9532
# GIF image data, version 89a, 26 x 22
# GIF image data, version 89a, 2609 x 16188
# GIF image data, version 89a, 2609 x 18759
# GIF image data, version 89a, 2609 x 8224
# GIF image data, version 89a, 2619 x 18759
# GIF image data, version 89a, 263 x 156
# GIF image data, version 89a, 2631 x 16188
# GIF image data, version 89a, 267 x 42
# GIF image data, version 89a, 27 x 40
# GIF image data, version 89a, 270 x 180
# GIF image data, version 89a, 270 x 200
# GIF image data, version 89a, 270 x 42
# GIF image data, version 89a, 273 x 275
# GIF image data, version 89a, 275 x 189
# GIF image data, version 89a, 27711 x 30319
# GIF image data, version 89a, 27719 x 25199
# GIF image data, version 89a, 280 x 226
# GIF image data, version 89a, 280 x 47
# GIF image data, version 89a, 280 x 50
# GIF image data, version 89a, 28524 x 25974
# GIF image data, version 89a, 288 x 170
# GIF image data, version 89a, 288 x 288
# GIF image data, version 89a, 292 x 100
# GIF image data, version 89a, 297 x 229
# GIF image data, version 89a, 3 x 2
# GIF image data, version 89a, 300 x 200
# GIF image data, version 89a, 300 x 250
# GIF image data, version 89a, 300 x 56
# GIF image data, version 89a, 300 x 90
# GIF image data, version 89a, 31 x 31
# GIF image data, version 89a, 310 x 25
# GIF image data, version 89a, 312 x 397
# GIF image data, version 89a, 32 x 32
# GIF image data, version 89a, 320 x 240
# GIF image data, version 89a, 320 x 425
# GIF image data, version 89a, 325 x 53
# GIF image data, version 89a, 330 x 334
# GIF image data, version 89a, 336 x 336
# GIF image data, version 89a, 3387 x 15370
# GIF image data, version 89a, 34 x 34
# GIF image data, version 89a, 345 x 176
# GIF image data, version 89a, 348 x 378
# GIF image data, version 89a, 350 x 150
# GIF image data, version 89a, 350 x 263
# GIF image data, version 89a, 350 x 350
# GIF image data, version 89a, 351 x 276
# GIF image data, version 89a, 360 x 240
# GIF image data, version 89a, 363 x 25
# GIF image data, version 89a, 375 x 197
# GIF image data, version 89a, 3877 x 5363
# GIF image data, version 89a, 39 x 40
# GIF image data, version 89a, 397 x 283
# GIF image data, version 89a, 4 x 4
# GIF image data, version 89a, 40 x 16
# GIF image data, version 89a, 40 x 50
# GIF image data, version 89a, 400 x 270
# GIF image data, version 89a, 400 x 300
# GIF image data, version 89a, 400 x 331
# GIF image data, version 89a, 407 x 15
# GIF image data, version 89a, 408 x 576
# GIF image data, version 89a, 411 x 380
# GIF image data, version 89a, 416 x 26
# GIF image data, version 89a, 42 x 39
# GIF image data, version 89a, 425 x 125
# GIF image data, version 89a, 425 x 267
# GIF image data, version 89a, 444 x 283
# GIF image data, version 89a, 444 x 62
# GIF image data, version 89a, 447 x 321
# GIF image data, version 89a, 450 x 596
# GIF image data, version 89a, 450 x 639
# GIF image data, version 89a, 4608 x 2592
# GIF image data, version 89a, 461 x 305
# GIF image data, version 89a, 468 x 60
# GIF image data, version 89a, 48 x 48
# GIF image data, version 89a, 480 x 270
# GIF image data, version 89a, 480 x 320
# GIF image data, version 89a, 480 x 360
# GIF image data, version 89a, 480 x 600
# GIF image data, version 89a, 487 x 229
# GIF image data, version 89a, 487 x 319
# GIF image data, version 89a, 49 x 50
# GIF image data, version 89a, 490 x 80
# GIF image data, version 89a, 5 x 5
# GIF image data, version 89a, 50 x 42
# GIF image data, version 89a, 50 x 50
# GIF image data, version 89a, 500 x 1
# GIF image data, version 89a, 500 x 185
# GIF image data, version 89a, 500 x 279
# GIF image data, version 89a, 500 x 280
# GIF image data, version 89a, 500 x 282
# GIF image data, version 89a, 500 x 718
# GIF image data, version 89a, 500 x 75
# GIF image data, version 89a, 500 x 80
# GIF image data, version 89a, 504 x 269
# GIF image data, version 89a, 51 x 10
# GIF image data, version 89a, 52 x 17
# GIF image data, version 89a, 520 x 144
# GIF image data, version 89a, 522 x 262
# GIF image data, version 89a, 526 x 157
# GIF image data, version 89a, 541 x 244
# GIF image data, version 89a, 550 x 120
# GIF image data, version 89a, 556 x 566
# GIF image data, version 89a, 560 x 34
# GIF image data, version 89a, 560 x 52
# GIF image data, version 89a, 574 x 392
# GIF image data, version 89a, 574 x 420
# GIF image data, version 89a, 580 x 13
# GIF image data, version 89a, 581 x 509
# GIF image data, version 89a, 590 x 25
# GIF image data, version 89a, 593 x 170
# GIF image data, version 89a, 594 x 433
# GIF image data, version 89a, 6 x 5
# GIF image data, version 89a, 600 x 10
# GIF image data, version 89a, 600 x 133
# GIF image data, version 89a, 600 x 338
# GIF image data, version 89a, 600 x 400
# GIF image data, version 89a, 600 x 777
# GIF image data, version 89a, 613 x 162
# GIF image data, version 89a, 64 x 64
# GIF image data, version 89a, 640 x 1680
# GIF image data, version 89a, 640 x 199
# GIF image data, version 89a, 640 x 31
# GIF image data, version 89a, 640 x 360
# GIF image data, version 89a, 640 x 480
# GIF image data, version 89a, 650 x 220
# GIF image data, version 89a, 652 x 231
# GIF image data, version 89a, 662 x 856
# GIF image data, version 89a, 668 x 331
# GIF image data, version 89a, 676 x 905
# GIF image data, version 89a, 680 x 680
# GIF image data, version 89a, 689 x 577
# GIF image data, version 89a, 700 x 526
# GIF image data, version 89a, 71 x 71
# GIF image data, version 89a, 719 x 81
# GIF image data, version 89a, 72 x 80
# GIF image data, version 89a, 74 x 57
# GIF image data, version 89a, 740 x 55
# GIF image data, version 89a, 75 x 75
# GIF image data, version 89a, 750 x 5013
# GIF image data, version 89a, 758 x 272
# GIF image data, version 89a, 76 x 87
# GIF image data, version 89a, 770 x 595
# GIF image data, version 89a, 780 x 4579
# GIF image data, version 89a, 793 x 400
# GIF image data, version 89a, 8 x 25
# GIF image data, version 89a, 80 x 40
# GIF image data, version 89a, 80 x 52
# GIF image data, version 89a, 80 x 60
# GIF image data, version 89a, 80 x 80
# GIF image data, version 89a, 800 x 270
# GIF image data, version 89a, 800 x 600
# GIF image data, version 89a, 81 x 125
# GIF image data, version 89a, 8193 x 8193
# GIF image data, version 89a, 8216 x 8216
# GIF image data, version 89a, 8241 x 18759
# GIF image data, version 89a, 8253 x 8231
# GIF image data, version 89a, 834 x 66
# GIF image data, version 89a, 8364
# GIF image data, version 89a, 85 x 9
# GIF image data, version 89a, 87 x 39
# GIF image data, version 89a, 874 x 532
# GIF image data, version 89a, 88 x 31
# GIF image data, version 89a, 88 x 62
# GIF image data, version 89a, 88 x 67
# GIF image data, version 89a, 880 x 6
# GIF image data, version 89a, 90 x 65
# GIF image data, version 89a, 90 x 90
# GIF image data, version 89a, 900 x 650
# GIF image data, version 89a, 922 x 524
# GIF image data, version 89a, 93 x 120
# GIF image data, version 89a, 946 x 8
# GIF image data, version 89a, 959 x 939
# GIF image data, version 89a, 960 x 540
# GIF image data, version 89a, 960 x 90
# GIF image data, version 89a, 970 x 250
# GIF image data, version 89a, 971 x 768
# GIF image data, version 89a, 98 x 19
# GIF image data, version 89a, 98 x 35
# GIF image data, version 89a, 98 x 51
# GIF image data, version 89a, 986 x 483
# ISO Media, MPEG v4 system, 3GPP
# ISO Media, MPEG v4 system, iTunes AAC-LC
# ISO Media, MPEG v4 system, iTunes AVC-LC
# ISO Media, MPEG v4 system, version 1
# ISO Media, MPEG v4 system, version 2
# JPEG 2000 image
# JPEG image data
# JPEG image data, EXIF standard
# JPEG image data, EXIF standard 2.1
# JPEG image data, EXIF standard 2.1, baseline, precision 0, 4360x414
# JPEG image data, EXIF standard 2.1, baseline, precision 0, 4360x691
# JPEG image data, EXIF standard 2.1, baseline, precision 0, 4360x692
# JPEG image data, EXIF standard 2.2
# JPEG image data, EXIF standard 2.2, baseline, precision 0, 4360x121
# JPEG image data, EXIF standard 2.2, baseline, precision 0, 4360x2365
# JPEG image data, EXIF standard 2.2, baseline, precision 0, 4360x3516
# JPEG image data, EXIF standard 2.2, comment: "photo "
# JPEG image data, EXIF standard 2.21
# JPEG image data, EXIF standard 2.21, baseline, precision 0, 4360x395
# JPEG image data, EXIF standard 2.3
# JPEG image data, EXIF standard, baseline, precision 0, 4360x1537
# JPEG image data, EXIF standard, baseline, precision 0, 4360x281
# JPEG image data, EXIF standard, baseline, precision 0, 4360x380
# JPEG image data, EXIF standard, baseline, precision 0, 4360x493
# JPEG image data, EXIF standard, baseline, precision 0, 4360x525
# JPEG image data, EXIF standard, baseline, precision 0, 4360x900
# JPEG image data, EXIF standard, baseline, precision 0, 4360x922
# JPEG image data, EXIF standard, comment: "AppleMark"
# JPEG image data, EXIF standard, comment: "CREATOR: gd-jpeg v1.0 (using ...
# JPEG image data, JFIF standard 1.00
# JPEG image data, JFIF standard 1.00, comment: "LEAD Technologies Inc.  ...
# JPEG image data, JFIF standard 1.00, comment: "VT-COMPRESS  v2.3 "
# JPEG image data, JFIF standard 1.01
# JPEG image data, JFIF standard 1.01, comment: ""><img src=x onerror=al ...
# JPEG image data, JFIF standard 1.01, comment: "*"
# JPEG image data, JFIF standard 1.01, comment: "1424787600"
# JPEG image data, JFIF standard 1.01, comment: "<% if request("#")<>""  ...
# JPEG image data, JFIF standard 1.01, comment: "<?php @eval($_POST['#'] ...
# JPEG image data, JFIF standard 1.01, comment: "<?php __halt_compiler() ...
# JPEG image data, JFIF standard 1.01, comment: "<?php echo(md5('acuneti ...
# JPEG image data, JFIF standard 1.01, comment: "<?php eval($_REQUEST['e ...
# JPEG image data, JFIF standard 1.01, comment: "<?php\015"
# JPEG image data, JFIF standard 1.01, comment: "AppleMark"
# JPEG image data, JFIF standard 1.01, comment: "CREATOR: gd-jpeg v1.0 ( ...
# JPEG image data, JFIF standard 1.01, comment: "Created with GIMP"
# JPEG image data, JFIF standard 1.01, comment: "Created with The GIMP"
# JPEG image data, JFIF standard 1.01, comment: "DYNAMIC+ BlackStone"
# JPEG image data, JFIF standard 1.01, comment: "File source: http://cod ...
# JPEG image data, JFIF standard 1.01, comment: "File source: http://com ...
# JPEG image data, JFIF standard 1.01, comment: "Generated by  IJG JPEG  ...
# JPEG image data, JFIF standard 1.01, comment: "GoodFon.ru"
# JPEG image data, JFIF standard 1.01, comment: "Intel(R) JPEG Library,  ...
# JPEG image data, JFIF standard 1.01, comment: "LEAD Technologies Inc.  ...
# JPEG image data, JFIF standard 1.01, comment: "NODIA,Inc. Q63"
# JPEG image data, JFIF standard 1.01, comment: "Optimized by JPEGmini 3 ...
# JPEG image data, JFIF standard 1.01, comment: "Photoshop 3.0"
# JPEG image data, JFIF standard 1.01, comment: "Powered by Cold Fusion  ...
# JPEG image data, JFIF standard 1.01, comment: "Processed By eBay with  ...
# JPEG image data, JFIF standard 1.01, comment: "Skyword:611485"
# JPEG image data, JFIF standard 1.01, comment: "This file was created b ...
# JPEG image data, JFIF standard 1.01, comment: "\030\344\304\006"
# JPEG image data, JFIF standard 1.01, comment: "\204\023q\330$\255x\337 ...
# JPEG image data, JFIF standard 1.01, comment: "\361\333,\360\364\034\3 ...
# JPEG image data, JFIF standard 1.01, comment: "cmp3.10.3.2Lq3 0x905c30 ...
# JPEG image data, JFIF standard 1.01, comment: "www.calendar-365.com"
# JPEG image data, JFIF standard 1.01, comment: "www.pixint.ru"
# JPEG image data, JFIF standard 1.01, thumbnail 32x32
# JPEG image data, JFIF standard 1.02
# JPEG image data, JFIF standard 1.02, baseline, precision 0, 4360x768
# JPEG image data, JFIF standard 1.02, comment: "*"
# JPEG image data, JFIF standard 1.02, comment: "File written by Adobe P ...
# JPEG image data, JFIF standard 1.02, comment: "Intel(R) IPP JPEG encod ...
# JPEG image data, JFIF standard 1.02, comment: "LEAD Technologies Inc.  ...
# JPEG image data, JFIF standard 1.02, comment: "Paint Tool -SAI- JPEG E ...
# JPEG image data, JFIF standard 1.02, comment: "T"
# JPEG image data, JFIF standard 1.02, comment: "\030\335}\004\001"
# JPEG image data, JFIF standard 1.02, thumbnail 32x32, baseline, precis ...
# JPEG image data, baseline, precision 0, 4360x720
# JPEG image data, comment: "GPEncoder"
# MGR bitmap, old format, 1-bit deep, 16-bit aligned
# MPEG ADTS, AAC, v2 LC, 22.05 kHz, monaural
# MPEG ADTS, AAC, v2 LC, 48 kHz, stereo
# MPEG ADTS, AAC, v4 LC, 44.1 kHz, stereo
# MPEG ADTS, layer II, v2, Monaural
# MPEG ADTS, layer III,  v2.5,   8 kbps, 8 kHz, Monaural
# MPEG ADTS, layer III,  v2.5,  16 kbps, 8 kHz, Monaural
# MPEG ADTS, layer III,  v2.5,  32 kbps, 8 kHz, Monaural
# MPEG ADTS, layer III,  v2.5,  64 kbps, 8 kHz, Monaural
# MPEG ADTS, layer III, v1,  32 kbps, 44.1 kHz, JntStereo
# MPEG ADTS, layer III, v1,  32 kbps, 44.1 kHz, Monaural
# MPEG ADTS, layer III, v1,  56 kbps, 44.1 kHz, JntStereo
# MPEG ADTS, layer III, v1,  96 kbps, 44.1 kHz, JntStereo
# MPEG ADTS, layer III, v1,  96 kbps, 44.1 kHz, Monaural
# MPEG ADTS, layer III, v1, 128 kbps, 44.1 kHz, JntStereo
# MPEG ADTS, layer III, v1, 128 kbps, 44.1 kHz, Monaural
# MPEG ADTS, layer III, v1, 128 kbps, 44.1 kHz, Stereo
# MPEG ADTS, layer III, v1, 128 kbps, 48 kHz, JntStereo
# MPEG ADTS, layer III, v1, 192 kbps, 44.1 kHz, JntStereo
# MPEG ADTS, layer III, v1, 224 kbps, 44.1 kHz, Stereo
# MPEG ADTS, layer III, v1, 320 kbps, 44.1 kHz, 2x Monaural
# MPEG ADTS, layer III, v1, 320 kbps, 44.1 kHz, JntStereo
# MPEG ADTS, layer III, v1, 320 kbps, 44.1 kHz, Stereo
# MPEG ADTS, layer III, v1, 320 kbps, 48 kHz, Monaural
# MPEG ADTS, layer III, v2,  16 kbps, 16 kHz, Monaural
# MPEG ADTS, layer III, v2,  32 kbps, 16 kHz, Monaural
# MPEG ADTS, layer III, v2,  32 kbps, 22.05 kHz, Monaural
# MPEG ADTS, layer III, v2,  64 kbps, 16 kHz, JntStereo
# MPEG ADTS, layer III, v2,  64 kbps, 22.05 kHz, Monaural
# MPEG ADTS, layer III, v2, 128 kbps, 22.05 kHz, JntStereo
# MPEG ADTS, layer III, v2, 22.05 kHz, Stereo
# MPEG sequence, v1, system multiplex
# MPEG sequence, v2, program multiplex
# MPEG transport stream data
# MS Windows icon resource
# MS Windows icon resource - 1 icon
# MS Windows icon resource - 1 iconZip archive data, at least v2.0 to ex ...
# MS Windows icon resource - 10 icons, 16x16, 16-colors
# MS Windows icon resource - 10 icons, 32x32, 16-colors
# MS Windows icon resource - 10 icons, 32x32, 2-colors
# MS Windows icon resource - 10 icons, 48x48, 16-colors
# MS Windows icon resource - 112 icons, 112-colors
# MS Windows icon resource - 12 icons, 16-colors
# MS Windows icon resource - 12 icons, 48x48, 16-colors
# MS Windows icon resource - 13 icons, 48x48, 16-colors
# MS Windows icon resource - 13 icons, 8x8, 256-colors
# MS Windows icon resource - 14 icons, 48x48, 16-colors
# MS Windows icon resource - 14 icons, 64x64, 256-colors
# MS Windows icon resource - 15 icons, 16-colors
# MS Windows icon resource - 16 icons, 16-colors
# MS Windows icon resource - 16 icons, 48x48, 16-colors
# MS Windows icon resource - 17 icons, 256-colors
# MS Windows icon resource - 18 icons, 16x16, 16-colors
# MS Windows icon resource - 2 icons, 16x16, 256-colors
# MS Windows icon resource - 2 icons, 256-colors
# MS Windows icon resource - 2 icons, 32x32, 16-colors
# MS Windows icon resource - 2 icons, 32x32, 256-colors
# MS Windows icon resource - 3 icons, 16x16, 16-colors
# MS Windows icon resource - 3 icons, 16x16, 256-colors
# MS Windows icon resource - 3 icons, 24x24, 16-colors
# MS Windows icon resource - 3 icons, 32x32, 16-colors
# MS Windows icon resource - 3 icons, 48x48, 256-colors
# MS Windows icon resource - 4 icons, 16x16, 16-colors
# MS Windows icon resource - 4 icons, 16x16, 256-colors
# MS Windows icon resource - 4 icons, 256-colors
# MS Windows icon resource - 4 icons, 32x32, 256-colors
# MS Windows icon resource - 4 icons, 48x48, 256-colors
# MS Windows icon resource - 4 icons, 64x64, 256-colors
# MS Windows icon resource - 5 icons, 16x16, 256-colors
# MS Windows icon resource - 5 icons, 256-colors
# MS Windows icon resource - 5 icons, 96x96, 256-colors
# MS Windows icon resource - 6 icons, 13x, 256-colors
# MS Windows icon resource - 6 icons, 16-colors
# MS Windows icon resource - 6 icons, 16x16, 16-colors
# MS Windows icon resource - 6 icons, 16x16, 256-colors
# MS Windows icon resource - 6 icons, 256-colors
# MS Windows icon resource - 6 icons, 32x32, 16-colors
# MS Windows icon resource - 6 icons, 32x32, 256-colors
# MS Windows icon resource - 6 icons, 48x48, 256-colors
# MS Windows icon resource - 7 icons, 16x16, 256-colors
# MS Windows icon resource - 7 icons, 256-colors
# MS Windows icon resource - 7 icons, 48x48, 256-colors
# MS Windows icon resource - 8 icons, 13x, 256-colors
# MS Windows icon resource - 8 icons, 256-colors
# MS Windows icon resource - 8 icons, 32x32, 16-colors
# MS Windows icon resource - 8 icons, 48x48, 256-colors
# MS Windows icon resource - 8 icons, 64x64, 256-colors
# MS Windows icon resource - 9 icons, 13x, 256-colors
# MS Windows icon resource - 9 icons, 16x16, 16-colors
# MS Windows icon resource - 9 icons, 256-colors
# MS Windows icon resource - 9 icons, 32x32, 16-colors
# MS Windows icon resource - 9 icons, 48x48, 16-colors
# MS Windows icon resource - 9 icons, 8x8, 256-colors
# Macromedia Flash Video
# Microsoft Disk Image, Virtual Server or Virtual PC
# Netpbm PPM "rawbits" image data, size = 798 x 529
# Nintendo Game Boy Advance ROM Image
# Ogg data, Vorbis audio, stereo, 44100 Hz, ~112000 bps, created by: Xip ...
# Ogg data, Vorbis audio, stereo, 44100 Hz, ~499821 bps, created by: Xip ...
# Ogg data, Vorbis audio, stereo, 44100 Hz, ~64001 bps, created by: Xiph ...
# Ogg data, Vorbis audio, stereo, 48000 Hz, ~256000 bps, created by: Xip ...
# OpenEXR image data, version 2, storage: scanline, compression: zip, da ...
# PC bitmap, Windows 3.x format, 1 x 1 x 24
# PC bitmap, Windows 3.x format, 1 x 12 x 24
# PC bitmap, Windows 3.x format, 1024 x 768 x 24
# PC bitmap, Windows 3.x format, 1064 x 722 x 24
# PC bitmap, Windows 3.x format, 107 x 107 x 8
# PC bitmap, Windows 3.x format, 1090 x 696 x 24
# PC bitmap, Windows 3.x format, 1122 x 1032 x 24
# PC bitmap, Windows 3.x format, 1152 x 751 x 24
# PC bitmap, Windows 3.x format, 1196 x 1548 x 24
# PC bitmap, Windows 3.x format, 1218 x 871 x 24
# PC bitmap, Windows 3.x format, 1229 x 757 x 32
# PC bitmap, Windows 3.x format, 1234 x 1233 x 32
# PC bitmap, Windows 3.x format, 129 x 129 x 32
# PC bitmap, Windows 3.x format, 134 x 38 x 4
# PC bitmap, Windows 3.x format, 1347 x 522 x 8
# PC bitmap, Windows 3.x format, 1366 x 768 x 32
# PC bitmap, Windows 3.x format, 137 x 96 x 24
# PC bitmap, Windows 3.x format, 14 x 14 x 24
# PC bitmap, Windows 3.x format, 1406 x 928 x 24
# PC bitmap, Windows 3.x format, 1440 x 900 x 24
# PC bitmap, Windows 3.x format, 1484 x 593 x 24
# PC bitmap, Windows 3.x format, 1600 x 1200 x 24
# PC bitmap, Windows 3.x format, 1600 x 900 x 16
# PC bitmap, Windows 3.x format, 169 x 126 x 24
# PC bitmap, Windows 3.x format, 1700 x 2338 x 1
# PC bitmap, Windows 3.x format, 1806 x 1020 x 32
# PC bitmap, Windows 3.x format, 1920 x 1080 x 16
# PC bitmap, Windows 3.x format, 1920 x 1080 x 24
# PC bitmap, Windows 3.x format, 1984 x 2807 x 24
# PC bitmap, Windows 3.x format, 2 x 11 x 24
# PC bitmap, Windows 3.x format, 2 x 5 x 24
# PC bitmap, Windows 3.x format, 2 x 7 x 24
# PC bitmap, Windows 3.x format, 20 x 20 x 24
# PC bitmap, Windows 3.x format, 200 x 54 x 24
# PC bitmap, Windows 3.x format, 2112 x 2112 x 32
# PC bitmap, Windows 3.x format, 213 x 60 x 32
# PC bitmap, Windows 3.x format, 225 x 320 x 24
# PC bitmap, Windows 3.x format, 233 x 234 x 24
# PC bitmap, Windows 3.x format, 2448 x 3264 x 24
# PC bitmap, Windows 3.x format, 248 x 83 x 8
# PC bitmap, Windows 3.x format, 256 x 145 x 24
# PC bitmap, Windows 3.x format, 256 x 256 x 24
# PC bitmap, Windows 3.x format, 275 x 174 x 8
# PC bitmap, Windows 3.x format, 276 x 321 x 24
# PC bitmap, Windows 3.x format, 2872 x 1504 x 8
# PC bitmap, Windows 3.x format, 3 x 2 x 24
# PC bitmap, Windows 3.x format, 3 x 5 x 24
# PC bitmap, Windows 3.x format, 3 x 6 x 24
# PC bitmap, Windows 3.x format, 3 x 7 x 24
# PC bitmap, Windows 3.x format, 3000 x 1244 x 32
# PC bitmap, Windows 3.x format, 304 x 136 x 8
# PC bitmap, Windows 3.x format, 32 x 32 x 24
# PC bitmap, Windows 3.x format, 3507 x 2480 x 24
# PC bitmap, Windows 3.x format, 3850 x 2975 x 8
# PC bitmap, Windows 3.x format, 396 x 212 x 24
# PC bitmap, Windows 3.x format, 4 x 3 x 24
# PC bitmap, Windows 3.x format, 4 x 4 x 24
# PC bitmap, Windows 3.x format, 464 x 448 x 24
# PC bitmap, Windows 3.x format, 472 x 472 x 24
# PC bitmap, Windows 3.x format, 487 x 302 x 8
# PC bitmap, Windows 3.x format, 5 x 3 x 24
# PC bitmap, Windows 3.x format, 5 x 4 x 24
# PC bitmap, Windows 3.x format, 500 x 257 x 24
# PC bitmap, Windows 3.x format, 500 x 375 x 24
# PC bitmap, Windows 3.x format, 500 x 432 x 24
# PC bitmap, Windows 3.x format, 539 x 156 x 24
# PC bitmap, Windows 3.x format, 544 x 165 x 8
# PC bitmap, Windows 3.x format, 545 x 292 x 24
# PC bitmap, Windows 3.x format, 566 x 360 x 24
# PC bitmap, Windows 3.x format, 579 x 589 x 32
# PC bitmap, Windows 3.x format, 6 x 2 x 24
# PC bitmap, Windows 3.x format, 6 x 3 x 24
# PC bitmap, Windows 3.x format, 600 x 600 x 24
# PC bitmap, Windows 3.x format, 604 x 453 x 24
# PC bitmap, Windows 3.x format, 604 x 512 x 24
# PC bitmap, Windows 3.x format, 61 x 13 x 8
# PC bitmap, Windows 3.x format, 640 x 800 x 24
# PC bitmap, Windows 3.x format, 640 x 960 x 24
# PC bitmap, Windows 3.x format, 680 x 877 x 24
# PC bitmap, Windows 3.x format, 682 x 384 x 24
# PC bitmap, Windows 3.x format, 683 x 384 x 24
# PC bitmap, Windows 3.x format, 717 x 558 x 8
# PC bitmap, Windows 3.x format, 720 x 900 x 24
# PC bitmap, Windows 3.x format, 751 x 579 x 24
# PC bitmap, Windows 3.x format, 752 x 1735 x 8
# PC bitmap, Windows 3.x format, 765 x 799 x 24
# PC bitmap, Windows 3.x format, 774 x 1152 x 24
# PC bitmap, Windows 3.x format, 800 x 1095 x 24
# PC bitmap, Windows 3.x format, 800 x 1347 x 24
# PC bitmap, Windows 3.x format, 800 x 600 x 24
# PC bitmap, Windows 3.x format, 811 x 671 x 24
# PC bitmap, Windows 3.x format, 816 x 1056 x 24
# PC bitmap, Windows 3.x format, 819 x 460 x 24
# PC bitmap, Windows 3.x format, 822 x 1025 x 24
# PC bitmap, Windows 3.x format, 822 x 1045 x 8
# PC bitmap, Windows 3.x format, 864 x 540 x 8
# PC bitmap, Windows 3.x format, 9 x 1 x 24
# PC bitmap, Windows 3.x format, 936 x 619 x 24
# PC bitmap, Windows 3.x format, 959 x 717 x 24
# PC bitmap, Windows 3.x format, 96 x 16 x 8
# PC bitmap, Windows 3.x format, 96 x 48 x 8
# PC bitmap, Windows 3.x format, 981 x 1278 x 24
# PC bitmap, Windows 3.x format, 988 x 1278 x 24
# PCX ver. 2.5 image data bounding box [-23530, 56806] - [18299, 39613], ...
# PCX ver. 2.5 image data bounding box [1792, 25971] - [30322, 29285], 1 ...
# PE Unknown PE signature MS Windows icon resource - 1 icon0x0 (GUI) Int ...
# PNG image data
# PNG image data, 1 x 1, 1-bit colormap, non-interlaced
# PNG image data, 1 x 1, 8-bit colormap, non-interlaced
# PNG image data, 1 x 1, 8-bit/color RGB, non-interlaced
# PNG image data, 1 x 1, 8-bit/color RGBA, non-interlaced
# PNG image data, 1 x 120, 8-bit/color RGB, non-interlaced
# PNG image data, 1 x 50, 1-bit colormap, non-interlaced
# PNG image data, 1 x 94, 8-bit/color RGBA, non-interlaced
# PNG image data, 10 x 10, 8-bit/color RGBA, non-interlaced
# PNG image data, 100 x 100, 8-bit/color RGB, non-interlaced
# PNG image data, 100 x 100, 8-bit/color RGBA, non-interlaced
# PNG image data, 100 x 125, 8-bit/color RGBA, non-interlaced
# PNG image data, 100 x 150, 8-bit/color RGBA, non-interlaced
# PNG image data, 100 x 18, 8-bit/color RGB, non-interlaced
# PNG image data, 100 x 3385, 8-bit/color RGB, non-interlaced
# PNG image data, 100 x 34, 8-bit grayscale, non-interlaced
# PNG image data, 100 x 41, 8-bit/color RGBA, non-interlaced
# PNG image data, 100 x 75, 8-bit/color RGB, non-interlaced
# PNG image data, 1002 x 589, 8-bit/color RGB, non-interlaced
# PNG image data, 1005 x 1190, 8-bit/color RGBA, non-interlaced
# PNG image data, 1006 x 1100, 8-bit/color RGBA, non-interlaced
# PNG image data, 1006 x 1400, 8-bit/color RGB, non-interlaced
# PNG image data, 1008 x 550, 8-bit/color RGBA, non-interlaced
# PNG image data, 1010 x 575, 8-bit/color RGBA, non-interlaced
# PNG image data, 1012 x 584, 8-bit/color RGBA, non-interlaced
# PNG image data, 1013474657 x 1681788170, 60-bit
# PNG image data, 1016 x 654, 8-bit/color RGB, non-interlaced
# PNG image data, 1018 x 3242, 8-bit/color RGBA, non-interlaced
# PNG image data, 1021 x 1292, 8-bit/color RGB, non-interlaced
# PNG image data, 1024 x 1024, 8-bit/color RGBA, non-interlaced
# PNG image data, 1024 x 1325, 8-bit/color RGBA, non-interlaced
# PNG image data, 1024 x 523, 8-bit/color RGBA, non-interlaced
# PNG image data, 1024 x 678, 8-bit/color RGB, non-interlaced
# PNG image data, 1024 x 742, 8-bit/color RGB, non-interlaced
# PNG image data, 1024 x 768, 8-bit/color RGB, non-interlaced
# PNG image data, 1024 x 768, 8-bit/color RGBA, non-interlaced
# PNG image data, 1025 x 487, 8-bit/color RGB, non-interlaced
# PNG image data, 1025 x 661, 8-bit/color RGB, non-interlaced
# PNG image data, 1025 x 830, 8-bit/color RGB, non-interlaced
# PNG image data, 1026 x 907, 8-bit/color RGBA, non-interlaced
# PNG image data, 103 x 67, 8-bit/color RGBA, non-interlaced
# PNG image data, 1031 x 461, 8-bit/color RGB, non-interlaced
# PNG image data, 1041 x 288, 8-bit/color RGB, non-interlaced
# PNG image data, 1046 x 630, 8-bit colormap, non-interlaced
# PNG image data, 105 x 109, 8-bit/color RGB, non-interlaced
# PNG image data, 105 x 50, 8-bit/color RGBA, non-interlaced
# PNG image data, 1054 x 772, 8-bit/color RGBA, non-interlaced
# PNG image data, 106 x 160, 8-bit/color RGBA, non-interlaced
# PNG image data, 106 x 36, 8-bit/color RGBA, interlaced
# PNG image data, 1061 x 357, 8-bit/color RGBA, non-interlaced
# PNG image data, 1067 x 800, 8-bit/color RGB, non-interlaced
# PNG image data, 1073 x 483, 8-bit/color RGB, non-interlaced
# PNG image data, 1073 x 701, 8-bit/color RGB, non-interlaced
# PNG image data, 1079 x 1775, 8-bit/color RGB, non-interlaced
# PNG image data, 1080 x 1920, 8-bit/color RGB, non-interlaced
# PNG image data, 1080 x 772, 8-bit/color RGB, non-interlaced
# PNG image data, 1083 x 809, 8-bit/color RGB, non-interlaced
# PNG image data, 1084 x 1482, 8-bit/color RGB, non-interlaced
# PNG image data, 1086 x 443, 8-bit/color RGBA, non-interlaced
# PNG image data, 1086 x 529, 8-bit/color RGB, non-interlaced
# PNG image data, 1093 x 556, 8-bit/color RGB, non-interlaced
# PNG image data, 1098 x 111, 8-bit/color RGBA, non-interlaced
# PNG image data, 110 x 41, 8-bit/color RGBA, non-interlaced
# PNG image data, 1113 x 764, 8-bit/color RGB, non-interlaced
# PNG image data, 1113 x 764, 8-bit/color RGBA, non-interlaced
# PNG image data, 1118 x 889, 8-bit/color RGB, non-interlaced
# PNG image data, 112 x 126, 8-bit/color RGBA, non-interlaced
# PNG image data, 1134 x 854, 8-bit/color RGB, non-interlaced
# PNG image data, 1147 x 422, 8-bit/color RGBA, non-interlaced
# PNG image data, 115 x 115, 8-bit colormap, non-interlaced
# PNG image data, 115 x 115, 8-bit/color RGBA, non-interlaced
# PNG image data, 1150 x 1000, 8-bit/color RGBA, non-interlaced
# PNG image data, 1152 x 864, 8-bit/color RGB, non-interlaced
# PNG image data, 1154 x 440, 8-bit/color RGB, non-interlaced
# PNG image data, 116 x 41, 8-bit colormap, non-interlaced
# PNG image data, 1163 x 556, 8-bit/color RGBA, non-interlaced
# PNG image data, 1185 x 1215, 8-bit/color RGBA, non-interlaced
# PNG image data, 1194 x 201, 8-bit/color RGB, non-interlaced
# PNG image data, 1196 x 389, 8-bit/color RGBA, non-interlaced
# PNG image data, 120 x 120, 8-bit/color RGBA, non-interlaced
# PNG image data, 120 x 25, 8-bit/color RGBA, non-interlaced
# PNG image data, 120 x 31, 8-bit/color RGBA, non-interlaced
# PNG image data, 120 x 60, 8-bit colormap, non-interlaced
# PNG image data, 120 x 60, 8-bit/color RGB, non-interlaced
# PNG image data, 120 x 95, 8-bit/color RGBA, non-interlaced
# PNG image data, 1200 x 1177, 8-bit/color RGB, non-interlaced
# PNG image data, 1200 x 1549, 8-bit/color RGB, non-interlaced
# PNG image data, 1200 x 1697, 8-bit/color RGBA, non-interlaced
# PNG image data, 1200 x 675, 8-bit/color RGBA, non-interlaced
# PNG image data, 1200 x 750, 8-bit/color RGBA, non-interlaced
# PNG image data, 121 x 140, 8-bit/color RGB, non-interlaced
# PNG image data, 121 x 152, 8-bit/color RGB, non-interlaced
# PNG image data, 1214 x 521, 8-bit/color RGB, non-interlaced
# PNG image data, 122 x 34, 8-bit/color RGBA, interlaced
# PNG image data, 1222 x 566, 8-bit/color RGBA, non-interlaced
# PNG image data, 123 x 89, 8-bit/color RGB, non-interlaced
# PNG image data, 1242 x 671, 8-bit/color RGB, non-interlaced
# PNG image data, 1250 x 1000, 8-bit/color RGBA, non-interlaced
# PNG image data, 1250 x 1250, 8-bit/color RGBA, non-interlaced
# PNG image data, 126 x 131, 8-bit/color RGBA, non-interlaced
# PNG image data, 127 x 19, 8-bit colormap, non-interlaced
# PNG image data, 127 x 35, 8-bit/color RGBA, non-interlaced
# PNG image data, 1270 x 7147, 8-bit/color RGB, non-interlaced
# PNG image data, 1279 x 699, 8-bit/color RGB, non-interlaced
# PNG image data, 128 x 128, 8-bit colormap, non-interlaced
# PNG image data, 128 x 128, 8-bit/color RGB, non-interlaced
# PNG image data, 128 x 128, 8-bit/color RGBA, non-interlaced
# PNG image data, 128 x 38, 8-bit/color RGBA, non-interlaced
# PNG image data, 1280 x 1024, 8-bit/color RGB, non-interlaced
# PNG image data, 1280 x 1024, 8-bit/color RGBA, non-interlaced
# PNG image data, 1280 x 1216, 8-bit/color RGBA, non-interlaced
# PNG image data, 1280 x 1280, 8-bit/color RGB, non-interlaced
# PNG image data, 1280 x 720, 8-bit/color RGBA, non-interlaced
# PNG image data, 1280 x 854, 8-bit/color RGBA, non-interlaced
# PNG image data, 1280 x 984, 8-bit/color RGB, non-interlaced
# PNG image data, 1282 x 867, 8-bit/color RGBA, non-interlaced
# PNG image data, 1284 x 689, 8-bit/color RGBA, non-interlaced
# PNG image data, 1287 x 452, 8-bit/color RGBA, non-interlaced
# PNG image data, 129 x 129, 8-bit/color RGB, non-interlaced
# PNG image data, 129 x 129, 8-bit/color RGBA, non-interlaced
# PNG image data, 1293 x 820, 8-bit/color RGBA, non-interlaced
# PNG image data, 13 x 10, 8-bit/color RGB, non-interlaced
# PNG image data, 13 x 19, 8-bit/color RGBA, non-interlaced
# PNG image data, 1310 x 604, 8-bit/color RGBA, non-interlaced
# PNG image data, 1318 x 1326, 8-bit/color RGB, non-interlaced
# PNG image data, 132 x 124, 8-bit/color RGB, non-interlaced
# PNG image data, 132 x 146, 8-bit/color RGB, non-interlaced
# PNG image data, 132 x 33, 8-bit/color RGB, non-interlaced
# PNG image data, 133 x 43, 8-bit/color RGBA, non-interlaced
# PNG image data, 1331 x 1049, 8-bit/color RGBA, non-interlaced
# PNG image data, 1333 x 336, 8-bit/color RGBA, non-interlaced
# PNG image data, 1334 x 750, 8-bit/color RGB, non-interlaced
# PNG image data, 1336 x 1020, 8-bit/color RGBA, non-interlaced
# PNG image data, 135 x 135, 8-bit/color RGBA, non-interlaced
# PNG image data, 1350 x 2936, 8-bit/color RGB, non-interlaced
# PNG image data, 1360 x 768, 8-bit/color RGB, non-interlaced
# PNG image data, 1362 x 664, 8-bit/color RGB, non-interlaced
# PNG image data, 1362 x 736, 8-bit/color RGBA, non-interlaced
# PNG image data, 1363 x 635, 8-bit/color RGB, non-interlaced
# PNG image data, 1364 x 132, 8-bit/color RGB, non-interlaced
# PNG image data, 1366 x 667, 8-bit/color RGBA, non-interlaced
# PNG image data, 1366 x 730, 8-bit/color RGB, non-interlaced
# PNG image data, 1366 x 744, 8-bit/color RGB, non-interlaced
# PNG image data, 1366 x 768, 8-bit grayscale, non-interlaced
# PNG image data, 1366 x 768, 8-bit/color RGB, non-interlaced
# PNG image data, 1366 x 768, 8-bit/color RGBA, non-interlaced
# PNG image data, 1368 x 768, 8-bit/color RGB, non-interlaced
# PNG image data, 1370 x 968, 8-bit/color RGB, non-interlaced
# PNG image data, 1379 x 854, 8-bit colormap, non-interlaced
# PNG image data, 138 x 41, 8-bit/color RGBA, non-interlaced
# PNG image data, 138 x 82, 8-bit/color RGBA, non-interlaced
# PNG image data, 1382 x 902, 8-bit/color RGB, non-interlaced
# PNG image data, 1387 x 1795, 8-bit/color RGBA, non-interlaced
# PNG image data, 14 x 14, 8-bit/color RGBA, non-interlaced
# PNG image data, 1403 x 758, 8-bit/color RGBA, non-interlaced
# PNG image data, 1416 x 609, 8-bit/color RGBA, non-interlaced
# PNG image data, 142 x 30, 8-bit/color RGBA, non-interlaced
# PNG image data, 143 x 200, 8-bit/color RGBA, non-interlaced
# PNG image data, 143 x 55, 8-bit/color RGBA, non-interlaced
# PNG image data, 144 x 144, 8-bit gray+alpha, non-interlaced
# PNG image data, 144 x 144, 8-bit/color RGBA, non-interlaced
# PNG image data, 1440 x 2560, 8-bit/color RGB, non-interlaced
# PNG image data, 1440 x 2560, 8-bit/color RGBA, non-interlaced
# PNG image data, 1440 x 900, 8-bit colormap, non-interlaced
# PNG image data, 1440 x 900, 8-bit/color RGBA, non-interlaced
# PNG image data, 1445 x 92, 8-bit/color RGB, non-interlaced
# PNG image data, 1452 x 744, 8-bit/color RGBA, non-interlaced
# PNG image data, 1457 x 1891, 8-bit/color RGB, non-interlaced
# PNG image data, 146 x 122, 8-bit/color RGB, non-interlaced
# PNG image data, 1468 x 2240, 8-bit/color RGB, non-interlaced
# PNG image data, 1481 x 788, 8-bit/color RGB, non-interlaced
# PNG image data, 1491 x 848, 8-bit/color RGB, non-interlaced
# PNG image data, 1496 x 864, 8-bit/color RGBA, non-interlaced
# PNG image data, 15 x 15, 8-bit/color RGBA, non-interlaced
# PNG image data, 150 x 100, 8-bit/color RGBA, non-interlaced
# PNG image data, 150 x 136, 8-bit/color RGBA, non-interlaced
# PNG image data, 150 x 150, 8-bit colormap, non-interlaced
# PNG image data, 150 x 150, 8-bit/color RGB, non-interlaced
# PNG image data, 150 x 150, 8-bit/color RGBA, non-interlaced
# PNG image data, 150 x 28, 8-bit/color RGB, non-interlaced
# PNG image data, 150 x 39, 8-bit/color RGBA, non-interlaced
# PNG image data, 150 x 70, 8-bit/color RGBA, non-interlaced
# PNG image data, 151 x 37, 8-bit/color RGBA, non-interlaced
# PNG image data, 1513 x 578, 8-bit/color RGB, non-interlaced
# PNG image data, 152 x 11, 8-bit/color RGBA, non-interlaced
# PNG image data, 1524 x 753, 8-bit/color RGBA, non-interlaced
# PNG image data, 153 x 59, 8-bit colormap, non-interlaced
# PNG image data, 1536 x 1613, 8-bit/color RGB, non-interlaced
# PNG image data, 154 x 21, 8-bit/color RGBA, non-interlaced
# PNG image data, 154 x 33, 8-bit/color RGBA, non-interlaced
# PNG image data, 156 x 100, 8-bit/color RGB, non-interlaced
# PNG image data, 156 x 39, 8-bit/color RGB, non-interlaced
# PNG image data, 157 x 275, 8-bit/color RGB, non-interlaced
# PNG image data, 1576 x 439, 8-bit/color RGB, non-interlaced
# PNG image data, 158 x 41, 8-bit colormap, interlaced
# PNG image data, 159 x 28, 8-bit/color RGBA, non-interlaced
# PNG image data, 16 x 16, 1-bit grayscale, non-interlaced
# PNG image data, 16 x 16, 4-bit colormap, non-interlaced
# PNG image data, 16 x 16, 8-bit grayscale, non-interlaced
# PNG image data, 16 x 16, 8-bit/color RGB, non-interlaced
# PNG image data, 16 x 16, 8-bit/color RGBA, non-interlaced
# PNG image data, 16 x 32, 8-bit/color RGBA, non-interlaced
# PNG image data, 160 x 125, 8-bit/color RGBA, non-interlaced
# PNG image data, 160 x 600, 8-bit/color RGB, interlaced
# PNG image data, 160 x 64, 16-bit/color RGBA, non-interlaced
# PNG image data, 1600 x 1600, 8-bit/color RGB, non-interlaced
# PNG image data, 1600 x 447, 8-bit/color RGB, non-interlaced
# PNG image data, 1600 x 454, 8-bit/color RGBA, non-interlaced
# PNG image data, 1600 x 900, 8-bit/color RGB, non-interlaced
# PNG image data, 1600 x 900, 8-bit/color RGBA, non-interlaced
# PNG image data, 1600 x 936, 8-bit/color RGB, non-interlaced
# PNG image data, 1602 x 942, 8-bit/color RGB, non-interlaced
# PNG image data, 161 x 123, 8-bit/color RGB, non-interlaced
# PNG image data, 164 x 44, 8-bit/color RGBA, non-interlaced
# PNG image data, 164 x 440, 8-bit/color RGB, non-interlaced
# PNG image data, 165 x 243, 8-bit/color RGBA, non-interlaced
# PNG image data, 1664 x 382, 8-bit/color RGB, non-interlaced
# PNG image data, 167 x 409, 8-bit/color RGBA, non-interlaced
# PNG image data, 167 x 61, 8-bit/color RGB, non-interlaced
# PNG image data, 1680 x 1050, 8-bit/color RGB, non-interlaced
# PNG image data, 170 x 180, 8-bit/color RGBA, non-interlaced
# PNG image data, 170 x 52, 8-bit/color RGBA, non-interlaced
# PNG image data, 170 x 80, 8-bit/color RGBA, non-interlaced
# PNG image data, 1700 x 2338, 8-bit/color RGB, non-interlaced
# PNG image data, 1706 x 862, 8-bit/color RGB, non-interlaced
# PNG image data, 1720 x 963, 8-bit/color RGB, non-interlaced
# PNG image data, 173 x 33, 8-bit/color RGBA, non-interlaced
# PNG image data, 174 x 29, 8-bit/color RGB, non-interlaced
# PNG image data, 174 x 43, 8-bit/color RGBA, non-interlaced
# PNG image data, 1748 x 1181, 8-bit/color RGBA, non-interlaced
# PNG image data, 175 x 234, 8-bit/color RGBA, non-interlaced
# PNG image data, 1751474532 x 1040858228, 105-bit
# PNG image data, 1754 x 1037, 8-bit/color RGB, non-interlaced
# PNG image data, 1754 x 834, 8-bit/color RGB, non-interlaced
# PNG image data, 177 x 42, 8-bit/color RGBA, non-interlaced
# PNG image data, 177 x 85, 8-bit/color RGBA, non-interlaced
# PNG image data, 179 x 112, 8-bit/color RGBA, non-interlaced
# PNG image data, 1792 x 975, 8-bit/color RGB, non-interlaced
# PNG image data, 180 x 125, 8-bit/color RGB, non-interlaced
# PNG image data, 180 x 320, 8-bit/color RGB, non-interlaced
# PNG image data, 180 x 53, 8-bit/color RGB, non-interlaced
# PNG image data, 180 x 76, 8-bit/color RGBA, non-interlaced
# PNG image data, 1800 x 1800, 8-bit/color RGB, non-interlaced
# PNG image data, 1818 x 942, 8-bit/color RGB, non-interlaced
# PNG image data, 182 x 54, 8-bit/color RGBA, non-interlaced
# PNG image data, 183 x 36, 8-bit grayscale, non-interlaced
# PNG image data, 185 x 49, 8-bit/color RGBA, non-interlaced
# PNG image data, 185 x 71, 8-bit/color RGB, interlaced
# PNG image data, 1859 x 2626, 8-bit/color RGB, non-interlaced
# PNG image data, 186 x 60, 8-bit/color RGBA, non-interlaced
# PNG image data, 187 x 170, 8-bit/color RGBA, non-interlaced
# PNG image data, 187 x 87, 8-bit/color RGBA, non-interlaced
# PNG image data, 188 x 45, 8-bit colormap, non-interlaced
# PNG image data, 1899 x 77, 8-bit/color RGB, non-interlaced
# PNG image data, 19 x 19, 8-bit/color RGBA, non-interlaced
# PNG image data, 19 x 9, 8-bit/color RGBA, non-interlaced
# PNG image data, 190 x 63, 8-bit/color RGBA, non-interlaced
# PNG image data, 1919 x 1079, 8-bit/color RGBA, non-interlaced
# PNG image data, 1920 x 1017, 8-bit/color RGB, non-interlaced
# PNG image data, 1920 x 1080, 8-bit/color RGB, non-interlaced
# PNG image data, 1920 x 1080, 8-bit/color RGBA, interlaced
# PNG image data, 1920 x 1080, 8-bit/color RGBA, non-interlaced
# PNG image data, 1924 x 1000, 8-bit/color RGBA, non-interlaced
# PNG image data, 1928 x 607, 8-bit/color RGBA, non-interlaced
# PNG image data, 195 x 156, 8-bit/color RGB, non-interlaced
# PNG image data, 196 x 57, 8-bit/color RGBA, non-interlaced
# PNG image data, 197 x 42, 8-bit colormap, interlaced
# PNG image data, 197 x 60, 8-bit/color RGB, non-interlaced
# PNG image data, 198 x 198, 8-bit grayscale, non-interlaced
# PNG image data, 198 x 47, 8-bit/color RGBA, non-interlaced
# PNG image data, 2 x 1, 8-bit/color RGBA, non-interlaced
# PNG image data, 2 x 14, 8-bit/color RGBA, non-interlaced
# PNG image data, 200 x 143, 8-bit colormap, non-interlaced
# PNG image data, 200 x 144, 8-bit colormap, interlaced
# PNG image data, 200 x 200, 8-bit/color RGB, non-interlaced
# PNG image data, 200 x 200, 8-bit/color RGBA, non-interlaced
# PNG image data, 200 x 32, 8-bit/color RGB, non-interlaced
# PNG image data, 200 x 90, 8-bit/color RGB, non-interlaced
# PNG image data, 2000 x 1500, 8-bit/color RGBA, non-interlaced
# PNG image data, 2000 x 2000, 8-bit/color RGBA, non-interlaced
# PNG image data, 2000 x 23, 8-bit/color RGBA, non-interlaced
# PNG image data, 201 x 53, 8-bit/color RGBA, non-interlaced
# PNG image data, 201 x 70, 8-bit/color RGBA, non-interlaced
# PNG image data, 202 x 116, 8-bit/color RGB, non-interlaced
# PNG image data, 202 x 202, 8-bit/color RGBA, non-interlaced
# PNG image data, 2022 x 850, 8-bit/color RGBA, non-interlaced
# PNG image data, 2022486 x 3, 8-bit/color RGBA, non-interlaced
# PNG image data, 2048 x 1536, 8-bit/color RGB, non-interlaced
# PNG image data, 2054 x 523264, 8-bit/color RGBA, non-interlaced
# PNG image data, 206 x 536, 8-bit/color RGBA, non-interlaced
# PNG image data, 207 x 155, 8-bit/color RGBA, non-interlaced
# PNG image data, 207 x 206, 8-bit colormap, non-interlaced
# PNG image data, 207 x 206, 8-bit/color RGBA, non-interlaced
# PNG image data, 210 x 140, 8-bit/color RGB, non-interlaced
# PNG image data, 210 x 391, 8-bit/color RGB, non-interlaced
# PNG image data, 211 x 211, 8-bit/color RGBA, non-interlaced
# ...
# PNG image data, 640 x 507, 8-bit/color RGB, non-interlaced
# PNG image data, 640 x 876, 8-bit/color RGBA, non-interlaced
# PNG image data, 640 x 920, 8-bit/color RGBA, non-interlaced
# PNG image data, 640 x 949, 8-bit/color RGB, non-interlaced
# PNG image data, 640 x 960, 8-bit grayscale, non-interlaced
# PNG image data, 640 x 960, 8-bit/color RGB, non-interlaced
# PNG image data, 64250 x 64250, 8-bit/color RGB, non-interlaced
# PNG image data, 643 x 190, 8-bit/color RGB, non-interlaced
# PNG image data, 644 x 364, 8-bit/color RGBA, non-interlaced
# PNG image data, 644 x 479, 8-bit/color RGBA, non-interlaced
# PNG image data, 645 x 380, 8-bit/color RGBA, non-interlaced
# PNG image data, 646 x 144, 8-bit/color RGB, non-interlaced
# PNG image data, 646 x 152, 8-bit/color RGBA, non-interlaced
# PNG image data, 648 x 280, 8-bit/color RGB, non-interlaced
# PNG image data, 648 x 532, 8-bit/color RGB, non-interlaced
# PNG image data, 649 x 361, 8-bit/color RGB, non-interlaced
# PNG image data, 65 x 43, 8-bit colormap, non-interlaced
# PNG image data, 650 x 372, 8-bit/color RGBA, non-interlaced
# PNG image data, 650 x 432, 8-bit/color RGB, non-interlaced
# PNG image data, 650 x 650, 8-bit/color RGB, non-interlaced
# PNG image data, 650 x 852, 8-bit colormap, non-interlaced
# PNG image data, 652 x 215, 8-bit/color RGBA, non-interlaced
# PNG image data, 653 x 137, 8-bit/color RGBA, non-interlaced
# PNG image data, 654 x 452, 8-bit/color RGB, non-interlaced
# PNG image data, 657 x 885, 8-bit/color RGBA, non-interlaced
# PNG image data, 659 x 701, 8-bit/color RGBA, non-interlaced
# PNG image data, 660 x 503, 8-bit/color RGBA, non-interlaced
# PNG image data, 665 x 264, 8-bit/color RGB, non-interlaced
# PNG image data, 665 x 666, 8-bit/color RGBA, non-interlaced
# PNG image data, 667 x 429, 8-bit/color RGB, non-interlaced
# PNG image data, 668 x 510, 8-bit/color RGBA, non-interlaced
# PNG image data, 672 x 429, 8-bit/color RGBA, non-interlaced
# PNG image data, 673 x 387, 8-bit/color RGB, non-interlaced
# PNG image data, 675 x 800, 8-bit/color RGB, non-interlaced
# PNG image data, 681 x 424, 8-bit/color RGBA, non-interlaced
# PNG image data, 683 x 1024, 8-bit/color RGB, non-interlaced
# PNG image data, 683 x 428, 8-bit/color RGB, non-interlaced
# PNG image data, 685 x 635, 8-bit/color RGBA, non-interlaced
# PNG image data, 686 x 676, 8-bit/color RGB, non-interlaced
# PNG image data, 687 x 269, 8-bit/color RGBA, non-interlaced
# PNG image data, 687 x 752, 8-bit/color RGB, non-interlaced
# PNG image data, 69 x 20, 8-bit/color RGBA, non-interlaced
# PNG image data, 691 x 392, 8-bit/color RGBA, non-interlaced
# PNG image data, 695 x 270, 8-bit/color RGBA, non-interlaced
# PNG image data, 696 x 555, 8-bit/color RGBA, non-interlaced
# PNG image data, 698 x 697, 8-bit/color RGB, non-interlaced
# PNG image data, 7 x 10, 4-bit colormap, non-interlaced
# PNG image data, 70 x 480, 8-bit/color RGBA, non-interlaced
# PNG image data, 70 x 70, 8-bit/color RGBA, non-interlaced
# PNG image data, 70 x 97, 8-bit/color RGB, interlaced
# PNG image data, 700 x 1068, 8-bit/color RGBA, non-interlaced
# PNG image data, 700 x 394, 8-bit/color RGBA, non-interlaced
# PNG image data, 700 x 806, 8-bit/color RGB, non-interlaced
# PNG image data, 704 x 1418, 8-bit/color RGB, non-interlaced
# PNG image data, 704 x 586, 8-bit/color RGBA, non-interlaced
# PNG image data, 705 x 186, 8-bit/color RGBA, non-interlaced
# PNG image data, 706 x 252, 8-bit/color RGBA, non-interlaced
# PNG image data, 708 x 632, 8-bit/color RGB, non-interlaced
# PNG image data, 710 x 602, 8-bit/color RGBA, non-interlaced
# PNG image data, 713 x 1509, 8-bit/color RGB, non-interlaced
# PNG image data, 719 x 1280, 8-bit/color RGB, non-interlaced
# PNG image data, 719 x 188, 8-bit/color RGBA, non-interlaced
# PNG image data, 719 x 421, 8-bit/color RGBA, non-interlaced
# PNG image data, 72 x 16, 8-bit colormap, non-interlaced
# PNG image data, 72 x 72, 8-bit colormap, non-interlaced
# PNG image data, 72 x 72, 8-bit/color RGBA, non-interlaced
# PNG image data, 720 x 1280, 8-bit/color RGB, non-interlaced
# PNG image data, 720 x 222, 8-bit/color RGBA, non-interlaced
# PNG image data, 720 x 540, 8-bit/color RGBA, non-interlaced
# PNG image data, 720 x 924, 8-bit/color RGBA, non-interlaced
# PNG image data, 724 x 3450, 1-bit colormap, non-interlaced
# PNG image data, 726 x 407, 8-bit/color RGBA, non-interlaced
# PNG image data, 727 x 146, 8-bit/color RGB, non-interlaced
# PNG image data, 729 x 5296, 8-bit/color RGB, non-interlaced
# PNG image data, 730 x 1319, 8-bit/color RGBA, non-interlaced
# PNG image data, 732 x 406, 8-bit/color RGB, non-interlaced
# PNG image data, 732 x 458, 8-bit/color RGB, non-interlaced
# PNG image data, 733 x 492, 8-bit/color RGBA, non-interlaced
# PNG image data, 733 x 757, 8-bit/color RGB, non-interlaced
# PNG image data, 74 x 96, 8-bit/color RGB, non-interlaced
# PNG image data, 740 x 922, 8-bit/color RGBA, non-interlaced
# PNG image data, 743 x 492, 8-bit/color RGBA, non-interlaced
# PNG image data, 746 x 657, 8-bit/color RGB, non-interlaced
# PNG image data, 748 x 711, 8-bit/color RGBA, non-interlaced
# PNG image data, 750 x 1334, 8-bit/color RGB, non-interlaced
# PNG image data, 751 x 411, 8-bit/color RGB, non-interlaced
# PNG image data, 754 x 594, 8-bit/color RGB, non-interlaced
# PNG image data, 756 x 1204, 8-bit/color RGBA, non-interlaced
# PNG image data, 76 x 25, 8-bit colormap, non-interlaced
# PNG image data, 762 x 95, 8-bit/color RGB, non-interlaced
# PNG image data, 763 x 193, 8-bit/color RGB, non-interlaced
# PNG image data, 763 x 763, 8-bit/color RGB, non-interlaced
# PNG image data, 764 x 437, 8-bit/color RGBA, non-interlaced
# PNG image data, 765 x 556, 8-bit/color RGBA, non-interlaced
# PNG image data, 766 x 604, 8-bit/color RGB, non-interlaced
# PNG image data, 767 x 489, 8-bit/color RGBA, non-interlaced
# PNG image data, 767 x 728, 8-bit/color RGB, non-interlaced
# PNG image data, 768 x 1024, 8-bit/color RGB, non-interlaced
# PNG image data, 768 x 1280, 8-bit/color RGB, non-interlaced
# PNG image data, 768 x 134610944, 0-bit
# PNG image data, 768 x 644, 8-bit/color RGB, non-interlaced
# PNG image data, 773 x 293, 8-bit/color RGBA, non-interlaced
# PNG image data, 783 x 359, 8-bit/color RGB, non-interlaced
# PNG image data, 783 x 4535, 8-bit colormap, non-interlaced
# PNG image data, 785 x 901, 8-bit/color RGBA, non-interlaced
# PNG image data, 79 x 52, 8-bit/color RGB, non-interlaced
# PNG image data, 791 x 633, 8-bit/color RGB, non-interlaced
# PNG image data, 792 x 1120, 8-bit/color RGB, non-interlaced
# PNG image data, 792 x 4979, 8-bit colormap, non-interlaced
# PNG image data, 793 x 1123, 8-bit/color RGB, non-interlaced
# PNG image data, 797 x 548, 8-bit/color RGBA, non-interlaced
# PNG image data, 798 x 376, 8-bit/color RGB, non-interlaced
# PNG image data, 8 x 20, 8-bit/color RGBA, non-interlaced
# PNG image data, 80 x 131, 8-bit gray+alpha, non-interlaced
# PNG image data, 80 x 15, 8-bit colormap, non-interlaced
# PNG image data, 80 x 80, 8-bit/color RGBA, non-interlaced
# PNG image data, 800 x 1035, 8-bit/color RGBA, non-interlaced
# PNG image data, 800 x 1215, 8-bit/color RGB, non-interlaced
# PNG image data, 800 x 250, 8-bit gray+alpha, non-interlaced
# PNG image data, 800 x 4046, 8-bit/color RGB, non-interlaced
# PNG image data, 800 x 450, 8-bit/color RGBA, non-interlaced
# PNG image data, 800 x 533, 8-bit/color RGB, non-interlaced
# PNG image data, 800 x 561, 8-bit/color RGB, interlaced
# PNG image data, 800 x 566, 8-bit/color RGB, non-interlaced
# PNG image data, 800 x 600, 8-bit/color RGB, non-interlaced
# PNG image data, 800 x 622, 8-bit/color RGBA, non-interlaced
# PNG image data, 800 x 74, 8-bit/color RGBA, non-interlaced
# PNG image data, 800 x 800, 8-bit/color RGB, non-interlaced
# PNG image data, 800 x 923, 8-bit/color RGBA, non-interlaced
# PNG image data, 804 x 447, 8-bit/color RGBA, non-interlaced
# PNG image data, 804 x 858, 8-bit/color RGBA, non-interlaced
# PNG image data, 805 x 497, 8-bit/color RGB, non-interlaced
# PNG image data, 807 x 605, 8-bit/color RGBA, non-interlaced
# PNG image data, 813 x 857, 8-bit/color RGB, non-interlaced
# PNG image data, 815 x 436, 8-bit/color RGB, non-interlaced
# PNG image data, 8158 x 1, 8-bit grayscale, non-interlaced
# PNG image data, 819 x 460, 8-bit/color RGB, non-interlaced
# PNG image data, 820 x 666, 8-bit/color RGBA, non-interlaced
# PNG image data, 822 x 1045, 8-bit/color RGB, non-interlaced
# PNG image data, 824 x 381, 8-bit/color RGBA, non-interlaced
# PNG image data, 824 x 514, 8-bit/color RGBA, non-interlaced
# PNG image data, 825 x 1380, 8-bit/color RGB, non-interlaced
# PNG image data, 83 x 151, 8-bit/color RGBA, non-interlaced
# PNG image data, 83 x 84, 8-bit/color RGBA, interlaced
# PNG image data, 830 x 1030, 8-bit/color RGBA, non-interlaced
# PNG image data, 836 x 456, 8-bit/color RGBA, non-interlaced
# PNG image data, 837 x 49, 8-bit/color RGB, non-interlaced
# PNG image data, 840 x 505, 16-bit/color RGB, non-interlaced
# PNG image data, 85 x 15, 8-bit/color RGB, non-interlaced
# PNG image data, 85 x 82, 8-bit/color RGBA, non-interlaced
# PNG image data, 850 x 1170, 8-bit/color RGB, non-interlaced
# PNG image data, 850 x 250, 8-bit/color RGBA, non-interlaced
# PNG image data, 851 x 396, 8-bit/color RGBA, non-interlaced
# PNG image data, 854 x 569, 8-bit/color RGB, non-interlaced
# PNG image data, 859 x 1529, 8-bit/color RGBA, non-interlaced
# PNG image data, 859 x 253, 8-bit/color RGBA, non-interlaced
# PNG image data, 872 x 814, 8-bit/color RGBA, non-interlaced
# PNG image data, 876 x 550, 8-bit/color RGBA, non-interlaced
# PNG image data, 88 x 62, 8-bit/color RGB, non-interlaced
# PNG image data, 88 x 88, 8-bit/color RGBA, non-interlaced
# PNG image data, 89 x 14, 8-bit/color RGBA, non-interlaced
# PNG image data, 890 x 350, 8-bit/color RGBA, non-interlaced
# PNG image data, 893 x 687, 8-bit/color RGBA, non-interlaced
# PNG image data, 896 x 496, 8-bit/color RGB, non-interlaced
# PNG image data, 9 x 16, 8-bit/color RGBA, non-interlaced
# PNG image data, 9 x 5, 8-bit/color RGBA, non-interlaced
# PNG image data, 90 x 33, 8-bit/color RGBA, non-interlaced
# PNG image data, 90 x 400, 8-bit/color RGBA, non-interlaced
# PNG image data, 90 x 50, 8-bit/color RGBA, non-interlaced
# PNG image data, 90 x 68, 8-bit/color RGBA, non-interlaced
# PNG image data, 900 x 506, 8-bit/color RGBA, non-interlaced
# PNG image data, 900 x 535, 8-bit/color RGB, non-interlaced
# PNG image data, 900 x 600, 8-bit/color RGBA, non-interlaced
# PNG image data, 900 x 900, 8-bit/color RGB, non-interlaced
# PNG image data, 903 x 561, 8-bit/color RGB, non-interlaced
# PNG image data, 908 x 601, 8-bit/color RGB, non-interlaced
# PNG image data, 911 x 573, 8-bit/color RGB, non-interlaced
# PNG image data, 912 x 602, 8-bit/color RGBA, non-interlaced
# PNG image data, 912 x 62, 8-bit/color RGBA, non-interlaced
# PNG image data, 93 x 85, 8-bit/color RGB, non-interlaced
# PNG image data, 930 x 221, 8-bit/color RGB, non-interlaced
# PNG image data, 932 x 182, 8-bit/color RGB, non-interlaced
# PNG image data, 939 x 85, 8-bit/color RGB, non-interlaced
# PNG image data, 943 x 714, 8-bit/color RGB, non-interlaced
# PNG image data, 945 x 572, 8-bit/color RGB, non-interlaced
# PNG image data, 946 x 588, 8-bit/color RGB, non-interlaced
# PNG image data, 9460301 x 1297780736, 77-bit/color RGBA, non-interlace ...
# PNG image data, 949 x 439, 8-bit/color RGB, non-interlaced
# PNG image data, 950 x 240, 8-bit/color RGB, non-interlaced
# PNG image data, 950 x 279, 8-bit/color RGB, non-interlaced
# PNG image data, 955 x 367, 8-bit/color RGB, non-interlaced
# PNG image data, 957 x 1002, 8-bit/color RGBA, non-interlaced
# PNG image data, 96 x 77, 8-bit/color RGBA, non-interlaced
# PNG image data, 96 x 89, 8-bit/color RGB, non-interlaced
# PNG image data, 96 x 96, 8-bit colormap, non-interlaced
# PNG image data, 96 x 96, 8-bit/color RGBA, non-interlaced
# PNG image data, 960 x 100, 8-bit/color RGBA, non-interlaced
# PNG image data, 960 x 330, 8-bit/color RGBA, non-interlaced
# PNG image data, 960 x 540, 8-bit/color RGB, non-interlaced
# PNG image data, 960 x 600, 8-bit/color RGB, non-interlaced
# PNG image data, 961 x 301, 8-bit/color RGBA, non-interlaced
# PNG image data, 966 x 166, 8-bit/color RGBA, non-interlaced
# PNG image data, 969 x 942, 8-bit/color RGB, non-interlaced
# PNG image data, 972 x 59, 8-bit/color RGB, non-interlaced
# PNG image data, 973 x 517, 8-bit/color RGBA, non-interlaced
# PNG image data, 974 x 292, 8-bit/color RGBA, non-interlaced
# PNG image data, 975 x 975, 8-bit/color RGB, non-interlaced
# PNG image data, 977 x 162, 8-bit/color RGBA, non-interlaced
# PNG image data, 977 x 252, 8-bit/color RGB, non-interlaced
# PNG image data, 978 x 1057, 8-bit/color RGBA, non-interlaced
# PNG image data, 991 x 483, 8-bit/color RGBA, non-interlaced
# PNG image data, 993 x 1012, 8-bit/color RGBA, non-interlaced
# PNG image data, 998 x 696, 8-bit/color RGB, non-interlaced
# Paint Shop Pro Image File
# RIFF (little-endian) data, AVI, 1156 x 862, 30.00 fps, video: H.264 X. ...
# RIFF (little-endian) data, AVI, 1280 x 800, 30.00 fps, video: XviD, au ...
# RIFF (little-endian) data, AVI, 1360 x 768, 30.00 fps, video: XviD, au ...
# RIFF (little-endian) data, AVI, 1600 x 900, 20.00 fps, video: XviD
# RIFF (little-endian) data, AVI, 176 x 144, ~15 fps, video: Motion JPEG ...
# RIFF (little-endian) data, AVI, 320 x 240, 20.00 fps, video: Motion JP ...
# RIFF (little-endian) data, AVI, 444 x 5, 10.00 fps, video: uncompresse ...
# RIFF (little-endian) data, AVI, 460 x 480, ~30 fps, video: XviD
# RIFF (little-endian) data, AVI, 480 x 360, 25.00 fps, video: Microsoft ...
# RIFF (little-endian) data, AVI, 640 x 360, 25.00 fps, video: H.264 X.2 ...
# RIFF (little-endian) data, AVI, 640 x 360, ~30 fps, video: H.264 X.264 ...
# RIFF (little-endian) data, AVI, 640 x 480, 30.00 fps, video: XviD, aud ...
# RIFF (little-endian) data, AVI, 776 x 406, ~15 fps, video: XviD, audio ...
# RIFF (little-endian) data, WAVE audio, GSM 6.10, mono 8000 Hz
# RIFF (little-endian) data, WAVE audio, IMA ADPCM, mono 8000 Hz
# RIFF (little-endian) data, WAVE audio, ITU G.711 A-law, mono 8000 Hz
# RIFF (little-endian) data, WAVE audio, ITU G.711 mu-law, mono 8000 Hz
# RIFF (little-endian) data, WAVE audio, MPEG Layer 3, mono 11025 Hz
# RIFF (little-endian) data, WAVE audio, MPEG Layer 3, mono 8000 Hz
# RIFF (little-endian) data, WAVE audio, Microsoft ADPCM, mono 11025 Hz
# RIFF (little-endian) data, WAVE audio, Microsoft ADPCM, mono 22050 Hz
# RIFF (little-endian) data, WAVE audio, Microsoft ADPCM, mono 44100 Hz
# RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 110 ...
# RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 160 ...
# RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 220 ...
# RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 320 ...
# RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 441 ...
# RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 800 ...
# RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, stereo 2 ...
# RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, stereo 4 ...
# RIFF (little-endian) data, WAVE audio, Microsoft PCM, 8 bit, mono 1102 ...
# RIFF (little-endian) data, WAVE audio, Microsoft PCM, 8 bit, mono 2205 ...
# RIFF (little-endian) data, WAVE audio, Microsoft PCM, 8 bit, mono 8000 ...
# RIFF (little-endian) data, WAVE audio, stereo 48000 Hz
# RLE image data, 22012 x 17485, lower left corner: 22004, lower right c ...
# SVG Scalable Vector Graphics image
# Solitaire Image Recorder format
# TIFF image data, big-endian
# TIFF image data, little-endian
# Targa image data - Map 1
# Targa image data - Map 1 x 257
# Targa image data - Map 257 x 256
# Targa image data - Mono 184
# Targa image data - RGB
# Targa image data - RGB 256 x 196
# Targa image data - RGB 32 x 32
# VISX image file
# Windows Enhanced Metafile (EMF) image data version 0x10000
# gzip compressed data, was "IMAGE#PO#AW00664564755_JPEG.exe", from FAT  ...
# gzip compressed data, was "image3.scr", from FAT filesystem (MS-DOS, O ...
# image/png; name="Resume Fidel Wiley.zip"\015,
# u-boot legacy uImage, Linux Kernel Image, Linux/MIPS, OS Kernel Image  ...
# u-boot legacy uImage, N750F9K1103VB, Linux/MIPS, OS Kernel Image (lzma ...
# u-boot legacy uImage, ZyXEL Keenetic Start, Linux/MIPS, OS Kernel Imag ...

# %% [markdown]
# ## Archives

# %%
arch_keywords = ['archive', 'compressed']
arch_crit = headers.file_type.map(mapKeywords(arch_keywords))
arch_types = sorted(headers.file_type[~exec_crit & ~text_crit & ~media_crit & arch_crit].unique())
print('Total unique archive types: {}\n'.format(len(arch_types)))
for t in arch_types:
    print(t)
# Out:
# Total unique archive types: 1343
#
# , Nullsoft Installer self-extracting archive
# 7-zip archive data, version 0.2
# 7-zip archive data, version 0.3
# 7-zip archive data, version 0.4
# 7-zip archive data, version 32.3
# ACB archive data
# ACE archive data version 20, from Win/32, version 10 to extract
# ACE archive data version 20, from Win/32, version 20 to extract, conta ...
# ACE archive data version 20, from Win/32, version 20 to extract, solid
# ARJ archive data, v102, slash-switched, original name: ,
# ARJ archive data, v4, slash-switched, original name: RESTORE.INS, os:  ...
# ASCII cpio archive (SVR4 with no CRC)
# ASCII cpio archive (pre-SVR4 or odc)
# ASD archive data
# Arhangel archive data
# Atari MSA archive data, 4113 sectors per track, starting track: 5141,  ...
# BlakHole archive data
# Dzip archive data, version 67.76
# FreeArc archive <http://freearc.org>
# HIT archive data
# JAR compressed with pack200,
# JAR compressed with pack200, version 150.7
# LHa (2.x) archive data [lh5]
# LHa (2.x) archive data [lh6]
# LHa (2.x)/LHark archive data [lh7] - header level 2
# LHarc 1.x/ARX archive data [lh0]
# LHarc 1.x/ARX archive data [lh1]
# Linux Compressed ROM File System data, little endian size 9367552 vers ...
# Logitech Compress archive data
# MS Compress archive data
# Macromedia Flash data (compressed), version 10
# Macromedia Flash data (compressed), version 108
# Macromedia Flash data (compressed), version 11
# Macromedia Flash data (compressed), version 12
# Macromedia Flash data (compressed), version 13
# Macromedia Flash data (compressed), version 14
# Macromedia Flash data (compressed), version 15
# Macromedia Flash data (compressed), version 16
# Macromedia Flash data (compressed), version 17
# Macromedia Flash data (compressed), version 18
# Macromedia Flash data (compressed), version 19
# Macromedia Flash data (compressed), version 20
# Macromedia Flash data (compressed), version 21
# Macromedia Flash data (compressed), version 22
# Macromedia Flash data (compressed), version 23
# Macromedia Flash data (compressed), version 24
# Macromedia Flash data (compressed), version 25
# Macromedia Flash data (compressed), version 26
# Macromedia Flash data (compressed), version 27
# Macromedia Flash data (compressed), version 28
# Macromedia Flash data (compressed), version 29
# Macromedia Flash data (compressed), version 30
# Macromedia Flash data (compressed), version 32
# Macromedia Flash data (compressed), version 46
# Macromedia Flash data (compressed), version 6
# Macromedia Flash data (compressed), version 7
# Macromedia Flash data (compressed), version 77data
# Macromedia Flash data (compressed), version 8
# Macromedia Flash data (compressed), version 9
# Microsoft Cabinet archive data, 1002831 bytes, 24 files
# Microsoft Cabinet archive data, 100637 bytes, 1 file
# Microsoft Cabinet archive data, 10224 bytes, 1 file
# Microsoft Cabinet archive data, 1028313 bytes, 128 files
# Microsoft Cabinet archive data, 1067361 bytes, 13 files
# Microsoft Cabinet archive data, 10746244 bytes, 218 files
# Microsoft Cabinet archive data, 10912685 bytes, 17 files
# Microsoft Cabinet archive data, 1100544 bytes, 1 file
# Microsoft Cabinet archive data, 110113 bytes, 2 files
# Microsoft Cabinet archive data, 11014917 bytes, 22 files
# Microsoft Cabinet archive data, 110156 bytes, 128 files
# Microsoft Cabinet archive data, 1103197 bytes, 1 file
# Microsoft Cabinet archive data, 110901 bytes, 88 files
# Microsoft Cabinet archive data, 1120583 bytes, 1 file
# Microsoft Cabinet archive data, 1163278 bytes, 38 files
# Microsoft Cabinet archive data, 1199638 bytes, 2 files
# Microsoft Cabinet archive data, 120226 bytes, 2 files
# Microsoft Cabinet archive data, 120668 bytes, 2 files
# Microsoft Cabinet archive data, 1227 bytes, 1 file
# Microsoft Cabinet archive data, 122730 bytes, 2 files
# Microsoft Cabinet archive data, 1231 bytes, 1 file
# Microsoft Cabinet archive data, 1235980 bytes, 5 files
# Microsoft Cabinet archive data, 124690 bytes, 2 files
# Microsoft Cabinet archive data, 12477 bytes, 3 files
# Microsoft Cabinet archive data, 12622 bytes, 4 files
# Microsoft Cabinet archive data, 126727 bytes, 1 file
# Microsoft Cabinet archive data, 1276013 bytes, 7 files
# Microsoft Cabinet archive data, 12842333 bytes, 1 file
# Microsoft Cabinet archive data, 129931 bytes, 2 files
# Microsoft Cabinet archive data, 130575 bytes, 1 file
# Microsoft Cabinet archive data, 1305896 bytes, 3 files
# Microsoft Cabinet archive data, 1312256 bytes, 8 files
# Microsoft Cabinet archive data, 13178548 bytes, 22 files
# Microsoft Cabinet archive data, 1321 bytes, 1 file
# Microsoft Cabinet archive data, 132545 bytes, 6 files
# Microsoft Cabinet archive data, 132862 bytes, 2 files
# Microsoft Cabinet archive data, 132866 bytes, 2 files
# Microsoft Cabinet archive data, 132872 bytes, 2 files
# Microsoft Cabinet archive data, 132910 bytes, 2 files
# Microsoft Cabinet archive data, 132928 bytes, 2 files
# Microsoft Cabinet archive data, 133104 bytes, 2 files
# Microsoft Cabinet archive data, 133292 bytes, 2 files
# Microsoft Cabinet archive data, 133502 bytes, 2 files
# Microsoft Cabinet archive data, 1336095 bytes, 3 files
# Microsoft Cabinet archive data, 13590009 bytes, 12 files
# Microsoft Cabinet archive data, 137418 bytes, 2 files
# Microsoft Cabinet archive data, 1375653 bytes, 4 files
# Microsoft Cabinet archive data, 1409423 bytes, 14 files
# Microsoft Cabinet archive data, 1411268 bytes, 2 files
# Microsoft Cabinet archive data, 141530 bytes, 2 files
# Microsoft Cabinet archive data, 1429839 bytes, 4 files
# Microsoft Cabinet archive data, 1433330 bytes, 98 files
# Microsoft Cabinet archive data, 143844 bytes, 2 files
# Microsoft Cabinet archive data, 144664 bytes, 9 files
# Microsoft Cabinet archive data, 14484127 bytes, 20 files
# Microsoft Cabinet archive data, 1468713 bytes, 2 files
# Microsoft Cabinet archive data, 1476650 bytes, 88 files
# Microsoft Cabinet archive data, 1503791 bytes, 3 files
# Microsoft Cabinet archive data, 1514955 bytes, 17 files
# Microsoft Cabinet archive data, 15158 bytes, 2 files
# Microsoft Cabinet archive data, 152154 bytes, 2 files
# Microsoft Cabinet archive data, 1522455 bytes, 5 files
# Microsoft Cabinet archive data, 152640 bytes, 17 files
# Microsoft Cabinet archive data, 1540 bytes, 2 files
# Microsoft Cabinet archive data, 1550036 bytes, 6 files
# Microsoft Cabinet archive data, 156504 bytes, 1 file
# Microsoft Cabinet archive data, 16005002 bytes, 25 files
# Microsoft Cabinet archive data, 16311339 bytes, 517 files
# Microsoft Cabinet archive data, 16449878 bytes, 18 files
# Microsoft Cabinet archive data, 1648608 bytes, 2 files
# Microsoft Cabinet archive data, 1670179 bytes, 20 files
# Microsoft Cabinet archive data, 1674206 bytes, 3 files
# Microsoft Cabinet archive data, 1695 bytes, 1 file
# Microsoft Cabinet archive data, 17084704 bytes, 4 files
# Microsoft Cabinet archive data, 1714 bytes, 1 file
# Microsoft Cabinet archive data, 17323388 bytes, 27 files
# Microsoft Cabinet archive data, 17769 bytes, 4 files
# Microsoft Cabinet archive data, 1790387 bytes, 1 file
# Microsoft Cabinet archive data, 1794154 bytes, 1 file
# Microsoft Cabinet archive data, 1804137 bytes, 1 file
# Microsoft Cabinet archive data, 1810358 bytes, 12 files
# Microsoft Cabinet archive data, 18172 bytes, 1 file
# Microsoft Cabinet archive data, 18178 bytes, 1 file
# Microsoft Cabinet archive data, 18195 bytes, 1 file
# Microsoft Cabinet archive data, 18210 bytes, 1 file
# Microsoft Cabinet archive data, 18215 bytes, 1 file
# Microsoft Cabinet archive data, 18223 bytes, 1 file
# Microsoft Cabinet archive data, 18236 bytes, 1 file
# Microsoft Cabinet archive data, 18238 bytes, 1 file
# Microsoft Cabinet archive data, 18246 bytes, 1 file
# Microsoft Cabinet archive data, 18254 bytes, 1 file
# Microsoft Cabinet archive data, 18257 bytes, 1 file
# Microsoft Cabinet archive data, 18259 bytes, 1 file
# Microsoft Cabinet archive data, 18260 bytes, 1 file
# Microsoft Cabinet archive data, 18261 bytes, 1 file
# Microsoft Cabinet archive data, 18262 bytes, 1 file
# Microsoft Cabinet archive data, 18271 bytes, 1 file
# Microsoft Cabinet archive data, 18281 bytes, 1 file
# Microsoft Cabinet archive data, 18284 bytes, 1 file
# Microsoft Cabinet archive data, 18287 bytes, 1 file
# Microsoft Cabinet archive data, 18289 bytes, 1 file
# Microsoft Cabinet archive data, 1850 bytes, 3 files
# Microsoft Cabinet archive data, 185760 bytes, 4 files
# Microsoft Cabinet archive data, 18624 bytes, 1 file
# Microsoft Cabinet archive data, 1869 bytes, 1 file
# Microsoft Cabinet archive data, 18733 bytes, 1 file
# Microsoft Cabinet archive data, 18734 bytes, 1 file
# Microsoft Cabinet archive data, 18735 bytes, 1 file
# Microsoft Cabinet archive data, 18739 bytes, 1 file
# Microsoft Cabinet archive data, 18745 bytes, 1 file
# Microsoft Cabinet archive data, 18792 bytes, 1 file
# Microsoft Cabinet archive data, 18802 bytes, 1 file
# Microsoft Cabinet archive data, 18806 bytes, 1 file
# Microsoft Cabinet archive data, 18810 bytes, 1 file
# Microsoft Cabinet archive data, 18811 bytes, 1 file
# Microsoft Cabinet archive data, 18812 bytes, 1 file
# Microsoft Cabinet archive data, 18813 bytes, 1 file
# Microsoft Cabinet archive data, 18814 bytes, 1 file
# Microsoft Cabinet archive data, 18816 bytes, 1 file
# Microsoft Cabinet archive data, 18817 bytes, 1 file
# Microsoft Cabinet archive data, 18819 bytes, 1 file
# Microsoft Cabinet archive data, 18820 bytes, 1 file
# Microsoft Cabinet archive data, 18821 bytes, 1 file
# Microsoft Cabinet archive data, 18823 bytes, 1 file
# Microsoft Cabinet archive data, 18826 bytes, 1 file
# Microsoft Cabinet archive data, 18827 bytes, 1 file
# Microsoft Cabinet archive data, 18829 bytes, 1 file
# Microsoft Cabinet archive data, 18830 bytes, 1 file
# Microsoft Cabinet archive data, 18832 bytes, 1 file
# Microsoft Cabinet archive data, 18833 bytes, 1 file
# Microsoft Cabinet archive data, 18837 bytes, 1 file
# Microsoft Cabinet archive data, 18841 bytes, 1 file
# Microsoft Cabinet archive data, 18844 bytes, 1 file
# Microsoft Cabinet archive data, 18848 bytes, 1 file
# Microsoft Cabinet archive data, 18850 bytes, 1 file
# Microsoft Cabinet archive data, 18852 bytes, 1 file
# Microsoft Cabinet archive data, 18856 bytes, 1 file
# Microsoft Cabinet archive data, 18867 bytes, 1 file
# Microsoft Cabinet archive data, 18876 bytes, 1 file
# Microsoft Cabinet archive data, 18902 bytes, 1 file
# Microsoft Cabinet archive data, 18915 bytes, 1 file
# Microsoft Cabinet archive data, 18916 bytes, 1 file
# Microsoft Cabinet archive data, 18917 bytes, 1 file
# Microsoft Cabinet archive data, 18918 bytes, 1 file
# Microsoft Cabinet archive data, 18920 bytes, 1 file
# Microsoft Cabinet archive data, 18921885 bytes, 4 files
# Microsoft Cabinet archive data, 18923 bytes, 1 file
# Microsoft Cabinet archive data, 18924 bytes, 1 file
# Microsoft Cabinet archive data, 18925 bytes, 1 file
# Microsoft Cabinet archive data, 18927 bytes, 1 file
# Microsoft Cabinet archive data, 18928 bytes, 1 file
# Microsoft Cabinet archive data, 18929 bytes, 1 file
# Microsoft Cabinet archive data, 18932 bytes, 1 file
# Microsoft Cabinet archive data, 18934 bytes, 1 file
# Microsoft Cabinet archive data, 18935 bytes, 1 file
# Microsoft Cabinet archive data, 18936 bytes, 1 file
# Microsoft Cabinet archive data, 18938 bytes, 1 file
# Microsoft Cabinet archive data, 18939 bytes, 1 file
# Microsoft Cabinet archive data, 18940 bytes, 1 file
# Microsoft Cabinet archive data, 18941 bytes, 1 file
# Microsoft Cabinet archive data, 18942 bytes, 1 file
# Microsoft Cabinet archive data, 18943 bytes, 1 file
# Microsoft Cabinet archive data, 18944 bytes, 1 file
# Microsoft Cabinet archive data, 18945 bytes, 1 file
# Microsoft Cabinet archive data, 18947 bytes, 1 file
# Microsoft Cabinet archive data, 18948 bytes, 1 file
# Microsoft Cabinet archive data, 18949 bytes, 1 file
# Microsoft Cabinet archive data, 18951 bytes, 1 file
# Microsoft Cabinet archive data, 18952 bytes, 1 file
# Microsoft Cabinet archive data, 18953 bytes, 1 file
# Microsoft Cabinet archive data, 18954 bytes, 1 file
# Microsoft Cabinet archive data, 18955 bytes, 1 file
# Microsoft Cabinet archive data, 18956 bytes, 1 file
# Microsoft Cabinet archive data, 18957 bytes, 1 file
# Microsoft Cabinet archive data, 18959 bytes, 1 file
# Microsoft Cabinet archive data, 18960 bytes, 1 file
# Microsoft Cabinet archive data, 18965 bytes, 1 file
# Microsoft Cabinet archive data, 18968 bytes, 1 file
# Microsoft Cabinet archive data, 18969 bytes, 1 file
# Microsoft Cabinet archive data, 18971 bytes, 1 file
# Microsoft Cabinet archive data, 18973 bytes, 1 file
# Microsoft Cabinet archive data, 18976 bytes, 1 file
# Microsoft Cabinet archive data, 18979 bytes, 1 file
# Microsoft Cabinet archive data, 18984 bytes, 1 file
# Microsoft Cabinet archive data, 18986 bytes, 1 file
# Microsoft Cabinet archive data, 18987 bytes, 1 file
# Microsoft Cabinet archive data, 18989 bytes, 1 file
# Microsoft Cabinet archive data, 19004 bytes, 1 file
# Microsoft Cabinet archive data, 19006 bytes, 1 file
# Microsoft Cabinet archive data, 19010 bytes, 1 file
# Microsoft Cabinet archive data, 19013 bytes, 1 file
# Microsoft Cabinet archive data, 19025 bytes, 1 file
# Microsoft Cabinet archive data, 19029 bytes, 1 file
# Microsoft Cabinet archive data, 19079 bytes, 1 file
# Microsoft Cabinet archive data, 19082 bytes, 1 file
# Microsoft Cabinet archive data, 19083 bytes, 1 file
# Microsoft Cabinet archive data, 19085 bytes, 1 file
# Microsoft Cabinet archive data, 19092 bytes, 1 file
# Microsoft Cabinet archive data, 1918764 bytes, 79 files
# Microsoft Cabinet archive data, 19314 bytes, 1 file
# Microsoft Cabinet archive data, 19316 bytes, 1 file
# Microsoft Cabinet archive data, 19321 bytes, 1 file
# Microsoft Cabinet archive data, 19322 bytes, 1 file
# Microsoft Cabinet archive data, 19326 bytes, 1 file
# Microsoft Cabinet archive data, 19328 bytes, 1 file
# Microsoft Cabinet archive data, 19329 bytes, 1 file
# Microsoft Cabinet archive data, 19333 bytes, 1 file
# Microsoft Cabinet archive data, 19337 bytes, 1 file
# Microsoft Cabinet archive data, 19338 bytes, 1 file
# Microsoft Cabinet archive data, 19341 bytes, 1 file
# Microsoft Cabinet archive data, 19343 bytes, 1 file
# Microsoft Cabinet archive data, 19344 bytes, 1 file
# Microsoft Cabinet archive data, 19346 bytes, 1 file
# Microsoft Cabinet archive data, 19347 bytes, 1 file
# Microsoft Cabinet archive data, 19348 bytes, 1 file
# Microsoft Cabinet archive data, 19349 bytes, 1 file
# Microsoft Cabinet archive data, 19350 bytes, 1 file
# Microsoft Cabinet archive data, 19352 bytes, 1 file
# Microsoft Cabinet archive data, 19353 bytes, 1 file
# Microsoft Cabinet archive data, 19354 bytes, 1 file
# Microsoft Cabinet archive data, 19355 bytes, 1 file
# Microsoft Cabinet archive data, 19359 bytes, 1 file
# Microsoft Cabinet archive data, 19361 bytes, 1 file
# Microsoft Cabinet archive data, 19363 bytes, 1 file
# Microsoft Cabinet archive data, 19364 bytes, 1 file
# Microsoft Cabinet archive data, 19368 bytes, 1 file
# Microsoft Cabinet archive data, 19370 bytes, 1 file
# Microsoft Cabinet archive data, 19372 bytes, 1 file
# Microsoft Cabinet archive data, 19373 bytes, 1 file
# Microsoft Cabinet archive data, 19374 bytes, 1 file
# Microsoft Cabinet archive data, 19390 bytes, 1 file
# Microsoft Cabinet archive data, 19391 bytes, 1 file
# Microsoft Cabinet archive data, 19406 bytes, 1 file
# Microsoft Cabinet archive data, 19407 bytes, 1 file
# Microsoft Cabinet archive data, 19408 bytes, 1 file
# Microsoft Cabinet archive data, 19409 bytes, 1 file
# Microsoft Cabinet archive data, 19412 bytes, 1 file
# Microsoft Cabinet archive data, 19415 bytes, 1 file
# Microsoft Cabinet archive data, 19418 bytes, 1 file
# Microsoft Cabinet archive data, 19419 bytes, 1 file
# Microsoft Cabinet archive data, 19422 bytes, 1 file
# Microsoft Cabinet archive data, 19429 bytes, 1 file
# Microsoft Cabinet archive data, 19438 bytes, 1 file
# Microsoft Cabinet archive data, 19439 bytes, 1 file
# Microsoft Cabinet archive data, 19456 bytes, 1 file
# Microsoft Cabinet archive data, 19531 bytes, 1 file
# Microsoft Cabinet archive data, 19535 bytes, 1 file
# Microsoft Cabinet archive data, 19540 bytes, 1 file
# Microsoft Cabinet archive data, 19546 bytes, 1 file
# Microsoft Cabinet archive data, 19550 bytes, 1 file
# Microsoft Cabinet archive data, 19553 bytes, 1 file
# Microsoft Cabinet archive data, 19556 bytes, 1 file
# Microsoft Cabinet archive data, 19557 bytes, 1 file
# Microsoft Cabinet archive data, 19559 bytes, 1 file
# Microsoft Cabinet archive data, 19560 bytes, 1 file
# Microsoft Cabinet archive data, 19562 bytes, 1 file
# Microsoft Cabinet archive data, 19566 bytes, 1 file
# Microsoft Cabinet archive data, 19568 bytes, 1 file
# Microsoft Cabinet archive data, 19571 bytes, 1 file
# Microsoft Cabinet archive data, 19572 bytes, 1 file
# Microsoft Cabinet archive data, 19576 bytes, 1 file
# Microsoft Cabinet archive data, 19577 bytes, 1 file
# Microsoft Cabinet archive data, 19580 bytes, 1 file
# Microsoft Cabinet archive data, 19581 bytes, 1 file
# Microsoft Cabinet archive data, 19584 bytes, 1 file
# Microsoft Cabinet archive data, 19693214 bytes, 2 files
# Microsoft Cabinet archive data, 19696 bytes, 1 file
# Microsoft Cabinet archive data, 19699 bytes, 1 file
# Microsoft Cabinet archive data, 19704 bytes, 1 file
# Microsoft Cabinet archive data, 19706 bytes, 1 file
# Microsoft Cabinet archive data, 19711 bytes, 1 file
# Microsoft Cabinet archive data, 19745 bytes, 1 file
# Microsoft Cabinet archive data, 19908 bytes, 1 file
# Microsoft Cabinet archive data, 20030 bytes, 1 file
# Microsoft Cabinet archive data, 20037 bytes, 1 file
# Microsoft Cabinet archive data, 20047 bytes, 1 file
# Microsoft Cabinet archive data, 20049 bytes, 1 file
# Microsoft Cabinet archive data, 20059 bytes, 1 file
# Microsoft Cabinet archive data, 20120 bytes, 1 file
# Microsoft Cabinet archive data, 20122 bytes, 1 file
# Microsoft Cabinet archive data, 20124 bytes, 1 file
# Microsoft Cabinet archive data, 20130 bytes, 1 file
# Microsoft Cabinet archive data, 20131 bytes, 1 file
# Microsoft Cabinet archive data, 20320 bytes, 1 file
# Microsoft Cabinet archive data, 203451 bytes, 1 file
# Microsoft Cabinet archive data, 20360 bytes, 1 file
# Microsoft Cabinet archive data, 20445594 bytes, 26 files
# Microsoft Cabinet archive data, 20530 bytes, 2 files
# Microsoft Cabinet archive data, 2058824 bytes, 395 files
# Microsoft Cabinet archive data, 211518 bytes, 1 file
# Microsoft Cabinet archive data, 2138264 bytes, 50 files
# Microsoft Cabinet archive data, 21608 bytes, 11 files
# Microsoft Cabinet archive data, 2172736 bytes, 2 files
# Microsoft Cabinet archive data, 21763916 bytes, 4 files
# Microsoft Cabinet archive data, 21948 bytes, 1 file
# Microsoft Cabinet archive data, 21949 bytes, 1 file
# Microsoft Cabinet archive data, 21950 bytes, 1 file
# Microsoft Cabinet archive data, 21955 bytes, 1 file
# Microsoft Cabinet archive data, 21956 bytes, 1 file
# Microsoft Cabinet archive data, 21957 bytes, 1 file
# Microsoft Cabinet archive data, 21959 bytes, 1 file
# Microsoft Cabinet archive data, 21961 bytes, 1 file
# Microsoft Cabinet archive data, 21962 bytes, 1 file
# Microsoft Cabinet archive data, 21963 bytes, 1 file
# Microsoft Cabinet archive data, 21964 bytes, 1 file
# Microsoft Cabinet archive data, 21966 bytes, 1 file
# Microsoft Cabinet archive data, 21968 bytes, 1 file
# Microsoft Cabinet archive data, 21969 bytes, 1 file
# Microsoft Cabinet archive data, 21970 bytes, 1 file
# Microsoft Cabinet archive data, 21972 bytes, 1 file
# Microsoft Cabinet archive data, 21973 bytes, 1 file
# Microsoft Cabinet archive data, 21974 bytes, 1 file
# Microsoft Cabinet archive data, 21978 bytes, 1 file
# Microsoft Cabinet archive data, 2225532 bytes, 1 file
# Microsoft Cabinet archive data, 22492 bytes, 1 file
# Microsoft Cabinet archive data, 22525 bytes, 1 file
# Microsoft Cabinet archive data, 22539 bytes, 1 file
# Microsoft Cabinet archive data, 22543 bytes, 1 file
# Microsoft Cabinet archive data, 22549 bytes, 1 file
# Microsoft Cabinet archive data, 22551 bytes, 1 file
# Microsoft Cabinet archive data, 22553 bytes, 1 file
# Microsoft Cabinet archive data, 22555 bytes, 1 file
# Microsoft Cabinet archive data, 22556 bytes, 1 file
# Microsoft Cabinet archive data, 225569 bytes, 1 file
# Microsoft Cabinet archive data, 22559 bytes, 1 file
# Microsoft Cabinet archive data, 22564 bytes, 1 file
# Microsoft Cabinet archive data, 22570 bytes, 1 file
# Microsoft Cabinet archive data, 22571 bytes, 1 file
# Microsoft Cabinet archive data, 22572 bytes, 1 file
# Microsoft Cabinet archive data, 22578 bytes, 1 file
# Microsoft Cabinet archive data, 22579 bytes, 1 file
# Microsoft Cabinet archive data, 22580 bytes, 1 file
# Microsoft Cabinet archive data, 22581 bytes, 1 file
# Microsoft Cabinet archive data, 22583 bytes, 1 file
# Microsoft Cabinet archive data, 22589 bytes, 1 file
# Microsoft Cabinet archive data, 22594 bytes, 1 file
# Microsoft Cabinet archive data, 226298 bytes, 4 files
# Microsoft Cabinet archive data, 226346 bytes, 1 file
# Microsoft Cabinet archive data, 22877 bytes, 1 file
# Microsoft Cabinet archive data, 22886 bytes, 1 file
# Microsoft Cabinet archive data, 22887 bytes, 1 file
# Microsoft Cabinet archive data, 22950 bytes, 2 files
# Microsoft Cabinet archive data, 23032 bytes, 1 file
# Microsoft Cabinet archive data, 23041 bytes, 1 file
# Microsoft Cabinet archive data, 23042 bytes, 1 file
# Microsoft Cabinet archive data, 23045 bytes, 1 file
# Microsoft Cabinet archive data, 23047 bytes, 1 file
# Microsoft Cabinet archive data, 23048 bytes, 1 file
# Microsoft Cabinet archive data, 23049 bytes, 1 file
# Microsoft Cabinet archive data, 23050 bytes, 1 file
# Microsoft Cabinet archive data, 23051 bytes, 1 file
# Microsoft Cabinet archive data, 23052 bytes, 1 file
# Microsoft Cabinet archive data, 23053 bytes, 1 file
# Microsoft Cabinet archive data, 23055 bytes, 1 file
# Microsoft Cabinet archive data, 23057 bytes, 1 file
# Microsoft Cabinet archive data, 23059 bytes, 1 file
# Microsoft Cabinet archive data, 23060 bytes, 1 file
# Microsoft Cabinet archive data, 23189 bytes, 1 file
# Microsoft Cabinet archive data, 23191 bytes, 1 file
# Microsoft Cabinet archive data, 233651 bytes, 7 files
# Microsoft Cabinet archive data, 2377 bytes, 5 files
# Microsoft Cabinet archive data, 24538 bytes, 2 files
# Microsoft Cabinet archive data, 246158 bytes, 1 file
# Microsoft Cabinet archive data, 24638 bytes, 1 file
# Microsoft Cabinet archive data, 24644 bytes, 1 file
# Microsoft Cabinet archive data, 24661 bytes, 1 file
# Microsoft Cabinet archive data, 25006 bytes, 1 file
# Microsoft Cabinet archive data, 25009 bytes, 1 file
# Microsoft Cabinet archive data, 25014 bytes, 1 file
# Microsoft Cabinet archive data, 252862 bytes, 1 file
# Microsoft Cabinet archive data, 25344901 bytes, 1 file
# Microsoft Cabinet archive data, 25797 bytes, 1 file
# Microsoft Cabinet archive data, 259575 bytes, 7 files
# Microsoft Cabinet archive data, 2602534 bytes, 9 files
# Microsoft Cabinet archive data, 260586 bytes, 1 file
# Microsoft Cabinet archive data, 261885 bytes, 4 files
# Microsoft Cabinet archive data, 262994 bytes, 1 file
# Microsoft Cabinet archive data, 265847 bytes, 1 file
# Microsoft Cabinet archive data, 26755 bytes, 2 files
# Microsoft Cabinet archive data, 2679261 bytes, 1 file
# Microsoft Cabinet archive data, 27034 bytes, 1 file
# Microsoft Cabinet archive data, 27037 bytes, 1 file
# Microsoft Cabinet archive data, 27048 bytes, 1 file
# Microsoft Cabinet archive data, 2710 bytes, 1 file
# Microsoft Cabinet archive data, 27214 bytes, 1 file
# Microsoft Cabinet archive data, 27220 bytes, 1 file
# Microsoft Cabinet archive data, 27223 bytes, 1 file
# Microsoft Cabinet archive data, 27228 bytes, 1 file
# Microsoft Cabinet archive data, 27230 bytes, 1 file
# Microsoft Cabinet archive data, 27231 bytes, 1 file
# Microsoft Cabinet archive data, 27232 bytes, 1 file
# Microsoft Cabinet archive data, 27233 bytes, 1 file
# Microsoft Cabinet archive data, 27234 bytes, 1 file
# Microsoft Cabinet archive data, 27235 bytes, 1 file
# Microsoft Cabinet archive data, 27237 bytes, 1 file
# Microsoft Cabinet archive data, 27238 bytes, 1 file
# Microsoft Cabinet archive data, 27240 bytes, 1 file
# Microsoft Cabinet archive data, 27246 bytes, 1 file
# Microsoft Cabinet archive data, 27249 bytes, 1 file
# Microsoft Cabinet archive data, 27251 bytes, 1 file
# Microsoft Cabinet archive data, 27253 bytes, 1 file
# Microsoft Cabinet archive data, 27261 bytes, 1 file
# Microsoft Cabinet archive data, 273782 bytes, 1 file
# Microsoft Cabinet archive data, 2800582 bytes, 63 files
# Microsoft Cabinet archive data, 285 bytes, 1 file
# Microsoft Cabinet archive data, 286428 bytes, 2 files
# Microsoft Cabinet archive data, 2942033 bytes, 4 files
# Microsoft Cabinet archive data, 30390 bytes, 1 file
# Microsoft Cabinet archive data, 30391 bytes, 1 file
# Microsoft Cabinet archive data, 30392 bytes, 1 file
# Microsoft Cabinet archive data, 30393 bytes, 1 file
# Microsoft Cabinet archive data, 3047551 bytes, 12537 files
# Microsoft Cabinet archive data, 30485 bytes, 1 file
# Microsoft Cabinet archive data, 30594 bytes, 1 file
# Microsoft Cabinet archive data, 30933 bytes, 2 files
# Microsoft Cabinet archive data, 31008 bytes, 1 file
# Microsoft Cabinet archive data, 31239 bytes, 1 file
# Microsoft Cabinet archive data, 31242 bytes, 1 file
# Microsoft Cabinet archive data, 31267 bytes, 1 file
# Microsoft Cabinet archive data, 31296 bytes, 1 file
# Microsoft Cabinet archive data, 31304 bytes, 1 file
# Microsoft Cabinet archive data, 313090 bytes, 31 files
# Microsoft Cabinet archive data, 31312 bytes, 1 file
# Microsoft Cabinet archive data, 31318 bytes, 1 file
# Microsoft Cabinet archive data, 31324 bytes, 1 file
# Microsoft Cabinet archive data, 31327 bytes, 1 file
# Microsoft Cabinet archive data, 31328 bytes, 1 file
# Microsoft Cabinet archive data, 31331 bytes, 1 file
# Microsoft Cabinet archive data, 31337 bytes, 1 file
# Microsoft Cabinet archive data, 31339 bytes, 1 file
# Microsoft Cabinet archive data, 31343 bytes, 1 file
# Microsoft Cabinet archive data, 31344 bytes, 1 file
# Microsoft Cabinet archive data, 31354 bytes, 1 file
# Microsoft Cabinet archive data, 31355 bytes, 1 file
# Microsoft Cabinet archive data, 31358 bytes, 1 file
# Microsoft Cabinet archive data, 3190696 bytes, 30 files
# Microsoft Cabinet archive data, 32112 bytes, 1 file
# Microsoft Cabinet archive data, 32165 bytes, 34 files
# Microsoft Cabinet archive data, 329373 bytes, 2 files
# Microsoft Cabinet archive data, 330345 bytes, 4 files
# Microsoft Cabinet archive data, 33039 bytes, 1 file
# Microsoft Cabinet archive data, 3326981 bytes, 2 files
# Microsoft Cabinet archive data, 333868 bytes, 2 files
# Microsoft Cabinet archive data, 337513 bytes, 1 file
# Microsoft Cabinet archive data, 338355 bytes, 2 files
# Microsoft Cabinet archive data, 33907 bytes, 1 file
# Microsoft Cabinet archive data, 34378 bytes, 2 files
# Microsoft Cabinet archive data, 3480337 bytes, 23 files
# Microsoft Cabinet archive data, 351836 bytes, 1 file
# Microsoft Cabinet archive data, 3544006 bytes, 1 file
# Microsoft Cabinet archive data, 3557592 bytes, 2 files
# Microsoft Cabinet archive data, 36096 bytes, 6 files
# Microsoft Cabinet archive data, 361098 bytes, 44 files
# Microsoft Cabinet archive data, 36378 bytes, 1 file
# Microsoft Cabinet archive data, 36716 bytes, 1 file
# Microsoft Cabinet archive data, 3688161 bytes, 40 files
# Microsoft Cabinet archive data, 3748965 bytes, 13 files
# Microsoft Cabinet archive data, 3837558 bytes, 2 files
# Microsoft Cabinet archive data, 39270 bytes, 1 file
# Microsoft Cabinet archive data, 39272 bytes, 1 file
# Microsoft Cabinet archive data, 393498 bytes, 1 file
# Microsoft Cabinet archive data, 39370 bytes, 3 files
# Microsoft Cabinet archive data, 39818 bytes, 22 files
# Microsoft Cabinet archive data, 399433 bytes, 2 files
# Microsoft Cabinet archive data, 4072590 bytes, 32 files
# Microsoft Cabinet archive data, 41864 bytes, 17 files
# Microsoft Cabinet archive data, 41921320 bytes, 2 files
# Microsoft Cabinet archive data, 4219235 bytes, 4 files
# Microsoft Cabinet archive data, 423485 bytes, 4 files
# Microsoft Cabinet archive data, 425426 bytes, 29 files
# Microsoft Cabinet archive data, 4402539 bytes, 2 files
# Microsoft Cabinet archive data, 441215 bytes, 1 file
# Microsoft Cabinet archive data, 444146 bytes, 6 files
# Microsoft Cabinet archive data, 44718 bytes, 1 file
# Microsoft Cabinet archive data, 44724 bytes, 1 file
# Microsoft Cabinet archive data, 44740 bytes, 1 file
# Microsoft Cabinet archive data, 44751 bytes, 1 file
# Microsoft Cabinet archive data, 44754 bytes, 1 file
# Microsoft Cabinet archive data, 44768 bytes, 1 file
# Microsoft Cabinet archive data, 44773 bytes, 1 file
# Microsoft Cabinet archive data, 452027 bytes, 4 files
# Microsoft Cabinet archive data, 4544 bytes, 2 files
# Microsoft Cabinet archive data, 4632637 bytes, 8 files
# Microsoft Cabinet archive data, 4721475 bytes, 2 files
# Microsoft Cabinet archive data, 477442 bytes, 4 files
# Microsoft Cabinet archive data, 48151 bytes, 1 file
# Microsoft Cabinet archive data, 48425 bytes, 2 files
# Microsoft Cabinet archive data, 487558 bytes, 4 files
# Microsoft Cabinet archive data, 49082 bytes, 1 file
# Microsoft Cabinet archive data, 493020 bytes, 4 files
# Microsoft Cabinet archive data, 49565 bytes, 1 file
# Microsoft Cabinet archive data, 49640 bytes, 1 file
# Microsoft Cabinet archive data, 49661 bytes, 1 file
# Microsoft Cabinet archive data, 49695 bytes, 1 file
# Microsoft Cabinet archive data, 4971714 bytes, 21 files
# Microsoft Cabinet archive data, 50006 bytes, 1 file
# Microsoft Cabinet archive data, 50015 bytes, 1 file
# Microsoft Cabinet archive data, 501477 bytes, 7 files
# Microsoft Cabinet archive data, 502962 bytes, 237 files
# Microsoft Cabinet archive data, 5085798 bytes, 4 files
# Microsoft Cabinet archive data, 51033 bytes, 2 files
# Microsoft Cabinet archive data, 5109596 bytes, 9 files
# Microsoft Cabinet archive data, 5186058 bytes, 76 files
# Microsoft Cabinet archive data, 522876 bytes, 4 files
# Microsoft Cabinet archive data, 52521 bytes, 1 file
# Microsoft Cabinet archive data, 52681 bytes, 1 file
# Microsoft Cabinet archive data, 53749 bytes, 1 file
# Microsoft Cabinet archive data, 538727 bytes, 2 files
# Microsoft Cabinet archive data, 5398 bytes, 4 files
# Microsoft Cabinet archive data, 54007 bytes, 1 file
# Microsoft Cabinet archive data, 54009 bytes, 1 file
# Microsoft Cabinet archive data, 5463657 bytes, 4 files
# Microsoft Cabinet archive data, 5493323 bytes, 1 file
# Microsoft Cabinet archive data, 553805 bytes, 13 files
# Microsoft Cabinet archive data, 56 bytes
# Microsoft Cabinet archive data, 56928 bytes, 1 file
# Microsoft Cabinet archive data, 573879 bytes, 1 file
# Microsoft Cabinet archive data, 57591 bytes, 1 file
# Microsoft Cabinet archive data, 584386 bytes, 2 files
# Microsoft Cabinet archive data, 5913943 bytes, 20 files
# Microsoft Cabinet archive data, 5916 bytes, 1 file
# Microsoft Cabinet archive data, 594586 bytes, 22 files
# Microsoft Cabinet archive data, 6045 bytes, 1 file
# Microsoft Cabinet archive data, 6171762 bytes, 2 files
# Microsoft Cabinet archive data, 61720 bytes, 2 files
# Microsoft Cabinet archive data, 6179 bytes, 5 files
# Microsoft Cabinet archive data, 6235143 bytes, 1391 files
# Microsoft Cabinet archive data, 627904 bytes, 2 files
# Microsoft Cabinet archive data, 628536 bytes, 2 files
# Microsoft Cabinet archive data, 629138 bytes, 21 files
# Microsoft Cabinet archive data, 6296565 bytes, 100 files
# Microsoft Cabinet archive data, 6305 bytes, 1 file
# Microsoft Cabinet archive data, 633883 bytes, 3 files
# Microsoft Cabinet archive data, 637294 bytes, 3 files
# Microsoft Cabinet archive data, 637490 bytes, 1 file
# Microsoft Cabinet archive data, 6479289 bytes, 6 files
# Microsoft Cabinet archive data, 648038 bytes, 1 file
# Microsoft Cabinet archive data, 6509 bytes, 1 file
# Microsoft Cabinet archive data, 6557 bytes, 1 file
# Microsoft Cabinet archive data, 657629 bytes, 1 file
# Microsoft Cabinet archive data, 658874 bytes, 1 file
# Microsoft Cabinet archive data, 660315 bytes, 1 file
# Microsoft Cabinet archive data, 66856 bytes, 1 file
# Microsoft Cabinet archive data, 66857 bytes, 1 file
# Microsoft Cabinet archive data, 6714 bytes, 7 files
# Microsoft Cabinet archive data, 67163 bytes, 1 file
# Microsoft Cabinet archive data, 6892 bytes, 2 files
# Microsoft Cabinet archive data, 695785 bytes, 4 files
# Microsoft Cabinet archive data, 698471 bytes, 4 files
# Microsoft Cabinet archive data, 700500 bytes, 9 files
# Microsoft Cabinet archive data, 702766 bytes, 1 file
# Microsoft Cabinet archive data, 709338 bytes, 12 files
# Microsoft Cabinet archive data, 711228 bytes, 4 files
# Microsoft Cabinet archive data, 71192 bytes, 12 files
# Microsoft Cabinet archive data, 712999 bytes, 4 files
# Microsoft Cabinet archive data, 71581 bytes, 1 file
# Microsoft Cabinet archive data, 7228 bytes, 2 files
# Microsoft Cabinet archive data, 724855 bytes, 20 files
# Microsoft Cabinet archive data, 74509 bytes, 7 files
# Microsoft Cabinet archive data, 74821 bytes, 2 files
# Microsoft Cabinet archive data, 75593 bytes, 1 file
# Microsoft Cabinet archive data, 75596 bytes, 1 file
# Microsoft Cabinet archive data, 75597 bytes, 1 file
# Microsoft Cabinet archive data, 75598 bytes, 1 file
# Microsoft Cabinet archive data, 759009 bytes, 4 files
# Microsoft Cabinet archive data, 7681 bytes, 1 file
# Microsoft Cabinet archive data, 7744 bytes, 6 files
# Microsoft Cabinet archive data, 787527 bytes, 2 files
# Microsoft Cabinet archive data, 7990 bytes, 1 file
# Microsoft Cabinet archive data, 800952 bytes, 4 files
# Microsoft Cabinet archive data, 809 bytes, 1 file
# Microsoft Cabinet archive data, 81352 bytes, 2 files
# Microsoft Cabinet archive data, 82411 bytes, 1 file
# Microsoft Cabinet archive data, 8423457 bytes, 6 files
# Microsoft Cabinet archive data, 8583 bytes, 1 file
# Microsoft Cabinet archive data, 858885 bytes, 15 files
# Microsoft Cabinet archive data, 87303 bytes, 94 files
# Microsoft Cabinet archive data, 886528 bytes, 2 files
# Microsoft Cabinet archive data, 9009 bytes, 1 file
# Microsoft Cabinet archive data, 9127538 bytes, 28 files
# Microsoft Cabinet archive data, 9162098 bytes, 2 files
# Microsoft Cabinet archive data, 9288 bytes, 1 file
# Microsoft Cabinet archive data, 930017 bytes, 2 files
# Microsoft Cabinet archive data, 9390 bytes, 1 file
# Microsoft Cabinet archive data, 9465 bytes, 1 file
# Microsoft Cabinet archive data, 9492 bytes, 1 file
# Microsoft Cabinet archive data, 9503 bytes, 1 file
# Microsoft Cabinet archive data, 9646 bytes, 1 file
# Microsoft Cabinet archive data, 967 bytes, 1 file
# Microsoft Cabinet archive data, 976188 bytes, 2 files
# Microsoft Cabinet archive data, 9772 bytes, 1 file
# Microsoft Cabinet archive data, 977253 bytes, 1 file
# Microsoft Cabinet archive data, 9776 bytes, 1 file
# Microsoft Cabinet archive data, 98078 bytes, 186 files
# Microsoft Cabinet archive data, 9822 bytes, 1 file
# Microsoft Cabinet archive data, 991055 bytes, 21 files
# Microsoft Cabinet archive data, 9911342 bytes, 121 files
# Microsoft Cabinet archive data, 9957 bytes, 1 file
# Microsoft Cabinet archive data, 997 bytes, 1 file
# PAK archive data
# POSIX tar archive
# POSIX tar archive (GNU)
# PPMD archive data
# PPMN archive data
# PowerISO Direct-Access-Archive
# RAR archive data,
# RAR archive data, flags: Locked,
# RAR archive data, v0,
# RAR archive data, v0, flags: Archive volume, Commented, Authenticated,
# RAR archive data, v0, flags: Commented, Locked,
# RAR archive data, v1, flags: Archive volume, Commented, Solid, Authent ...
# RAR archive data, v11,
# RAR archive data, v12,
# RAR archive data, v14, flags: Archive volume, os: Win32
# RAR archive data, v14, flags: Locked, os: Unix
# RAR archive data, v14, flags: Locked, os: Win32
# RAR archive data, v14, flags: os: Unix
# RAR archive data, v14, flags: os: Win32
# RAR archive data, v14, os: MS-DOS
# RAR archive data, v14, os: Unix
# RAR archive data, v14, os: Win32
# RAR archive data, v15,
# RAR archive data, v17,
# RAR archive data, v19,
# RAR archive data, v1a,
# RAR archive data, v1b,
# RAR archive data, v1d, flags: Archive volume, Locked, os: Win32
# RAR archive data, v1d, flags: Archive volume, os: Win32
# RAR archive data, v1d, flags: Locked, Solid, os: Win32
# RAR archive data, v1d, flags: Locked, os: Win32
# RAR archive data, v1d, flags: Solid, os: Win32
# RAR archive data, v1d, flags: os: Win32
# RAR archive data, v1d, os: Unix
# RAR archive data, v1d, os: Win32
# RAR archive data, v20,
# RAR archive data, v20, flags:
# RAR archive data, v20, flags: Archive volume, Commented, Authenticated ...
# RAR archive data, v20, flags: Archive volume, Locked, Solid, Authentic ...
# RAR archive data, v20, flags: Solid, Authenticated,
# RAR archive data, v22,
# RAR archive data, v24, flags: Archive volume, Commented, Solid, Authen ...
# RAR archive data, v24, flags: Archive volume, Locked, os: MS-DOS
# RAR archive data, v24, os: Win32
# RAR archive data, v25,
# RAR archive data, v26,
# RAR archive data, v29,
# RAR archive data, v29, flags: Commented, Authenticated,
# RAR archive data, v2a,
# RAR archive data, v2b,
# RAR archive data, v2d,
# RAR archive data, v2e,
# RAR archive data, v3,
# RAR archive data, v30,
# RAR archive data, v32,
# RAR archive data, v33,
# RAR archive data, v33, flags: Solid, Authenticated,
# RAR archive data, v38,
# RAR archive data, v39,
# RAR archive data, v3b,
# RAR archive data, v3e,
# RAR archive data, v3f,
# RAR archive data, v4,
# RAR archive data, v40,
# RAR archive data, v41,
# RAR archive data, v44, os: Win32
# RAR archive data, v45,
# RAR archive data, v46,
# RAR archive data, v48,
# RAR archive data, v49,
# RAR archive data, v4a,
# RAR archive data, v4c,
# RAR archive data, v4c, flags: Commented, Locked, Solid,
# RAR archive data, v4c, os: Unix
# RAR archive data, v4e,
# RAR archive data, v5,
# RAR archive data, v50,
# RAR archive data, v51,
# RAR archive data, v52,
# RAR archive data, v54,
# RAR archive data, v55,
# RAR archive data, v56,
# RAR archive data, v58,
# RAR archive data, v59,
# RAR archive data, v59, flags: Archive volume, Commented, Solid,
# RAR archive data, v5a,
# RAR archive data, v5b, os: MS-DOS
# RAR archive data, v5c,
# RAR archive data, v5c, flags: Solid,
# RAR archive data, v5e,
# RAR archive data, v60,
# RAR archive data, v61,
# RAR archive data, v63,
# RAR archive data, v64,
# RAR archive data, v65,
# RAR archive data, v68,
# RAR archive data, v69,
# RAR archive data, v6a, flags: Archive volume, Locked, Authenticated,
# RAR archive data, v6c,
# RAR archive data, v6e,
# RAR archive data, v6f, flags: Locked,
# RAR archive data, v7,
# RAR archive data, v71,
# RAR archive data, v74,
# RAR archive data, v77,
# RAR archive data, v77, flags: Commented, Authenticated,
# RAR archive data, v7a,
# RAR archive data, v7b,
# RAR archive data, v7b, flags: Archive volume, Commented, Locked, Solid ...
# RAR archive data, v7d, flags: Commented, Authenticated,
# RAR archive data, v8,
# RAR archive data, v80,
# RAR archive data, v80, flags: Archive volume, Locked,
# RAR archive data, v80, flags: Archive volume, Locked, Solid,
# RAR archive data, v80, flags: Commented, Locked,
# RAR archive data, v80, flags: Commented, Solid, Authenticated,
# RAR archive data, v80, os: Unix
# RAR archive data, v81,
# RAR archive data, v82,
# RAR archive data, v85,
# RAR archive data, v86,
# RAR archive data, v86, flags: Archive volume, Commented, Solid,
# RAR archive data, v88,
# RAR archive data, v8a,
# RAR archive data, v8c,
# RAR archive data, v8d,
# RAR archive data, v8d, flags: Archive volume, Solid, Authenticated,
# RAR archive data, v8e,
# RAR archive data, v8f,
# RAR archive data, v9,
# RAR archive data, v90,
# RAR archive data, v91,
# RAR archive data, v99,
# RAR archive data, v9a,
# RAR archive data, v9d,
# RAR archive data, va0,
# RAR archive data, va0, flags: Commented, Locked, Solid, Authenticated,
# RAR archive data, va1,
# RAR archive data, va1, flags: Archive volume, Commented,
# RAR archive data, va2,
# RAR archive data, va4,
# RAR archive data, va7,
# RAR archive data, va8,
# RAR archive data, vab,
# RAR archive data, vab, flags: Archive volume, Commented, os: Unix
# RAR archive data, vab, flags: Locked, Authenticated,
# RAR archive data, vad,
# RAR archive data, vad, flags: Locked, Solid,
# RAR archive data, vae,
# RAR archive data, vb,
# RAR archive data, vb0, flags: Archive volume,
# RAR archive data, vb3,
# RAR archive data, vb3, flags: Locked, Solid,
# RAR archive data, vb5,
# RAR archive data, vb6,
# RAR archive data, vb8,
# RAR archive data, vb9,
# RAR archive data, vba,
# RAR archive data, vbb,
# RAR archive data, vbd,
# RAR archive data, vbe,
# RAR archive data, vbf,
# RAR archive data, vc1,
# RAR archive data, vc1, flags: Commented, Solid,
# RAR archive data, vc3,
# RAR archive data, vc4,
# RAR archive data, vc6,
# RAR archive data, vc8,
# RAR archive data, vc8, flags: Archive volume,
# RAR archive data, vc9, os: Win32
# RAR archive data, vca,
# RAR archive data, vca, flags: Commented, Authenticated,
# RAR archive data, vcc,
# RAR archive data, vcd,
# RAR archive data, vce,
# RAR archive data, vd,
# RAR archive data, vd3,
# RAR archive data, vd6,
# RAR archive data, vd8,
# RAR archive data, vdc,
# RAR archive data, vdd,
# RAR archive data, vde,
# RAR archive data, vdf,
# RAR archive data, ve,
# RAR archive data, ve3,
# RAR archive data, ve4,
# RAR archive data, ve6,
# RAR archive data, ve8,
# RAR archive data, vea,
# RAR archive data, veb,
# RAR archive data, vf,
# RAR archive data, vf0,
# RAR archive data, vf1,
# RAR archive data, vf2,
# RAR archive data, vf3,
# RAR archive data, vf5, flags: Archive volume, Solid,
# RAR archive data, vf8, flags: Commented,
# RAR archive data, vf9, flags: Archive volume, Commented, Locked, Solid ...
# RAR archive data, vf9, flags: Commented,
# RAR archive data, vfb,
# RAR archive data, vfb, flags: Commented, Authenticated,
# RAR archive data, vfd,
# RAR archive data, vfe,
# TTComp archive data
# UHarc archive data
# XZ compressed data
# YAC archive data
# Zip archive data
# Zip archive data (empty)
# Zip archive data, at least v0.9 to extract
# Zip archive data, at least v1.0 to extract
# Zip archive data, at least v1.0 to extractZip archive data, at least v ...
# Zip archive data, at least v2.0 to extract
# Zip archive data, at least v3.0 to extract
# Zip multi-volume archive data, at least PKZIP v2.50 to extract
# \020)\006 X\177Zip archive data, at least v1.0 to extract
# \020)\006 X\177Zip archive data, at least v1.0 to extractdata
# bzip2 compressed data, block size = 100k
# bzip2 compressed data, block size = 200k
# bzip2 compressed data, block size = 500k
# bzip2 compressed data, block size = 600k
# bzip2 compressed data, block size = 900k
# current ar archive
# gzip compressed data
# gzip compressed data, encrypted, last modified: Thu Jan 29 19:38:08 19 ...
# gzip compressed data, from FAT filesystem (MS-DOS, OS/2, NT)
# gzip compressed data, from FAT filesystem (MS-DOS, OS/2, NT), max spee ...
# gzip compressed data, from NTFS filesystem (NT)
# gzip compressed data, from NTFS filesystem (NT), last modified: Wed Ap ...
# gzip compressed data, from NTFS filesystem (NT), max compression
# gzip compressed data, from NTFS filesystem (NT), max speed
# gzip compressed data, from Unix
# gzip compressed data, from Unix, last modified: Fri Apr  3 00:50:56 20 ...
# gzip compressed data, from Unix, last modified: Fri Apr  5 05:49:11 20 ...
# gzip compressed data, from Unix, last modified: Fri Apr  8 00:39:06 20 ...
# gzip compressed data, from Unix, last modified: Fri Apr 12 21:59:18 20 ...
# gzip compressed data, from Unix, last modified: Fri Aug 19 06:52:35 20 ...
# gzip compressed data, from Unix, last modified: Fri Aug 23 09:14:36 20 ...
# gzip compressed data, from Unix, last modified: Fri Aug 26 06:12:40 20 ...
# gzip compressed data, from Unix, last modified: Fri Aug 26 14:14:51 20 ...
# gzip compressed data, from Unix, last modified: Fri Aug 26 14:16:35 20 ...
# gzip compressed data, from Unix, last modified: Fri Aug 26 14:26:57 20 ...
# gzip compressed data, from Unix, last modified: Fri Aug 26 14:30:38 20 ...
# gzip compressed data, from Unix, last modified: Fri Aug 26 14:34:45 20 ...
# gzip compressed data, from Unix, last modified: Fri Aug 28 13:53:17 20 ...
# gzip compressed data, from Unix, last modified: Fri Aug 28 20:17:15 20 ...
# gzip compressed data, from Unix, last modified: Fri Dec  7 07:00:38 20 ...
# gzip compressed data, from Unix, last modified: Fri Dec 18 08:11:45 20 ...
# gzip compressed data, from Unix, last modified: Fri Dec 27 01:40:27 20 ...
# gzip compressed data, from Unix, last modified: Fri Jan  9 08:36:11 20 ...
# gzip compressed data, from Unix, last modified: Fri Jan 13 15:46:56 20 ...
# gzip compressed data, from Unix, last modified: Fri Jan 15 11:59:49 20 ...
# gzip compressed data, from Unix, last modified: Fri Jan 22 07:57:49 20 ...
# gzip compressed data, from Unix, last modified: Fri Jul 25 07:56:36 20 ...
# gzip compressed data, from Unix, last modified: Fri Jun 13 22:44:52 20 ...
# gzip compressed data, from Unix, last modified: Fri Mar  7 10:28:00 20 ...
# gzip compressed data, from Unix, last modified: Fri Mar 16 06:02:52 20 ...
# gzip compressed data, from Unix, last modified: Fri Mar 25 13:17:36 20 ...
# gzip compressed data, from Unix, last modified: Fri Mar 28 03:55:13 20 ...
# gzip compressed data, from Unix, last modified: Fri Mar 28 05:44:28 20 ...
# gzip compressed data, from Unix, last modified: Fri May  1 14:41:18 20 ...
# gzip compressed data, from Unix, last modified: Fri May 10 00:40:42 20 ...
# gzip compressed data, from Unix, last modified: Fri May 30 15:59:15 20 ...
# gzip compressed data, from Unix, last modified: Fri Nov  1 18:29:11 20 ...
# gzip compressed data, from Unix, last modified: Fri Nov  6 15:04:25 20 ...
# gzip compressed data, from Unix, last modified: Fri Nov 30 09:45:40 20 ...
# gzip compressed data, from Unix, last modified: Fri Sep 30 05:50:33 20 ...
# gzip compressed data, from Unix, last modified: Mon Apr 15 13:00:58 20 ...
# gzip compressed data, from Unix, last modified: Mon Apr 20 20:13:48 20 ...
# gzip compressed data, from Unix, last modified: Mon Aug  3 19:31:02 20 ...
# gzip compressed data, from Unix, last modified: Mon Aug 12 08:25:41 20 ...
# gzip compressed data, from Unix, last modified: Mon Aug 20 15:16:56 20 ...
# gzip compressed data, from Unix, last modified: Mon Aug 22 15:38:06 20 ...
# gzip compressed data, from Unix, last modified: Mon Dec 14 12:16:44 20 ...
# gzip compressed data, from Unix, last modified: Mon Dec 23 08:23:36 20 ...
# gzip compressed data, from Unix, last modified: Mon Feb  8 06:22:31 20 ...
# gzip compressed data, from Unix, last modified: Mon Feb 18 07:01:35 20 ...
# gzip compressed data, from Unix, last modified: Mon Feb 18 16:06:32 20 ...
# gzip compressed data, from Unix, last modified: Mon Feb 22 03:05:46 20 ...
# gzip compressed data, from Unix, last modified: Mon Jan 25 16:02:18 20 ...
# gzip compressed data, from Unix, last modified: Mon Jul  4 01:50:49 20 ...
# gzip compressed data, from Unix, last modified: Mon Jul  4 03:10:51 20 ...
# gzip compressed data, from Unix, last modified: Mon Jul 11 00:58:54 20 ...
# gzip compressed data, from Unix, last modified: Mon Jul 23 09:19:40 20 ...
# gzip compressed data, from Unix, last modified: Mon Jun  9 11:18:54 20 ...
# gzip compressed data, from Unix, last modified: Mon Jun 11 01:48:28 20 ...
# gzip compressed data, from Unix, last modified: Mon Mar  2 02:21:25 20 ...
# gzip compressed data, from Unix, last modified: Mon Mar  7 11:34:02 20 ...
# gzip compressed data, from Unix, last modified: Mon Mar 23 09:26:43 20 ...
# gzip compressed data, from Unix, last modified: Mon Mar 23 10:41:57 20 ...
# gzip compressed data, from Unix, last modified: Mon Mar 24 07:56:18 20 ...
# gzip compressed data, from Unix, last modified: Mon May  5 23:01:09 20 ...
# gzip compressed data, from Unix, last modified: Mon Nov  2 01:16:38 20 ...
# gzip compressed data, from Unix, last modified: Mon Oct  3 06:34:25 20 ...
# gzip compressed data, from Unix, last modified: Mon Oct  3 13:29:53 20 ...
# gzip compressed data, from Unix, last modified: Mon Oct  8 18:31:39 20 ...
# gzip compressed data, from Unix, last modified: Mon Oct 28 08:33:00 20 ...
# gzip compressed data, from Unix, last modified: Mon Sep 23 01:32:38 20 ...
# gzip compressed data, from Unix, last modified: Mon Sep 23 01:32:50 20 ...
# gzip compressed data, from Unix, last modified: Sat Apr 25 06:37:51 20 ...
# gzip compressed data, from Unix, last modified: Sat Aug 27 12:46:38 20 ...
# gzip compressed data, from Unix, last modified: Sat Aug 31 22:50:40 20 ...
# gzip compressed data, from Unix, last modified: Sat Dec  5 13:20:01 20 ...
# gzip compressed data, from Unix, last modified: Sat Dec 14 06:26:35 20 ...
# gzip compressed data, from Unix, last modified: Sat Dec 28 14:19:20 20 ...
# gzip compressed data, from Unix, last modified: Sat Feb 22 00:02:11 20 ...
# gzip compressed data, from Unix, last modified: Sat Jul 23 13:26:44 20 ...
# gzip compressed data, from Unix, last modified: Sat Jul 26 18:02:36 20 ...
# gzip compressed data, from Unix, last modified: Sat Jun 11 22:12:06 20 ...
# gzip compressed data, from Unix, last modified: Sat Mar  7 17:15:43 20 ...
# gzip compressed data, from Unix, last modified: Sat Mar 25 09:53:31 20 ...
# gzip compressed data, from Unix, last modified: Sat May  2 02:22:48 20 ...
# ...
# gzip compressed data, was "4050209-19.04.2016.tar", from FAT filesyste ...
# gzip compressed data, was "4343310-21.04.2016.tar", from FAT filesyste ...
# gzip compressed data, was "4550613-19.04.2016.tar", from FAT filesyste ...
# gzip compressed data, was "4HGm2b.tar", from Unix, last modified: Sun  ...
# gzip compressed data, was "5182208-19.04.2016.tar", from FAT filesyste ...
# gzip compressed data, was "5190102-20.04.2016.tar", from FAT filesyste ...
# gzip compressed data, was "5583402-19.04.2016.tar", from FAT filesyste ...
# gzip compressed data, was "6530711-20.04.2016.tar", from FAT filesyste ...
# gzip compressed data, was "70272851", last modified: Wed Sep  2 07:11: ...
# gzip compressed data, was "7781508-19.04.2016.tar", from FAT filesyste ...
# gzip compressed data, was "7970211-19.04.2016.tar", from FAT filesyste ...
# gzip compressed data, was "8262407-21.04.2016.tar", from FAT filesyste ...
# gzip compressed data, was "8364112-20.04.2016.tar", from FAT filesyste ...
# gzip compressed data, was "9374913-20.04.2016.tar", from FAT filesyste ...
# gzip compressed data, was "9463908-20.04.2016.tar", from FAT filesyste ...
# gzip compressed data, was "Alyundun", from Unix, last modified: Fri Ma ...
# gzip compressed data, was "Annual Conference Law of the Sea.exe", from ...
# gzip compressed data, was "BL-R16547805 & Packing List.exe", from FAT  ...
# gzip compressed data, was "BLME_PRXY-SUMMV_20160601_161852_MEAG201602_ ...
# gzip compressed data, was "BTD.exe?a=004", from Unix, last modified: M ...
# gzip compressed data, was "Bill of Laden.exe", from Unix, last modifie ...
# gzip compressed data, was "DOC#75498532015.exe", from FAT filesystem ( ...
# gzip compressed data, was "DOC#765342.exe", from FAT filesystem (MS-DO ...
# gzip compressed data, was "DOC#786409112015.exe", from FAT filesystem  ...
# gzip compressed data, was "DOC#79653412012015.exe", from FAT filesyste ...
# gzip compressed data, was "Diskpart.exe", from Unix, last modified: Th ...
# gzip compressed data, was "Exploit.HTML.Bagle.Gen-3-eml.html", from Un ...
# gzip compressed data, was "FD0-konboot-v1.1-2in1.img", from FAT filesy ...
# gzip compressed data, was "FSDPvE4yoaCvSPHkza.swf", last modified: Thu ...
# gzip compressed data, was "HTML.Phishing.Bank-23.html", from Unix, las ...
# gzip compressed data, was "HTML.Phishing.Bank-26.html", from Unix, las ...
# gzip compressed data, was "HTML.Phishing.Bank-54.html", from Unix, las ...
# gzip compressed data, was "HTTC4900.exe", from FAT filesystem (MS-DOS, ...
# gzip compressed data, was "INQUIRY. 02-2015-106_contract_120150EPS rev ...
# gzip compressed data, was "INVOICE89940-0AB9729F.exe", from FAT filesy ...
# gzip compressed data, was "Introductory Documentsyement.scr", from FAT ...
# gzip compressed data, was "Invoice.exe", from FAT filesystem (MS-DOS,  ...
# gzip compressed data, was "Invoice_TSINV43002_from_tip_top_delivery.rt ...
# gzip compressed data, was "Israel's Ambassador to the United States.ex ...
# gzip compressed data, was "LIST.exe", from FAT filesystem (MS-DOS, OS/ ...
# gzip compressed data, was "MSF_Meterpreter_Direct.pcap", from Unix, la ...
# gzip compressed data, was "MalOffice.docm", from Unix, last modified:  ...
# gzip compressed data, was "Marchiti_output3EC9950.exe", from FAT files ...
# gzip compressed data, was "Marchiti_outputEABD88F.exe", from FAT files ...
# gzip compressed data, was "Modified mtcn slip.jar", from Unix, last mo ...
# gzip compressed data, was "Moneygram Slip.jar", from Unix, last modifi ...
# gzip compressed data, was "NEW-ORDER#0297.exe", from FAT filesystem (M ...
# gzip compressed data, was "New Order.exe", from FAT filesystem (MS-DOS ...
# gzip compressed data, was "New Order.scr", from FAT filesystem (MS-DOS ...
# gzip compressed data, was "New QP #150351_Docx.scr", from FAT filesyst ...
# gzip compressed data, was "NewList QP #1503511_Docx.scr", from FAT fil ...
# gzip compressed data, was "New_Order.scr", from FAT filesystem (MS-DOS ...
# gzip compressed data, was "ORDER LIST.exe", from FAT filesystem (MS-DO ...
# gzip compressed data, was "Order List.exe", from FAT filesystem (MS-DO ...
# gzip compressed data, was "Order Sample.exe", from FAT filesystem (MS- ...
# gzip compressed data, was "Order Sheet.exe", from FAT filesystem (MS-D ...
# gzip compressed data, was "Order inquiry.exe", from FAT filesystem (MS ...
# gzip compressed data, was "Order.exe", from FAT filesystem (MS-DOS, OS ...
# gzip compressed data, was "Order.scr", from FAT filesystem (MS-DOS, OS ...
# gzip compressed data, was "P.I#9898000_html.exe", from FAT filesystem  ...
# gzip compressed data, was "PACKINGLIST.pdf.exe", from FAT filesystem ( ...
# gzip compressed data, was "PLCmd", from Unix, last modified: Mon Mar 2 ...
# gzip compressed data, was "PO#201510-000177.exe", from FAT filesystem  ...
# gzip compressed data, was "PO.exe", from FAT filesystem (MS-DOS, OS/2, ...
# gzip compressed data, was "PO0000052E4110.com", from FAT filesystem (M ...
# gzip compressed data, was "PO894947FAC300.exe", from FAT filesystem (M ...
# gzip compressed data, was "PO_002910.exe", from FAT filesystem (MS-DOS ...
# gzip compressed data, was "PURCHASE-ORDER9050955FEB9F.com", from FAT f ...
# gzip compressed data, was "PURCHASING ORDER.exe", from FAT filesystem  ...
# gzip compressed data, was "Passport id.jar", from Unix, last modified: ...
# gzip compressed data, was "PrismLink", from Unix, last modified: Sun M ...
# gzip compressed data, was "Product Details.exe", from FAT filesystem ( ...
# gzip compressed data, was "Purchase Order.exe", from FAT filesystem (M ...
# gzip compressed data, was "Quotation.exe", from FAT filesystem (MS-DOS ...
# gzip compressed data, was "REQUEST ORDER (2).exe", from Unix, last mod ...
# gzip compressed data, was "REVISED PO 233407.exe", from FAT filesystem ...
# gzip compressed data, was "RXt24b.tar", from Unix, last modified: Fri  ...
# gzip compressed data, was "Request-for-Interview.exe", from Unix, last ...
# gzip compressed data, was "SWI-034043-3454954954954945-320439939320433 ...
# gzip compressed data, was "Sample(3D)_Docx.scr", from FAT filesystem ( ...
# gzip compressed data, was "Sample(3D)_XLS.scr", from FAT filesystem (M ...
# gzip compressed data, was "Sample-09210.exe", from FAT filesystem (MS- ...
# gzip compressed data, was "Sample.exe", from FAT filesystem (MS-DOS, O ...
# gzip compressed data, was "Samples.exe", from FAT filesystem (MS-DOS,  ...
# gzip compressed data, was "Scan.exe", from FAT filesystem (MS-DOS, OS/ ...
# gzip compressed data, was "Scan.txt", from FAT filesystem (MS-DOS, OS/ ...
# gzip compressed data, was "Scan0048.exe", from FAT filesystem (MS-DOS, ...
# gzip compressed data, was "Scan10001.exe", from FAT filesystem (MS-DOS ...
# gzip compressed data, was "Scan100011.exe", from FAT filesystem (MS-DO ...
# gzip compressed data, was "Scan_00000001.exe", from FAT filesystem (MS ...
# gzip compressed data, was "SplunkforDNS.tar", last modified: Sun Mar   ...
# gzip compressed data, was "Swift1001.exe", from FAT filesystem (MS-DOS ...
# gzip compressed data, was "Swiftcopy9650000USD.exe", from Unix, last m ...
# gzip compressed data, was "T672977543CTGS.com", from FAT filesystem (M ...
# gzip compressed data, was "TL# 6784_4726.exe", from FAT filesystem (MS ...
# gzip compressed data, was "TNT.exe", from FAT filesystem (MS-DOS, OS/2 ...
# gzip compressed data, was "TNT.txt", from FAT filesystem (MS-DOS, OS/2 ...
# gzip compressed data, was "TWTTQBQL26789045-TOWER-MATERIALSX.exe", fro ...
# gzip compressed data, was "The Cheque To Our Accounts Department.exe", ...
# gzip compressed data, was "Total Order.exe", from FAT filesystem (MS-D ...
# gzip compressed data, was "Transfer Copy.exe", from Unix, last modifie ...
# gzip compressed data, was "Transfer_details.scr", from FAT filesystem  ...
# gzip compressed data, was "VA0008461446438264.js", from FAT filesystem ...
# gzip compressed data, was "VA021326611085966.js", from FAT filesystem  ...
# gzip compressed data, was "VA0214215904665507.js", from FAT filesystem ...
# gzip compressed data, was "VA0301995820111484.js", from FAT filesystem ...
# gzip compressed data, was "VA0402583781417904.js", from FAT filesystem ...
# gzip compressed data, was "VA0610999942830893.js", from FAT filesystem ...
# gzip compressed data, was "VA1002937102192238.js", from FAT filesystem ...
# gzip compressed data, was "VA120923350689869.js", from FAT filesystem  ...
# gzip compressed data, was "VA1309210830441148.js", from FAT filesystem ...
# gzip compressed data, was "VA1409902019907132.js", from FAT filesystem ...
# gzip compressed data, was "VA1509472182598544.js", from FAT filesystem ...
# gzip compressed data, was "VA15139933269984.js", from FAT filesystem ( ...
# gzip compressed data, was "VA1610799653705798.js", from FAT filesystem ...
# gzip compressed data, was "VA1612155449834856.js", from FAT filesystem ...
# gzip compressed data, was "VA170555514888248.js", from FAT filesystem  ...
# gzip compressed data, was "VA1709534040586239.js", from FAT filesystem ...
# gzip compressed data, was "VA1803335177450831.js", from FAT filesystem ...
# gzip compressed data, was "VA1806818166962237.js", from FAT filesystem ...
# gzip compressed data, was "VA2003392515879107.js", from FAT filesystem ...
# gzip compressed data, was "VA2014488700255230.js", from FAT filesystem ...
# gzip compressed data, was "VA210454659895828.js", from FAT filesystem  ...
# gzip compressed data, was "VA2203390664757303.js", from FAT filesystem ...
# gzip compressed data, was "VA2309436678279496.js", from FAT filesystem ...
# gzip compressed data, was "VA240519074616474.js", from FAT filesystem  ...
# gzip compressed data, was "VA2706631393322298.js", from FAT filesystem ...
# gzip compressed data, was "VA290529256183653.js", from FAT filesystem  ...
# gzip compressed data, was "VA3113461526797880.js", from FAT filesystem ...
# gzip compressed data, was "VA3204611917814445.js", from FAT filesystem ...
# gzip compressed data, was "VA3303634859974173.js", from FAT filesystem ...
# gzip compressed data, was "VA3405130438521772.js", from FAT filesystem ...
# gzip compressed data, was "VA3706145862249163.js", from FAT filesystem ...
# gzip compressed data, was "VA3811591034420754.js", from FAT filesystem ...
# gzip compressed data, was "VA3909631255955111.js", from FAT filesystem ...
# gzip compressed data, was "VA4103639815871286.js", from FAT filesystem ...
# gzip compressed data, was "VA4104339625132113.js", from FAT filesystem ...
# gzip compressed data, was "VA4108596725979993.js", from FAT filesystem ...
# gzip compressed data, was "VA4312655668465322.js", from FAT filesystem ...
# gzip compressed data, was "VA4703174352191121.js", from FAT filesystem ...
# gzip compressed data, was "VA4711802963200086.js", from FAT filesystem ...
# gzip compressed data, was "VSS Power Engineering Services Company.exe" ...
# gzip compressed data, was "X292_HVIPC560F15.NA04.LOD", from Unix, last ...
# gzip compressed data, was "YacDl6_2015.1.19_1.exe", from Unix, last mo ...
# gzip compressed data, was "______ _____ ___ ______ _______ ___ ____ __ ...
# gzip compressed data, was "aahpxwkhqp", from Unix, last modified: Fri  ...
# gzip compressed data, was "amazoncard.exe", from FAT filesystem (MS-DO ...
# gzip compressed data, was "autorule.tar", from Unix, last modified: Su ...
# gzip compressed data, was "backup.tar.C28853", from Unix, last modifie ...
# gzip compressed data, was "bdins.js", from Unix, last modified: Mon Ju ...
# gzip compressed data, was "ccleaners.vbs_virus", from Unix, last modif ...
# gzip compressed data, was "cloner.dsk", from Unix, last modified: Sat  ...
# gzip compressed data, was "copypdf PONO78905432189E6FCF3F.scr", from F ...
# gzip compressed data, was "dist/carbon-0.9.10.tar", last modified: Thu ...
# gzip compressed data, was "dist/dpkt-1.8.tar", last modified: Wed May  ...
# gzip compressed data, was "dist/mastiff-0.6.0.tar", last modified: Thu ...
# gzip compressed data, was "dist/pefile-1.2.10-139.tar", last modified: ...
# gzip compressed data, was "dist/pycrypto-2.6.1.tar", last modified: Mo ...
# gzip compressed data, was "dist/volatility-2.3.1.tar", last modified:  ...
# gzip compressed data, was "dmesg.0", from Unix, last modified: Sat Jul ...
# gzip compressed data, was "dumb", from Unix, last modified: Mon Mar  3 ...
# gzip compressed data, was "flash.swf", from Unix, last modified: Wed J ...
# gzip compressed data, was "flood.tar", from Unix, last modified: Tue O ...
# gzip compressed data, was "id.html", from Unix, last modified: Sat May ...
# gzip compressed data, was "igb-5.0.5.tar", from Unix, last modified: M ...
# gzip compressed data, was "install_flashplayer.exe", from FAT filesyst ...
# gzip compressed data, was "invoice & packing list.exe", from FAT files ...
# gzip compressed data, was "kill.tar", from Unix, last modified: Thu Fe ...
# gzip compressed data, was "macle.bin", from Unix, last modified: Wed J ...
# gzip compressed data, was "main.ps", from Unix, last modified: Mon Jul ...
# gzip compressed data, was "material list.exe", from FAT filesystem (MS ...
# gzip compressed data, was "moatad.js", from Unix, last modified: Fri J ...
# gzip compressed data, was "mokvvkvktp", from Unix, last modified: Fri  ...
# gzip compressed data, was "mspre.dll", from FAT filesystem (MS-DOS, OS ...
# gzip compressed data, was "num3_flash", from Unix, last modified: Mon  ...
# gzip compressed data, was "ofiller_v2.4.tar", from Unix, last modified ...
# gzip compressed data, was "passport photo.jar", from Unix, last modifi ...
# gzip compressed data, was "payment.scr", from FAT filesystem (MS-DOS,  ...
# gzip compressed data, was "paymentcopy.exe", from FAT filesystem (MS-D ...
# gzip compressed data, was "pdfcrack-0.14.tar", from Unix, last modifie ...
# gzip compressed data, was "php_malware.7z.xz", from FAT filesystem (MS ...
# gzip compressed data, was "pizz.tar", from FAT filesystem (MS-DOS, OS/ ...
# gzip compressed data, was "po#4219.exe", from FAT filesystem (MS-DOS,  ...
# gzip compressed data, was "proforma ##9889800.exe", from FAT filesyste ...
# gzip compressed data, was "proformainvoice0011739.exe", from FAT files ...
# gzip compressed data, was "pxfwk.min.js", from Unix, last modified: Th ...
# gzip compressed data, was "q8bot", from Unix, last modified: Tue Dec   ...
# gzip compressed data, was "receipt_20160125.doc", from Unix, last modi ...
# gzip compressed data, was "reply to client comment on lcm ga.pdf", fro ...
# gzip compressed data, was "reply to client comment on n system descrip ...
# gzip compressed data, was "retroarch-0.9.9.tar", from Unix, last modif ...
# gzip compressed data, was "sample.exe", from FAT filesystem (MS-DOS, O ...
# gzip compressed data, was "scan.js", from FAT filesystem (MS-DOS, OS/2 ...
# gzip compressed data, was "scan22062015.scr", from FAT filesystem (MS- ...
# gzip compressed data, was "seed.tar", from Unix, last modified: Sun Fe ...
# gzip compressed data, was "seed.tar", from Unix, last modified: Wed Ma ...
# gzip compressed data, was "sentinel.js", from Unix, last modified: Thu ...
# gzip compressed data, was "soru", from Unix, last modified: Sun May 15 ...
# gzip compressed data, was "south.exe", from FAT filesystem (MS-DOS, OS ...
# gzip compressed data, was "talpa-binpack-ubuntu_3.2.0-41-generic-66ubu ...
# gzip compressed data, was "teli.tar", from FAT filesystem (MS-DOS, OS/ ...
# gzip compressed data, was "temp-1473996358.959516", last modified: Thu ...
# gzip compressed data, was "the.burning.zone.s01e011.read.nfo.french.pd ...
# gzip compressed data, was "towsfnjufdbu.exe", from Unix, last modified ...
# gzip compressed data, was "transaction slip_jpg.jar", from Unix, last  ...
# gzip compressed data, was "udp.tar", from FAT filesystem (MS-DOS, OS/2 ...
# gzip compressed data, was "update.exe", last modified: Fri Aug  7 07:2 ...
# gzip compressed data, was "wallet4ae23ceea-062b-4609-8232-496b85fc5177 ...
# gzip compressed data, was "win32process.pyd", from FAT filesystem (MS- ...
# gzip compressed data, was "winnt.exe", from Unix, last modified: Tue D ...
# gzip compressed data, was "wz_tooltip.min.js", from Unix, last modifie ...
# gzip compressed data, was "xudpss", from Unix, last modified: Mon Dec  ...
# lzip compressed data, version: 1
# tar archive
# xar archive - version 1

# %% [markdown]
# ## Documents

# %%
doc_keywords = ['pdf', 'microsoft ', 'composite document file', 'fdf document', 'opendocument']
doc_crit = headers.file_type.map(mapKeywords(doc_keywords))
doc_types = sorted(headers.file_type[~exec_crit & ~text_crit & ~media_crit & ~arch_crit & doc_crit].unique())
print('Total unique document types: {}\n'.format(len(doc_types)))
for t in doc_types:
    print(t)
# Out:
# Total unique document types: 58
#
# Composite Document File V2 Document, Big Endian, Os 0, Version: 0.0
# Composite Document File V2 Document, Big Endian, Os 65535, Version: 25 ...
# Composite Document File V2 Document, Little Endian, Os 0, Version: 3.1 ...
# Composite Document File V2 Document, Little Endian, Os 0, Version: 3.9 ...
# Composite Document File V2 Document, Little Endian, Os: MacOS, Version ...
# Composite Document File V2 Document, Little Endian, Os: Windows, Versi ...
# Composite Document File V2 Document, No summary info
# Composite Document File V2 Document, corrupt: Can't expand summary_inf ...
# Composite Document File V2 Document, corrupt: Can't read SAT
# Composite Document File V2 Document, corrupt: Can't read SSAT
# Composite Document File V2 Document, corrupt: Can't read directory
# Composite Document File V2 Document, corrupt: Cannot read short stream
# Composite Document File V2 Document, corrupt: Cannot read summary info
# FDF document, version 1.2
# Microsoft ASF
# Microsoft Access Database
# Microsoft DirectDraw Surface (DDS), 1024 x 512, DXT1
# Microsoft DirectDraw Surface (DDS), 128 x 128,
# Microsoft Document Imaging Format
# Microsoft Excel 2007+
# Microsoft ICM Color Profile
# Microsoft OOXML
# Microsoft Office Document
# Microsoft Office Document Microsoft Word Document
# Microsoft Outlook email folder (>=2003)
# Microsoft PowerPoint 2007+
# Microsoft Windows Autorun file.
# Microsoft Word 2007+
# Microsoft a.out
# Mozilla XUL fastload dataMicrosoft Word 2007+
# OpenDocument Presentation
# OpenDocument Spreadsheet
# OpenDocument Template
# PDF document, version .
# PDF document, version 0.1
# PDF document, version 0.9
# PDF document, version 1.0
# PDF document, version 1.1
# PDF document, version 1.2
# PDF document, version 1.3
# PDF document, version 1.4
# PDF document, version 1.5
# PDF document, version 1.6
# PDF document, version 1.7
# PDF document, version 1.8
# PDF document, version 1.\015
# PDF document, version L.
# PDF document, version Y..
# PDF document, version \001.
# PDF document, version \007.3
# PDF document, version a.a
# PDF documentdata, version 1.4
# x86 boot sector, Microsoft Windows XP MBR, Serial 0x421ed97c; partitio ...
# x86 boot sector, Microsoft Windows XP MBR, Serial 0x61fb004e; partitio ...
# x86 boot sector, Microsoft Windows XP MBR, Serial 0xb3e6aeb2; partitio ...
# x86 boot sector, Microsoft Windows XP MBR, Serial 0xc878ef17; partitio ...
# x86 boot sector, Microsoft Windows XP MBR, Serial 0xdb7f7745; partitio ...
# x86 boot sector, Microsoft Windows XP mbr; partition 1: ID=0x1, active ...

# %% [markdown]
# ## Remaining types

# %%
# Used to tune the previous sections for missing types
other_types = sorted(headers.file_type[~exec_crit & ~text_crit & ~media_crit & ~arch_crit & ~doc_crit].unique())
print('Total unique remaining types: {}\n'.format(len(other_types)))
for t in other_types:
    print(t)
# Out:
# Total unique remaining types: 448
#
# # ISO 9660 CD-ROM filesystem data '20130508_0737'
# # ISO 9660 CD-ROM filesystem data '20130508_0750'
# # ISO 9660 CD-ROM filesystem data '20150723_1825'
# # ISO 9660 CD-ROM filesystem data '20151026_1649'
# # ISO 9660 CD-ROM filesystem data 'CDROM'
# # ISO 9660 CD-ROM filesystem data 'DBAN' (bootable)
# # ISO 9660 CD-ROM filesystem data 'DISC'
# # ISO 9660 CD-ROM filesystem data 'Dropbox Installer'
# # ISO 9660 CD-ROM filesystem data 'HACKVENT_2015'
# # ISO 9660 CD-ROM filesystem data 'Installer'
# # ISO 9660 CD-ROM filesystem data 'J_CENA_X64FREV_EN-US_DV5' (bootable ...
# # ISO 9660 CD-ROM filesystem data 'KMSPico 10.1.9'
# # ISO 9660 CD-ROM filesystem data 'KMSPico 10.2.1'
# # ISO 9660 CD-ROM filesystem data 'MT410' (bootable)
# # ISO 9660 CD-ROM filesystem data 'NEW'
# # ISO 9660 CD-ROM filesystem data 'NEW' (bootable)
# # ISO 9660 CD-ROM filesystem data 'Samples'
# # ISO 9660 CD-ROM filesystem data 'Windows Loader 2.6'
# # ISO 9660 CD-ROM filesystem data 'chntpw 140201' (bootable)
# # ISO 9660 CD-ROM filesystem data (bootable)
# (Corel/WP)
# , MZ for MS-DOS
# , code offset 0x3c+2, OEM-ID "RajuRam ", sectors/cluster 32, FAT  1, M ...
# , code offset 0x58+2, OEM-ID "MSDOS5.0", sectors/cluster 8, Media desc ...
# 5View capture file
# 8086 relocatable (Microsoft)
# @CTV
# AIX core file fulldump 32-bit 64-bit
# AIX core file fulldump 32-bit 64-bit, \264\024
# AIX core file fulldump 32-bit, \267\377\230\377\260\377\310\377\215\37 ...
# AIX core file fulldump 32-bit, \374\377\377\375\377\377\377\376\377\01 ...
# AIX core file fulldump 32-bit, \377\377 64-bit
# AIX core file fulldump 32-bit, \377\377\377\377\377\377\377\377\377\37 ...
# AMUSIC Adlib Tracker
# Adaptive Multi-Rate Codec (GSM telephony)
# Adobe InDesign Document
# Amiga Workbench icon, vers. 20696
# Apple Desktop Services Store
# Apple Driver Map, blocksize 512, blockcount 52418, devtype 0, devid 0, ...
# Apple binary property list
# AppleDouble encoded Macintosh file
# AppleSingle encoded Macintosh file
# Applesoft BASIC program data, first line number 16
# Atari 68xxx CPX file (version 002e)
# Atari 68xxx CPX file (version 3030)
# AutoDesk AutoCAD R2000
# BIOS (ia32) ROM Ext. (85*512)
# BitTorrent file
# Clarion Developer (v2 and above) data file, encrypted, memo file exist ...
# ColorSync ICC Profile
# Compiled PSI (v2) data (t$\364]+\311f\271\201\267\272\342\017|\2151U\0 ...
# DBase 3 data file
# DBase 3 data file (1 records)
# DBase 3 data file (1600 records)
# DBase 3 data file (1969578383 records)
# DBase 3 data file (4300 records)
# DBase 3 data file (5036 records)
# DBase 3 data file (888 records)
# DBase 3 data file with memo(s) (1955288661 records)
# DBase 3 data file with memo(s) (614690274 records)
# DBase 3 index file
# DICOM medical imaging data
# DOS EPS Binary File Postscript starts at byte 32 length 2410318 TIFF s ...
# DOS EPS Binary File Postscript starts at byte 32 length 827325 TIFF st ...
# DOS floppy 1440k, x86 hard disk boot sector
# DWG AutoDesk AutoCAD 2004/2005/2006
# DWG AutoDesk AutoCAD 2007/2008/2009
# DWG AutoDesk AutoCAD 2010/2011
# Dalvik dex file (optimized for host) version 036
# Dalvik dex file version 035
# Debian binary package (format 2.0)
# DjVu multiple page document
# Dyalog APL
# Dyalog APL transfer
# Dyalog APL version 0 .0
# Dyalog APL version 190 .111
# Dyalog APL version 22 .167
# Dyalog APL version 3 .0
# Dyalog APL version 9 .18
# Dyalog APL version 95 .133
# EPUB document
# EPUB ebook data
# Emacs v18 byte-compiled Lisp data
# Embedded OpenType (EOT)
# Encore not stripped -
# FORTRAN program,
# Fasttracker II module sound data Title: "ElasticDreams       \032DigiB ...
# Fasttracker II module sound data Title: "super mario brothers\032FastT ...
# FoxBase MDX, creation-date 108-10-16, update-date 108-10-16, 4/48 tags ...
# FoxBase+/dBase III DBF, 2 records * 117, update-date 116-6-27, at offs ...
# GCC precompiled header (version 014) for C
# GLS_BINARY_LSB_FIRST
# GLS_BINARY_MSB_FIRST
# GNU message catalog (little endian), revision 0, 1784 messages
# GPG key public ring
# GPG symmetrically encrypted data (CAST5 cipher)
# GStreamer binary registry, version 1.0.0
# Gameboy ROM: "PM_CRYSTAL", [ROM+MBC3+TIMER+RAM+BATT], ROM: 16Mbit, RAM ...
# HP PCL printer data
# Hangul (Korean) Word Processor File 3.0
# Hitachi SH big-endian COFF object, not stripped
# Hitachi SH big-endian COFF object, stripped
# IDA (Interactive Disassembler) database
# IFF data, Z-machine or Glulx saved game file (Quetzal)
# ISO Media
# ISO Media, Apple QuickTime movie
# ISO Media, JPEG 2000
# Infocom game data (Z-machine 1, Release 43523 / Serial 3=\003r~Q)
# InstallShield CAB
# Intel serial flash for PCH ROM
# Internet Explorer cache file version Ver 5.2
# JPEG 2000 Part 1 (JP2)
# Java Jar file data (zip)
# Java serialization data, version 5
# Kompas drawing 12.0 SP1
# Linux rev 1.0 ext4 filesystem data, UUID=ce28a582-486d-41b1-8c66-1690e ...
# Lotus 1-2-3
# Lotus WordPro
# Lua bytecode, version 5.1
# MDMP crash report data
# MIPSEB Ucode
# MMDF mailbox
# MS Outlook Express DBX file, message database
# MS Windows 3.x help file
# MS Windows 64bit crash dump, 4992030524978970960 pages
# MS Windows HtmlHelp Data
# MS Windows Vista Event Log, 98 chunks (no. 97 in use), next record no. ...
# MS Windows registry file, NT/2000 or above
# MS Windows shortcut
# MS Windows shortcut, Has Description string, Has Working directory, Ic ...
# MS Windows shortcut, Item id list present, Has Description string, Has ...
# MS Windows shortcut, Item id list present, Has Description string, cti ...
# MS Windows shortcut, Item id list present, Has Relative path, Has Work ...
# MS Windows shortcut, Item id list present, Has Relative path, Has comm ...
# MS Windows shortcut, Item id list present, Has Relative path, Icon, ct ...
# MS Windows shortcut, Item id list present, Has Working directory, Has  ...
# MS Windows shortcut, Item id list present, Has command line arguments, ...
# MS Windows shortcut, Item id list present, Points to a file or directo ...
# MS Windows shortcut, Item id list present, ctime=Mon Jan  1 08:52:58 1 ...
# MS Windows shortcut, Item id list present, ctime=Thu Nov  5 04:59:07 2 ...
# MS Windows shortcut, Points to a file or directory, Has Working direct ...
# MSVC .res
# MSVC program database ver \002
# MSVC program database ver \004
# MSVC program database ver \004  \001   \313\001  \274\007      \304\00 ...
# MacBinary III data with surprising version number
# Macintosh HFS Extended version 4 data last mounted by: '10.0', created ...
# Macromedia Flash data, version 10
# Macromedia Flash data, version 11
# Macromedia Flash data, version 12
# Macromedia Flash data, version 13
# Macromedia Flash data, version 14
# Macromedia Flash data, version 15
# Macromedia Flash data, version 17
# Macromedia Flash data, version 18
# Macromedia Flash data, version 19
# Macromedia Flash data, version 20
# Macromedia Flash data, version 22
# Macromedia Flash data, version 23
# Macromedia Flash data, version 248
# Macromedia Flash data, version 25
# Macromedia Flash data, version 26
# Macromedia Flash data, version 27
# Macromedia Flash data, version 28
# Macromedia Flash data, version 32
# Macromedia Flash data, version 4
# Macromedia Flash data, version 5
# Macromedia Flash data, version 6
# Macromedia Flash data, version 7
# Macromedia Flash data, version 8
# Macromedia Flash data, version 9
# Macromedia Flash data, version 96
# Maple help database
# Matroska data
# Minix filesystem, V2 (big endian), 0 zones
# Minix filesystem, V2, 0 zones
# Minix filesystem, V2, 30 char names (big endian), 12387 zones
# Minix filesystem, V2, 30 char names (big endian), 27809 zones
# Minix filesystem, V2, 30 char names (big endian), 65338 zones
# Minix filesystem, V2, 30 char names (big endian), 8267 zones
# Minix filesystem, V2, 30 char names, 0 zones
# Minix filesystem, V2, 30 char names, 49388 zones
# Minix filesystem, V2, 30 char names, 5376 zones
# Minix filesystem, V3, 22381 zones
# Minix filesystem, V3, 2410 zones
# Mobipocket E-book "Beneath_the_Surface__Killer_Wha"
# Mobipocket E-book "Cauldron_of_Ghosts"
# Mobipocket E-book "Immortals_of-Amish_Tripathi"
# MySQL MyISAM index file Version 1
# NetXRay capture file - version 001.100 (Ethernet)
# None ...
# Ogg data
# OpenOffice.org 1.x Writer document
# OpenSSH RSA public key
# OpenType font data
# PDP-11 UNIX/RT ldp
# PDP-11 kernel overlay
# PE Unknown PE signature (Unknown subsystem Intel 80386, for MS Windows
# PE Unknown PE signature 0x0 (GUI) Intel 80386 Mono/.Net assembly, for  ...
# PE Unknown PE signature 0x0 (GUI) Intel 80386, for MS Windows
# PE Unknown PE signature 0x0 (Unknown subsystem 0x0) Intel 80386, for M ...
# PE Unknown PE signature 0x2 (GUI) Intel 80386, for MS Windows
# PE Unknown PE signature 0x50b (GUI) Intel 80386, for MS Windows, UPX c ...
# PE Unknown PE signature 0x726c (GUI) Intel 80386, for MS Windows
# PE Unknown PE signature 0x818e (Unknown subsystem 0x0) Intel 80386, fo ...
# PE Unknown PE signature 0x910b (Unknown subsystem 0x9002) Intel 80386, ...
# PEM certificate
# PEM certificate request
# PFM data - N\334
# PFM data - VH
# PFM data - W\214
# PFM data - v\030
# PGP key public ring
# PGP key security ring
# PGP message
# PGP public key block
# PGP signature
# PHP WSDL cache, version 0x0e, created Sat Feb 21 01:45:30 2015, uri: " ...
# PHP script Zend Optimizer data
# PPD file, version "4.3"
# PPD file, version "4.3"\015
# Palm OS dynamic library data "<html>"
# PlaySID v2.2+ (AMIGA) sidtune w/ header v2, single song, default song: ...
# RIFF (big-endian) data
# RIFF (little-endian) data
# RPM v3.0 bin i386/x86_64
# RealMedia file
# SPEC
# SQLite 3.x database
# SQLite 3.x database, user version 1
# SQLite 3.x database, user version 26
# SQLite 3.x database, user version 28
# SQLite 3.x database, user version 34
# SQLite 3.x database, user version 4
# SQLite 3.x database, user version 7
# SYMMETRY i386 .o not stripped version 272733045
# SYSLINUX loader (version 4.03)
# SYSLINUX loader (version 4.05)
# Sendmail frozen configuration
# Sendmail frozen configuration  - version
# Sendmail frozen configuration  - version &
# Sendmail frozen configuration  - version &#35441;&#12395;&#12394;&#123 ...
# Sendmail frozen configuration  - version &H03&H00&H00&H00&H04&H00&H00& ...
# Sendmail frozen configuration  - version <meta http-equiv="refresh" co ...
# Sendmail frozen configuration  - version K\027\205i\177"(\217!\262\373 ...
# Sendmail frozen configuration  - version \002\013#2\275BXs\206Ch\372\2 ...
# Sendmail frozen configuration  - version \003\177\201\254\326-\254\357 ...
# Sendmail frozen configuration  - version \022J\300Kz\374\356 ~\362\215 ...
# Sendmail frozen configuration  - version \035\220\222\225\232\236z\234 ...
# Sendmail frozen configuration  - version \202\376\006\262\003\343fF\01 ...
# Sendmail frozen configuration  - version \2134aDcwX90ijo3qcxkeDKyqYrW6 ...
# Sendmail frozen configuration  - version \240\3202\234W\027\241MP:ek\3 ...
# Sendmail frozen configuration  - version \323enbkenb+enbkenbkenbkenbke ...
# Sendmail frozen configuration  - version \323kkkkkkk+kkkkkkkkkkkkkkkkk ...
# Sendmail frozen configuration  - version \344\346\377\212\272\316DUP\2 ...
# Sendmail frozen configuration  - version a http-equiv="refresh" conten ...
# Sendmail frozen configuration  - version b^\324n\273\021c\032:C\344K\0 ...
# Sendmail frozen configuration  - version eta http-equiv="refresh" cont ...
# Sendmail frozen configuration  - version jjj,\213jjjjjjjjjjjjjjjjjjjjj ...
# Sendmail frozen configuration  - version u=\336T\302\364\252WK\262\374 ...
# Sendmail frozen configuration  - version {L\241\030|L?\030}L.5yL\373^\ ...
# Sniffer capture file - version 1.16 (Ethernet)
# Sony Wave64 RIFF data
# Spectrum .TAP data "0712light_" - BASIC program
# Spectrum .TAP data "\024         " - number array
# Standard MIDI data (format 1) using 11 tracks at 1/384
# Standard MIDI data (format 1) using 14 tracks at 1/1024
# Standard MIDI data (format 1) using 15 tracks at 1/480
# Standard MIDI data (format 1) using 17 tracks at 1/120
# Standard MIDI data (format 1) using 3 tracks at 1/384
# Standard MIDI data (format 1) using 4 tracks at 1/96
# Standard MIDI data (format 1) using 5 tracks at 1/1024
# Standard MIDI data (format 1) using 5 tracks at 1/120
# Standard MIDI data (format 1) using 6 tracks at 1/1024
# Standard MIDI data (format 1) using 6 tracks at 1/240
# Standard MIDI data (format 1) using 6 tracks at 1/480
# Standard MIDI data (format 1) using 9 tracks at 1/384
# Symbian installation file (Symbian OS 9.x)
# SysEx File -
# SysEx File - IDP
# SysEx File - Kurzweil/Future Retro, Channel 61
# SysEx File - Sony
# TeX font metric data (\271)
# Tower32/600/400 68020 object - version 18224
# Tower32/800 68010 not stripped
# Transport Neutral Encapsulation Format
# TrueType font collection data, 2.0, 4 fonts
# TrueType font data
# Unknown PE signature 0xb8 (GUI) Intel 80386, for MS Windows
# Unreal Engine Package, version: 610, names: 5, imports: 27904, exports ...
# VMware nvram
# Vim swap file, version 7.3
# Vim swap file, version 7.4
# Warcraft III map file
# Web Open Font Format, flavor 1330926671, length 25424, version 1.0
# Web Open Font Format, flavor 1330926671, length 28220, version 0.0
# Web Open Font Format, flavor 65536, length 100640, version 7.504
# Web Open Font Format, flavor 65536, length 13988, version 0.0
# Web Open Font Format, flavor 65536, length 14360, version 0.0
# Web Open Font Format, flavor 65536, length 18924, version 0.0
# Web Open Font Format, flavor 65536, length 19460, version 1.1
# Web Open Font Format, flavor 65536, length 20248, version 1.1
# Web Open Font Format, flavor 65536, length 21292, version 1.1
# Web Open Font Format, flavor 65536, length 21316, version 1.0
# Web Open Font Format, flavor 65536, length 21956, version 1.1
# Web Open Font Format, flavor 65536, length 22748, version 1.1
# Web Open Font Format, flavor 65536, length 22852, version 1.0
# Web Open Font Format, flavor 65536, length 22908, version 1.0
# Web Open Font Format, flavor 65536, length 24864, version 1.1
# Web Open Font Format, flavor 65536, length 27448, version 1.0
# Web Open Font Format, flavor 65536, length 27504, version 1.0
# Web Open Font Format, flavor 65536, length 28312, version 1.0
# Web Open Font Format, flavor 65536, length 28896, version 0.0
# Web Open Font Format, flavor 65536, length 31916, version 0.0
# Web Open Font Format, flavor 65536, length 35700, version 1.1
# Web Open Font Format, flavor 65536, length 36320, version 1.1
# Web Open Font Format, flavor 65536, length 45712, version 7.504
# Web Open Font Format, flavor 65536, length 50472, version 1.1
# Web Open Font Format, flavor 65536, length 54720, version 7.504
# Web Open Font Format, flavor 65536, length 65452, version 1.0
# Web Open Font Format, flavor 65536, length 6856, version 1.0
# Web Open Font Format, flavor 65536, length 71508, version 1.0
# Web Open Font Format, flavor 65536, length 82560, version 1.1
# WebM
# Winamp plug in
# Windows Program Information File for .\PKLOGS~1.EXE, directory=.\, Tru ...
# Windows Program Information File for C:\DOCUME~1\payroll\MYDOCU~1\DOWN ...
# Windows Program Information File for C:\PROGRA~1\CHODE\HIDE.BAT
# Windows Program Information File for G:\APPL\EST\EST.EXE, directory=G: ...
# Windows Program Information File for H:\OLD_HO~1\EMLYN\ABSORBER.EXE, d ...
# Windows Program Information File for \\BPL\SYS\PUBLIC\SETPASS.EXE, dir ...
# Windows Program Information File for _DEFAULT.BAT, Windows NT-style
# Windows Recycle Bin INFO2 file (Win2k - WinXP)
# X11 SNF font data, LSB first
# X11 SNF font data, MSB first
# XPConnect Typelib version 1.1
# XPConnect Typelib version 1.2
# Zip data (MIME type "application/vnd.adobe.air-application-installer-p ...
# Zip data (MIME type "application/vnd.adobe.air-ucf-package+zip"?)
# \240\375R\274\253\177datadata
# \340Z3e\226\177, for MS Windows
# \357\234D\002\177 (GUI) Intel 80386, for MS Windows
# a /usr/bin/coreutils --coreutils-prog-shebang=basename script, ASCII t ...
# a /usr/bin/coreutils --coreutils-prog-shebang=chroot script, ASCII tex ...
# application/vnd.ms-excel; name="8570_Rechnung_1666-45164_201610,
# application/vnd.ms-excel;\015,
# big endian ispell hash file (?), 8-bit, no capitalization, 26 flags
# compiled Java class data, version 45.3
# compiled Java class data, version 46.0 (Java 1.2)
# compiled Java class data, version 48.0 (Java 1.4)
# compiled Java class data, version 49.0 (Java 1.5)
# compiled Java class data, version 50.0 (Java 1.6)
# compiled Java class data, version 51.0
# compiled Java class data, version 52.0
# compress'd data 16 bits
# dBase IV DBT of \232\231\231\231\231\231\033@.DBF, blocks size 3166931 ...
# dBase IV DBT of \232\231\231\231\231\231\033@.DBF, next free block ind ...
# dBase IV DBT of \330\001.DBF, blocks size 472, next free block index 3 ...
# dBase IV DBT of \340s.DBF, blocks size 1387, next free block index 1
# dBase IV DBT of \377\356\377\356\002.DBF, blocks size 304, block lengt ...
# dBase IV DBT of \377\356\377\356\002.DBF, blocks size 397, block lengt ...
# dBase IV DBT of \377\356\377\356\002\020\004.DBF, blocks size 328, blo ...
# dBase IV DBT of \377\356\377\356\002\020\004.DBF, blocks size 378, blo ...
# dBase IV DBT of \377\356\377\356\002\020\004.DBF, blocks size 446, blo ...
# dBase IV DBT of \377\356\377\356\002\020\004.DBF, blocks size 490, blo ...
# dBase IV DBT of `.DBF, blocks size 48, block length 1536, next free bl ...
# dBase IV DBT of ailable.DBF, blocks size 1986096725, next free block i ...
# dBase IV DBT of g\301.DBF, blocks size 6415, next free block index 83
# dBase IV DBT of p.DBF, blocks size 51, next free block index 4
# dBase IV DBT, blocks size 1, next free block index 7566674, 1st item " ...
# dBase IV DBT, blocks size 4294916384, next free block index 92290795,  ...
# data
# datadata
# empty
# extended tcpdump capture file (little-endian) - version 2.4 (Ethernet, ...
# frozen file 1.0 (or gzip 0.5)
# iNES ROM dump, 2x16k PRG, 1x8k CHR, [Horiz.]
# lif file
# locale data table
# magic binary file for file(1) cmd (version 10) (little endian)
# mc68k COFF object
# ms-windows metafont .wmf
# multipart/alternative; ,
# multipart/form-data; boundary=--MULTI-PARTS-FORM-DATA-BOUNDARY\015,
# multipart/mixed;        boundary="_0a6f05c8-d760-42e9-b776-27a4,
# multipart/mixed; boundary="===============1517379684=="\015,
# multipart/mixed; boundary=Apple-Mail-B619D76F-D3AC-3463-6687-1C,
# multipart/mixed;,
# multipart/mixed;\015,
# multipart/related; start=<op.mhtml.1348854977223.44164e0f5667aa,
# multipart/related; start=<op.mhtml.1395523575023.ceb28e3969473d,
# multipart/related; start=<op.mhtml.1396021553323.80a4986e0b2403,
# multipart/related; start=<op.mhtml.1398703633280.a83e7e25107351,
# multipart/related; start=<op.mhtml.1398705218933.2a5c082f013511,
# multipart/related; start=<op.mhtml.1399144305795.a41448270f6b50,
# multipart/related; start=<op.mhtml.1399996623947.a5ffd47c433d71,
# multipart/related; start=<op.mhtml.1401128017916.d5ecf105110b30,
# multipart/related; start=<op.mhtml.1401128054808.f72b8036100a08,
# multipart/related; start=<op.mhtml.1401128069362.faa52036100a08,
# multipart/related; start=<op.mhtml.1422099028838.52ad736a5934fd,
# multipart/related; start=<op.mhtml.1436292538629.00460a430b70fc,
# multipart/signed; protocol="application/pkcs7-signature";\015,
# multipart/x-zip; name="DOC69366.zip"\015,
# multipart/x-zip; name="IMG_9510.zip"\015,
# multipart/x-zip; name="INVOICE_ralf.vonpetersdorff.extern.zip"\015,
# mumps avl global (V82) with 10 byte name
# nan
# pcap-ng capture file - version 1.0
# pcap-ng capture file - version 1.256
# ps database from kernel
# ps database from kernel \377j\004Host 'fp76f01e5d.chbd214.ap.nuro.jp'  ...
# ps database version \025 from kernel \002
# pxelinux loader (version 3.70 or newer)
# python 2.4 byte-compiled
# python 2.5 byte-compiled
# python 2.6 byte-compiled
# python 2.7 byte-compiled
# python 3.1 byte-compiled
# raw G3 data, byte-padded
# shared library
# tcpdump capture file (big-endian) - version 2.4 (Ethernet, capture len ...
# tcpdump capture file (big-endian) - version 2.4 (raw IP, capture lengt ...
# tcpdump capture file (little-endian) - version 2.4 (802.11, capture le ...
# tcpdump capture file (little-endian) - version 2.4 (Ethernet, capture  ...
# tcpdump capture file (little-endian) - version 2.4 (Linux "cooked", ca ...
# tcpdump capture file (little-endian) - version 2.4 (No link-layer enca ...
# tcpdump capture file (little-endian) - version 2.4 (raw IP, capture le ...
# tcpdump capture file (little-endian) - version 2.4, capture length 655 ...
# tcpdump capture file (little-endian) - version 8194.8196, capture leng ...
# vCalendar calendar file
# vCard visiting card
# very short file (no magic)
# x
# x86 boot sector
# x86 boot sector, code offset 0x33
# x86 boot sector, code offset 0x3c, OEM-ID "MSDOS5.0", sectors/cluster  ...
# x86 boot sector, code offset 0x44, OEM-ID "IBM PNCI", sectors/cluster  ...
# x86 boot sector, code offset 0x52
# x86 boot sector, code offset 0x52, OEM-ID "NTFS    ", sectors/cluster  ...
# x86 boot sector, code offset 0xb
# x86 boot sector, code offset 0xc0, OEM-ID "      \320\274", Bytes/sect ...
# x86 boot sector; partition 1: ID=0x27, starthead 32, startsector 2048, ...
# x86 boot sector; partition 1: ID=0x7, active, starthead 32, startsecto ...
# x86 boot sector; partition 1: ID=0x7, starthead 32, startsector 2048,  ...
# x86 boot sector; partition 1: ID=0x72, starthead 13, startsector 19202 ...
# x86 boot sector; partition 1: ID=0x83, starthead 32, startsector 2048, ...
# x86 boot sector; partition 1: ID=0xee, starthead 0, startsector 1, 429 ...
# x86 boot sector; partition 4: ID=0x40, starthead 0, startsector 392033 ...

# %%
exec_count = headers[exec_crit].drop_duplicates(subset='md5').md5.resample('M').count().rename('Executables')
text_count = headers[text_crit].drop_duplicates(subset='md5').md5.resample('M').count().rename('Text files')
media_count = headers[media_crit].drop_duplicates(subset='md5').md5.resample('M').count().rename('Media')
arch_count = headers[arch_crit].drop_duplicates(subset='md5').md5.resample('M').count().rename('Archives')
doc_count = headers[doc_crit].drop_duplicates(subset='md5').md5.resample('M').count().rename('Documents')
other_count = headers[~exec_crit & ~text_crit & ~media_crit & ~arch_crit & ~doc_crit].drop_duplicates(subset='md5').md5.resample('M').count().rename('Other')

monthly_percent = pd.concat([exec_count, doc_count, arch_count, text_count, other_count, media_count], axis=1)
monthly_percent = monthly_percent.divide(monthly_percent.sum(axis=1), axis=0)
plotByMonthPercentage(monthly_percent, 'monthly_percent_unique', 'File types by percentage (only unique MD5)')

# %%
# Sanity check
assert len(file_types) == len(exec_types) + len(text_types) + len(media_types) + len(doc_types) + len(arch_types) + len(other_types)

# %% [markdown]
# # Antivirus Classification
#
# The amount of vendors varies throughout the time, hence the choice of normalizing by dividing the positive classifications by the total amount of vendors at the time of the analysis.
#
# The following accounts only for unique samples, for duplicated samples only the last analysis is taken into account. Samples that were unknown in VirusTotal are given a value of -1.

# %%
# Keeping this in a separate cell, since it takes 'some' time to exec
av_col = headers.drop_duplicates(subset='md5', keep='last').antivirus
av_col = av_col.apply(normalize)

# %%
av_col_known = av_col[av_col != -1]
av_col_unknown = av_col[av_col == -1]
print('Number of known (in VirusTotal) samples:\t{}'.format(av_col_known.count()))
print('Number of unknown samples:\t\t\t{}'.format(av_col_unknown.count()))
print('Mean for known samples:\t\t\t\t{:.2f}'.format(av_col_known.mean()))
print('Standard deviation for known samples:\t\t{:.2f}'.format(av_col_known.std()))
# Out:
# Number of known (in VirusTotal) samples:	371837
# Number of unknown samples:			178212
# Mean for known samples:				0.28
# Standard deviation for known samples:		0.31

# %% [markdown]
# The main problem now is defining the threshold that classifies a sample as malware.
#
# The following values may need tweaking...

# %%
NOTMAL_THR = 0.1
MAL_THR = 0.3
av_col_notmal = av_col_known[av_col_known < NOTMAL_THR]
av_col_mal = av_col_known[av_col_known > MAL_THR]
av_col_grey = av_col_known[(NOTMAL_THR <= av_col_known) & (av_col_known <= MAL_THR)]
print('Malware:\t{} ({:.2f})'.format(av_col_mal.count(), av_col_mal.count()/av_col_known.count()))
print('Not malware:\t{} ({:.2f})'.format(av_col_notmal.count(), av_col_notmal.count()/av_col_known.count()))
print('Grey area:\t{} ({:.2f})'.format(av_col_grey.count(), av_col_grey.count()/av_col_known.count()))

# Sanity check
assert len(av_col_known) == len(av_col_notmal) + len(av_col_mal) + len(av_col_grey)

av_col_notmal = av_col_notmal.resample('M').count().rename('Not malware [0, {})'.format(NOTMAL_THR))
av_col_mal = av_col_mal.resample('M').count().rename('Malware ({}, 1]'.format(MAL_THR))
av_col_grey = av_col_grey.resample('M').count().rename('Grey area [{}, {}]'.format(NOTMAL_THR, MAL_THR))

malware_percent = pd.concat([av_col_mal, av_col_grey, av_col_notmal], axis=1)
malware_percent = malware_percent.divide(malware_percent.sum(axis=1), axis=0)
plotByMonthPercentage(malware_percent, 'malware_percent', 'Samples classified as malware by percentage (only unique MD5)')
# Out:
# Malware:	135247 (0.36)
# Not malware:	160967 (0.43)
# Grey area:	75623 (0.20)

# %% [markdown]
# ## Evolution in duplicated samples
#
# How long until an unknown sample becomes known?
#
# Do samples tend to increase or decrease in classification (i.e. false positive rate, false negative)?
#
# How much time do vendors take to identify new malware (i.e. time from 0.0 to some threshold)?

# %%
dups_class = headers.copy()
dups_class['index'] = dups_class.index
# Apply the normalization again, to facilitate filtering
dups_class['antivirus'] = dups_class['antivirus'].apply(normalize)
# Keep only duplicated samples that changed the antivirus classification
dups_class = dups_class.drop_duplicates(['md5', 'antivirus'])
# Keep only duplicated that changed in time, don't have access to the fulltimestamp, hence same day samples
# won't be helpful
# dups_class = dups_class.drop_duplicates(['md5', 'index'], keep='last')
# Keep only duplicates
dups_class = dups_class[dups_class.duplicated(subset='md5', keep=False)]

# %% [markdown]
# ### From unknown to known
#
# Check how much time it takes for a sample to go from unknown to known, this doesn't take into account if the sample is actually malware or not.

# %%
# If the first submission was unknown (-1), calculate the time it took until
# sample became known.
def unknown_to_known(sample):
    if sample[0] == -1:
        for idx, val in enumerate(sample[1:]):
            if val != -1:
                # We take the average between the submission when the sample was known and the
                # submission before that, to give the vendors some slack
                # + 1 because we're enumerating from [1:]
                avg_days = (sample.index[idx + 1] - sample.index[idx]).days / 2
                return (sample.index[idx + 1] - sample.index[0]).days - avg_days
    else:
        return -1.0
        
dups_unk_to_k = dups_class.groupby('md5').agg({'antivirus': unknown_to_known}).antivirus.rename('days')
dups_unk_to_k = (dups_unk_to_k[dups_unk_to_k.map(lambda x: x != -1)]).astype(int)

print('Mean (in days) for a sample to become known:\t{:.2f}'.format(dups_unk_to_k.mean()))
print('Median for a sample to become known:\t\t{:.2f}'.format(dups_unk_to_k.median()))
print('Standard deviation (in days):\t\t\t{:.2f}'.format(dups_unk_to_k.std()))
# Out:
# Mean (in days) for a sample to become known:	19.56
# Median for a sample to become known:		0.00
# Standard deviation (in days):			55.75

# %% [markdown]
# One must take into account that the only available information is from malwr.com, which means samples may become known sooner, but one only knows after the sample has been resubmitted.
#
# ### Tendency in the classification
#
# Check if the tendency for duplicated samples is to increase or decrease, in terms of classification.
#
# Given that the classification results are only shown for vendors that have seen the sample, an upward tendency reflects a false negative tendency, while a downward tendency indicates a false positive tendency.

# %%
# Calculates the tendency for a given sample, based on duplicated submissions
# Returns 1 for positive tendency (later submissions have higher classification)
# Returns -1 for negative tendency (later submissions have lower classification)
# Returns 0 for no tendency (classification between submissions doesn't go above a threshold)
# Returns -2 if there aren't enough submissions to check for a tendency
def tendency(sample):
    from functools import reduce
    # If the submissions didn't vary by more than this threshold, no tendency
    CHANGE_THR = 0.05
    values = []
    
    for idx, val in sample.iteritems():
        if val != -1:
            values.append(val)
    # Not enough values to check for tendency
    if len(values) < 2:
        return -2
    
    diff = [y - x for x, y in zip(values, values[1:])]
    # The mean variation is above the threshold
    if reduce(lambda x, y: abs(x) + abs(y), diff)/len(diff) > CHANGE_THR:
        pos = sum(x > 0 for x in diff)
        neg = sum(x < 0 for x in diff)
        return 1 if pos > neg else -1
    else:
        return 0
        

dups_tendency = dups_class.groupby('md5').agg({'antivirus': tendency}).antivirus.rename('tendency').astype(int)

# %%
pos_tend = dups_tendency[dups_tendency == 1]
neg_tend = dups_tendency[dups_tendency == -1]

print('Number of submissions with positive tendency: {} ({:.2f})'.format(pos_tend.count(), pos_tend.count()/dups_tendency.count()))
print('Number of submissions with negative tendency: {} ({:.2f})'.format(neg_tend.count(), neg_tend.count()/dups_tendency.count()))
# Out:
# Number of submissions with positive tendency: 10828 (0.44)
# Number of submissions with negative tendency: 563 (0.02)

# %% [markdown]
# The positive tendency for over 50% of duplicated samples shows that vendors do prefer to classify
#
# that the sample takes some time to propagate between vendors, while the negative tendency around 2% reflects a low false positive rate correction, meaning that vendors do not tend to unclassify a sample as malware.

# %% [markdown]
# ### Average time to classify a malware
#
# How much time does it take for a sample to go from "not malware" to "malware". Assuming the previous threshold.

# %%
# Calculate the days it took for a sample go from below the threshold
# to above the malware threshold. Only includes samples that were known but
# not classified as malware
def zero_to_malware(sample):
    if 0 <= sample[0] < NOTMAL_THR:
        for idx, val in enumerate(sample[1:]):
            if val > 0.3:
                # + 1 because we're enumerating from [1:]
                avg_days = (sample.index[idx + 1] - sample.index[idx]).days / 2
                return (sample.index[idx + 1] - sample.index[0]).days - avg_days
        # If the sample never goes above the threshold
        return -1
    else:
        return -1
    
dups_zero_to_mal = dups_class.groupby('md5').agg({'antivirus': zero_to_malware}).antivirus.rename('days')
dups_zero_to_mal = dups_zero_to_mal[dups_zero_to_mal != -1]
# print(dups_zero_to_mal)

print('Mean (in days) to go from below the threshold to above:\t{:.2f}'.format(dups_zero_to_mal.mean()))
print('Median to go from below the threshold to above:\t\t{:.2f}'.format(dups_zero_to_mal.median()))
print('Standard deviation:\t\t\t\t\t{:.2f}'.format(dups_zero_to_mal.std()))
# Out:
# Mean (in days) to go from below the threshold to above:	46.10
# Median to go from below the threshold to above:		4.50
# Standard deviation:					108.43

# %% [markdown]
# Like before, the obtained values are limited by the rebumissions to malwr.com, hence giving some slack between the submission above the threshold and the one before.
#
# # Focusing on PE32 samples

# %% [markdown]
# ## Sample size

# %%
# Monthly count for PE32 samples
crit_pe32 = headers.file_type.map(lambda x: str(x).startswith('PE32 '))
pe32 = headers[crit_pe32]
pe_monthly_count = pe32.md5.resample('M').count()
pe_monthly_count = pe_monthly_count.rename('PE32 samples')
plotByMonth(pe_monthly_count,
            'pe_monthly_count',
            'PE Monthly Count ($\mu$={:.0f}, $\Sigma$={})'.format(pe_monthly_count.mean(), pe_monthly_count.sum()))

# %% [markdown]
# ## Antivirus classification

# %%
# Keeping this in a separate cell, since it takes 'some' time to exec
av_col = pe32.drop_duplicates(subset='md5', keep='last').antivirus
av_col = av_col.apply(normalize)

# %%
av_col_known = av_col[av_col != -1]
av_col_unknown = av_col[av_col == -1]
print('Number of known (in VirusTotal) samples:\t{}'.format(av_col_known.count()))
print('Number of unknown samples:\t\t\t{}'.format(av_col_unknown.count()))
print('Mean for known samples:\t\t\t\t{:.2f}'.format(av_col_known.mean()))
print('Standard deviation for known samples:\t\t{:.2f}'.format(av_col_known.std()))
# Out:
# Number of known (in VirusTotal) samples:	236286
# Number of unknown samples:			91008
# Mean for known samples:				0.37
# Standard deviation for known samples:		0.33

# %%
av_col_notmal = av_col_known[av_col_known < NOTMAL_THR]
av_col_mal = av_col_known[av_col_known > MAL_THR]
av_col_grey = av_col_known[(NOTMAL_THR <= av_col_known) & (av_col_known <= MAL_THR)]
print('Malware:\t{} ({:.2f})'.format(av_col_mal.count(), av_col_mal.count()/av_col_known.count()))
print('Not malware:\t{} ({:.2f})'.format(av_col_notmal.count(), av_col_notmal.count()/av_col_known.count()))
print('Grey area:\t{} ({:.2f})'.format(av_col_grey.count(), av_col_grey.count()/av_col_known.count()))

# Sanity check
assert len(av_col_known) == len(av_col_notmal) + len(av_col_mal) + len(av_col_grey)

av_col_notmal = av_col_notmal.resample('M').count().rename('Not malware [0, {})'.format(NOTMAL_THR))
av_col_mal = av_col_mal.resample('M').count().rename('Malware ({}, 1]'.format(MAL_THR))
av_col_grey = av_col_grey.resample('M').count().rename('Grey area [{}, {}]'.format(NOTMAL_THR, MAL_THR))

malware_percent = pd.concat([av_col_mal, av_col_grey, av_col_notmal], axis=1)
malware_percent = malware_percent.divide(malware_percent.sum(axis=1), axis=0)
plotByMonthPercentage(malware_percent, 'malware_percent', 'Samples classified as malware by percentage (only unique MD5)')
# Out:
# Malware:	111322 (0.47)
# Not malware:	75376 (0.32)
# Grey area:	49588 (0.21)

# %% [markdown]
# ## Evolution in duplicated samples

# %%
dups_class = pe32.copy()
dups_class['index'] = dups_class.index
# Apply the normalization again, to facilitate filtering
dups_class['antivirus'] = dups_class['antivirus'].apply(normalize)
# Keep only duplicated samples that changed the antivirus classification
dups_class = dups_class.drop_duplicates(['md5', 'antivirus'])
# Keep only duplicated that changed in time, don't have access to the fulltimestamp, hence same day samples
# won't be helpful
dups_class = dups_class.drop_duplicates(['md5', 'index'], keep='last')
# Keep only duplicates
dups_class = dups_class[dups_class.duplicated(subset='md5', keep=False)]

# %% [markdown]
# ### From unknown to known

# %%
# If the first submission was unknown (-1), calculate the time it took until
# sample became known.
def unknown_to_known(sample):
    if sample[0] == -1:
        for idx, val in enumerate(sample[1:]):
            if val != -1:
                # We take the average between the submission when the sample was known and the
                # submission before that, to give the vendors some slack
                # + 1 because we're enumerating from [1:]
                avg_days = (sample.index[idx + 1] - sample.index[idx]).days / 2
                return (sample.index[idx + 1] - sample.index[0]).days - avg_days
    else:
        return -1.0
        
dups_unk_to_k = dups_class.groupby('md5').agg({'antivirus': unknown_to_known}).antivirus.rename('days')
dups_unk_to_k = (dups_unk_to_k[dups_unk_to_k.map(lambda x: x != -1)]).astype(int)

print('Mean (in days) for a sample to become known:\t{:.2f}'.format(dups_unk_to_k.mean()))
print('Standard deviation (in days):\t\t\t{:.2f}'.format(dups_unk_to_k.std()))
# Out:
# Mean (in days) for a sample to become known:	33.09
# Standard deviation (in days):			69.71

# %% [markdown]
# ### Tendency in the classification

# %%
# Calculates the tendency for a given sample, based on duplicated submissions
# Returns 1 for positive tendency (later submissions have higher classification)
# Returns -1 for negative tendency (later submissions have lower classification)
# Returns 0 for no tendency (classification between submissions doesn't go above a threshold)
# Returns -2 if there aren't enough submissions to check for a tendency
def tendency(sample):
    from functools import reduce
    # If the submissions didn't vary by more than this threshold, no tendency
    CHANGE_THR = 0.05
    values = []
    
    for idx, val in sample.iteritems():
        if val != -1:
            values.append(val)
    # Not enough values to check for tendency
    if len(values) < 2:
        return -2
    
    diff = [y - x for x, y in zip(values, values[1:])]
    # The mean variation is above the threshold
    if reduce(lambda x, y: abs(x) + abs(y), diff)/len(diff) > CHANGE_THR:
        pos = sum(x > 0 for x in diff)
        neg = sum(x < 0 for x in diff)
        return 1 if pos > neg else -1
    else:
        return 0
        

dups_tendency = dups_class.groupby('md5').agg({'antivirus': tendency}).antivirus.rename('tendency')

# %%
pos_tend = dups_tendency[dups_tendency == 1]
neg_tend = dups_tendency[dups_tendency == -1]

print('Number of submissions with positive tendency: {} ({:.2f})'.format(pos_tend.count(), pos_tend.count()/dups_tendency.count()))
print('Number of submissions with negative tendency: {} ({:.2f})'.format(neg_tend.count(), neg_tend.count()/dups_tendency.count()))
# Out:
# Number of submissions with positive tendency: 6569 (0.49)
# Number of submissions with negative tendency: 299 (0.02)

# %% [markdown]
# ### Average time to classify a malware

# %%
# Calculate the days it took for a sample go from below the threshold
# to above the malware threshold. Only includes samples that were known but
# not classified as malware
def zero_to_malware(sample):
    if 0 <= sample[0] < NOTMAL_THR:
        for idx, val in enumerate(sample[1:]):
            if val > 0.5:
                # + 1 because we're enumerating from [1:]
                avg_days = (sample.index[idx + 1] - sample.index[idx]).days / 2
                return (sample.index[idx + 1] - sample.index[0]).days - avg_days
        # If the sample never goes above the threshold
        return -1
    else:
        return -1
    
dups_zero_to_mal = dups_class.groupby('md5').agg({'antivirus': zero_to_malware}).antivirus.rename('days').astype(int)
dups_zero_to_mal = dups_zero_to_mal[dups_zero_to_mal != -1]

print('Mean (in days) to go from below the threshold to above: {:.2f}'.format(dups_zero_to_mal.mean()))
print('Median to go from below the threshold to above: {:.2f}'.format(dups_zero_to_mal.median()))
print('Standard deviation (in days): {:.2f}'.format(dups_zero_to_mal.std()))
# Out:
# Mean (in days) to go from below the threshold to above: 42.85
# Median to go from below the threshold to above: 7.00
# Standard deviation (in days): 101.06
