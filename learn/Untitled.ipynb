# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data_folder = '../data/csv_data/'
extension = '.csv.gz'
build_path = lambda x: data_folder + x + extension

# %%
ori_dataset = pd.read_csv(build_path('strict_dataset')).set_index('link')
dataset = pd.read_csv(build_path('all_samples')).set_index('link')

# %%
dataset = dataset[dataset.index.isin(ori_dataset.index)]

# %%
dataset
# Out:
#                                              ADVAPI32.DLL  ADVAPI32.dll  \
# link
# ZTQwYTQ4M2U3MDM0NGI1YmFhNjgzMTcwYTcwM2Y2NDU         False         False
# ZTZhNjE4OTIzNzU2NGVkZWI4MzE3ZTVmYTkyNWEzYWY         False         False
# ZjYwNDRhOWJhZjM3NGU4ODllODVjZmNhZDdlZTU4ZTE         False         False
# NzQ1MTRiYzNmM2MyNGZjZmI5ZWZiZjhjZjlkZjM1OTE         False         False
# YzA1NzIxMzQ2OTlhNGYwNjlmMDc1Yjg0MWEyOTc2NGI         False         False
# NzdkMTAwZjJmNGE4NDExNTlkMTFkYjA0MTBmZTIwOTU         False         False
# ZTA1ZTlkYjY1NzU1NGIxZjg0ODJhOWRmMmFlNTczMDU         False         False
# NjQ2NmY4OWI1YmQwNDQ4YmJhZjYzMTNiYTkyNjY4N2E         False          True
# YzQ2ODVhMGU4N2U5NDEyYTljYjBiOGM2ZTE3ZDViY2Q         False         False
# OWUzNTIxZGY1M2MxNDY3NmIyYmEwM2YzMzhmMzc2YjA         False          True
# OTEwZWYyNTIzNWJiNDZhNjhhOWRlZGMwMWU4NzVjZWU         False         False
# M2FiNGI1NmZlZTI5NDBiNzgzZDhjMmY5ZTZjMTY5Zjg         False         False
# ...
